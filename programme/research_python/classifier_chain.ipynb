# %%
import pandas as pd
import numpy as np
import os
import time
import subprocess
import re
import random

from math import sqrt
from sklearn.model_selection import  train_test_split
from sklearn.model_selection import KFold
from sklearn.naive_bayes import MultinomialNB  
from sklearn.metrics import classification_report
from sklearn.metrics import coverage_error
from sklearn.metrics import label_ranking_loss
from sklearn.metrics import hamming_loss
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import zero_one_loss
from sklearn.metrics import jaccard_similarity_score

# %%
def read_data(dataPath):
    # input: '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'
    # read data
    data = pd.read_csv(os.path.join(dataPath,'X.csv'), index_col=0).reset_index(drop=True)
    label = pd.read_csv(os.path.join(dataPath,'Y.csv'), index_col=0).reset_index(drop=True)
    return data,label

def naiveBayes_multi_label_training(X_train, y_train):
    start = time.time()
    
    n_label = y_train.shape[1]
    
    order = random.sample(list(range(n_label)),n_label) # get orders
    
    classifier_list = [MultinomialNB() for i in range(n_label)] # create a classifier chain
    
    for i in range(n_label):
        if i == 0:
            classifier_list[i].fit(X_train,y_train.iloc[:, order[i]])
        else:
            X_train = pd.concat([X_train, y_train.iloc[:,order[i-1]]],axis=1) # put the previous label into attribute space
            classifier_list[i].fit(X_train,y_train.iloc[:,order[i]])

    end = time.time()
    training_time = end-start
    
    return classifier_list, training_time, order

def naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order):
    y_predict = pd.DataFrame(index=X_test.index)
    y_prob = pd.DataFrame(index=X_test.index)
    y_true = pd.DataFrame(index=X_test.index)
    
    start = time.time()
    
    for i in range(n_label):
        y_predict_i = classifier_list[i].predict(X_test)
        y_predict = pd.concat([y_predict, pd.DataFrame(y_predict_i,index=X_test.index)],axis=1)

        y_predict_prob_i = classifier_list[i].predict_proba(X_test)[:,1]
        y_prob = pd.concat([y_prob, pd.DataFrame(y_predict_prob_i,index=X_test.index)],axis=1)

        X_test = pd.concat([X_test, pd.DataFrame(y_predict_i,index=X_test.index)],axis=1,ignore_index=True) # put the previous label into attribute space

    end = time.time()
    testing_time = end-start
        
    return y_predict, y_prob, testing_time

def evaluation(y_pred, y_prob, y_true):
    coverage = coverage_error(y_true, y_prob)
    hamming = hamming_loss(y_true, y_pred)
    ranking_loss = label_ranking_loss(y_true, y_prob)
    
    f1_macro = metrics.f1_score(y_true, y_pred, average='macro')
    f1_micro = metrics.f1_score(y_true, y_pred, average='micro')
    
    acc = jaccard_similarity_score(y_true, y_pred) # jaccard_similarity_score
    zero_one = zero_one_loss(y_true, y_pred) # 0-1 error 
    
    f1_each = metrics.f1_score(y_true, y_pred, average=None)
    
    
    performance = {"coverage_error":coverage,
                   "ranking_loss":ranking_loss,
                   "hamming_loss":hamming,
                   "f1_macro":f1_macro,
                   "f1_micro":f1_micro,
                   "Jaccard_Index":acc,
                   "zero_one_error":zero_one,
                   "f1_each_label":f1_each}
    return performance


def CC_test(data, label, dataPath, random_state=3071980):
    
    # data set information
    n_label = label.shape[1]
    n_attr = data.shape[1]
    n_instance = data.shape[0]
    avg_label_per_instance = label.sum(axis=1).mean()
    
    # split training and test data set
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.5, random_state=random_state)
    
    # training
    print("--- start training ---\n")
    classifier_list, training_time, order = naiveBayes_multi_label_training(X_train, y_train)
    
    # testing
    print("--- start testing ---\n")
    y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order)
    
    # evaluation
    y_test = y_test.iloc[:,order]
    performance = evaluation(y_predict, y_prob, y_test)
    
    # print data information
    print("--- Data Information ---")
    print("dataset:", dataPath)
    print("number of label:",n_label)
    print("number of attribute:",n_attr)
    print("number of instance:",n_instance,"\n")
    
    # print orders
    print("\n--- Order of the chain ---")
    print(label.columns[order])
    print("")
    
    # print performance
    print("--- Performance ---")
    for key, value in performance.items():
        if key == "f1_each_label":
            print("\n- f1 for each label -")
            for i in range(n_label):
                print("label_"+label.columns[i],"=",round(value[i],2))
        elif key == "coverage_error":
            print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
        else:
            print(key,'=',round(value,2))
            
def ECC_test(data, label, dataPath, random_state=3071980, ensemble = 5):
    
    # data set information
    n_label = label.shape[1]
    n_attr = data.shape[1]
    n_instance = data.shape[0]
    avg_label_per_instance = label.sum(axis=1).mean()
    
    # split training and test data set
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.5, random_state=random_state)
    
    # ensemble
    y_pred_ensemble = pd.DataFrame(np.zeros(y_test.shape),columns=y_test.columns, index=y_test.index)
    y_prob_ensemble = pd.DataFrame(np.zeros(y_test.shape),columns=y_test.columns, index=y_test.index)
    for i in range(ensemble):
        # training
        #print("--- start training ---\n")
        classifier_list, training_time, order = naiveBayes_multi_label_training(X_train, y_train)

        # print orders
        print("Order of the chain:",label.columns[order])

        # testing
        #print("--- start testing ---\n")
        y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order)

        y_predict.columns = label.columns[order]
        y_prob.columns = label.columns[order]
        y_predict = y_predict[label.columns]
        y_prob = y_prob[label.columns]

        y_pred_ensemble = y_pred_ensemble + y_predict
        y_prob_ensemble = y_prob_ensemble + y_prob

    y_pred_ensemble = (((y_pred_ensemble / ensemble) >= 0.5)*1).astype('int')
    y_prob_ensemble = y_prob_ensemble / ensemble 
    
    # evaluation
    performance = evaluation(y_pred_ensemble, y_prob_ensemble, y_test)
    
    # print data information
    print("--- Data Information ---")
    print("dataset:", dataPath)
    print("number of label:",n_label)
    print("number of attribute:",n_attr)
    print("number of instance:",n_instance,"\n")
    
    # print orders
    print("\n--- Order of the chain ---")
    print(label.columns[order])
    print("")
    
    # print performance
    print("--- Performance ---")
    for key, value in performance.items():
        if key == "f1_each_label":
            print("\n- f1 for each label -")
            for i in range(n_label):
                print("label_"+label.columns[i],"=",round(value[i],2))
        elif key == "coverage_error":
            print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
        else:
            print(key,'=',round(value,2))

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

# train - test
print("------ Binary Relevance using Naive Bayes ------")
ECC_test(data, label, dataPath, 12343, 50)
# Out:
# ------ Binary Relevance using Naive Bayes ------
# Order of the chain: Index(['federal---state-issues', 'act', 'smoking', 'federal-government', 'sa',
#        'united-states', 'health', 'united-kingdom', 'tas',
#        'healthcare-facilities', 'lifestyle-and-leisure',
#        'science-and-technology', 'community-and-society',
#        'government-and-politics', 'education', 'exercise-and-fitness',
#        'obesity', 'research', 'nsw', 'heart-disease', 'states-and-territories',
#        'diet-and-nutrition', 'advertising', 'industry', 'qld',
#        'diseases-and-disorders', 'medical-research',
#        'doctors-and-medical-professionals', 'cancer',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'vic', 'children', 'food-and-beverage',
#        'australia', 'diabetes', 'health-policy', 'advertising-and-marketing',
#        'schools', 'child-health-and-behaviour',
#        'business-economics-and-finance', 'wa'],
#       dtype='object')
# Order of the chain: Index(['act', 'family-and-children', 'diseases-and-disorders',
#        'business-economics-and-finance', 'food-and-beverage', 'nsw',
#        'exercise-and-fitness', 'vic', 'health', 'medical-research', 'qld',
#        'obesity', 'children', 'smoking', 'education', 'tas',
#        'diet-and-nutrition', 'united-kingdom', 'diabetes',
#        'federal-government', 'advertising-and-marketing', 'industry',
#        'federal---state-issues', 'heart-disease', 'community-and-society',
#        'health-policy', 'child-health-and-behaviour', 'australia',
#        'doctors-and-medical-professionals', 'schools', 'advertising',
#        'government-and-politics',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'healthcare-facilities', 'wa', 'united-states', 'cancer', 'research',
#        'science-and-technology', 'states-and-territories',
#        'lifestyle-and-leisure', 'sa'],
#       dtype='object')
# Order of the chain: Index(['government-and-politics', 'wa', 'united-kingdom',
#        'federal---state-issues', 'smoking', 'healthcare-facilities',
#        'states-and-territories',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'industry', 'advertising',
#        'exercise-and-fitness', 'act', 'sa', 'science-and-technology',
#        'business-economics-and-finance', 'vic', 'health', 'medical-research',
#        'tas', 'community-and-society', 'education', 'cancer', 'health-policy',
#        'federal-government', 'heart-disease', 'diabetes', 'united-states',
#        'obesity', 'advertising-and-marketing', 'research',
#        'child-health-and-behaviour', 'diet-and-nutrition',
#        'lifestyle-and-leisure', 'australia',
#        'doctors-and-medical-professionals', 'nsw', 'schools',
#        'diseases-and-disorders', 'food-and-beverage', 'qld', 'children'],
#       dtype='object')
# Order of the chain: Index(['research', 'lifestyle-and-leisure', 'nsw', 'act', 'vic',
#        'exercise-and-fitness', 'federal-government', 'food-and-beverage',
#        'child-health-and-behaviour', 'smoking',
#        'indigenous-aboriginal-and-torres-strait-islander', 'heart-disease',
#        'industry', 'doctors-and-medical-professionals', 'education',
#        'science-and-technology', 'government-and-politics',
#        'diseases-and-disorders', 'diabetes', 'obesity', 'medical-research',
#        'children', 'health', 'qld', 'australia', 'united-states',
#        'health-policy', 'wa', 'cancer', 'united-kingdom', 'sa',
#        'federal---state-issues', 'diet-and-nutrition',
#        'business-economics-and-finance', 'tas', 'healthcare-facilities',
#        'advertising', 'advertising-and-marketing', 'community-and-society',
#        'schools', 'family-and-children', 'states-and-territories'],
#       dtype='object')
# Order of the chain: Index(['cancer', 'diet-and-nutrition', 'act', 'vic', 'government-and-politics',
#        'health-policy', 'business-economics-and-finance',
#        'community-and-society', 'research',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'diseases-and-disorders', 'obesity', 'sa', 'family-and-children',
#        'health', 'heart-disease', 'qld', 'medical-research', 'tas', 'schools',
#        'healthcare-facilities', 'doctors-and-medical-professionals', 'wa',
#        'united-states', 'states-and-territories', 'food-and-beverage',
#        'exercise-and-fitness', 'advertising', 'lifestyle-and-leisure',
#        'federal---state-issues', 'federal-government',
#        'child-health-and-behaviour', 'advertising-and-marketing', 'diabetes',
#        'science-and-technology', 'nsw', 'australia', 'children', 'education',
#        'smoking', 'united-kingdom', 'industry'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'cancer', 'food-and-beverage', 'schools',
#        'industry', 'australia', 'obesity', 'united-kingdom', 'children',
#        'family-and-children', 'research', 'nsw', 'diseases-and-disorders',
#        'states-and-territories', 'medical-research', 'exercise-and-fitness',
#        'business-economics-and-finance', 'act', 'united-states',
#        'child-health-and-behaviour', 'wa', 'community-and-society', 'smoking',
#        'government-and-politics', 'advertising', 'diabetes', 'health-policy',
#        'education', 'advertising-and-marketing', 'science-and-technology',
#        'lifestyle-and-leisure',
#        'indigenous-aboriginal-and-torres-strait-islander', 'heart-disease',
#        'tas', 'doctors-and-medical-professionals', 'diet-and-nutrition', 'qld',
#        'health', 'healthcare-facilities', 'federal-government', 'sa', 'vic'],
#       dtype='object')
# Order of the chain: Index(['tas', 'medical-research', 'australia', 'advertising',
#        'federal---state-issues', 'child-health-and-behaviour',
#        'diet-and-nutrition', 'food-and-beverage', 'exercise-and-fitness',
#        'advertising-and-marketing', 'community-and-society', 'children', 'sa',
#        'lifestyle-and-leisure', 'business-economics-and-finance',
#        'science-and-technology', 'nsw', 'states-and-territories',
#        'federal-government', 'united-states', 'obesity', 'health',
#        'family-and-children', 'research', 'vic', 'government-and-politics',
#        'heart-disease', 'doctors-and-medical-professionals', 'united-kingdom',
#        'health-policy', 'education', 'smoking', 'diseases-and-disorders',
#        'diabetes', 'act', 'healthcare-facilities',
#        'indigenous-aboriginal-and-torres-strait-islander', 'qld', 'cancer',
#        'schools', 'industry', 'wa'],
#       dtype='object')
# Order of the chain: Index(['family-and-children',
#        'indigenous-aboriginal-and-torres-strait-islander', 'education',
#        'federal-government', 'heart-disease', 'research', 'act',
#        'community-and-society', 'food-and-beverage', 'lifestyle-and-leisure',
#        'schools', 'diseases-and-disorders', 'government-and-politics',
#        'united-kingdom', 'tas', 'science-and-technology', 'vic',
#        'united-states', 'cancer', 'diet-and-nutrition', 'diabetes',
#        'medical-research', 'nsw', 'qld', 'wa', 'smoking', 'health-policy',
#        'federal---state-issues', 'industry', 'australia',
#        'advertising-and-marketing', 'health', 'exercise-and-fitness',
#        'advertising', 'business-economics-and-finance', 'sa',
#        'healthcare-facilities', 'doctors-and-medical-professionals',
#        'states-and-territories', 'children', 'child-health-and-behaviour',
#        'obesity'],
#       dtype='object')
# Order of the chain: Index(['science-and-technology', 'heart-disease', 'united-states', 'cancer',
#        'indigenous-aboriginal-and-torres-strait-islander', 'obesity', 'tas',
#        'business-economics-and-finance', 'australia', 'healthcare-facilities',
#        'act', 'food-and-beverage', 'family-and-children', 'diet-and-nutrition',
#        'vic', 'industry', 'federal-government', 'government-and-politics',
#        'sa', 'research', 'advertising-and-marketing',
#        'doctors-and-medical-professionals', 'health', 'states-and-territories',
#        'exercise-and-fitness', 'children', 'advertising', 'qld',
#        'community-and-society', 'nsw', 'education', 'lifestyle-and-leisure',
#        'diseases-and-disorders', 'child-health-and-behaviour', 'schools',
#        'medical-research', 'diabetes', 'federal---state-issues', 'smoking',
#        'united-kingdom', 'health-policy', 'wa'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'healthcare-facilities',
#        'states-and-territories', 'exercise-and-fitness',
#        'indigenous-aboriginal-and-torres-strait-islander', 'sa', 'act',
#        'medical-research', 'community-and-society', 'health-policy', 'smoking',
#        'advertising-and-marketing', 'government-and-politics', 'diabetes',
#        'united-kingdom', 'cancer', 'nsw', 'tas', 'diet-and-nutrition', 'wa',
#        'research', 'industry', 'heart-disease', 'advertising',
#        'family-and-children', 'science-and-technology', 'food-and-beverage',
#        'australia', 'health', 'obesity', 'children', 'vic',
#        'doctors-and-medical-professionals', 'federal-government', 'education',
#        'schools', 'lifestyle-and-leisure', 'business-economics-and-finance',
#        'child-health-and-behaviour', 'qld', 'united-states',
#        'diseases-and-disorders'],
#       dtype='object')
# Order of the chain: Index(['advertising-and-marketing', 'health-policy', 'united-kingdom',
#        'diabetes', 'education', 'nsw', 'australia', 'smoking', 'cancer', 'qld',
#        'heart-disease', 'vic', 'health', 'doctors-and-medical-professionals',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'federal---state-issues', 'states-and-territories',
#        'diseases-and-disorders', 'medical-research', 'tas', 'advertising',
#        'united-states', 'obesity', 'science-and-technology',
#        'federal-government', 'wa', 'act', 'schools', 'children', 'research',
#        'child-health-and-behaviour', 'exercise-and-fitness',
#        'healthcare-facilities', 'industry', 'business-economics-and-finance',
#        'lifestyle-and-leisure', 'family-and-children',
#        'government-and-politics', 'diet-and-nutrition', 'food-and-beverage',
#        'sa', 'community-and-society'],
#       dtype='object')
# Order of the chain: Index(['wa', 'diseases-and-disorders',
#        'indigenous-aboriginal-and-torres-strait-islander', 'children',
#        'industry', 'science-and-technology', 'diabetes', 'tas',
#        'medical-research', 'federal---state-issues', 'research', 'smoking',
#        'exercise-and-fitness', 'health', 'community-and-society',
#        'healthcare-facilities', 'heart-disease',
#        'doctors-and-medical-professionals', 'family-and-children', 'cancer',
#        'states-and-territories', 'united-states', 'australia', 'schools', 'sa',
#        'qld', 'advertising', 'food-and-beverage', 'government-and-politics',
#        'education', 'business-economics-and-finance', 'lifestyle-and-leisure',
#        'health-policy', 'vic', 'united-kingdom', 'diet-and-nutrition', 'act',
#        'federal-government', 'obesity', 'child-health-and-behaviour',
#        'advertising-and-marketing', 'nsw'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'wa', 'health', 'diseases-and-disorders',
#        'research', 'tas', 'diabetes', 'australia', 'healthcare-facilities',
#        'lifestyle-and-leisure', 'nsw', 'qld', 'health-policy', 'advertising',
#        'sa', 'act', 'children', 'community-and-society', 'schools',
#        'doctors-and-medical-professionals', 'exercise-and-fitness',
#        'business-economics-and-finance', 'food-and-beverage', 'vic',
#        'diet-and-nutrition', 'heart-disease', 'obesity', 'family-and-children',
#        'government-and-politics', 'science-and-technology',
#        'federal-government', 'smoking', 'united-states',
#        'advertising-and-marketing', 'cancer', 'education',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'states-and-territories', 'united-kingdom',
#        'child-health-and-behaviour', 'industry', 'medical-research'],
#       dtype='object')
# Order of the chain: Index(['smoking', 'nsw', 'exercise-and-fitness', 'united-kingdom', 'wa', 'vic',
#        'schools', 'act', 'diseases-and-disorders', 'australia',
#        'indigenous-aboriginal-and-torres-strait-islander', 'heart-disease',
#        'industry', 'healthcare-facilities', 'lifestyle-and-leisure',
#        'food-and-beverage', 'business-economics-and-finance',
#        'doctors-and-medical-professionals', 'states-and-territories', 'health',
#        'science-and-technology', 'child-health-and-behaviour',
#        'federal---state-issues', 'diabetes', 'advertising',
#        'government-and-politics', 'medical-research', 'sa', 'obesity', 'qld',
#        'advertising-and-marketing', 'community-and-society', 'cancer',
#        'children', 'tas', 'united-states', 'family-and-children',
#        'diet-and-nutrition', 'federal-government', 'health-policy', 'research',
#        'education'],
#       dtype='object')
# Order of the chain: Index(['act', 'federal-government', 'diet-and-nutrition',
#        'business-economics-and-finance', 'exercise-and-fitness', 'wa',
#        'obesity', 'advertising-and-marketing', 'science-and-technology',
#        'children', 'doctors-and-medical-professionals',
#        'government-and-politics', 'states-and-territories', 'australia',
#        'heart-disease', 'health', 'research', 'cancer', 'industry', 'sa',
#        'lifestyle-and-leisure', 'schools', 'food-and-beverage',
#        'healthcare-facilities', 'nsw',
#        'indigenous-aboriginal-and-torres-strait-islander', 'medical-research',
#        'advertising', 'vic', 'education', 'health-policy', 'united-kingdom',
#        'united-states', 'federal---state-issues', 'tas',
#        'child-health-and-behaviour', 'community-and-society', 'smoking',
#        'family-and-children', 'qld', 'diseases-and-disorders', 'diabetes'],
#       dtype='object')
# Order of the chain: Index(['vic', 'qld', 'diabetes', 'research', 'smoking',
#        'states-and-territories', 'sa', 'doctors-and-medical-professionals',
#        'food-and-beverage', 'business-economics-and-finance', 'children',
#        'cancer', 'advertising', 'tas', 'united-kingdom', 'united-states',
#        'diseases-and-disorders', 'australia', 'federal---state-issues',
#        'community-and-society', 'schools', 'industry', 'federal-government',
#        'advertising-and-marketing', 'exercise-and-fitness', 'wa',
#        'diet-and-nutrition', 'education', 'act', 'child-health-and-behaviour',
#        'medical-research', 'science-and-technology', 'nsw',
#        'indigenous-aboriginal-and-torres-strait-islander', 'health',
#        'lifestyle-and-leisure', 'healthcare-facilities', 'family-and-children',
#        'health-policy', 'obesity', 'government-and-politics', 'heart-disease'],
#       dtype='object')
# Order of the chain: Index(['tas', 'children', 'health-policy', 'heart-disease',
#        'healthcare-facilities', 'states-and-territories', 'advertising',
#        'diabetes', 'act', 'nsw', 'united-states', 'diseases-and-disorders',
#        'wa', 'food-and-beverage', 'community-and-society',
#        'government-and-politics', 'schools', 'education',
#        'child-health-and-behaviour', 'industry', 'smoking',
#        'federal---state-issues', 'research', 'vic',
#        'advertising-and-marketing', 'australia',
#        'business-economics-and-finance', 'lifestyle-and-leisure', 'qld',
#        'obesity', 'doctors-and-medical-professionals', 'federal-government',
#        'sa', 'united-kingdom', 'medical-research', 'diet-and-nutrition',
#        'health', 'science-and-technology', 'cancer', 'family-and-children',
#        'exercise-and-fitness',
#        'indigenous-aboriginal-and-torres-strait-islander'],
#       dtype='object')
# Order of the chain: Index(['federal-government', 'children', 'diabetes', 'family-and-children',
#        'lifestyle-and-leisure', 'cancer', 'sa', 'united-states', 'health',
#        'government-and-politics', 'qld', 'tas', 'wa', 'act', 'advertising',
#        'united-kingdom', 'vic', 'schools', 'medical-research',
#        'community-and-society', 'research', 'australia', 'health-policy',
#        'child-health-and-behaviour',
#        'indigenous-aboriginal-and-torres-strait-islander', 'obesity',
#        'doctors-and-medical-professionals', 'diseases-and-disorders',
#        'food-and-beverage', 'healthcare-facilities',
#        'advertising-and-marketing', 'smoking', 'nsw', 'diet-and-nutrition',
#        'education', 'business-economics-and-finance', 'heart-disease',
#        'exercise-and-fitness', 'federal---state-issues',
#        'science-and-technology', 'states-and-territories', 'industry'],
#       dtype='object')
# Order of the chain: Index(['wa', 'heart-disease', 'sa', 'exercise-and-fitness', 'medical-research',
#        'healthcare-facilities', 'advertising', 'children', 'smoking',
#        'states-and-territories', 'health-policy', 'schools', 'education',
#        'science-and-technology', 'tas', 'advertising-and-marketing',
#        'united-kingdom', 'community-and-society', 'government-and-politics',
#        'food-and-beverage', 'obesity', 'child-health-and-behaviour',
#        'doctors-and-medical-professionals', 'health', 'qld', 'industry',
#        'federal---state-issues', 'vic', 'act', 'research', 'united-states',
#        'cancer', 'australia',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'diabetes', 'lifestyle-and-leisure',
#        'federal-government', 'diseases-and-disorders', 'diet-and-nutrition',
#        'nsw', 'business-economics-and-finance'],
#       dtype='object')
# Order of the chain: Index(['doctors-and-medical-professionals', 'australia',
#        'healthcare-facilities', 'exercise-and-fitness',
#        'advertising-and-marketing', 'federal-government',
#        'lifestyle-and-leisure', 'health-policy',
#        'indigenous-aboriginal-and-torres-strait-islander', 'diabetes',
#        'diet-and-nutrition', 'business-economics-and-finance', 'wa',
#        'diseases-and-disorders', 'tas', 'vic', 'nsw', 'community-and-society',
#        'education', 'sa', 'heart-disease', 'schools', 'united-states',
#        'research', 'qld', 'united-kingdom', 'health', 'advertising',
#        'children', 'science-and-technology', 'industry', 'family-and-children',
#        'states-and-territories', 'medical-research', 'obesity', 'cancer',
#        'federal---state-issues', 'food-and-beverage', 'act', 'smoking',
#        'government-and-politics', 'child-health-and-behaviour'],
#       dtype='object')
# Order of the chain: Index(['australia', 'indigenous-aboriginal-and-torres-strait-islander',
#        'federal-government', 'child-health-and-behaviour', 'schools',
#        'industry', 'obesity', 'research', 'tas', 'wa', 'qld', 'heart-disease',
#        'federal---state-issues', 'states-and-territories',
#        'diet-and-nutrition', 'exercise-and-fitness', 'cancer', 'vic',
#        'doctors-and-medical-professionals', 'diseases-and-disorders',
#        'medical-research', 'united-kingdom', 'health-policy',
#        'family-and-children', 'science-and-technology',
#        'healthcare-facilities', 'business-economics-and-finance', 'diabetes',
#        'food-and-beverage', 'community-and-society', 'government-and-politics',
#        'lifestyle-and-leisure', 'united-states', 'smoking', 'children',
#        'advertising-and-marketing', 'health', 'nsw', 'education', 'sa',
#        'advertising', 'act'],
#       dtype='object')
# Order of the chain: Index(['cancer', 'health-policy', 'medical-research', 'vic', 'smoking',
#        'government-and-politics', 'child-health-and-behaviour', 'nsw',
#        'united-states', 'act', 'federal---state-issues',
#        'community-and-society',
#        'indigenous-aboriginal-and-torres-strait-islander', 'sa', 'research',
#        'heart-disease', 'children', 'schools', 'diet-and-nutrition',
#        'doctors-and-medical-professionals', 'diabetes', 'wa',
#        'business-economics-and-finance', 'science-and-technology', 'tas',
#        'exercise-and-fitness', 'states-and-territories', 'health',
#        'united-kingdom', 'diseases-and-disorders', 'obesity', 'advertising',
#        'qld', 'federal-government', 'education', 'australia',
#        'family-and-children', 'healthcare-facilities', 'food-and-beverage',
#        'lifestyle-and-leisure', 'advertising-and-marketing', 'industry'],
#       dtype='object')
# Order of the chain: Index(['government-and-politics', 'cancer',
#        'doctors-and-medical-professionals', 'education', 'family-and-children',
#        'tas', 'act', 'indigenous-aboriginal-and-torres-strait-islander',
#        'united-kingdom', 'qld', 'medical-research',
#        'child-health-and-behaviour', 'industry', 'science-and-technology',
#        'federal---state-issues', 'health-policy', 'diabetes', 'children',
#        'australia', 'federal-government', 'wa', 'sa', 'states-and-territories',
#        'diseases-and-disorders', 'vic', 'research', 'community-and-society',
#        'lifestyle-and-leisure', 'obesity', 'united-states', 'heart-disease',
#        'diet-and-nutrition', 'nsw', 'advertising-and-marketing', 'schools',
#        'business-economics-and-finance', 'exercise-and-fitness', 'health',
#        'food-and-beverage', 'healthcare-facilities', 'smoking', 'advertising'],
#       dtype='object')
# Order of the chain: Index(['act', 'federal-government', 'cancer', 'healthcare-facilities',
#        'schools', 'family-and-children', 'qld', 'exercise-and-fitness',
#        'business-economics-and-finance', 'united-kingdom', 'smoking',
#        'diseases-and-disorders', 'child-health-and-behaviour',
#        'medical-research', 'obesity', 'research', 'sa',
#        'advertising-and-marketing', 'wa', 'community-and-society', 'vic',
#        'education', 'doctors-and-medical-professionals',
#        'federal---state-issues', 'australia', 'tas', 'states-and-territories',
#        'nsw', 'diabetes', 'health', 'food-and-beverage', 'united-states',
#        'industry', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'science-and-technology', 'advertising', 'heart-disease',
#        'health-policy', 'diet-and-nutrition', 'lifestyle-and-leisure',
#        'government-and-politics'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'obesity', 'cancer', 'nsw', 'vic', 'schools',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'child-health-and-behaviour', 'act', 'family-and-children', 'diabetes',
#        'medical-research', 'australia', 'food-and-beverage',
#        'science-and-technology', 'sa', 'wa', 'qld', 'federal-government',
#        'education', 'advertising', 'heart-disease', 'exercise-and-fitness',
#        'government-and-politics', 'business-economics-and-finance',
#        'community-and-society', 'united-kingdom', 'lifestyle-and-leisure',
#        'doctors-and-medical-professionals', 'children', 'industry',
#        'united-states', 'health', 'smoking', 'diseases-and-disorders',
#        'health-policy', 'tas', 'healthcare-facilities', 'research',
#        'diet-and-nutrition', 'states-and-territories',
#        'advertising-and-marketing'],
#       dtype='object')
# Order of the chain: Index(['federal-government', 'advertising', 'health-policy', 'education',
#        'diet-and-nutrition', 'act', 'united-states', 'exercise-and-fitness',
#        'federal---state-issues', 'united-kingdom',
#        'business-economics-and-finance', 'nsw', 'wa',
#        'doctors-and-medical-professionals', 'lifestyle-and-leisure',
#        'children', 'diseases-and-disorders', 'family-and-children',
#        'healthcare-facilities', 'research', 'states-and-territories',
#        'community-and-society', 'industry', 'tas', 'australia',
#        'science-and-technology', 'obesity', 'child-health-and-behaviour',
#        'qld', 'cancer', 'vic',
#        'indigenous-aboriginal-and-torres-strait-islander', 'medical-research',
#        'diabetes', 'schools', 'government-and-politics', 'sa',
#        'advertising-and-marketing', 'smoking', 'heart-disease',
#        'food-and-beverage', 'health'],
#       dtype='object')
# Order of the chain: Index(['diabetes', 'industry', 'diseases-and-disorders', 'heart-disease',
#        'health-policy', 'federal-government', 'tas', 'united-states',
#        'medical-research', 'children', 'cancer',
#        'indigenous-aboriginal-and-torres-strait-islander', 'smoking', 'act',
#        'community-and-society', 'health', 'states-and-territories', 'wa',
#        'education', 'advertising-and-marketing', 'obesity',
#        'federal---state-issues', 'business-economics-and-finance', 'sa',
#        'government-and-politics', 'doctors-and-medical-professionals',
#        'family-and-children', 'schools', 'exercise-and-fitness', 'advertising',
#        'nsw', 'research', 'vic', 'child-health-and-behaviour',
#        'lifestyle-and-leisure', 'australia', 'science-and-technology',
#        'diet-and-nutrition', 'qld', 'food-and-beverage', 'united-kingdom',
#        'healthcare-facilities'],
#       dtype='object')
# Order of the chain: Index(['diet-and-nutrition', 'advertising-and-marketing',
#        'child-health-and-behaviour', 'diseases-and-disorders', 'schools',
#        'federal-government', 'states-and-territories', 'diabetes', 'education',
#        'smoking', 'federal---state-issues', 'advertising',
#        'community-and-society', 'nsw', 'medical-research',
#        'exercise-and-fitness', 'wa', 'qld', 'health-policy', 'sa', 'vic',
#        'australia', 'healthcare-facilities', 'lifestyle-and-leisure',
#        'business-economics-and-finance', 'health', 'science-and-technology',
#        'act', 'united-states', 'tas', 'doctors-and-medical-professionals',
#        'government-and-politics', 'industry', 'heart-disease',
#        'united-kingdom', 'obesity',
#        'indigenous-aboriginal-and-torres-strait-islander', 'cancer',
#        'family-and-children', 'food-and-beverage', 'children', 'research'],
#       dtype='object')
# Order of the chain: Index(['qld', 'children', 'child-health-and-behaviour', 'education',
#        'federal-government', 'diseases-and-disorders',
#        'business-economics-and-finance', 'medical-research', 'schools',
#        'heart-disease', 'smoking', 'diet-and-nutrition',
#        'lifestyle-and-leisure', 'research', 'exercise-and-fitness',
#        'government-and-politics', 'doctors-and-medical-professionals', 'tas',
#        'vic', 'industry', 'cancer', 'diabetes', 'advertising-and-marketing',
#        'nsw', 'family-and-children', 'advertising', 'united-states', 'wa',
#        'community-and-society', 'sa', 'australia', 'health-policy',
#        'states-and-territories', 'health', 'food-and-beverage',
#        'united-kingdom', 'indigenous-aboriginal-and-torres-strait-islander',
#        'federal---state-issues', 'obesity', 'act', 'healthcare-facilities',
#        'science-and-technology'],
#       dtype='object')
# Order of the chain: Index(['united-kingdom', 'states-and-territories', 'qld', 'diet-and-nutrition',
#        'community-and-society', 'tas', 'sa', 'heart-disease',
#        'federal---state-issues', 'cancer', 'medical-research', 'wa', 'act',
#        'industry', 'obesity', 'education', 'research', 'diabetes',
#        'child-health-and-behaviour', 'science-and-technology', 'smoking',
#        'health-policy', 'family-and-children', 'diseases-and-disorders',
#        'federal-government', 'children', 'business-economics-and-finance',
#        'vic', 'schools', 'food-and-beverage', 'australia',
#        'doctors-and-medical-professionals', 'nsw', 'healthcare-facilities',
#        'advertising', 'indigenous-aboriginal-and-torres-strait-islander',
#        'health', 'united-states', 'government-and-politics',
#        'advertising-and-marketing', 'exercise-and-fitness',
#        'lifestyle-and-leisure'],
#       dtype='object')
# Order of the chain: Index(['sa', 'doctors-and-medical-professionals', 'science-and-technology',
#        'healthcare-facilities', 'tas', 'research', 'qld', 'nsw',
#        'federal-government', 'obesity', 'vic', 'community-and-society',
#        'smoking', 'children', 'united-kingdom', 'heart-disease',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'government-and-politics', 'lifestyle-and-leisure',
#        'advertising-and-marketing', 'child-health-and-behaviour', 'industry',
#        'wa', 'business-economics-and-finance', 'health',
#        'diseases-and-disorders', 'education', 'diet-and-nutrition',
#        'states-and-territories', 'family-and-children', 'exercise-and-fitness',
#        'medical-research', 'food-and-beverage', 'diabetes', 'act',
#        'health-policy', 'united-states', 'advertising', 'cancer', 'australia',
#        'federal---state-issues', 'schools'],
#       dtype='object')
# Order of the chain: Index(['exercise-and-fitness', 'united-states',
#        'business-economics-and-finance', 'qld', 'wa', 'heart-disease',
#        'science-and-technology', 'community-and-society', 'smoking', 'sa',
#        'research', 'diseases-and-disorders', 'education', 'schools',
#        'advertising', 'healthcare-facilities', 'health-policy',
#        'states-and-territories', 'children', 'lifestyle-and-leisure',
#        'australia', 'vic', 'nsw', 'food-and-beverage', 'united-kingdom',
#        'advertising-and-marketing', 'act', 'family-and-children', 'obesity',
#        'doctors-and-medical-professionals', 'federal---state-issues',
#        'indigenous-aboriginal-and-torres-strait-islander', 'tas', 'industry',
#        'cancer', 'federal-government', 'diet-and-nutrition',
#        'medical-research', 'government-and-politics',
#        'child-health-and-behaviour', 'health', 'diabetes'],
#       dtype='object')
# Order of the chain: Index(['family-and-children', 'business-economics-and-finance',
#        'food-and-beverage', 'diseases-and-disorders', 'states-and-territories',
#        'schools', 'act', 'united-states', 'federal---state-issues',
#        'doctors-and-medical-professionals', 'tas', 'exercise-and-fitness',
#        'sa', 'obesity', 'diabetes', 'qld', 'vic', 'advertising', 'industry',
#        'medical-research', 'cancer', 'health-policy', 'research',
#        'united-kingdom', 'heart-disease', 'science-and-technology',
#        'government-and-politics',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'community-and-society',
#        'child-health-and-behaviour', 'health', 'federal-government', 'nsw',
#        'wa', 'children', 'advertising-and-marketing', 'australia',
#        'diet-and-nutrition', 'smoking', 'education', 'healthcare-facilities'],
#       dtype='object')
# Order of the chain: Index(['children', 'vic', 'research', 'federal---state-issues',
#        'heart-disease', 'health-policy', 'family-and-children',
#        'food-and-beverage', 'schools', 'healthcare-facilities',
#        'exercise-and-fitness', 'doctors-and-medical-professionals',
#        'advertising', 'government-and-politics', 'community-and-society',
#        'diseases-and-disorders', 'act', 'qld', 'tas', 'nsw',
#        'federal-government', 'lifestyle-and-leisure', 'science-and-technology',
#        'diabetes', 'indigenous-aboriginal-and-torres-strait-islander',
#        'industry', 'states-and-territories', 'united-states', 'australia',
#        'wa', 'united-kingdom', 'education', 'health', 'sa',
#        'business-economics-and-finance', 'advertising-and-marketing',
#        'child-health-and-behaviour', 'obesity', 'smoking', 'medical-research',
#        'diet-and-nutrition', 'cancer'],
#       dtype='object')
# Order of the chain: Index(['united-kingdom', 'diabetes', 'science-and-technology', 'education',
#        'doctors-and-medical-professionals', 'family-and-children',
#        'community-and-society', 'child-health-and-behaviour',
#        'indigenous-aboriginal-and-torres-strait-islander', 'food-and-beverage',
#        'advertising', 'states-and-territories', 'diseases-and-disorders',
#        'business-economics-and-finance', 'advertising-and-marketing',
#        'children', 'sa', 'united-states', 'research', 'cancer', 'nsw',
#        'diet-and-nutrition', 'smoking', 'obesity', 'vic',
#        'healthcare-facilities', 'government-and-politics', 'health',
#        'exercise-and-fitness', 'health-policy', 'medical-research',
#        'heart-disease', 'wa', 'industry', 'australia', 'act', 'qld', 'schools',
#        'tas', 'lifestyle-and-leisure', 'federal-government',
#        'federal---state-issues'],
#       dtype='object')
# Order of the chain: Index(['doctors-and-medical-professionals', 'family-and-children',
#        'diet-and-nutrition', 'medical-research', 'tas',
#        'lifestyle-and-leisure', 'research', 'nsw', 'diabetes', 'health',
#        'government-and-politics', 'food-and-beverage',
#        'states-and-territories', 'industry', 'education',
#        'exercise-and-fitness', 'advertising', 'obesity', 'qld', 'act',
#        'smoking', 'community-and-society', 'wa', 'united-kingdom', 'schools',
#        'advertising-and-marketing', 'business-economics-and-finance',
#        'heart-disease', 'federal-government', 'australia', 'children',
#        'science-and-technology', 'united-states', 'diseases-and-disorders',
#        'federal---state-issues', 'cancer', 'sa', 'health-policy', 'vic',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'child-health-and-behaviour', 'healthcare-facilities'],
#       dtype='object')
# Order of the chain: Index(['sa', 'united-kingdom', 'diet-and-nutrition',
#        'child-health-and-behaviour', 'federal-government', 'wa',
#        'indigenous-aboriginal-and-torres-strait-islander', 'cancer',
#        'advertising', 'act', 'advertising-and-marketing', 'tas',
#        'family-and-children', 'united-states',
#        'business-economics-and-finance', 'vic', 'industry', 'smoking',
#        'healthcare-facilities', 'community-and-society', 'medical-research',
#        'science-and-technology', 'doctors-and-medical-professionals', 'qld',
#        'federal---state-issues', 'heart-disease', 'education', 'australia',
#        'diseases-and-disorders', 'nsw', 'states-and-territories',
#        'health-policy', 'food-and-beverage', 'health', 'obesity',
#        'exercise-and-fitness', 'diabetes', 'schools', 'children', 'research',
#        'government-and-politics', 'lifestyle-and-leisure'],
#       dtype='object')
# Order of the chain: Index(['food-and-beverage', 'states-and-territories', 'lifestyle-and-leisure',
#        'vic', 'obesity', 'government-and-politics', 'medical-research',
#        'united-states', 'united-kingdom', 'education',
#        'indigenous-aboriginal-and-torres-strait-islander', 'industry', 'wa',
#        'diet-and-nutrition', 'australia', 'federal-government',
#        'federal---state-issues', 'diabetes', 'research', 'act',
#        'heart-disease', 'tas', 'family-and-children',
#        'doctors-and-medical-professionals', 'smoking',
#        'child-health-and-behaviour', 'children', 'advertising-and-marketing',
#        'cancer', 'science-and-technology', 'advertising',
#        'business-economics-and-finance', 'qld', 'diseases-and-disorders',
#        'nsw', 'healthcare-facilities', 'health-policy',
#        'community-and-society', 'sa', 'schools', 'exercise-and-fitness',
#        'health'],
#       dtype='object')
# Order of the chain: Index(['vic', 'doctors-and-medical-professionals', 'united-states', 'diabetes',
#        'business-economics-and-finance', 'smoking',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'advertising-and-marketing', 'nsw', 'obesity', 'industry', 'research',
#        'exercise-and-fitness', 'sa', 'advertising', 'lifestyle-and-leisure',
#        'child-health-and-behaviour', 'qld', 'australia', 'schools',
#        'family-and-children', 'heart-disease', 'medical-research',
#        'government-and-politics', 'act', 'health', 'cancer',
#        'food-and-beverage', 'tas', 'children', 'states-and-territories', 'wa',
#        'diseases-and-disorders', 'federal-government', 'health-policy',
#        'education', 'healthcare-facilities', 'united-kingdom',
#        'federal---state-issues', 'diet-and-nutrition', 'community-and-society',
#        'science-and-technology'],
#       dtype='object')
# Order of the chain: Index(['united-kingdom', 'wa', 'government-and-politics', 'united-states',
#        'tas', 'family-and-children', 'doctors-and-medical-professionals',
#        'australia', 'research', 'community-and-society', 'obesity',
#        'medical-research', 'food-and-beverage', 'diet-and-nutrition',
#        'federal---state-issues',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'nsw', 'children', 'states-and-territories',
#        'health-policy', 'advertising-and-marketing', 'education',
#        'healthcare-facilities', 'act', 'schools', 'child-health-and-behaviour',
#        'heart-disease', 'federal-government', 'exercise-and-fitness',
#        'advertising', 'business-economics-and-finance',
#        'science-and-technology', 'smoking', 'industry', 'health', 'cancer',
#        'vic', 'qld', 'sa', 'diseases-and-disorders', 'diabetes'],
#       dtype='object')
# Order of the chain: Index(['act', 'research', 'diabetes', 'states-and-territories',
#        'federal---state-issues', 'tas', 'cancer', 'government-and-politics',
#        'australia', 'education', 'science-and-technology', 'heart-disease',
#        'doctors-and-medical-professionals', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander', 'nsw',
#        'business-economics-and-finance', 'food-and-beverage', 'health-policy',
#        'child-health-and-behaviour', 'advertising', 'healthcare-facilities',
#        'vic', 'advertising-and-marketing', 'smoking', 'exercise-and-fitness',
#        'industry', 'community-and-society', 'united-states', 'sa',
#        'lifestyle-and-leisure', 'schools', 'qld', 'united-kingdom',
#        'family-and-children', 'diet-and-nutrition', 'wa', 'obesity',
#        'diseases-and-disorders', 'health', 'medical-research',
#        'federal-government'],
#       dtype='object')
# Order of the chain: Index(['obesity', 'tas', 'science-and-technology', 'heart-disease', 'children',
#        'food-and-beverage', 'indigenous-aboriginal-and-torres-strait-islander',
#        'federal---state-issues', 'lifestyle-and-leisure', 'diabetes',
#        'family-and-children', 'medical-research', 'united-states',
#        'health-policy', 'wa', 'health', 'smoking', 'government-and-politics',
#        'cancer', 'diet-and-nutrition', 'sa', 'healthcare-facilities',
#        'advertising-and-marketing', 'act', 'united-kingdom',
#        'community-and-society', 'business-economics-and-finance', 'qld',
#        'australia', 'exercise-and-fitness', 'schools',
#        'states-and-territories', 'child-health-and-behaviour', 'industry',
#        'nsw', 'doctors-and-medical-professionals', 'research',
#        'federal-government', 'diseases-and-disorders', 'vic', 'advertising',
#        'education'],
#       dtype='object')
# Order of the chain: Index(['exercise-and-fitness', 'industry', 'qld', 'child-health-and-behaviour',
#        'advertising', 'science-and-technology',
#        'doctors-and-medical-professionals', 'act', 'states-and-territories',
#        'nsw', 'health', 'wa', 'diet-and-nutrition', 'federal---state-issues',
#        'smoking', 'government-and-politics', 'schools', 'australia',
#        'united-states', 'diseases-and-disorders', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander', 'health-policy',
#        'food-and-beverage', 'healthcare-facilities',
#        'business-economics-and-finance', 'medical-research',
#        'community-and-society', 'advertising-and-marketing', 'cancer',
#        'lifestyle-and-leisure', 'research', 'education', 'heart-disease',
#        'tas', 'obesity', 'federal-government', 'united-kingdom', 'diabetes',
#        'family-and-children', 'vic', 'sa'],
#       dtype='object')
# Order of the chain: Index(['family-and-children', 'vic', 'wa', 'states-and-territories', 'sa',
#        'heart-disease', 'business-economics-and-finance', 'tas', 'research',
#        'schools', 'children', 'healthcare-facilities', 'united-kingdom',
#        'obesity', 'doctors-and-medical-professionals', 'cancer', 'nsw',
#        'united-states', 'exercise-and-fitness', 'advertising',
#        'indigenous-aboriginal-and-torres-strait-islander', 'medical-research',
#        'act', 'diseases-and-disorders', 'qld', 'community-and-society',
#        'federal-government', 'science-and-technology', 'australia',
#        'lifestyle-and-leisure', 'federal---state-issues',
#        'advertising-and-marketing', 'government-and-politics', 'health-policy',
#        'food-and-beverage', 'health', 'diet-and-nutrition', 'education',
#        'industry', 'child-health-and-behaviour', 'diabetes', 'smoking'],
#       dtype='object')
# Order of the chain: Index(['exercise-and-fitness', 'united-states', 'act', 'sa',
#        'food-and-beverage', 'education', 'community-and-society',
#        'diseases-and-disorders', 'science-and-technology',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'diet-and-nutrition', 'federal---state-issues', 'advertising', 'cancer',
#        'advertising-and-marketing', 'health', 'tas',
#        'child-health-and-behaviour', 'research', 'government-and-politics',
#        'lifestyle-and-leisure', 'australia', 'healthcare-facilities',
#        'states-and-territories', 'obesity', 'schools', 'medical-research',
#        'heart-disease', 'wa', 'industry', 'nsw', 'diabetes', 'qld', 'children',
#        'health-policy', 'smoking', 'family-and-children', 'united-kingdom',
#        'doctors-and-medical-professionals', 'federal-government',
#        'business-economics-and-finance', 'vic'],
#       dtype='object')
# Order of the chain: Index(['sa', 'industry', 'diseases-and-disorders', 'medical-research',
#        'health-policy', 'health', 'advertising', 'heart-disease',
#        'family-and-children', 'vic', 'federal-government',
#        'business-economics-and-finance', 'states-and-territories',
#        'government-and-politics', 'child-health-and-behaviour', 'nsw',
#        'united-states', 'obesity', 'smoking',
#        'indigenous-aboriginal-and-torres-strait-islander', 'children',
#        'united-kingdom', 'australia', 'research', 'lifestyle-and-leisure',
#        'doctors-and-medical-professionals', 'cancer', 'exercise-and-fitness',
#        'schools', 'science-and-technology', 'diet-and-nutrition',
#        'food-and-beverage', 'healthcare-facilities',
#        'advertising-and-marketing', 'wa', 'qld', 'federal---state-issues',
#        'act', 'education', 'diabetes', 'tas', 'community-and-society'],
#       dtype='object')
# Order of the chain: Index(['smoking', 'australia', 'obesity', 'lifestyle-and-leisure',
#        'exercise-and-fitness', 'family-and-children', 'states-and-territories',
#        'doctors-and-medical-professionals', 'united-states', 'wa',
#        'business-economics-and-finance', 'science-and-technology',
#        'advertising-and-marketing',
#        'indigenous-aboriginal-and-torres-strait-islander', 'cancer',
#        'diabetes', 'education', 'healthcare-facilities',
#        'federal---state-issues', 'children', 'diseases-and-disorders',
#        'health', 'vic', 'act', 'advertising', 'heart-disease', 'industry',
#        'research', 'federal-government', 'sa', 'medical-research',
#        'diet-and-nutrition', 'government-and-politics', 'united-kingdom',
#        'nsw', 'tas', 'child-health-and-behaviour', 'community-and-society',
#        'food-and-beverage', 'health-policy', 'qld', 'schools'],
#       dtype='object')
# Order of the chain: Index(['diet-and-nutrition', 'health-policy', 'government-and-politics',
#        'united-kingdom', 'healthcare-facilities', 'qld', 'wa',
#        'federal-government', 'science-and-technology', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'states-and-territories', 'child-health-and-behaviour', 'cancer',
#        'schools', 'family-and-children', 'medical-research',
#        'doctors-and-medical-professionals', 'food-and-beverage',
#        'community-and-society', 'diabetes', 'lifestyle-and-leisure',
#        'exercise-and-fitness', 'australia', 'advertising', 'nsw', 'research',
#        'advertising-and-marketing', 'health', 'heart-disease',
#        'federal---state-issues', 'obesity', 'smoking',
#        'diseases-and-disorders', 'act', 'tas', 'united-states',
#        'business-economics-and-finance', 'sa', 'industry', 'education', 'vic'],
#       dtype='object')
# Order of the chain: Index(['australia', 'lifestyle-and-leisure', 'education', 'medical-research',
#        'health-policy', 'united-kingdom', 'health', 'schools',
#        'advertising-and-marketing', 'federal---state-issues', 'obesity',
#        'cancer', 'sa', 'advertising', 'qld', 'diet-and-nutrition', 'industry',
#        'children', 'healthcare-facilities', 'food-and-beverage',
#        'heart-disease', 'business-economics-and-finance',
#        'doctors-and-medical-professionals', 'diabetes',
#        'government-and-politics', 'smoking', 'states-and-territories',
#        'exercise-and-fitness', 'vic', 'tas', 'community-and-society', 'wa',
#        'act', 'diseases-and-disorders', 'united-states',
#        'science-and-technology', 'research', 'nsw',
#        'child-health-and-behaviour',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'federal-government'],
#       dtype='object')
# Order of the chain: Index(['united-states', 'research', 'family-and-children', 'education',
#        'lifestyle-and-leisure', 'diseases-and-disorders', 'sa',
#        'healthcare-facilities', 'united-kingdom', 'diabetes',
#        'states-and-territories', 'health', 'science-and-technology',
#        'federal---state-issues', 'exercise-and-fitness', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander', 'tas', 'wa',
#        'federal-government', 'qld', 'schools', 'industry',
#        'business-economics-and-finance', 'community-and-society', 'nsw',
#        'heart-disease', 'obesity', 'cancer', 'advertising', 'health-policy',
#        'food-and-beverage', 'government-and-politics',
#        'child-health-and-behaviour', 'vic', 'smoking', 'medical-research',
#        'act', 'advertising-and-marketing', 'australia', 'diet-and-nutrition',
#        'doctors-and-medical-professionals'],
#       dtype='object')
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
#
# --- Order of the chain ---
# Index(['united-states', 'research', 'family-and-children', 'education',
#        'lifestyle-and-leisure', 'diseases-and-disorders', 'sa',
#        'healthcare-facilities', 'united-kingdom', 'diabetes',
#        'states-and-territories', 'health', 'science-and-technology',
#        'federal---state-issues', 'exercise-and-fitness', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander', 'tas', 'wa',
#        'federal-government', 'qld', 'schools', 'industry',
#        'business-economics-and-finance', 'community-and-society', 'nsw',
#        'heart-disease', 'obesity', 'cancer', 'advertising', 'health-policy',
#        'food-and-beverage', 'government-and-politics',
#        'child-health-and-behaviour', 'vic', 'smoking', 'medical-research',
#        'act', 'advertising-and-marketing', 'australia', 'diet-and-nutrition',
#        'doctors-and-medical-professionals'],
#       dtype='object')
#
# --- Performance ---
# coverage_error = 13.93 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.14
# hamming_loss = 0.11
# f1_macro = 0.27
# f1_micro = 0.39
# Jaccard_Index = 0.26
# zero_one_error = 0.97
#
# - f1 for each label -
# label_act = 0.0
# label_advertising = 0.31
# label_advertising-and-marketing = 0.39
# label_australia = 0.6
# label_business-economics-and-finance = 0.31
# label_cancer = 0.26
# label_child-health-and-behaviour = 0.36
# label_children = 0.28
# label_community-and-society = 0.06
# label_diabetes = 0.27
# label_diet-and-nutrition = 0.22
# label_diseases-and-disorders = 0.23
# label_doctors-and-medical-professionals = 0.19
# label_education = 0.15
# label_exercise-and-fitness = 0.18
# label_family-and-children = 0.11
# label_federal---state-issues = 0.14
# label_federal-government = 0.4
# label_food-and-beverage = 0.41
# label_government-and-politics = 0.27
# label_health = 0.4
# label_health-policy = 0.39
# label_healthcare-facilities = 0.24
# label_heart-disease = 0.29
# label_indigenous-aboriginal-and-torres-strait-islander = 0.0
# label_industry = 0.26
# label_lifestyle-and-leisure = 0.2
# label_medical-research = 0.42
# label_nsw = 0.3
# label_obesity = 0.72
# label_qld = 0.17
# label_research = 0.42
# label_sa = 0.1
# label_schools = 0.38
# label_science-and-technology = 0.12
# label_smoking = 0.11
# label_states-and-territories = 0.41
# label_tas = 0.08
# label_united-kingdom = 0.16
# label_united-states = 0.63
# label_vic = 0.17
# label_wa = 0.06
