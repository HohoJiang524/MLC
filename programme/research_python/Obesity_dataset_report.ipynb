# %%
import pandas as pd
import numpy as np
import os
import time
import subprocess
import re
import random
import arff

from math import sqrt
from sklearn.model_selection import  train_test_split
from sklearn.model_selection import KFold
from sklearn.naive_bayes import MultinomialNB  
from sklearn.metrics import classification_report
from sklearn.metrics import coverage_error
from sklearn.metrics import label_ranking_loss
from sklearn.metrics import hamming_loss
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import zero_one_loss
from sklearn.metrics import jaccard_similarity_score

# %% [markdown]
# # functions

# %%
def read_data(dataPath):
    # input: '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'
    # read data
    data = pd.read_csv(os.path.join(dataPath,'X.csv'), index_col=0).reset_index(drop=True)
    label = pd.read_csv(os.path.join(dataPath,'Y.csv'), index_col=0).reset_index(drop=True)
    return data,label

def evaluation(y_pred, y_prob, y_true):
    coverage = 0
    hamming = hamming_loss(y_true, y_pred)
    ranking_loss = 0
    
    f1_macro = metrics.f1_score(y_true, y_pred, average='macro')
    f1_micro = metrics.f1_score(y_true, y_pred, average='micro')
    
    acc = 0
    for i in range(y_true.shape[0]):
        acc += jaccard_similarity_score(y_true.iloc[i,:], y_pred.iloc[i,:]) # jaccard_similarity_score
    acc = round(acc / y_true.shape[0],2)
    
    zero_one = zero_one_loss(y_true, y_pred) # 0-1 error 
    
    f1_each = metrics.f1_score(y_true, y_pred, average=None)
    
    #confusion_matrix = y_pred - y_true
    
    performance = {"coverage_error":coverage,
                   "ranking_loss":ranking_loss,
                   "hamming_loss":hamming,
                   "f1_macro":f1_macro,
                   "f1_micro":f1_micro,
                   "Jaccard_Index":acc,
                   "zero_one_error":zero_one,
                   "f1_each_label":f1_each}
    return performance

def get_confusion_matrix(y_pred, y_test, column_names):
    """confusion matrix """
    confusion_matrix = pd.DataFrame(np.array(y_pred) - np.array(y_test), columns=column_names)
    pos = pd.DataFrame((np.array(y_pred) == np.array(y_test)) & (np.array(y_pred) == 1), columns=y_test.columns).sum(axis=0)
    neg = pd.DataFrame((np.array(y_pred) == np.array(y_test)) & (np.array(y_pred) == 0), columns=y_test.columns).sum(axis=0)
    for i in range(confusion_matrix.shape[1]): 
        name = confusion_matrix.iloc[:,i].name
        temp = confusion_matrix.iloc[:,i].value_counts()
        TP = pos[name]
        TN = neg[name]
        if 1 in temp.index:
            FP = temp[1]
        else:
            FP = 0
        if -1 in temp.index:
            FN = temp[-1]
        else:
            FN = 0
            
        
        print("{0}: TP:{1}, TN:{2}, FP:{3}, FN:{4}".format(name, TP, TN, FP, FN))

# %% [markdown]
# # read data

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

data, label = read_data(dataPath) # read data

# get data information
n_label = label.shape[1]
n_attr = data.shape[1]
n_instance = data.shape[0]
avg_label_per_instance = label.sum(axis=1).mean()
avg_instance_per_label = label.sum(axis=0).mean()
# print data information
print("\n--- Data Information ---")
print("dataset:", dataPath)
print("number of label:",n_label)
print("number of attribute:",n_attr)
print("number of instance:",n_instance)
print("avgerage number of labels for an instance:",avg_label_per_instance)
print("avgerage number of positive instances for a label:",avg_instance_per_label,"the std:",sqrt(label.sum(axis=0).var()),"\n")

print("-- number of positive instances --")
print(label.sum(axis=0))
# Out:
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
# avgerage number of labels for an instance: 3.2480359147025815
# avgerage number of positive instances for a label: 68.9047619047619 the std: 87.33362147641554
#
# -- number of positive instances --
# act                                                  26
# advertising                                          23
# advertising-and-marketing                            27
# australia                                           342
# business-economics-and-finance                       31
# cancer                                               21
# child-health-and-behaviour                           97
# children                                             59
# community-and-society                                55
# diabetes                                             57
# diet-and-nutrition                                  119
# diseases-and-disorders                               67
# doctors-and-medical-professionals                    48
# education                                            18
# exercise-and-fitness                                 52
# family-and-children                                  31
# federal---state-issues                               23
# federal-government                                   76
# food-and-beverage                                    41
# government-and-politics                              68
# health                                              299
# health-policy                                        42
# healthcare-facilities                                33
# heart-disease                                        24
# indigenous-aboriginal-and-torres-strait-islander     25
# industry                                             19
# lifestyle-and-leisure                                21
# medical-research                                     86
# nsw                                                  68
# obesity                                             444
# qld                                                  49
# research                                             56
# sa                                                   39
# schools                                              32
# science-and-technology                               23
# smoking                                              22
# states-and-territories                               86
# tas                                                  25
# united-kingdom                                       38
# united-states                                        98
# vic                                                  41
# wa                                                   43
# dtype: int64

# %% [markdown]
# ## co-occurance

# %%
cooccurrence_matrix = label.T.dot(label)
np.fill_diagonal(cooccurrence_matrix.values, 0)
#cooccurrence_matrix.to_csv('/Users/jiangjunhao/Desktop/cooccurrence_matrix.csv', index=False)

# %% [markdown]
# # Binary Relevance
#
# ## BR using naive Bayes classifier

# %%
def naiveBayes_multi_label_training(X_train, y_train):
    start = time.time()
    
    n_label = y_train.shape[1]
    classifier_list = [MultinomialNB() for i in range(n_label)]
    for i in range(n_label):
        classifier_list[i].fit(X_train,y_train.iloc[:,i])
    
    end = time.time()
    training_time = end-start
    
    return classifier_list, training_time

def naiveBayes_multi_label_testing(X_test, n_label, classifier_list):
    y_predict = pd.DataFrame()
    y_prob = pd.DataFrame()
    
    start = time.time()
    
    for i in range(n_label):
        y_predict_i = classifier_list[i].predict(X_test)
        y_predict = pd.concat([y_predict, pd.DataFrame(y_predict_i)],axis=1)
        
        y_predict_prob_i = classifier_list[i].predict_proba(X_test)[:,1]
        y_prob = pd.concat([y_prob, pd.DataFrame(y_predict_prob_i)],axis=1)
        
    end = time.time()
    testing_time = end-start
        
    return y_predict, y_prob, testing_time

def BR_test(data, label, dataPath, random_state=3071980):
    
    # data set information
    n_label = label.shape[1]
    n_attr = data.shape[1]
    n_instance = data.shape[0]
    avg_label_per_instance = label.sum(axis=1).mean()
    
    # split training and test data set
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.5, random_state=random_state)
    
    print("-- test index --")
    print(X_test.index)
    
    # training
    print("--- start training ---\n")
    classifier_list, training_time = naiveBayes_multi_label_training(X_train, y_train)
    
    # testing
    print("--- start testing ---\n")
    y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list)
    
    # evaluation
    performance = evaluation(y_predict, y_prob, y_test)
    
    # print data information
    print("--- Data Information ---")
    print("dataset:", dataPath)
    print("number of label:",n_label)
    print("number of attribute:",n_attr)
    print("number of instance:",n_instance,"\n")
    
    # get confusion matrix
    get_confusion_matrix(y_predict, y_test, y_test.columns)
    
    # print performance
    print("--- Performance ---")
    for key, value in performance.items():
        if key == "f1_each_label":
            print("\n- f1 for each label -")
            for i in range(n_label):
                print("label_"+label.columns[i],"=",round(value[i],2))
        elif key == "coverage_error":
            print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
        else:
            print(key,'=',round(value,2))
            
# two fold cross-validation
def two_fold_BR_test(data, label, dataPath, n_iter=5, random_state=3071980):
    
    # data set information
    n_label = label.shape[1]
    n_attr = data.shape[1]
    n_instance = data.shape[0]
    avg_label_per_instance = label.sum(axis=1).mean()
    
    # 2-fold cross validatiom
    KF=KFold(n_splits=2, shuffle=True, random_state=random_state)
    i = 0
    
    performance = {}
    for train_index,test_index in KF.split(data):
        i += 1
        
        X_train,X_test=data.iloc[train_index,:],data.iloc[test_index,:]
        y_train,y_test=label.iloc[train_index,:],label.iloc[test_index,:]
        
        print("--- kfold time="+str(i)+" ---")
        # training
        classifier_list, training_time = naiveBayes_multi_label_training(X_train, y_train)
        # testing
        y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list)
        
        # evaluation
        if performance == {}:
            performance = evaluation(y_predict, y_prob, y_test)
        else:
            performance_i = evaluation(y_predict, y_prob, y_test)
            for key, value in performance_i.items():
                performance[key] = (performance[key] + value)/2
            else:
                performance[key] = value
    
    # print data information
    print("\n--- Data Information ---")
    print("dataset:", dataPath)
    print("number of label:",n_label)
    print("number of attribute:",n_attr)
    print("number of instance:",n_instance,"\n")
    
    # print performance
    print("--- 2 fold cross-validation Performance ---")
    for key, value in performance.items():
        if key == "f1_each_label":
            continue
        elif key == "coverage_error":
            print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
        else:
            print(key,'=',round(value,2))

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

# train - test
print("------ Binary Relevance using Naive Bayes ------")
BR_test(data, label, dataPath,3071980)

#print("")
#print("------ two_fold Binary Relevance using Naive Bayes ------")
#two_fold_BR_test(data, label, dataPath,3071980)
# Out:
# ------ Binary Relevance using Naive Bayes ------
# -- test index --
# Int64Index([465, 368, 408, 584, 701, 805, 625, 615, 862, 495,
#             ...
#              92, 490, 367, 800, 491, 627, 655, 274, 867,  44],
#            dtype='int64', length=446)
# --- start training ---
#
# --- start testing ---
#
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
# act: TP:0, TN:427, FP:4, FN:15
# advertising: TP:9, TN:416, FP:19, FN:2
# advertising-and-marketing: TP:10, TN:404, FP:31, FN:1
# australia: TP:92, TN:209, FP:57, FN:88
# business-economics-and-finance: TP:6, TN:418, FP:16, FN:6
# cancer: TP:2, TN:428, FP:8, FN:8
# child-health-and-behaviour: TP:20, TN:343, FP:55, FN:28
# children: TP:6, TN:385, FP:30, FN:25
# community-and-society: TP:2, TN:403, FP:17, FN:24
# diabetes: TP:14, TN:399, FP:24, FN:9
# diet-and-nutrition: TP:12, TN:361, FP:21, FN:52
# diseases-and-disorders: TP:8, TN:378, FP:37, FN:23
# doctors-and-medical-professionals: TP:7, TN:405, FP:9, FN:25
# education: TP:1, TN:429, FP:4, FN:12
# exercise-and-fitness: TP:3, TN:408, FP:14, FN:21
# family-and-children: TP:2, TN:418, FP:10, FN:16
# federal---state-issues: TP:3, TN:423, FP:9, FN:11
# federal-government: TP:23, TN:370, FP:30, FN:23
# food-and-beverage: TP:10, TN:395, FP:26, FN:15
# government-and-politics: TP:13, TN:355, FP:59, FN:19
# health: TP:54, TN:241, FP:43, FN:108
# health-policy: TP:11, TN:403, FP:17, FN:15
# healthcare-facilities: TP:4, TN:410, FP:19, FN:13
# heart-disease: TP:1, TN:416, FP:23, FN:6
# indigenous-aboriginal-and-torres-strait-islander: TP:2, TN:424, FP:11, FN:9
# industry: TP:4, TN:420, FP:17, FN:5
# lifestyle-and-leisure: TP:0, TN:432, FP:6, FN:8
# medical-research: TP:19, TN:365, FP:38, FN:24
# nsw: TP:8, TN:400, FP:14, FN:24
# obesity: TP:167, TN:147, FP:80, FN:52
# qld: TP:7, TN:405, FP:16, FN:18
# research: TP:11, TN:395, FP:25, FN:15
# sa: TP:1, TN:422, FP:5, FN:18
# schools: TP:9, TN:407, FP:20, FN:10
# science-and-technology: TP:0, TN:427, FP:8, FN:11
# smoking: TP:1, TN:425, FP:7, FN:13
# states-and-territories: TP:20, TN:356, FP:43, FN:27
# tas: TP:1, TN:431, FP:3, FN:11
# united-kingdom: TP:4, TN:410, FP:16, FN:16
# united-states: TP:30, TN:378, FP:20, FN:18
# vic: TP:4, TN:408, FP:17, FN:17
# wa: TP:1, TN:428, FP:2, FN:15
# --- Performance ---
# coverage_error = 13.6 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.13
# hamming_loss = 0.1
# f1_macro = 0.26
# f1_micro = 0.4
# Jaccard_Index = 0.9
# zero_one_error = 0.98
#
# - f1 for each label -
# label_act = 0.0
# label_advertising = 0.46
# label_advertising-and-marketing = 0.38
# label_australia = 0.56
# label_business-economics-and-finance = 0.35
# label_cancer = 0.2
# label_child-health-and-behaviour = 0.33
# label_children = 0.18
# label_community-and-society = 0.09
# label_diabetes = 0.46
# label_diet-and-nutrition = 0.25
# label_diseases-and-disorders = 0.21
# label_doctors-and-medical-professionals = 0.29
# label_education = 0.11
# label_exercise-and-fitness = 0.15
# label_family-and-children = 0.13
# label_federal---state-issues = 0.23
# label_federal-government = 0.46
# label_food-and-beverage = 0.33
# label_government-and-politics = 0.25
# label_health = 0.42
# label_health-policy = 0.41
# label_healthcare-facilities = 0.2
# label_heart-disease = 0.06
# label_indigenous-aboriginal-and-torres-strait-islander = 0.17
# label_industry = 0.27
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.38
# label_nsw = 0.3
# label_obesity = 0.72
# label_qld = 0.29
# label_research = 0.35
# label_sa = 0.08
# label_schools = 0.38
# label_science-and-technology = 0.0
# label_smoking = 0.09
# label_states-and-territories = 0.36
# label_tas = 0.12
# label_united-kingdom = 0.2
# label_united-states = 0.61
# label_vic = 0.19
# label_wa = 0.11

# %%
# data set information
n_label = label.shape[1]
n_attr = data.shape[1]
n_instance = data.shape[0]
avg_label_per_instance = label.sum(axis=1).mean()

# split training and test data set
# X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.5, random_state=random_state)
X_train = data[data.index.isin(index)==False]
X_test = data[data.index.isin(index)==True]
y_train = label[label.index.isin(index)==False]
y_test = label[label.index.isin(index)==True]

print("-- test index --")
print(X_test.index)

# training
print("--- start training ---\n")
classifier_list, training_time = naiveBayes_multi_label_training(X_train, y_train)

# testing
print("--- start testing ---\n")
y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list)

# get confusion matrix
get_confusion_matrix(y_predict, y_test, y_test.columns)
    
# evaluation
performance = evaluation(y_predict, y_prob, y_test)


# print data information
print("--- Data Information ---")
print("dataset:", dataPath)
print("number of label:",n_label)
print("number of attribute:",n_attr)
print("number of instance:",n_instance,"\n")

# print performance
print("--- Performance ---")
for key, value in performance.items():
    if key == "f1_each_label":
        print("\n- f1 for each label -")
        for i in range(n_label):
            print("label_"+label.columns[i],"=",round(value[i],2))
    elif key == "coverage_error":
        print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
    else:
        print(key,'=',round(value,2))
# Out:
# -- test index --
# Int64Index([  4,   5,   7,   8,  15,  16,  17,  21,  23,  24,
#             ...
#             876, 878, 879, 880, 881, 882, 884, 888, 889, 890],
#            dtype='int64', length=446)
# --- start training ---
#
# --- start testing ---
#
# act: TP:1, TN:422, FP:16, FN:7
# advertising: TP:7, TN:417, FP:18, FN:4
# advertising-and-marketing: TP:8, TN:409, FP:24, FN:5
# australia: TP:96, TN:206, FP:64, FN:80
# business-economics-and-finance: TP:6, TN:408, FP:25, FN:7
# cancer: TP:3, TN:430, FP:2, FN:11
# child-health-and-behaviour: TP:21, TN:341, FP:47, FN:37
# children: TP:7, TN:386, FP:23, FN:30
# community-and-society: TP:2, TN:408, FP:11, FN:25
# diabetes: TP:10, TN:392, FP:24, FN:20
# diet-and-nutrition: TP:20, TN:337, FP:54, FN:35
# diseases-and-disorders: TP:7, TN:389, FP:23, FN:27
# doctors-and-medical-professionals: TP:3, TN:414, FP:8, FN:21
# education: TP:1, TN:429, FP:9, FN:7
# exercise-and-fitness: TP:5, TN:406, FP:12, FN:23
# family-and-children: TP:1, TN:415, FP:13, FN:17
# federal---state-issues: TP:6, TN:428, FP:8, FN:4
# federal-government: TP:17, TN:373, FP:34, FN:22
# food-and-beverage: TP:9, TN:393, FP:32, FN:12
# government-and-politics: TP:9, TN:371, FP:41, FN:25
# health: TP:61, TN:213, FP:88, FN:84
# health-policy: TP:6, TN:408, FP:14, FN:18
# healthcare-facilities: TP:4, TN:416, FP:14, FN:12
# heart-disease: TP:3, TN:425, FP:9, FN:9
# indigenous-aboriginal-and-torres-strait-islander: TP:1, TN:429, FP:5, FN:11
# industry: TP:4, TN:414, FP:22, FN:6
# lifestyle-and-leisure: TP:0, TN:436, FP:1, FN:9
# medical-research: TP:27, TN:358, FP:43, FN:18
# nsw: TP:4, TN:401, FP:12, FN:29
# obesity: TP:163, TN:146, FP:72, FN:65
# qld: TP:5, TN:418, FP:10, FN:13
# research: TP:16, TN:387, FP:26, FN:17
# sa: TP:2, TN:418, FP:10, FN:16
# schools: TP:8, TN:418, FP:9, FN:11
# science-and-technology: TP:2, TN:423, FP:10, FN:11
# smoking: TP:1, TN:427, FP:11, FN:7
# states-and-territories: TP:12, TN:358, FP:44, FN:32
# tas: TP:0, TN:433, FP:1, FN:12
# united-kingdom: TP:6, TN:418, FP:12, FN:10
# united-states: TP:35, TN:365, FP:31, FN:15
# vic: TP:2, TN:417, FP:12, FN:15
# wa: TP:1, TN:419, FP:7, FN:19
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
# --- Performance ---
# coverage_error = 14.19 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.14
# hamming_loss = 0.1
# f1_macro = 0.27
# f1_micro = 0.4
# Jaccard_Index = 0.9
# zero_one_error = 0.98
#
# - f1 for each label -
# label_act = 0.08
# label_advertising = 0.39
# label_advertising-and-marketing = 0.36
# label_australia = 0.57
# label_business-economics-and-finance = 0.27
# label_cancer = 0.32
# label_child-health-and-behaviour = 0.33
# label_children = 0.21
# label_community-and-society = 0.1
# label_diabetes = 0.31
# label_diet-and-nutrition = 0.31
# label_diseases-and-disorders = 0.22
# label_doctors-and-medical-professionals = 0.17
# label_education = 0.11
# label_exercise-and-fitness = 0.22
# label_family-and-children = 0.06
# label_federal---state-issues = 0.5
# label_federal-government = 0.38
# label_food-and-beverage = 0.29
# label_government-and-politics = 0.21
# label_health = 0.41
# label_health-policy = 0.27
# label_healthcare-facilities = 0.24
# label_heart-disease = 0.25
# label_indigenous-aboriginal-and-torres-strait-islander = 0.11
# label_industry = 0.22
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.47
# label_nsw = 0.16
# label_obesity = 0.7
# label_qld = 0.3
# label_research = 0.43
# label_sa = 0.13
# label_schools = 0.44
# label_science-and-technology = 0.16
# label_smoking = 0.1
# label_states-and-territories = 0.24
# label_tas = 0.0
# label_united-kingdom = 0.35
# label_united-states = 0.6
# label_vic = 0.13
# label_wa = 0.07

# %% [markdown]
# ## BR using ESKDB

# %%
def get_arff(word_occurrence, label_matrix, savePath): # get attributes
    for z in range(len(label_matrix.columns)):
        attributes=[(word_occurrence.columns[i],['0', '1']) for i in range(len(word_occurrence.columns))]
        attributes.append(('label_'+label_matrix.columns[z],['0', '1']))

        data=[]
        i = 0
        while i < label_matrix.shape[0]:
            attr_data = [str(j) for j in list(word_occurrence.iloc[i,:])]
            label_data = [str(label_matrix.iloc[i,z])]
            row_data = attr_data+label_data
            data.append(row_data) 
            i+=1
        # set obj
        obj = {
           'description': u'',
           'relation': 'relation',
           'attributes': attributes,
           'data': data,
        }
        arff_data = arff.dumps(obj)
        w_file = open(savePath+label_matrix.columns[z]+".arff", "w")
        w_file.write(arff_data)
        w_file.close()

def run_eskdb(dataPath, resultFile, k, l, e, i):
    command = "./run_eskdb.sh "+resultFile+" "+k+" "+i+" "+l+" "+e+" "+dataPath
    subprocess.call("cd /Volumes/Samsung_T5/research/programme/research_python/", shell=True)
    print(command)
    return subprocess.call(command, shell=True)

def get_result(resultPath):

    y_pred = pd.DataFrame()
    y_true = pd.DataFrame()
    y_prob = pd.DataFrame()
    names = []
    for file in os.listdir(resultPath):
        with open(os.path.join(resultPath,file), 'r') as f:
            try:
                lines = f.readlines()
            except:
                print(file)
            else:
                names.append(file[:-4])
                pred = []
                true = []
                prob = []
                train_time_total = 0
                test_time_total = 0
                error_marco = 0
                for line in lines:
                    if line.startswith('pred'):
                        pred.append(int(re.search('pred :\t(.)',line).group(1)))
                        true.append(int(re.search('true :\t(.)',line).group(1)))
                        prob.append(float(re.search('prob :\t(.*)',line).group(1)))
                    elif line.startswith('RSME'):
                        rsme = float(re.search('RSME :\t\t(.*)',line).group(1))
                    elif line.startswith('Error'):
                        error = float(re.search('Error :\t\t(.*)',line).group(1))
                    elif line.startswith("Training time"):
                        train_time = float(re.search('Training time :\s{1,}(.*)',line).group(1))
                        train_time_total = train_time_total + train_time
                    elif line.startswith("Testing time"):
                        test_time = float(re.search('Testing time :\s{1,}(.*)',line).group(1))
                        test_time_total = test_time_total + test_time
                    elif line.startswith("["):
                        para = line
                    elif line.startswith("test0Indexes"):
                        index = list(map(int,re.search('test0Indexes: {(.*)}',line).group(1).split(', ')))

                y_pred = pd.concat([y_pred,pd.DataFrame(pred)],axis=1)
                y_true = pd.concat([y_true,pd.DataFrame(true)],axis=1)
                y_prob = pd.concat([y_prob,pd.DataFrame(prob)],axis=1)
    y_pred.columns = names
    y_true.columns = names
    y_pred.index = index
    y_true.index = index
    print(para)
    print("number of label:", y_pred.shape[1])
    print("training time:",train_time_total)
    print("testing time:",test_time_total)
    print("-- test index --")
    print(index)
    return y_pred,y_true,y_prob,index

# %%
# obesity
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

# get arff files
savePath = "/Users/jiangjunhao/Desktop/test/"
get_arff(data,label,savePath)

dataPath = "/Users/jiangjunhao/Desktop/test/"
resultFile = 'obesity_k5_e20_i5000'
k = '5'
i = '5000'
l = '2'
e = '20'

run_eskdb(dataPath, resultFile, k, l, e, i)

# %%
resultPath = '/Volumes/Samsung_T5/research/programme/ESKDB_HDP/result/obesity_k5_e20_i5000/'
y_pred,y_true,y_prob,index = get_result(resultPath)

performance = evaluation(y_pred=y_pred, y_true=y_true, y_prob=y_prob)

# get confusion mbatrix
print("\n--- Confusion matrix ---")
get_confusion_matrix(y_pred, y_true, y_true.columns)
    
# print performance
print("--- Performance ---")
for key, value in performance.items():
    if key == "f1_each_label":
        print("\n- f1 for each label -")
        for i in range(n_label):
            print("label_"+label.columns[i],"=",round(value[i],2))
    elif key == "coverage_error":
        print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
    else:
        print(key,'=',round(value,2))
# Out:
# [-t, /Users/jiangjunhao/Desktop/test//wa.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2339.0
# testing time: 1427.0
# -- test index --
# [4, 5, 7, 8, 15, 16, 17, 21, 23, 24, 31, 34, 35, 36, 39, 40, 41, 42, 43, 45, 46, 47, 48, 50, 52, 55, 56, 59, 60, 62, 63, 65, 66, 67, 70, 72, 75, 76, 78, 80, 84, 87, 90, 91, 92, 95, 100, 102, 103, 104, 107, 109, 110, 111, 112, 113, 114, 115, 116, 118, 120, 121, 126, 127, 129, 131, 132, 133, 134, 135, 136, 146, 154, 158, 163, 164, 167, 171, 172, 173, 175, 176, 178, 183, 185, 187, 189, 194, 195, 197, 198, 200, 202, 203, 204, 207, 208, 212, 213, 214, 217, 219, 221, 222, 223, 225, 228, 229, 230, 231, 232, 235, 239, 240, 241, 242, 243, 245, 247, 249, 251, 252, 253, 254, 256, 258, 260, 262, 263, 264, 265, 266, 268, 269, 270, 273, 275, 276, 277, 279, 281, 282, 283, 284, 285, 286, 288, 291, 293, 294, 295, 299, 300, 302, 304, 306, 307, 308, 311, 315, 316, 318, 321, 322, 325, 328, 329, 332, 333, 334, 336, 337, 338, 339, 342, 346, 347, 349, 352, 354, 355, 359, 360, 362, 366, 368, 369, 374, 375, 376, 384, 385, 386, 387, 388, 389, 391, 394, 399, 400, 403, 404, 405, 406, 407, 412, 413, 414, 416, 417, 419, 420, 422, 426, 428, 429, 432, 439, 441, 445, 447, 450, 452, 453, 455, 457, 459, 460, 461, 462, 464, 465, 468, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 486, 487, 491, 493, 495, 496, 497, 498, 500, 501, 503, 504, 505, 506, 514, 515, 517, 519, 521, 522, 523, 525, 527, 528, 529, 531, 533, 534, 538, 540, 545, 548, 549, 550, 551, 553, 554, 557, 558, 561, 564, 565, 566, 567, 569, 572, 573, 574, 575, 576, 580, 584, 587, 592, 597, 600, 602, 612, 614, 615, 616, 617, 619, 620, 621, 623, 624, 626, 627, 629, 630, 632, 634, 635, 637, 642, 643, 646, 648, 650, 651, 652, 655, 656, 657, 658, 660, 661, 662, 663, 664, 665, 668, 671, 676, 679, 681, 683, 686, 688, 689, 692, 696, 698, 702, 704, 705, 707, 708, 709, 711, 716, 718, 722, 724, 726, 728, 729, 730, 731, 733, 735, 736, 737, 739, 740, 741, 746, 753, 755, 759, 760, 762, 763, 764, 766, 767, 769, 770, 771, 772, 777, 778, 780, 781, 786, 788, 789, 790, 791, 792, 793, 794, 795, 797, 806, 808, 809, 811, 817, 818, 821, 822, 823, 824, 825, 829, 831, 833, 834, 835, 836, 837, 838, 841, 843, 845, 847, 849, 851, 854, 859, 860, 862, 863, 864, 866, 868, 869, 870, 871, 874, 876, 878, 879, 880, 881, 882, 884, 888, 889, 890]
#
# --- Confusion matrix ---
# act: TP:0, TN:434, FP:4, FN:8
# advertising-and-marketing: TP:4, TN:429, FP:4, FN:9
# advertising: TP:1, TN:433, FP:2, FN:10
# australia: TP:84, TN:227, FP:43, FN:92
# business-economics-and-finance: TP:0, TN:428, FP:5, FN:13
# cancer: TP:2, TN:431, FP:1, FN:12
# child-health-and-behaviour: TP:1, TN:382, FP:6, FN:57
# children: TP:3, TN:407, FP:2, FN:34
# community-and-society: TP:0, TN:416, FP:3, FN:27
# diabetes: TP:2, TN:412, FP:4, FN:28
# diet-and-nutrition: TP:1, TN:387, FP:4, FN:54
# diseases-and-disorders: TP:0, TN:403, FP:9, FN:34
# doctors-and-medical-professionals: TP:0, TN:421, FP:1, FN:24
# education: TP:0, TN:436, FP:2, FN:8
# exercise-and-fitness: TP:3, TN:416, FP:2, FN:25
# family-and-children: TP:0, TN:428, FP:0, FN:18
# federal---state-issues: TP:4, TN:433, FP:3, FN:6
# federal-government: TP:7, TN:403, FP:4, FN:32
# food-and-beverage: TP:5, TN:419, FP:6, FN:16
# government-and-politics: TP:1, TN:404, FP:8, FN:33
# health-policy: TP:5, TN:419, FP:3, FN:19
# health: TP:52, TN:216, FP:85, FN:93
# healthcare-facilities: TP:1, TN:425, FP:5, FN:15
# heart-disease: TP:0, TN:433, FP:1, FN:12
# indigenous-aboriginal-and-torres-strait-islander: TP:1, TN:429, FP:5, FN:11
# industry: TP:0, TN:433, FP:3, FN:10
# lifestyle-and-leisure: TP:0, TN:436, FP:1, FN:9
# medical-research: TP:6, TN:392, FP:9, FN:39
# nsw: TP:2, TN:411, FP:2, FN:31
# obesity: TP:153, TN:151, FP:67, FN:75
# qld: TP:2, TN:425, FP:3, FN:16
# research: TP:3, TN:401, FP:12, FN:30
# sa: TP:1, TN:424, FP:4, FN:17
# schools: TP:2, TN:424, FP:3, FN:17
# science-and-technology: TP:0, TN:429, FP:4, FN:13
# smoking: TP:0, TN:435, FP:3, FN:8
# states-and-territories: TP:6, TN:399, FP:3, FN:38
# tas: TP:0, TN:434, FP:0, FN:12
# united-kingdom: TP:2, TN:422, FP:8, FN:14
# united-states: TP:26, TN:389, FP:7, FN:24
# vic: TP:1, TN:428, FP:1, FN:16
# wa: TP:1, TN:424, FP:2, FN:19
# --- Performance ---
# coverage_error = 15.79 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.16
# hamming_loss = 0.08
# f1_macro = 0.16
# f1_micro = 0.35
# Jaccard_Index = 0.92
# zero_one_error = 0.94
#
# - f1 for each label -
# label_act = 0.0
# label_advertising = 0.38
# label_advertising-and-marketing = 0.14
# label_australia = 0.55
# label_business-economics-and-finance = 0.0
# label_cancer = 0.24
# label_child-health-and-behaviour = 0.03
# label_children = 0.14
# label_community-and-society = 0.0
# label_diabetes = 0.11
# label_diet-and-nutrition = 0.03
# label_diseases-and-disorders = 0.0
# label_doctors-and-medical-professionals = 0.0
# label_education = 0.0
# label_exercise-and-fitness = 0.18
# label_family-and-children = 0.0
# label_federal---state-issues = 0.47
# label_federal-government = 0.28
# label_food-and-beverage = 0.31
# label_government-and-politics = 0.05
# label_health = 0.31
# label_health-policy = 0.37
# label_healthcare-facilities = 0.09
# label_heart-disease = 0.0
# label_indigenous-aboriginal-and-torres-strait-islander = 0.11
# label_industry = 0.0
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.2
# label_nsw = 0.11
# label_obesity = 0.68
# label_qld = 0.17
# label_research = 0.13
# label_sa = 0.09
# label_schools = 0.17
# label_science-and-technology = 0.0
# label_smoking = 0.0
# label_states-and-territories = 0.23
# label_tas = 0.0
# label_united-kingdom = 0.15
# label_united-states = 0.63
# label_vic = 0.11
# label_wa = 0.09
# /Users/jiangjunhao/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# obesity
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

# get arff files
savePath = "/Users/jiangjunhao/Desktop/test/"
get_arff(data,label,savePath)

dataPath = "/Users/jiangjunhao/Desktop/test/"
resultFile = 'obesity_k2_e20_i5000'
k = '2'
i = '5000'
l = '2'
e = '20'

run_eskdb(dataPath, resultFile, k, l, e, i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-162-5d87123a1b3f> in <module>()
#       7 # get arff files
#       8 savePath = "/Users/jiangjunhao/Desktop/test/"
# ----> 9 get_arff(data,label,savePath)
#      10
#      11 dataPath = "/Users/jiangjunhao/Desktop/test/"
#
# <ipython-input-161-63665e9e70b5> in get_arff(word_occurrence, label_matrix, savePath)
#      19            'data': data,
#      20         }
# ---> 21         arff_data = arff.dumps(obj)
#      22         w_file = open(savePath+label_matrix.columns[z]+".arff", "w")
#      23         w_file.write(arff_data)
#
# ~/anaconda3/lib/python3.6/site-packages/arff.py in dumps(obj)
#    1056     '''
#    1057     encoder = ArffEncoder()
# -> 1058     return encoder.encode(obj)
#    1059 # =============================================================================
#
# ~/anaconda3/lib/python3.6/site-packages/arff.py in encode(self, obj)
#     930         :return: the ARFF file as an unicode string.
#     931         '''
# --> 932         data = [row for row in self.iter_encode(obj)]
#     933
#     934         return u'\n'.join(data)
#
# ~/anaconda3/lib/python3.6/site-packages/arff.py in <listcomp>(.0)
#     930         :return: the ARFF file as an unicode string.
#     931         '''
# --> 932         data = [row for row in self.iter_encode(obj)]
#     933
#     934         return u'\n'.join(data)
#
# ~/anaconda3/lib/python3.6/site-packages/arff.py in iter_encode(self, obj)
#     991         if 'data' in obj:
#     992             data = _get_data_object_for_encoding(obj.get('data'))
# --> 993             for line in data.encode_data(obj.get('data'), attributes):
#     994                 yield line
#     995
#
# ~/anaconda3/lib/python3.6/site-packages/arff.py in encode_data(self, data, attributes)
#     479                     s = '?'
#     480                 else:
# --> 481                     s = encode_string(unicode(value))
#     482                 new_data.append(s)
#     483
#
# KeyboardInterrupt:

# %%
resultPath = '/Volumes/Samsung_T5/research/programme/ESKDB_HDP/result/obesity_k2_e20_i5000/'
y_pred,y_true,y_prob,index = get_result(resultPath)

performance = evaluation(y_pred=y_pred, y_true=y_true, y_prob=y_prob)

# get confusion mbatrix
print("\n--- Confusion matrix ---")
get_confusion_matrix(y_pred, y_true, y_true.columns)
    
# print performance
print("--- Performance ---")
for key, value in performance.items():
    if key == "f1_each_label":
        print("\n- f1 for each label -")
        for i in range(n_label):
            print("label_"+label.columns[i],"=",round(value[i],2))
    elif key == "coverage_error":
        print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
    else:
        print(key,'=',round(value,2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-0f76ec290458> in <module>()
#       1 resultPath = '/Volumes/Samsung_T5/research/programme/ESKDB_HDP/result/obesity_k2_e20_i5000/'
# ----> 2 y_pred,y_true,y_prob,index = get_result(resultPath)
#       3
#       4 performance = evaluation(y_pred=y_pred, y_true=y_true, y_prob=y_prob)
#       5
#
# <ipython-input-5-f5c47c5ff113> in get_result(resultPath)
#      73                 y_true = pd.concat([y_true,pd.DataFrame(true)],axis=1)
#      74                 y_prob = pd.concat([y_prob,pd.DataFrame(prob)],axis=1)
# ---> 75     y_pred.columns = names
#      76     y_true.columns = names
#      77     y_pred.index = index
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
#     560         self._clear_item_cache()
#     561
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    3072             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    3073                              'new values have %d elements' %
# -> 3074                              (old_len, new_len))
#    3075
#    3076         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 42 elements, new values have 43 elements

# %% [markdown]
# ## analysis

# %%
print("--- number of positive instances in test data set ---")
print(y_test.sum())

print("--- number of positive instances in training data set ---")
print(y_train.sum())
# Out:
# --- number of positive instances in test data set ---
# act                                                   8
# advertising                                          11
# advertising-and-marketing                            13
# australia                                           176
# business-economics-and-finance                       13
# cancer                                               14
# child-health-and-behaviour                           58
# children                                             37
# community-and-society                                27
# diabetes                                             30
# diet-and-nutrition                                   55
# diseases-and-disorders                               34
# doctors-and-medical-professionals                    24
# education                                             8
# exercise-and-fitness                                 28
# family-and-children                                  18
# federal---state-issues                               10
# federal-government                                   39
# food-and-beverage                                    21
# government-and-politics                              34
# health                                              145
# health-policy                                        24
# healthcare-facilities                                16
# heart-disease                                        12
# indigenous-aboriginal-and-torres-strait-islander     12
# industry                                             10
# lifestyle-and-leisure                                 9
# medical-research                                     45
# nsw                                                  33
# obesity                                             228
# qld                                                  18
# research                                             33
# sa                                                   18
# schools                                              19
# science-and-technology                               13
# smoking                                               8
# states-and-territories                               44
# tas                                                  12
# united-kingdom                                       16
# united-states                                        50
# vic                                                  17
# wa                                                   20
# dtype: int64
# --- number of positive instances in training data set ---
# act                                                  18
# advertising                                          12
# advertising-and-marketing                            14
# australia                                           166
# business-economics-and-finance                       18
# cancer                                                7
# child-health-and-behaviour                           39
# children                                             22
# community-and-society                                28
# diabetes                                             27
# diet-and-nutrition                                   64
# diseases-and-disorders                               33
# doctors-and-medical-professionals                    24
# education                                            10
# exercise-and-fitness                                 24
# family-and-children                                  13
# federal---state-issues                               13
# federal-government                                   37
# food-and-beverage                                    20
# government-and-politics                              34
# health                                              154
# health-policy                                        18
# healthcare-facilities                                17
# heart-disease                                        12
# indigenous-aboriginal-and-torres-strait-islander     13
# industry                                              9
# lifestyle-and-leisure                                12
# medical-research                                     41
# nsw                                                  35
# obesity                                             216
# qld                                                  31
# research                                             23
# sa                                                   21
# schools                                              13
# science-and-technology                               10
# smoking                                              14
# states-and-territories                               42
# tas                                                  13
# united-kingdom                                       22
# united-states                                        48
# vic                                                  24
# wa                                                   23
# dtype: int64

# %% [markdown]
# ``
# --- Performance of BR-NB ---
# coverage_error = 14.29 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.14
# hamming_loss = 0.1
# f1_macro = 0.26
# f1_micro = 0.39
# Jaccard_Index = 0.9
# zero_one_error = 0.98
# ``
#
# ``
# --- Performance of BR-ESKDB --- I=5000, E=20, K=5
# coverage_error = 14.69 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.15
# hamming_loss = 0.08
# f1_macro = 0.17
# f1_micro = 0.33
# Jaccard_Index = 0.92
# zero_one_error = 0.95
# ``

# %% [markdown]
# - There is a non-balanced data problem that when the number of positive instance for a label is small, the f1 score of this label is very low. It makes the F1-macro(averageg by the number of labels) low. It also appears in other text data set like medical and enron
# ![title](img/1.png)
#
# - The memory used depends on the number of attributes, there are 1449 attributes in dataset `Medical` and it can run on my desktop.
#
# - there's a problem that when spliting the data set into training and test, there is no positive instance for some label in training set or testing set, and therefore, ESKDB does not work on that label.

# %% [markdown]
# # Classifier Chain
#
# ## CC using naive Bayes

# %%
def naiveBayes_multi_label_training(X_train, y_train):
    start = time.time()
    
    n_label = y_train.shape[1]
    
    order = random.sample(list(range(n_label)),n_label) # get orders
    
    classifier_list = [MultinomialNB() for i in range(n_label)] # create a classifier chain
    
    for i in range(n_label):
        if i == 0:
            classifier_list[i].fit(X_train,y_train.iloc[:, order[i]])
        else:
            X_train = pd.concat([X_train, y_train.iloc[:,order[i-1]]],axis=1) # put the previous label into attribute space
            classifier_list[i].fit(X_train,y_train.iloc[:,order[i]])

    end = time.time()
    training_time = end-start
    
    return classifier_list, training_time, order

def naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order):
    y_predict = pd.DataFrame(index=X_test.index)
    y_prob = pd.DataFrame(index=X_test.index)
    y_true = pd.DataFrame(index=X_test.index)
    
    start = time.time()
    
    for i in range(n_label):
        y_predict_i = classifier_list[i].predict(X_test)
        y_predict = pd.concat([y_predict, pd.DataFrame(y_predict_i,index=X_test.index)],axis=1)

        y_predict_prob_i = classifier_list[i].predict_proba(X_test)[:,1]
        y_prob = pd.concat([y_prob, pd.DataFrame(y_predict_prob_i,index=X_test.index)],axis=1)

        X_test = pd.concat([X_test, pd.DataFrame(y_predict_i,index=X_test.index)],axis=1,ignore_index=True) # put the previous label into attribute space

    end = time.time()
    testing_time = end-start
        
    return y_predict, y_prob, testing_time

def CC_test(data, label, dataPath, random_state=3071980):
    
    # data set information
    n_label = label.shape[1]
    n_attr = data.shape[1]
    n_instance = data.shape[0]
    avg_label_per_instance = label.sum(axis=1).mean()
    
    # split training and test data set
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=random_state)
    
    # training
    print("--- start training ---\n")
    classifier_list, training_time, order = naiveBayes_multi_label_training(X_train, y_train)
    
    # testing
    print("--- start testing ---\n")
    y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order)
    
    # evaluation
    y_test = y_test.iloc[:,order]
    performance = evaluation(y_predict, y_prob, y_test)
    
    # print data information
    print("--- Data Information ---")
    print("dataset:", dataPath)
    print("number of label:",n_label)
    print("number of attribute:",n_attr)
    print("number of instance:",n_instance,"\n")
    
    # print orders
    print("\n--- Order of the chain ---")
    print(label.columns[order])
    print("")
    
    # print performance
    print("--- Performance ---")
    for key, value in performance.items():
        if key == "f1_each_label":
            print("\n- f1 for each label -")
            for i in range(n_label):
                print("label_"+label.columns[i],"=",round(value[i],2))
        elif key == "coverage_error":
            print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
        else:
            print(key,'=',round(value,2))
            
def ECC_test(data, label, dataPath, random_state=3071980, ensemble = 5):
    
    # data set information
    n_label = label.shape[1]
    n_attr = data.shape[1]
    n_instance = data.shape[0]
    avg_label_per_instance = label.sum(axis=1).mean()
    
    # split training and test data set
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.5, random_state=random_state)
    
    # ensemble
    y_pred_ensemble = pd.DataFrame(np.zeros(y_test.shape),columns=y_test.columns, index=y_test.index)
    y_prob_ensemble = pd.DataFrame(np.zeros(y_test.shape),columns=y_test.columns, index=y_test.index)
    for i in range(ensemble):
        # training
        #print("--- start training ---\n")
        classifier_list, training_time, order = naiveBayes_multi_label_training(X_train, y_train)

        # print orders
        print("Order of the chain:",label.columns[order])

        # testing
        #print("--- start testing ---\n")
        y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order)

        y_predict.columns = label.columns[order]
        y_prob.columns = label.columns[order]
        y_predict = y_predict[label.columns]
        y_prob = y_prob[label.columns]

        y_pred_ensemble = y_pred_ensemble + y_predict
        y_prob_ensemble = y_prob_ensemble + y_prob

    y_pred_ensemble = (((y_pred_ensemble / ensemble) >= 0.5)*1).astype('int')
    y_prob_ensemble = y_prob_ensemble / ensemble 
    
    # evaluation
    performance = evaluation(y_pred_ensemble, y_prob_ensemble, y_test)
    
    # print data information
    print("--- Data Information ---")
    print("dataset:", dataPath)
    print("number of label:",n_label)
    print("number of attribute:",n_attr)
    print("number of instance:",n_instance,"\n")
    
    # print orders
    print("\n--- Order of the chain ---")
    print(label.columns[order])
    print("")
    
    # print performance
    print("--- Performance ---")
    for key, value in performance.items():
        if key == "f1_each_label":
            print("\n- f1 for each label -")
            for i in range(n_label):
                print("label_"+label.columns[i],"=",round(value[i],2))
        elif key == "coverage_error":
            print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
        else:
            print(key,'=',round(value,2))

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

# train - test
print("------ Binary Relevance using Naive Bayes ------")
ECC_test(data, label, dataPath, 3071980, 1)
# Out:
# ------ Binary Relevance using Naive Bayes ------
# Order of the chain: Index(['community-and-society', 'nsw', 'qld', 'education',
#        'diseases-and-disorders', 'exercise-and-fitness', 'act', 'australia',
#        'wa', 'doctors-and-medical-professionals',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'states-and-territories', 'lifestyle-and-leisure',
#        'advertising-and-marketing', 'healthcare-facilities',
#        'government-and-politics', 'family-and-children', 'sa', 'health',
#        'federal-government', 'health-policy', 'diabetes', 'obesity', 'cancer',
#        'advertising', 'schools', 'federal---state-issues', 'research',
#        'smoking', 'united-states', 'children', 'united-kingdom',
#        'science-and-technology', 'industry', 'vic',
#        'business-economics-and-finance', 'medical-research',
#        'child-health-and-behaviour', 'tas', 'heart-disease',
#        'food-and-beverage', 'diet-and-nutrition'],
#       dtype='object')
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
#
# --- Order of the chain ---
# Index(['community-and-society', 'nsw', 'qld', 'education',
#        'diseases-and-disorders', 'exercise-and-fitness', 'act', 'australia',
#        'wa', 'doctors-and-medical-professionals',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'states-and-territories', 'lifestyle-and-leisure',
#        'advertising-and-marketing', 'healthcare-facilities',
#        'government-and-politics', 'family-and-children', 'sa', 'health',
#        'federal-government', 'health-policy', 'diabetes', 'obesity', 'cancer',
#        'advertising', 'schools', 'federal---state-issues', 'research',
#        'smoking', 'united-states', 'children', 'united-kingdom',
#        'science-and-technology', 'industry', 'vic',
#        'business-economics-and-finance', 'medical-research',
#        'child-health-and-behaviour', 'tas', 'heart-disease',
#        'food-and-beverage', 'diet-and-nutrition'],
#       dtype='object')
#
# --- Performance ---
# coverage_error = 13.8 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.13
# hamming_loss = 0.11
# f1_macro = 0.26
# f1_micro = 0.38
# Jaccard_Index = 0.89
# zero_one_error = 0.97
#
# - f1 for each label -
# label_act = 0.0
# label_advertising = 0.35
# label_advertising-and-marketing = 0.37
# label_australia = 0.55
# label_business-economics-and-finance = 0.26
# label_cancer = 0.36
# label_child-health-and-behaviour = 0.3
# label_children = 0.18
# label_community-and-society = 0.09
# label_diabetes = 0.45
# label_diet-and-nutrition = 0.24
# label_diseases-and-disorders = 0.21
# label_doctors-and-medical-professionals = 0.26
# label_education = 0.11
# label_exercise-and-fitness = 0.15
# label_family-and-children = 0.14
# label_federal---state-issues = 0.24
# label_federal-government = 0.43
# label_food-and-beverage = 0.3
# label_government-and-politics = 0.25
# label_health = 0.41
# label_health-policy = 0.39
# label_healthcare-facilities = 0.26
# label_heart-disease = 0.1
# label_indigenous-aboriginal-and-torres-strait-islander = 0.16
# label_industry = 0.15
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.38
# label_nsw = 0.3
# label_obesity = 0.72
# label_qld = 0.31
# label_research = 0.37
# label_sa = 0.07
# label_schools = 0.38
# label_science-and-technology = 0.06
# label_smoking = 0.13
# label_states-and-territories = 0.39
# label_tas = 0.06
# label_united-kingdom = 0.19
# label_united-states = 0.55
# label_vic = 0.2
# label_wa = 0.11

# %%
# data set information
n_label = label.shape[1]
n_attr = data.shape[1]
n_instance = data.shape[0]
avg_label_per_instance = label.sum(axis=1).mean()

# split training and test data set
# X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.5, random_state=random_state)

X_train = data[data.index.isin(index)==False]
X_test = data[data.index.isin(index)==True]
y_train = label[label.index.isin(index)==False]
y_test = label[label.index.isin(index)==True]

print("-- test index --")
print(X_test.index)

# training
print("--- start training ---\n")
classifier_list, training_time, order = naiveBayes_multi_label_training(X_train, y_train)

# testing
print("--- start testing ---\n")
y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order)

# evaluation
y_test = y_test.iloc[:,order]
performance = evaluation(y_predict, y_prob, y_test)

# print data information
print("--- Data Information ---")
print("dataset:", dataPath)
print("number of label:",n_label)
print("number of attribute:",n_attr)
print("number of instance:",n_instance,"\n")

# print orders
print("\n--- Order of the chain ---")
print(label.columns[order])
print("")


# print performance
print("--- Performance ---")
for key, value in performance.items():
    if key == "f1_each_label":
        print("\n- f1 for each label -")
        for i in range(n_label):
            print("label_"+label.columns[i],"=",round(value[i],2))
    elif key == "coverage_error":
        print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
    else:
        print(key,'=',round(value,2))
# Out:
# -- test index --
# Int64Index([  4,   5,   7,   8,  15,  16,  17,  21,  23,  24,
#             ...
#             876, 878, 879, 880, 881, 882, 884, 888, 889, 890],
#            dtype='int64', length=446)
# --- start training ---
#
# --- start testing ---
#
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
#
# --- Order of the chain ---
# Index(['research', 'cancer', 'advertising', 'act', 'food-and-beverage', 'qld',
#        'vic', 'tas', 'family-and-children', 'heart-disease',
#        'federal---state-issues', 'children', 'diseases-and-disorders',
#        'diabetes', 'smoking', 'wa', 'government-and-politics', 'nsw',
#        'industry', 'education', 'united-kingdom', 'healthcare-facilities',
#        'doctors-and-medical-professionals', 'united-states',
#        'business-economics-and-finance', 'schools', 'medical-research',
#        'community-and-society', 'health-policy', 'federal-government',
#        'exercise-and-fitness', 'advertising-and-marketing',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'diet-and-nutrition', 'obesity',
#        'child-health-and-behaviour', 'science-and-technology', 'sa',
#        'states-and-territories', 'health', 'australia'],
#       dtype='object')
#
# --- Performance ---
# coverage_error = 14.34 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.15
# hamming_loss = 0.11
# f1_macro = 0.25
# f1_micro = 0.38
# Jaccard_Index = 0.89
# zero_one_error = 0.98
#
# - f1 for each label -
# label_act = 0.43
# label_advertising = 0.27
# label_advertising-and-marketing = 0.39
# label_australia = 0.08
# label_business-economics-and-finance = 0.28
# label_cancer = 0.29
# label_child-health-and-behaviour = 0.12
# label_children = 0.0
# label_community-and-society = 0.06
# label_diabetes = 0.19
# label_diet-and-nutrition = 0.33
# label_diseases-and-disorders = 0.22
# label_doctors-and-medical-professionals = 0.21
# label_education = 0.27
# label_exercise-and-fitness = 0.11
# label_family-and-children = 0.06
# label_federal---state-issues = 0.2
# label_federal-government = 0.15
# label_food-and-beverage = 0.2
# label_government-and-politics = 0.1
# label_health = 0.28
# label_health-policy = 0.24
# label_healthcare-facilities = 0.24
# label_heart-disease = 0.57
# label_indigenous-aboriginal-and-torres-strait-islander = 0.19
# label_industry = 0.36
# label_lifestyle-and-leisure = 0.44
# label_medical-research = 0.09
# label_nsw = 0.33
# label_obesity = 0.37
# label_qld = 0.22
# label_research = 0.35
# label_sa = 0.16
# label_schools = 0.0
# label_science-and-technology = 0.25
# label_smoking = 0.7
# label_states-and-territories = 0.31
# label_tas = 0.18
# label_united-kingdom = 0.15
# label_united-states = 0.26
# label_vic = 0.38
# label_wa = 0.61

# %% [markdown]
# ## Ensemble CC using naive Bayes (E = 10)

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

# train - test
print("------ Binary Relevance using Naive Bayes ------")
ECC_test(data, label, dataPath, random_state=3071980, ensemble=10)
# Out:
# ------ Binary Relevance using Naive Bayes ------
# Order of the chain: Index(['sa', 'doctors-and-medical-professionals', 'exercise-and-fitness',
#        'child-health-and-behaviour', 'federal-government', 'advertising',
#        'industry', 'medical-research', 'smoking', 'nsw', 'vic',
#        'diseases-and-disorders', 'cancer', 'diet-and-nutrition',
#        'states-and-territories', 'united-states', 'food-and-beverage', 'qld',
#        'government-and-politics', 'australia', 'federal---state-issues',
#        'united-kingdom', 'research', 'tas', 'schools', 'heart-disease',
#        'education', 'advertising-and-marketing', 'children', 'wa',
#        'lifestyle-and-leisure', 'health', 'health-policy',
#        'science-and-technology',
#        'indigenous-aboriginal-and-torres-strait-islander', 'diabetes',
#        'family-and-children', 'community-and-society', 'act',
#        'healthcare-facilities', 'business-economics-and-finance', 'obesity'],
#       dtype='object')
# Order of the chain: Index(['diet-and-nutrition', 'healthcare-facilities', 'obesity', 'act',
#        'smoking', 'indigenous-aboriginal-and-torres-strait-islander',
#        'advertising-and-marketing', 'health-policy', 'food-and-beverage',
#        'community-and-society', 'diabetes', 'industry', 'health', 'tas',
#        'education', 'exercise-and-fitness', 'lifestyle-and-leisure',
#        'family-and-children', 'children', 'united-states', 'cancer',
#        'federal-government', 'schools', 'heart-disease',
#        'doctors-and-medical-professionals', 'science-and-technology',
#        'australia', 'medical-research', 'advertising',
#        'business-economics-and-finance', 'wa', 'research', 'qld', 'vic',
#        'child-health-and-behaviour', 'united-kingdom',
#        'states-and-territories', 'nsw', 'government-and-politics', 'sa',
#        'federal---state-issues', 'diseases-and-disorders'],
#       dtype='object')
# Order of the chain: Index(['medical-research', 'healthcare-facilities', 'federal-government',
#        'smoking', 'family-and-children', 'united-kingdom', 'qld', 'education',
#        'act', 'heart-disease', 'tas', 'advertising-and-marketing', 'schools',
#        'diet-and-nutrition', 'wa', 'cancer', 'australia',
#        'federal---state-issues', 'community-and-society',
#        'science-and-technology', 'government-and-politics', 'sa', 'health',
#        'obesity', 'diabetes', 'diseases-and-disorders',
#        'business-economics-and-finance', 'exercise-and-fitness', 'research',
#        'doctors-and-medical-professionals', 'food-and-beverage', 'advertising',
#        'child-health-and-behaviour',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'states-and-territories', 'vic', 'lifestyle-and-leisure', 'industry',
#        'nsw', 'united-states', 'health-policy', 'children'],
#       dtype='object')
# Order of the chain: Index(['diseases-and-disorders', 'child-health-and-behaviour', 'education',
#        'federal---state-issues', 'healthcare-facilities', 'united-states',
#        'government-and-politics', 'cancer', 'act', 'exercise-and-fitness',
#        'diet-and-nutrition', 'sa', 'diabetes',
#        'business-economics-and-finance', 'vic', 'advertising', 'qld',
#        'children', 'united-kingdom', 'nsw', 'industry', 'research', 'wa',
#        'tas', 'heart-disease', 'states-and-territories',
#        'community-and-society', 'schools', 'food-and-beverage',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'advertising-and-marketing',
#        'science-and-technology', 'health-policy',
#        'doctors-and-medical-professionals', 'obesity', 'smoking',
#        'lifestyle-and-leisure', 'australia', 'health', 'medical-research',
#        'federal-government'],
#       dtype='object')
# Order of the chain: Index(['healthcare-facilities', 'exercise-and-fitness', 'smoking',
#        'business-economics-and-finance', 'community-and-society', 'nsw',
#        'diseases-and-disorders', 'diabetes', 'education', 'children',
#        'industry', 'schools', 'united-kingdom', 'advertising', 'qld',
#        'research', 'act', 'federal---state-issues', 'diet-and-nutrition',
#        'family-and-children', 'wa', 'sa', 'health-policy', 'food-and-beverage',
#        'science-and-technology', 'lifestyle-and-leisure',
#        'states-and-territories', 'child-health-and-behaviour', 'vic', 'health',
#        'federal-government', 'australia', 'government-and-politics',
#        'united-states', 'indigenous-aboriginal-and-torres-strait-islander',
#        'tas', 'cancer', 'medical-research', 'advertising-and-marketing',
#        'obesity', 'heart-disease', 'doctors-and-medical-professionals'],
#       dtype='object')
# Order of the chain: Index(['australia', 'united-states', 'lifestyle-and-leisure', 'united-kingdom',
#        'exercise-and-fitness', 'medical-research',
#        'doctors-and-medical-professionals', 'business-economics-and-finance',
#        'health-policy', 'government-and-politics',
#        'indigenous-aboriginal-and-torres-strait-islander', 'sa', 'cancer',
#        'states-and-territories', 'federal-government', 'community-and-society',
#        'federal---state-issues', 'nsw', 'family-and-children', 'advertising',
#        'tas', 'qld', 'wa', 'science-and-technology', 'industry',
#        'diet-and-nutrition', 'vic', 'children', 'heart-disease',
#        'child-health-and-behaviour', 'research', 'healthcare-facilities',
#        'diabetes', 'education', 'schools', 'smoking', 'obesity',
#        'food-and-beverage', 'health', 'advertising-and-marketing',
#        'diseases-and-disorders', 'act'],
#       dtype='object')
# Order of the chain: Index(['sa', 'schools', 'education', 'industry', 'food-and-beverage',
#        'research', 'advertising', 'obesity', 'diseases-and-disorders',
#        'diabetes', 'federal-government', 'nsw', 'lifestyle-and-leisure',
#        'science-and-technology', 'child-health-and-behaviour', 'vic',
#        'heart-disease', 'family-and-children',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'federal---state-issues', 'australia', 'healthcare-facilities',
#        'exercise-and-fitness', 'united-states', 'qld', 'smoking', 'health',
#        'community-and-society', 'advertising-and-marketing',
#        'doctors-and-medical-professionals', 'act', 'states-and-territories',
#        'diet-and-nutrition', 'government-and-politics', 'united-kingdom',
#        'tas', 'children', 'cancer', 'medical-research', 'health-policy', 'wa',
#        'business-economics-and-finance'],
#       dtype='object')
# Order of the chain: Index(['united-states', 'health-policy', 'diet-and-nutrition',
#        'family-and-children', 'cancer', 'diseases-and-disorders',
#        'exercise-and-fitness', 'food-and-beverage', 'medical-research',
#        'industry', 'schools', 'diabetes', 'united-kingdom', 'sa',
#        'doctors-and-medical-professionals', 'federal-government',
#        'science-and-technology', 'nsw', 'wa', 'obesity',
#        'healthcare-facilities', 'qld', 'advertising-and-marketing', 'children',
#        'business-economics-and-finance', 'child-health-and-behaviour',
#        'advertising', 'vic', 'tas',
#        'indigenous-aboriginal-and-torres-strait-islander', 'health',
#        'australia', 'smoking', 'heart-disease', 'act', 'education',
#        'lifestyle-and-leisure', 'research', 'government-and-politics',
#        'states-and-territories', 'community-and-society',
#        'federal---state-issues'],
#       dtype='object')
# Order of the chain: Index(['sa', 'united-states', 'health', 'food-and-beverage', 'wa',
#        'diet-and-nutrition', 'act', 'nsw', 'medical-research', 'children',
#        'tas', 'federal---state-issues', 'smoking', 'advertising-and-marketing',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'business-economics-and-finance', 'health-policy', 'education',
#        'government-and-politics', 'united-kingdom', 'research', 'industry',
#        'obesity', 'australia', 'federal-government', 'schools',
#        'heart-disease', 'qld', 'vic', 'lifestyle-and-leisure',
#        'child-health-and-behaviour', 'family-and-children',
#        'doctors-and-medical-professionals', 'science-and-technology',
#        'healthcare-facilities', 'exercise-and-fitness', 'advertising',
#        'diseases-and-disorders', 'diabetes', 'states-and-territories',
#        'community-and-society', 'cancer'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'diabetes', 'education', 'research',
#        'healthcare-facilities', 'sa',
#        'indigenous-aboriginal-and-torres-strait-islander', 'heart-disease',
#        'child-health-and-behaviour', 'doctors-and-medical-professionals',
#        'cancer', 'act', 'australia', 'tas', 'nsw',
#        'business-economics-and-finance', 'wa', 'states-and-territories',
#        'federal-government', 'science-and-technology',
#        'government-and-politics', 'lifestyle-and-leisure',
#        'community-and-society', 'united-states', 'exercise-and-fitness',
#        'smoking', 'food-and-beverage', 'schools', 'medical-research', 'health',
#        'advertising-and-marketing', 'advertising', 'industry', 'obesity',
#        'vic', 'diseases-and-disorders', 'united-kingdom',
#        'family-and-children', 'health-policy', 'qld', 'diet-and-nutrition',
#        'children'],
#       dtype='object')
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
#
# --- Order of the chain ---
# Index(['federal---state-issues', 'diabetes', 'education', 'research',
#        'healthcare-facilities', 'sa',
#        'indigenous-aboriginal-and-torres-strait-islander', 'heart-disease',
#        'child-health-and-behaviour', 'doctors-and-medical-professionals',
#        'cancer', 'act', 'australia', 'tas', 'nsw',
#        'business-economics-and-finance', 'wa', 'states-and-territories',
#        'federal-government', 'science-and-technology',
#        'government-and-politics', 'lifestyle-and-leisure',
#        'community-and-society', 'united-states', 'exercise-and-fitness',
#        'smoking', 'food-and-beverage', 'schools', 'medical-research', 'health',
#        'advertising-and-marketing', 'advertising', 'industry', 'obesity',
#        'vic', 'diseases-and-disorders', 'united-kingdom',
#        'family-and-children', 'health-policy', 'qld', 'diet-and-nutrition',
#        'children'],
#       dtype='object')
#
# --- Performance ---
# coverage_error = 13.64 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.13
# hamming_loss = 0.11
# f1_macro = 0.27
# f1_micro = 0.39
# Jaccard_Index = 0.89
# zero_one_error = 0.97
#
# - f1 for each label -
# label_act = 0.0
# label_advertising = 0.43
# label_advertising-and-marketing = 0.31
# label_australia = 0.57
# label_business-economics-and-finance = 0.36
# label_cancer = 0.4
# label_child-health-and-behaviour = 0.31
# label_children = 0.22
# label_community-and-society = 0.08
# label_diabetes = 0.44
# label_diet-and-nutrition = 0.25
# label_diseases-and-disorders = 0.19
# label_doctors-and-medical-professionals = 0.33
# label_education = 0.11
# label_exercise-and-fitness = 0.14
# label_family-and-children = 0.09
# label_federal---state-issues = 0.27
# label_federal-government = 0.46
# label_food-and-beverage = 0.34
# label_government-and-politics = 0.25
# label_health = 0.43
# label_health-policy = 0.41
# label_healthcare-facilities = 0.2
# label_heart-disease = 0.11
# label_indigenous-aboriginal-and-torres-strait-islander = 0.15
# label_industry = 0.2
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.38
# label_nsw = 0.29
# label_obesity = 0.7
# label_qld = 0.25
# label_research = 0.36
# label_sa = 0.07
# label_schools = 0.36
# label_science-and-technology = 0.11
# label_smoking = 0.17
# label_states-and-territories = 0.32
# label_tas = 0.09
# label_united-kingdom = 0.19
# label_united-states = 0.59
# label_vic = 0.19
# label_wa = 0.12

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

ensemble=10

# data set information
n_label = label.shape[1]
n_attr = data.shape[1]
n_instance = data.shape[0]
avg_label_per_instance = label.sum(axis=1).mean()

X_train = data[data.index.isin(index)==False]
X_test = data[data.index.isin(index)==True]
y_train = label[label.index.isin(index)==False]
y_test = label[label.index.isin(index)==True]

print("-- test index --")
print(X_test.index)

# ensemble
y_pred_ensemble = pd.DataFrame(np.zeros(y_test.shape),columns=y_test.columns, index=y_test.index)
y_prob_ensemble = pd.DataFrame(np.zeros(y_test.shape),columns=y_test.columns, index=y_test.index)
for i in range(ensemble):
    # training
    #print("--- start training ---\n")
    classifier_list, training_time, order = naiveBayes_multi_label_training(X_train, y_train)

    # print orders
    print("Order of the chain:",label.columns[order])

    # testing
    #print("--- start testing ---\n")
    y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order)

    y_predict.columns = label.columns[order]
    y_prob.columns = label.columns[order]
    y_predict = y_predict[label.columns]
    y_prob = y_prob[label.columns]

    y_pred_ensemble = y_pred_ensemble + y_predict
    y_prob_ensemble = y_prob_ensemble + y_prob

y_pred_ensemble = (((y_pred_ensemble / ensemble) >= 0.5)*1).astype('int')
y_prob_ensemble = y_prob_ensemble / ensemble 

# evaluation
performance = evaluation(y_pred_ensemble, y_prob_ensemble, y_test)

# print data information
print("--- Data Information ---")
print("dataset:", dataPath)
print("number of label:",n_label)
print("number of attribute:",n_attr)
print("number of instance:",n_instance,"\n")

# print orders
print("\n--- Order of the chain ---")
print(label.columns[order])
print("")

# get confusion matrix
get_confusion_matrix(y_pred_ensemble, y_test, y_test.columns)

# print performance
print("--- Performance ---")
for key, value in performance.items():
    if key == "f1_each_label":
        print("\n- f1 for each label -")
        for i in range(n_label):
            print("label_"+label.columns[i],"=",round(value[i],2))
    elif key == "coverage_error":
        print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
    else:
        print(key,'=',round(value,2))
# Out:
# -- test index --
# Int64Index([  4,   5,   7,   8,  15,  16,  17,  21,  23,  24,
#             ...
#             876, 878, 879, 880, 881, 882, 884, 888, 889, 890],
#            dtype='int64', length=446)
# Order of the chain: Index(['tas', 'united-kingdom', 'nsw', 'industry', 'united-states',
#        'australia', 'lifestyle-and-leisure', 'smoking',
#        'healthcare-facilities', 'states-and-territories', 'children',
#        'advertising', 'vic', 'research', 'family-and-children',
#        'diseases-and-disorders', 'education', 'diet-and-nutrition',
#        'federal-government', 'advertising-and-marketing',
#        'doctors-and-medical-professionals', 'diabetes', 'obesity', 'wa',
#        'food-and-beverage', 'business-economics-and-finance',
#        'medical-research', 'government-and-politics',
#        'child-health-and-behaviour', 'cancer',
#        'indigenous-aboriginal-and-torres-strait-islander', 'schools',
#        'health-policy', 'health', 'community-and-society', 'sa', 'act',
#        'federal---state-issues', 'heart-disease', 'exercise-and-fitness',
#        'qld', 'science-and-technology'],
#       dtype='object')
# Order of the chain: Index(['advertising-and-marketing', 'diseases-and-disorders', 'tas',
#        'food-and-beverage', 'health-policy', 'business-economics-and-finance',
#        'government-and-politics', 'federal---state-issues',
#        'child-health-and-behaviour', 'exercise-and-fitness',
#        'medical-research', 'wa', 'united-states', 'nsw',
#        'states-and-territories', 'diabetes', 'advertising', 'united-kingdom',
#        'industry', 'health', 'obesity', 'cancer', 'lifestyle-and-leisure',
#        'schools', 'qld', 'diet-and-nutrition', 'vic', 'australia', 'smoking',
#        'science-and-technology', 'heart-disease', 'research', 'children',
#        'education', 'act', 'family-and-children', 'federal-government',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'healthcare-facilities', 'sa', 'community-and-society',
#        'doctors-and-medical-professionals'],
#       dtype='object')
# Order of the chain: Index(['government-and-politics', 'cancer', 'business-economics-and-finance',
#        'federal---state-issues', 'medical-research', 'vic', 'obesity',
#        'science-and-technology', 'nsw', 'heart-disease',
#        'diseases-and-disorders', 'smoking', 'health', 'federal-government',
#        'advertising-and-marketing', 'advertising', 'states-and-territories',
#        'family-and-children', 'diet-and-nutrition', 'united-states',
#        'healthcare-facilities', 'community-and-society', 'sa', 'industry',
#        'research', 'schools', 'health-policy', 'act', 'united-kingdom',
#        'australia', 'tas', 'exercise-and-fitness', 'education',
#        'doctors-and-medical-professionals', 'child-health-and-behaviour',
#        'children', 'lifestyle-and-leisure', 'qld', 'wa', 'food-and-beverage',
#        'indigenous-aboriginal-and-torres-strait-islander', 'diabetes'],
#       dtype='object')
# Order of the chain: Index(['food-and-beverage', 'child-health-and-behaviour', 'nsw', 'research',
#        'smoking', 'act', 'states-and-territories', 'schools',
#        'healthcare-facilities', 'sa', 'united-states', 'cancer', 'education',
#        'wa', 'doctors-and-medical-professionals', 'qld',
#        'diseases-and-disorders', 'exercise-and-fitness', 'health-policy',
#        'health', 'industry', 'federal-government', 'diabetes', 'heart-disease',
#        'vic', 'obesity', 'diet-and-nutrition',
#        'business-economics-and-finance',
#        'indigenous-aboriginal-and-torres-strait-islander', 'children', 'tas',
#        'community-and-society', 'family-and-children',
#        'science-and-technology', 'united-kingdom', 'government-and-politics',
#        'lifestyle-and-leisure', 'advertising', 'medical-research',
#        'federal---state-issues', 'australia', 'advertising-and-marketing'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'food-and-beverage', 'vic',
#        'government-and-politics',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'doctors-and-medical-professionals', 'obesity', 'cancer', 'education',
#        'diabetes', 'australia', 'heart-disease', 'wa', 'research',
#        'advertising', 'sa', 'tas', 'federal-government', 'smoking',
#        'child-health-and-behaviour', 'family-and-children',
#        'advertising-and-marketing', 'medical-research', 'schools',
#        'lifestyle-and-leisure', 'united-kingdom', 'states-and-territories',
#        'exercise-and-fitness', 'diet-and-nutrition', 'qld', 'children',
#        'community-and-society', 'science-and-technology', 'industry', 'health',
#        'diseases-and-disorders', 'act', 'united-states', 'nsw',
#        'health-policy', 'healthcare-facilities',
#        'business-economics-and-finance'],
#       dtype='object')
# Order of the chain: Index(['healthcare-facilities', 'tas', 'industry', 'heart-disease', 'obesity',
#        'health', 'community-and-society', 'business-economics-and-finance',
#        'federal---state-issues', 'qld', 'food-and-beverage', 'australia',
#        'nsw', 'states-and-territories', 'medical-research', 'smoking',
#        'science-and-technology', 'schools', 'advertising-and-marketing', 'act',
#        'diet-and-nutrition', 'cancer', 'child-health-and-behaviour',
#        'doctors-and-medical-professionals', 'family-and-children',
#        'diseases-and-disorders', 'research', 'children', 'united-kingdom',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'diabetes', 'government-and-politics', 'wa',
#        'advertising', 'education', 'health-policy', 'sa', 'united-states',
#        'federal-government', 'exercise-and-fitness', 'vic'],
#       dtype='object')
# Order of the chain: Index(['wa', 'nsw', 'smoking', 'federal-government', 'federal---state-issues',
#        'government-and-politics', 'medical-research', 'diet-and-nutrition',
#        'states-and-territories', 'schools', 'science-and-technology',
#        'research', 'exercise-and-fitness', 'obesity', 'advertising',
#        'doctors-and-medical-professionals', 'family-and-children', 'sa',
#        'healthcare-facilities', 'australia', 'food-and-beverage',
#        'business-economics-and-finance', 'tas', 'qld', 'health',
#        'indigenous-aboriginal-and-torres-strait-islander', 'heart-disease',
#        'industry', 'community-and-society', 'children',
#        'lifestyle-and-leisure', 'diseases-and-disorders', 'diabetes',
#        'child-health-and-behaviour', 'united-kingdom',
#        'advertising-and-marketing', 'vic', 'cancer', 'united-states', 'act',
#        'health-policy', 'education'],
#       dtype='object')
# Order of the chain: Index(['science-and-technology', 'family-and-children', 'qld',
#        'doctors-and-medical-professionals', 'federal-government',
#        'food-and-beverage', 'research', 'business-economics-and-finance',
#        'medical-research', 'government-and-politics', 'health-policy', 'tas',
#        'heart-disease', 'smoking',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'states-and-territories', 'community-and-society', 'united-kingdom',
#        'exercise-and-fitness', 'education', 'diseases-and-disorders', 'act',
#        'industry', 'obesity', 'lifestyle-and-leisure', 'diet-and-nutrition',
#        'federal---state-issues', 'vic', 'united-states',
#        'healthcare-facilities', 'diabetes', 'schools', 'nsw', 'wa',
#        'child-health-and-behaviour', 'children', 'health', 'australia',
#        'advertising-and-marketing', 'sa', 'cancer', 'advertising'],
#       dtype='object')
# Order of the chain: Index(['health-policy', 'education', 'act', 'research', 'family-and-children',
#        'heart-disease', 'wa', 'doctors-and-medical-professionals',
#        'federal---state-issues', 'government-and-politics',
#        'exercise-and-fitness', 'healthcare-facilities',
#        'states-and-territories', 'lifestyle-and-leisure', 'tas', 'smoking',
#        'diseases-and-disorders', 'children', 'health', 'vic', 'industry',
#        'united-kingdom', 'united-states', 'australia', 'diet-and-nutrition',
#        'federal-government', 'community-and-society',
#        'business-economics-and-finance', 'diabetes', 'qld', 'cancer',
#        'advertising', 'medical-research', 'schools', 'nsw',
#        'advertising-and-marketing', 'food-and-beverage', 'obesity',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'child-health-and-behaviour', 'science-and-technology', 'sa'],
#       dtype='object')
# Order of the chain: Index(['federal-government', 'united-states', 'states-and-territories',
#        'health', 'sa', 'business-economics-and-finance',
#        'indigenous-aboriginal-and-torres-strait-islander', 'education',
#        'food-and-beverage', 'nsw', 'act', 'united-kingdom', 'smoking', 'qld',
#        'healthcare-facilities', 'heart-disease', 'exercise-and-fitness',
#        'diabetes', 'health-policy', 'federal---state-issues',
#        'doctors-and-medical-professionals', 'diseases-and-disorders',
#        'medical-research', 'advertising', 'wa', 'child-health-and-behaviour',
#        'schools', 'government-and-politics', 'obesity', 'family-and-children',
#        'australia', 'children', 'vic', 'tas', 'lifestyle-and-leisure',
#        'industry', 'research', 'diet-and-nutrition', 'community-and-society',
#        'cancer', 'advertising-and-marketing', 'science-and-technology'],
#       dtype='object')
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
#
# --- Order of the chain ---
# Index(['federal-government', 'united-states', 'states-and-territories',
#        'health', 'sa', 'business-economics-and-finance',
#        'indigenous-aboriginal-and-torres-strait-islander', 'education',
#        'food-and-beverage', 'nsw', 'act', 'united-kingdom', 'smoking', 'qld',
#        'healthcare-facilities', 'heart-disease', 'exercise-and-fitness',
#        'diabetes', 'health-policy', 'federal---state-issues',
#        'doctors-and-medical-professionals', 'diseases-and-disorders',
#        'medical-research', 'advertising', 'wa', 'child-health-and-behaviour',
#        'schools', 'government-and-politics', 'obesity', 'family-and-children',
#        'australia', 'children', 'vic', 'tas', 'lifestyle-and-leisure',
#        'industry', 'research', 'diet-and-nutrition', 'community-and-society',
#        'cancer', 'advertising-and-marketing', 'science-and-technology'],
#       dtype='object')
#
# act: TP:1, TN:416, FP:22, FN:7
# advertising: TP:9, TN:412, FP:23, FN:2
# advertising-and-marketing: TP:10, TN:403, FP:30, FN:3
# australia: TP:107, TN:205, FP:65, FN:69
# business-economics-and-finance: TP:6, TN:399, FP:34, FN:7
# cancer: TP:4, TN:423, FP:9, FN:10
# child-health-and-behaviour: TP:26, TN:334, FP:54, FN:32
# children: TP:9, TN:379, FP:30, FN:28
# community-and-society: TP:2, TN:402, FP:17, FN:25
# diabetes: TP:9, TN:381, FP:35, FN:21
# diet-and-nutrition: TP:17, TN:334, FP:57, FN:38
# diseases-and-disorders: TP:9, TN:383, FP:29, FN:25
# doctors-and-medical-professionals: TP:5, TN:411, FP:11, FN:19
# education: TP:1, TN:428, FP:10, FN:7
# exercise-and-fitness: TP:4, TN:404, FP:14, FN:24
# family-and-children: TP:1, TN:414, FP:14, FN:17
# federal---state-issues: TP:5, TN:416, FP:20, FN:5
# federal-government: TP:18, TN:370, FP:37, FN:21
# food-and-beverage: TP:9, TN:389, FP:36, FN:12
# government-and-politics: TP:9, TN:365, FP:47, FN:25
# health: TP:63, TN:210, FP:91, FN:82
# health-policy: TP:9, TN:404, FP:18, FN:15
# healthcare-facilities: TP:4, TN:414, FP:16, FN:12
# heart-disease: TP:3, TN:417, FP:17, FN:9
# indigenous-aboriginal-and-torres-strait-islander: TP:2, TN:424, FP:10, FN:10
# industry: TP:4, TN:405, FP:31, FN:6
# lifestyle-and-leisure: TP:0, TN:436, FP:1, FN:9
# medical-research: TP:28, TN:360, FP:41, FN:17
# nsw: TP:4, TN:397, FP:16, FN:29
# obesity: TP:168, TN:139, FP:79, FN:60
# qld: TP:6, TN:414, FP:14, FN:12
# research: TP:17, TN:380, FP:33, FN:16
# sa: TP:3, TN:404, FP:24, FN:15
# schools: TP:10, TN:408, FP:19, FN:9
# science-and-technology: TP:4, TN:411, FP:22, FN:9
# smoking: TP:1, TN:427, FP:11, FN:7
# states-and-territories: TP:13, TN:349, FP:53, FN:31
# tas: TP:0, TN:429, FP:5, FN:12
# united-kingdom: TP:7, TN:404, FP:26, FN:9
# united-states: TP:36, TN:356, FP:40, FN:14
# vic: TP:3, TN:414, FP:15, FN:14
# wa: TP:1, TN:417, FP:9, FN:19
# --- Performance ---
# coverage_error = 14.2 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.14
# hamming_loss = 0.11
# f1_macro = 0.26
# f1_micro = 0.39
# Jaccard_Index = 0.89
# zero_one_error = 0.98
#
# - f1 for each label -
# label_act = 0.06
# label_advertising = 0.42
# label_advertising-and-marketing = 0.38
# label_australia = 0.61
# label_business-economics-and-finance = 0.23
# label_cancer = 0.3
# label_child-health-and-behaviour = 0.38
# label_children = 0.24
# label_community-and-society = 0.09
# label_diabetes = 0.24
# label_diet-and-nutrition = 0.26
# label_diseases-and-disorders = 0.25
# label_doctors-and-medical-professionals = 0.25
# label_education = 0.11
# label_exercise-and-fitness = 0.17
# label_family-and-children = 0.06
# label_federal---state-issues = 0.29
# label_federal-government = 0.38
# label_food-and-beverage = 0.27
# label_government-and-politics = 0.2
# label_health = 0.42
# label_health-policy = 0.35
# label_healthcare-facilities = 0.22
# label_heart-disease = 0.19
# label_indigenous-aboriginal-and-torres-strait-islander = 0.17
# label_industry = 0.18
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.49
# label_nsw = 0.15
# label_obesity = 0.71
# label_qld = 0.32
# label_research = 0.41
# label_sa = 0.13
# label_schools = 0.42
# label_science-and-technology = 0.21
# label_smoking = 0.1
# label_states-and-territories = 0.24
# label_tas = 0.0
# label_united-kingdom = 0.29
# label_united-states = 0.57
# label_vic = 0.17
# label_wa = 0.07

# %% [markdown]
# ## Ensemble CC using naive Bayes (E = 50)

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

# train - test
print("------ Binary Relevance using Naive Bayes ------")
ECC_test(data, label, dataPath, random_state=3071980, ensemble=50)
# Out:
# ------ Binary Relevance using Naive Bayes ------
# Order of the chain: Index(['indigenous-aboriginal-and-torres-strait-islander',
#        'child-health-and-behaviour', 'research', 'health', 'smoking',
#        'obesity', 'industry', 'exercise-and-fitness',
#        'advertising-and-marketing', 'sa', 'states-and-territories', 'qld',
#        'diseases-and-disorders', 'wa', 'united-states',
#        'business-economics-and-finance', 'federal-government',
#        'doctors-and-medical-professionals', 'united-kingdom', 'diabetes',
#        'medical-research', 'cancer', 'vic', 'government-and-politics',
#        'health-policy', 'nsw', 'heart-disease', 'tas', 'healthcare-facilities',
#        'family-and-children', 'community-and-society', 'advertising',
#        'federal---state-issues', 'food-and-beverage', 'education', 'australia',
#        'schools', 'children', 'science-and-technology', 'act',
#        'diet-and-nutrition', 'lifestyle-and-leisure'],
#       dtype='object')
# Order of the chain: Index(['healthcare-facilities', 'advertising-and-marketing', 'health',
#        'cancer', 'obesity', 'united-states', 'vic',
#        'child-health-and-behaviour', 'diet-and-nutrition', 'wa', 'industry',
#        'advertising', 'science-and-technology', 'food-and-beverage',
#        'research', 'smoking', 'nsw', 'federal---state-issues',
#        'states-and-territories', 'exercise-and-fitness',
#        'indigenous-aboriginal-and-torres-strait-islander', 'act',
#        'family-and-children', 'education', 'heart-disease',
#        'diseases-and-disorders', 'australia', 'qld',
#        'doctors-and-medical-professionals', 'business-economics-and-finance',
#        'health-policy', 'federal-government', 'schools', 'sa', 'tas',
#        'lifestyle-and-leisure', 'community-and-society', 'medical-research',
#        'diabetes', 'children', 'united-kingdom', 'government-and-politics'],
#       dtype='object')
# Order of the chain: Index(['cancer', 'child-health-and-behaviour', 'wa', 'medical-research',
#        'smoking', 'australia', 'sa', 'food-and-beverage', 'schools',
#        'diabetes', 'science-and-technology', 'united-kingdom', 'obesity',
#        'education', 'nsw', 'vic', 'exercise-and-fitness',
#        'doctors-and-medical-professionals', 'community-and-society',
#        'states-and-territories', 'advertising', 'industry',
#        'lifestyle-and-leisure', 'diseases-and-disorders', 'qld', 'act',
#        'healthcare-facilities', 'advertising-and-marketing',
#        'federal-government', 'heart-disease', 'federal---state-issues',
#        'health-policy', 'united-states', 'business-economics-and-finance',
#        'government-and-politics', 'children', 'health', 'tas',
#        'indigenous-aboriginal-and-torres-strait-islander', 'research',
#        'family-and-children', 'diet-and-nutrition'],
#       dtype='object')
# Order of the chain: Index(['obesity', 'united-kingdom', 'science-and-technology', 'research',
#        'doctors-and-medical-professionals', 'diabetes', 'qld', 'tas',
#        'states-and-territories', 'vic', 'advertising-and-marketing',
#        'education', 'child-health-and-behaviour', 'federal-government',
#        'heart-disease', 'diet-and-nutrition', 'australia',
#        'business-economics-and-finance', 'united-states', 'industry',
#        'exercise-and-fitness', 'schools', 'government-and-politics',
#        'community-and-society', 'smoking', 'healthcare-facilities',
#        'federal---state-issues', 'advertising', 'wa', 'children', 'act',
#        'food-and-beverage', 'lifestyle-and-leisure', 'diseases-and-disorders',
#        'sa', 'indigenous-aboriginal-and-torres-strait-islander',
#        'health-policy', 'nsw', 'medical-research', 'cancer',
#        'family-and-children', 'health'],
#       dtype='object')
# Order of the chain: Index(['community-and-society', 'doctors-and-medical-professionals',
#        'united-kingdom', 'united-states', 'child-health-and-behaviour', 'act',
#        'diseases-and-disorders', 'federal-government',
#        'science-and-technology', 'healthcare-facilities', 'sa', 'nsw',
#        'schools', 'australia', 'qld', 'research', 'health-policy',
#        'business-economics-and-finance', 'cancer', 'federal---state-issues',
#        'medical-research', 'diet-and-nutrition',
#        'indigenous-aboriginal-and-torres-strait-islander', 'smoking',
#        'diabetes', 'education', 'states-and-territories',
#        'lifestyle-and-leisure', 'industry', 'family-and-children',
#        'heart-disease', 'food-and-beverage', 'children', 'tas', 'vic',
#        'health', 'government-and-politics', 'wa', 'advertising-and-marketing',
#        'exercise-and-fitness', 'obesity', 'advertising'],
#       dtype='object')
# Order of the chain: Index(['united-states', 'diabetes', 'nsw', 'doctors-and-medical-professionals',
#        'schools', 'exercise-and-fitness', 'industry', 'health',
#        'states-and-territories', 'federal---state-issues',
#        'healthcare-facilities', 'children', 'research',
#        'advertising-and-marketing', 'tas', 'united-kingdom', 'smoking',
#        'cancer', 'heart-disease', 'wa', 'government-and-politics',
#        'lifestyle-and-leisure', 'advertising', 'diseases-and-disorders',
#        'science-and-technology', 'child-health-and-behaviour',
#        'federal-government', 'diet-and-nutrition', 'education', 'australia',
#        'business-economics-and-finance', 'obesity', 'sa', 'health-policy',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'vic', 'act', 'qld', 'medical-research',
#        'food-and-beverage', 'community-and-society'],
#       dtype='object')
# Order of the chain: Index(['research', 'sa', 'wa', 'medical-research', 'united-states',
#        'education', 'health', 'diseases-and-disorders',
#        'indigenous-aboriginal-and-torres-strait-islander', 'qld',
#        'doctors-and-medical-professionals', 'federal-government',
#        'business-economics-and-finance', 'obesity', 'family-and-children',
#        'tas', 'industry', 'states-and-territories',
#        'advertising-and-marketing', 'children', 'diabetes',
#        'food-and-beverage', 'child-health-and-behaviour', 'australia',
#        'diet-and-nutrition', 'federal---state-issues', 'schools', 'cancer',
#        'heart-disease', 'smoking', 'health-policy', 'government-and-politics',
#        'healthcare-facilities', 'advertising', 'community-and-society',
#        'exercise-and-fitness', 'science-and-technology', 'united-kingdom',
#        'vic', 'lifestyle-and-leisure', 'act', 'nsw'],
#       dtype='object')
# Order of the chain: Index(['federal-government', 'schools', 'government-and-politics', 'health',
#        'medical-research', 'exercise-and-fitness', 'industry', 'qld',
#        'family-and-children', 'australia', 'nsw', 'sa', 'diabetes',
#        'diseases-and-disorders', 'heart-disease', 'act',
#        'healthcare-facilities', 'business-economics-and-finance',
#        'food-and-beverage', 'states-and-territories', 'education', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander', 'wa',
#        'lifestyle-and-leisure', 'doctors-and-medical-professionals', 'vic',
#        'united-kingdom', 'community-and-society', 'health-policy', 'smoking',
#        'advertising', 'cancer', 'science-and-technology', 'united-states',
#        'diet-and-nutrition', 'child-health-and-behaviour', 'obesity', 'tas',
#        'research', 'advertising-and-marketing', 'federal---state-issues'],
#       dtype='object')
# Order of the chain: Index(['child-health-and-behaviour', 'government-and-politics',
#        'health-policy', 'family-and-children', 'food-and-beverage', 'industry',
#        'schools', 'medical-research', 'united-states',
#        'federal---state-issues', 'doctors-and-medical-professionals',
#        'children', 'business-economics-and-finance', 'cancer',
#        'diseases-and-disorders', 'wa', 'qld', 'australia',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'exercise-and-fitness', 'vic', 'obesity',
#        'nsw', 'diabetes', 'diet-and-nutrition', 'research', 'sa', 'education',
#        'federal-government', 'smoking', 'healthcare-facilities',
#        'science-and-technology', 'tas', 'advertising', 'health',
#        'united-kingdom', 'advertising-and-marketing', 'heart-disease',
#        'community-and-society', 'states-and-territories', 'act'],
#       dtype='object')
# Order of the chain: Index(['tas', 'research', 'family-and-children', 'states-and-territories',
#        'food-and-beverage', 'medical-research', 'united-states',
#        'federal---state-issues', 'schools', 'diabetes',
#        'business-economics-and-finance', 'children', 'community-and-society',
#        'wa', 'diseases-and-disorders', 'smoking', 'vic',
#        'child-health-and-behaviour', 'health-policy', 'advertising',
#        'diet-and-nutrition', 'federal-government', 'science-and-technology',
#        'sa', 'obesity', 'doctors-and-medical-professionals', 'australia',
#        'united-kingdom', 'indigenous-aboriginal-and-torres-strait-islander',
#        'cancer', 'health', 'industry', 'exercise-and-fitness',
#        'lifestyle-and-leisure', 'advertising-and-marketing', 'qld', 'nsw',
#        'act', 'education', 'government-and-politics', 'heart-disease',
#        'healthcare-facilities'],
#       dtype='object')
# Order of the chain: Index(['advertising', 'schools', 'federal---state-issues', 'food-and-beverage',
#        'vic', 'australia', 'health', 'sa', 'family-and-children', 'education',
#        'wa', 'government-and-politics', 'act', 'medical-research',
#        'heart-disease', 'indigenous-aboriginal-and-torres-strait-islander',
#        'smoking', 'diet-and-nutrition', 'federal-government',
#        'science-and-technology', 'diseases-and-disorders',
#        'advertising-and-marketing', 'business-economics-and-finance',
#        'industry', 'health-policy', 'child-health-and-behaviour', 'qld',
#        'community-and-society', 'united-kingdom', 'children', 'diabetes',
#        'tas', 'lifestyle-and-leisure', 'obesity', 'nsw', 'cancer',
#        'united-states', 'research', 'healthcare-facilities',
#        'exercise-and-fitness', 'doctors-and-medical-professionals',
#        'states-and-territories'],
#       dtype='object')
# Order of the chain: Index(['qld', 'diet-and-nutrition', 'federal-government', 'industry',
#        'children', 'child-health-and-behaviour', 'exercise-and-fitness',
#        'education', 'wa', 'healthcare-facilities', 'food-and-beverage', 'vic',
#        'family-and-children', 'federal---state-issues', 'tas',
#        'medical-research', 'research', 'diseases-and-disorders',
#        'science-and-technology', 'government-and-politics',
#        'states-and-territories', 'lifestyle-and-leisure', 'health', 'nsw',
#        'schools', 'united-kingdom', 'advertising', 'diabetes',
#        'indigenous-aboriginal-and-torres-strait-islander', 'australia',
#        'obesity', 'cancer', 'health-policy', 'community-and-society', 'sa',
#        'united-states', 'act', 'business-economics-and-finance', 'smoking',
#        'heart-disease', 'advertising-and-marketing',
#        'doctors-and-medical-professionals'],
#       dtype='object')
# Order of the chain: Index(['nsw', 'children', 'australia', 'heart-disease', 'smoking', 'industry',
#        'health', 'government-and-politics', 'united-kingdom',
#        'food-and-beverage', 'federal-government', 'advertising',
#        'united-states', 'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'obesity', 'advertising-and-marketing',
#        'science-and-technology', 'medical-research', 'exercise-and-fitness',
#        'diseases-and-disorders', 'tas', 'wa', 'lifestyle-and-leisure',
#        'health-policy', 'doctors-and-medical-professionals',
#        'states-and-territories', 'cancer', 'education', 'diabetes', 'sa',
#        'research', 'business-economics-and-finance', 'act',
#        'diet-and-nutrition', 'community-and-society',
#        'child-health-and-behaviour', 'vic', 'schools', 'healthcare-facilities',
#        'qld', 'federal---state-issues'],
#       dtype='object')
# Order of the chain: Index(['exercise-and-fitness', 'tas', 'united-kingdom',
#        'federal---state-issues', 'vic', 'obesity', 'industry', 'cancer',
#        'smoking', 'diseases-and-disorders', 'child-health-and-behaviour', 'sa',
#        'family-and-children', 'children', 'qld', 'heart-disease',
#        'advertising-and-marketing', 'states-and-territories',
#        'government-and-politics', 'medical-research', 'wa', 'australia',
#        'diabetes', 'business-economics-and-finance', 'food-and-beverage',
#        'schools', 'doctors-and-medical-professionals', 'lifestyle-and-leisure',
#        'community-and-society', 'healthcare-facilities', 'research',
#        'science-and-technology', 'education', 'federal-government',
#        'advertising', 'health', 'act', 'diet-and-nutrition', 'nsw',
#        'indigenous-aboriginal-and-torres-strait-islander', 'health-policy',
#        'united-states'],
#       dtype='object')
# Order of the chain: Index(['smoking', 'business-economics-and-finance', 'act',
#        'diet-and-nutrition', 'child-health-and-behaviour', 'cancer',
#        'healthcare-facilities', 'nsw', 'tas',
#        'doctors-and-medical-professionals', 'lifestyle-and-leisure',
#        'australia', 'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'advertising-and-marketing',
#        'community-and-society', 'food-and-beverage', 'research', 'advertising',
#        'heart-disease', 'exercise-and-fitness', 'united-kingdom', 'education',
#        'diseases-and-disorders', 'health', 'qld', 'diabetes',
#        'science-and-technology', 'federal---state-issues', 'medical-research',
#        'states-and-territories', 'sa', 'schools', 'industry',
#        'government-and-politics', 'united-states', 'obesity', 'vic', 'wa',
#        'children', 'health-policy', 'federal-government'],
#       dtype='object')
# Order of the chain: Index(['nsw', 'industry', 'children', 'science-and-technology', 'tas', 'sa',
#        'federal---state-issues', 'healthcare-facilities', 'federal-government',
#        'states-and-territories',
#        'indigenous-aboriginal-and-torres-strait-islander', 'united-kingdom',
#        'business-economics-and-finance', 'health', 'vic',
#        'government-and-politics', 'diseases-and-disorders',
#        'community-and-society', 'family-and-children', 'research',
#        'child-health-and-behaviour', 'united-states', 'qld',
#        'lifestyle-and-leisure', 'obesity', 'advertising', 'food-and-beverage',
#        'exercise-and-fitness', 'smoking', 'health-policy', 'cancer',
#        'heart-disease', 'diabetes', 'doctors-and-medical-professionals',
#        'education', 'advertising-and-marketing', 'medical-research',
#        'australia', 'diet-and-nutrition', 'act', 'schools', 'wa'],
#       dtype='object')
# Order of the chain: Index(['doctors-and-medical-professionals', 'vic', 'heart-disease', 'industry',
#        'advertising-and-marketing', 'federal---state-issues',
#        'diet-and-nutrition', 'act', 'health-policy', 'united-states', 'tas',
#        'wa', 'food-and-beverage', 'healthcare-facilities', 'health',
#        'family-and-children', 'lifestyle-and-leisure', 'research',
#        'advertising', 'sa', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'exercise-and-fitness', 'business-economics-and-finance', 'schools',
#        'united-kingdom', 'diabetes', 'states-and-territories', 'cancer',
#        'smoking', 'diseases-and-disorders', 'obesity', 'qld', 'australia',
#        'education', 'government-and-politics', 'medical-research',
#        'federal-government', 'community-and-society', 'nsw',
#        'child-health-and-behaviour', 'science-and-technology'],
#       dtype='object')
# Order of the chain: Index(['healthcare-facilities', 'health-policy', 'industry', 'schools',
#        'diabetes', 'sa', 'advertising', 'child-health-and-behaviour',
#        'obesity', 'government-and-politics', 'lifestyle-and-leisure',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'advertising-and-marketing', 'tas', 'vic', 'community-and-society',
#        'health', 'food-and-beverage', 'cancer', 'heart-disease',
#        'united-states', 'exercise-and-fitness',
#        'doctors-and-medical-professionals', 'medical-research',
#        'business-economics-and-finance', 'family-and-children',
#        'federal---state-issues', 'smoking', 'united-kingdom',
#        'states-and-territories', 'nsw', 'act', 'wa', 'diseases-and-disorders',
#        'education', 'diet-and-nutrition', 'children', 'research',
#        'federal-government', 'science-and-technology', 'australia', 'qld'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'diseases-and-disorders', 'heart-disease',
#        'vic', 'cancer', 'states-and-territories', 'smoking', 'obesity',
#        'united-states', 'industry',
#        'indigenous-aboriginal-and-torres-strait-islander', 'food-and-beverage',
#        'nsw', 'qld', 'tas', 'research', 'diabetes', 'healthcare-facilities',
#        'wa', 'exercise-and-fitness', 'doctors-and-medical-professionals',
#        'advertising', 'advertising-and-marketing', 'australia',
#        'community-and-society', 'health-policy', 'lifestyle-and-leisure',
#        'health', 'children', 'education', 'child-health-and-behaviour',
#        'science-and-technology', 'family-and-children', 'united-kingdom',
#        'schools', 'business-economics-and-finance', 'diet-and-nutrition', 'sa',
#        'federal-government', 'government-and-politics', 'act',
#        'medical-research'],
#       dtype='object')
# Order of the chain: Index(['smoking', 'indigenous-aboriginal-and-torres-strait-islander',
#        'schools', 'health', 'health-policy', 'medical-research',
#        'community-and-society', 'family-and-children', 'united-states',
#        'food-and-beverage', 'children', 'act', 'wa', 'sa', 'diabetes', 'tas',
#        'business-economics-and-finance', 'united-kingdom',
#        'diet-and-nutrition', 'qld', 'vic', 'advertising-and-marketing',
#        'cancer', 'science-and-technology', 'lifestyle-and-leisure',
#        'diseases-and-disorders', 'federal---state-issues',
#        'states-and-territories', 'australia',
#        'doctors-and-medical-professionals', 'advertising', 'research',
#        'child-health-and-behaviour', 'industry', 'healthcare-facilities',
#        'nsw', 'education', 'obesity', 'heart-disease', 'exercise-and-fitness',
#        'government-and-politics', 'federal-government'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'diseases-and-disorders', 'children',
#        'healthcare-facilities', 'united-states', 'diabetes', 'schools',
#        'australia', 'indigenous-aboriginal-and-torres-strait-islander',
#        'exercise-and-fitness', 'heart-disease',
#        'business-economics-and-finance', 'sa', 'health', 'medical-research',
#        'nsw', 'science-and-technology', 'health-policy', 'obesity',
#        'states-and-territories', 'act', 'cancer', 'qld', 'tas',
#        'diet-and-nutrition', 'wa', 'advertising-and-marketing', 'education',
#        'child-health-and-behaviour', 'vic', 'food-and-beverage',
#        'federal-government', 'family-and-children', 'lifestyle-and-leisure',
#        'united-kingdom', 'government-and-politics', 'advertising', 'industry',
#        'doctors-and-medical-professionals', 'smoking', 'community-and-society',
#        'research'],
#       dtype='object')
# Order of the chain: Index(['tas', 'family-and-children', 'health', 'government-and-politics',
#        'qld', 'smoking', 'states-and-territories', 'medical-research',
#        'federal-government', 'diet-and-nutrition',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'science-and-technology', 'nsw', 'health-policy', 'heart-disease',
#        'united-states', 'obesity', 'education', 'diseases-and-disorders',
#        'food-and-beverage', 'united-kingdom', 'diabetes',
#        'business-economics-and-finance', 'sa', 'advertising-and-marketing',
#        'child-health-and-behaviour', 'doctors-and-medical-professionals',
#        'schools', 'research', 'australia', 'cancer', 'children', 'wa',
#        'community-and-society', 'exercise-and-fitness', 'vic',
#        'federal---state-issues', 'advertising', 'lifestyle-and-leisure',
#        'industry', 'healthcare-facilities', 'act'],
#       dtype='object')
# Order of the chain: Index(['diseases-and-disorders', 'schools', 'states-and-territories',
#        'business-economics-and-finance', 'child-health-and-behaviour', 'act',
#        'australia', 'sa', 'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'diabetes', 'vic', 'health', 'children',
#        'heart-disease', 'united-kingdom', 'exercise-and-fitness',
#        'united-states', 'obesity', 'medical-research', 'smoking',
#        'federal-government', 'food-and-beverage', 'industry',
#        'family-and-children', 'research', 'advertising', 'qld',
#        'advertising-and-marketing', 'cancer', 'diet-and-nutrition',
#        'healthcare-facilities', 'government-and-politics',
#        'doctors-and-medical-professionals', 'community-and-society',
#        'health-policy', 'nsw', 'tas', 'wa', 'science-and-technology',
#        'federal---state-issues', 'education'],
#       dtype='object')
# Order of the chain: Index(['medical-research', 'states-and-territories', 'schools', 'smoking',
#        'sa', 'cancer', 'food-and-beverage',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'diseases-and-disorders', 'advertising-and-marketing', 'obesity',
#        'community-and-society', 'united-kingdom', 'australia', 'health',
#        'healthcare-facilities', 'wa', 'education', 'science-and-technology',
#        'government-and-politics', 'united-states', 'heart-disease',
#        'exercise-and-fitness', 'nsw', 'health-policy',
#        'business-economics-and-finance', 'industry', 'federal---state-issues',
#        'research', 'diabetes', 'doctors-and-medical-professionals',
#        'federal-government', 'diet-and-nutrition', 'vic', 'advertising',
#        'child-health-and-behaviour', 'act', 'lifestyle-and-leisure',
#        'family-and-children', 'tas', 'qld', 'children'],
#       dtype='object')
# Order of the chain: Index(['wa', 'industry', 'federal---state-issues', 'heart-disease',
#        'lifestyle-and-leisure', 'child-health-and-behaviour',
#        'advertising-and-marketing', 'act', 'children', 'qld', 'education',
#        'family-and-children', 'health-policy', 'health', 'tas', 'research',
#        'doctors-and-medical-professionals', 'medical-research', 'schools',
#        'united-kingdom', 'advertising', 'nsw', 'australia', 'vic',
#        'government-and-politics', 'science-and-technology',
#        'community-and-society', 'food-and-beverage', 'states-and-territories',
#        'diet-and-nutrition', 'federal-government',
#        'business-economics-and-finance', 'cancer', 'exercise-and-fitness',
#        'united-states', 'sa', 'obesity', 'healthcare-facilities',
#        'indigenous-aboriginal-and-torres-strait-islander', 'smoking',
#        'diabetes', 'diseases-and-disorders'],
#       dtype='object')
# Order of the chain: Index(['advertising', 'child-health-and-behaviour',
#        'indigenous-aboriginal-and-torres-strait-islander', 'cancer',
#        'medical-research', 'australia', 'vic', 'federal-government',
#        'government-and-politics', 'nsw', 'advertising-and-marketing',
#        'diseases-and-disorders', 'business-economics-and-finance', 'education',
#        'diet-and-nutrition', 'heart-disease', 'united-kingdom',
#        'healthcare-facilities', 'states-and-territories',
#        'exercise-and-fitness', 'health-policy', 'family-and-children',
#        'diabetes', 'smoking', 'children', 'science-and-technology', 'schools',
#        'federal---state-issues', 'industry', 'sa', 'act', 'obesity', 'tas',
#        'food-and-beverage', 'united-states', 'health',
#        'doctors-and-medical-professionals', 'lifestyle-and-leisure',
#        'community-and-society', 'wa', 'research', 'qld'],
#       dtype='object')
# Order of the chain: Index(['tas', 'science-and-technology', 'medical-research', 'sa', 'health',
#        'doctors-and-medical-professionals', 'united-states', 'cancer',
#        'community-and-society',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'business-economics-and-finance', 'federal-government', 'nsw',
#        'health-policy', 'diabetes', 'exercise-and-fitness', 'qld',
#        'diseases-and-disorders', 'research', 'smoking', 'heart-disease',
#        'healthcare-facilities', 'schools', 'government-and-politics',
#        'children', 'states-and-territories', 'advertising-and-marketing',
#        'education', 'industry', 'australia', 'obesity',
#        'child-health-and-behaviour', 'diet-and-nutrition',
#        'family-and-children', 'federal---state-issues', 'act',
#        'united-kingdom', 'food-and-beverage', 'wa', 'vic',
#        'lifestyle-and-leisure', 'advertising'],
#       dtype='object')
# Order of the chain: Index(['doctors-and-medical-professionals', 'diabetes',
#        'federal---state-issues', 'states-and-territories',
#        'government-and-politics', 'cancer', 'australia', 'research',
#        'food-and-beverage', 'sa', 'united-states', 'united-kingdom', 'qld',
#        'obesity', 'family-and-children', 'smoking', 'tas',
#        'lifestyle-and-leisure', 'children', 'wa', 'diet-and-nutrition',
#        'medical-research', 'business-economics-and-finance', 'act',
#        'advertising-and-marketing', 'exercise-and-fitness', 'education',
#        'community-and-society', 'federal-government', 'heart-disease',
#        'science-and-technology', 'diseases-and-disorders', 'schools',
#        'advertising', 'vic', 'healthcare-facilities',
#        'child-health-and-behaviour', 'nsw',
#        'indigenous-aboriginal-and-torres-strait-islander', 'industry',
#        'health', 'health-policy'],
#       dtype='object')
# Order of the chain: Index(['exercise-and-fitness', 'diseases-and-disorders', 'education', 'nsw',
#        'schools', 'vic', 'federal---state-issues', 'advertising', 'tas',
#        'medical-research', 'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'qld', 'science-and-technology',
#        'child-health-and-behaviour', 'united-states', 'industry',
#        'doctors-and-medical-professionals', 'wa', 'united-kingdom',
#        'diet-and-nutrition', 'food-and-beverage', 'heart-disease', 'health',
#        'advertising-and-marketing', 'healthcare-facilities',
#        'states-and-territories', 'lifestyle-and-leisure', 'research',
#        'diabetes', 'obesity', 'children', 'act', 'australia', 'cancer',
#        'business-economics-and-finance', 'community-and-society', 'smoking',
#        'health-policy', 'government-and-politics', 'sa', 'federal-government'],
#       dtype='object')
# Order of the chain: Index(['united-states', 'federal-government', 'act', 'medical-research', 'wa',
#        'exercise-and-fitness', 'science-and-technology', 'qld', 'australia',
#        'children', 'vic', 'advertising-and-marketing', 'lifestyle-and-leisure',
#        'industry', 'food-and-beverage', 'states-and-territories',
#        'community-and-society', 'doctors-and-medical-professionals',
#        'indigenous-aboriginal-and-torres-strait-islander', 'sa', 'diabetes',
#        'advertising', 'cancer', 'health-policy', 'government-and-politics',
#        'smoking', 'diseases-and-disorders', 'federal---state-issues',
#        'obesity', 'united-kingdom', 'nsw', 'business-economics-and-finance',
#        'family-and-children', 'research', 'healthcare-facilities', 'tas',
#        'diet-and-nutrition', 'schools', 'child-health-and-behaviour', 'health',
#        'education', 'heart-disease'],
#       dtype='object')
# Order of the chain: Index(['states-and-territories', 'health-policy', 'diet-and-nutrition',
#        'government-and-politics', 'united-kingdom', 'federal---state-issues',
#        'sa', 'smoking', 'medical-research', 'education', 'schools', 'children',
#        'federal-government', 'qld', 'cancer', 'industry',
#        'community-and-society', 'research', 'tas', 'heart-disease',
#        'united-states', 'wa', 'business-economics-and-finance',
#        'science-and-technology',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'healthcare-facilities', 'vic', 'act', 'advertising',
#        'child-health-and-behaviour', 'nsw', 'diabetes',
#        'lifestyle-and-leisure', 'obesity', 'food-and-beverage', 'health',
#        'family-and-children', 'australia', 'doctors-and-medical-professionals',
#        'diseases-and-disorders', 'exercise-and-fitness',
#        'advertising-and-marketing'],
#       dtype='object')
# Order of the chain: Index(['diseases-and-disorders', 'act', 'obesity', 'australia',
#        'advertising-and-marketing',
#        'indigenous-aboriginal-and-torres-strait-islander', 'education',
#        'child-health-and-behaviour', 'diet-and-nutrition',
#        'family-and-children', 'tas', 'lifestyle-and-leisure',
#        'government-and-politics', 'science-and-technology', 'sa',
#        'health-policy', 'schools', 'community-and-society',
#        'doctors-and-medical-professionals', 'smoking', 'exercise-and-fitness',
#        'cancer', 'united-kingdom', 'states-and-territories',
#        'federal-government', 'industry', 'vic', 'medical-research',
#        'advertising', 'health', 'united-states', 'federal---state-issues',
#        'wa', 'business-economics-and-finance', 'diabetes', 'heart-disease',
#        'qld', 'food-and-beverage', 'children', 'research', 'nsw',
#        'healthcare-facilities'],
#       dtype='object')
# Order of the chain: Index(['research', 'obesity', 'diet-and-nutrition', 'qld', 'health',
#        'states-and-territories', 'exercise-and-fitness', 'food-and-beverage',
#        'sa', 'business-economics-and-finance', 'smoking',
#        'child-health-and-behaviour', 'united-states', 'healthcare-facilities',
#        'medical-research', 'industry', 'health-policy', 'cancer',
#        'advertising-and-marketing', 'doctors-and-medical-professionals', 'act',
#        'advertising', 'diseases-and-disorders', 'government-and-politics',
#        'diabetes', 'wa', 'australia',
#        'indigenous-aboriginal-and-torres-strait-islander', 'children', 'tas',
#        'vic', 'united-kingdom', 'heart-disease', 'family-and-children',
#        'federal---state-issues', 'lifestyle-and-leisure', 'education',
#        'schools', 'community-and-society', 'nsw', 'science-and-technology',
#        'federal-government'],
#       dtype='object')
# Order of the chain: Index(['wa', 'child-health-and-behaviour', 'doctors-and-medical-professionals',
#        'lifestyle-and-leisure', 'medical-research', 'government-and-politics',
#        'science-and-technology', 'food-and-beverage', 'act', 'education',
#        'vic', 'united-kingdom', 'australia', 'industry', 'research',
#        'indigenous-aboriginal-and-torres-strait-islander', 'schools',
#        'federal---state-issues', 'tas', 'advertising',
#        'advertising-and-marketing', 'healthcare-facilities', 'heart-disease',
#        'states-and-territories', 'health', 'diabetes', 'family-and-children',
#        'smoking', 'community-and-society', 'children',
#        'diseases-and-disorders', 'obesity', 'qld', 'exercise-and-fitness',
#        'united-states', 'diet-and-nutrition', 'health-policy',
#        'business-economics-and-finance', 'nsw', 'sa', 'cancer',
#        'federal-government'],
#       dtype='object')
# Order of the chain: Index(['wa', 'research', 'smoking', 'health', 'nsw', 'science-and-technology',
#        'obesity', 'industry', 'community-and-society',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'federal---state-issues', 'united-kingdom', 'advertising-and-marketing',
#        'lifestyle-and-leisure', 'cancer', 'education', 'diet-and-nutrition',
#        'qld', 'advertising', 'exercise-and-fitness',
#        'business-economics-and-finance', 'states-and-territories', 'children',
#        'act', 'family-and-children', 'diseases-and-disorders', 'health-policy',
#        'sa', 'diabetes', 'doctors-and-medical-professionals', 'schools',
#        'federal-government', 'government-and-politics', 'tas',
#        'medical-research', 'child-health-and-behaviour', 'heart-disease',
#        'vic', 'healthcare-facilities', 'united-states', 'australia',
#        'food-and-beverage'],
#       dtype='object')
# Order of the chain: Index(['states-and-territories', 'industry', 'sa', 'education',
#        'diseases-and-disorders', 'healthcare-facilities',
#        'lifestyle-and-leisure', 'family-and-children', 'united-kingdom',
#        'smoking', 'health-policy', 'government-and-politics', 'children',
#        'diabetes', 'research', 'qld', 'business-economics-and-finance',
#        'diet-and-nutrition', 'wa', 'health', 'exercise-and-fitness',
#        'advertising', 'australia', 'obesity', 'vic', 'community-and-society',
#        'food-and-beverage', 'united-states', 'advertising-and-marketing',
#        'doctors-and-medical-professionals',
#        'indigenous-aboriginal-and-torres-strait-islander', 'nsw',
#        'child-health-and-behaviour', 'act', 'science-and-technology',
#        'schools', 'federal-government', 'federal---state-issues',
#        'heart-disease', 'tas', 'medical-research', 'cancer'],
#       dtype='object')
# Order of the chain: Index(['lifestyle-and-leisure', 'act', 'nsw', 'diseases-and-disorders',
#        'doctors-and-medical-professionals', 'diet-and-nutrition', 'research',
#        'exercise-and-fitness', 'government-and-politics',
#        'science-and-technology', 'medical-research', 'schools', 'wa',
#        'obesity', 'health', 'business-economics-and-finance',
#        'healthcare-facilities', 'food-and-beverage',
#        'indigenous-aboriginal-and-torres-strait-islander', 'education',
#        'cancer', 'advertising', 'states-and-territories', 'diabetes',
#        'federal---state-issues', 'tas', 'united-states', 'united-kingdom',
#        'vic', 'heart-disease', 'federal-government', 'smoking',
#        'advertising-and-marketing', 'community-and-society', 'qld',
#        'family-and-children', 'child-health-and-behaviour', 'children',
#        'australia', 'health-policy', 'industry', 'sa'],
#       dtype='object')
# Order of the chain: Index(['exercise-and-fitness', 'australia', 'family-and-children',
#        'science-and-technology', 'government-and-politics', 'cancer',
#        'medical-research', 'doctors-and-medical-professionals', 'diabetes',
#        'vic', 'united-kingdom', 'child-health-and-behaviour',
#        'advertising-and-marketing', 'health-policy', 'schools', 'health',
#        'obesity', 'food-and-beverage', 'wa', 'diet-and-nutrition', 'research',
#        'nsw', 'federal---state-issues', 'lifestyle-and-leisure', 'act',
#        'business-economics-and-finance', 'industry', 'community-and-society',
#        'healthcare-facilities', 'united-states', 'states-and-territories',
#        'advertising', 'heart-disease', 'education', 'federal-government',
#        'tas', 'indigenous-aboriginal-and-torres-strait-islander', 'qld', 'sa',
#        'diseases-and-disorders', 'smoking', 'children'],
#       dtype='object')
# Order of the chain: Index(['united-kingdom', 'research', 'community-and-society', 'smoking', 'sa',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'business-economics-and-finance',
#        'healthcare-facilities', 'vic', 'family-and-children',
#        'advertising-and-marketing', 'nsw', 'children', 'united-states',
#        'child-health-and-behaviour', 'diseases-and-disorders', 'diabetes',
#        'science-and-technology', 'medical-research', 'diet-and-nutrition',
#        'qld', 'doctors-and-medical-professionals', 'industry', 'schools',
#        'obesity', 'exercise-and-fitness', 'food-and-beverage', 'health',
#        'federal-government', 'states-and-territories', 'wa', 'australia',
#        'tas', 'education', 'government-and-politics', 'federal---state-issues',
#        'heart-disease', 'cancer', 'health-policy', 'advertising', 'act'],
#       dtype='object')
# Order of the chain: Index(['federal-government', 'act', 'united-states', 'health-policy', 'wa',
#        'business-economics-and-finance', 'diabetes', 'healthcare-facilities',
#        'advertising', 'research', 'australia', 'qld', 'exercise-and-fitness',
#        'science-and-technology', 'lifestyle-and-leisure', 'cancer', 'health',
#        'nsw', 'education', 'advertising-and-marketing', 'diet-and-nutrition',
#        'child-health-and-behaviour', 'united-kingdom',
#        'diseases-and-disorders', 'sa', 'schools', 'states-and-territories',
#        'family-and-children', 'children', 'industry', 'obesity', 'smoking',
#        'medical-research', 'government-and-politics', 'community-and-society',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'doctors-and-medical-professionals', 'federal---state-issues', 'tas',
#        'food-and-beverage', 'heart-disease', 'vic'],
#       dtype='object')
# Order of the chain: Index(['sa', 'health', 'diabetes', 'education', 'tas',
#        'states-and-territories', 'nsw', 'industry', 'australia', 'wa',
#        'heart-disease', 'doctors-and-medical-professionals', 'children',
#        'exercise-and-fitness', 'food-and-beverage', 'cancer', 'vic',
#        'government-and-politics', 'business-economics-and-finance', 'qld',
#        'science-and-technology', 'act', 'healthcare-facilities', 'smoking',
#        'child-health-and-behaviour', 'health-policy', 'federal---state-issues',
#        'united-states', 'medical-research', 'lifestyle-and-leisure',
#        'indigenous-aboriginal-and-torres-strait-islander', 'obesity',
#        'diet-and-nutrition', 'schools', 'advertising-and-marketing',
#        'community-and-society', 'federal-government', 'diseases-and-disorders',
#        'research', 'family-and-children', 'united-kingdom', 'advertising'],
#       dtype='object')
# Order of the chain: Index(['community-and-society', 'education', 'science-and-technology',
#        'health-policy', 'united-states', 'children', 'states-and-territories',
#        'lifestyle-and-leisure', 'child-health-and-behaviour',
#        'medical-research', 'advertising', 'vic', 'australia',
#        'family-and-children', 'schools', 'doctors-and-medical-professionals',
#        'health', 'diet-and-nutrition', 'wa', 'diseases-and-disorders',
#        'indigenous-aboriginal-and-torres-strait-islander', 'smoking',
#        'business-economics-and-finance', 'food-and-beverage', 'obesity', 'qld',
#        'government-and-politics', 'federal---state-issues', 'research',
#        'united-kingdom', 'federal-government', 'sa', 'nsw',
#        'exercise-and-fitness', 'act', 'healthcare-facilities', 'heart-disease',
#        'cancer', 'tas', 'diabetes', 'advertising-and-marketing', 'industry'],
#       dtype='object')
# Order of the chain: Index(['qld', 'advertising-and-marketing', 'business-economics-and-finance',
#        'united-states', 'heart-disease', 'nsw', 'federal-government',
#        'healthcare-facilities', 'diabetes', 'family-and-children', 'vic',
#        'advertising', 'doctors-and-medical-professionals', 'act', 'research',
#        'tas', 'government-and-politics', 'wa', 'diet-and-nutrition', 'cancer',
#        'children', 'education', 'health-policy', 'obesity',
#        'community-and-society', 'exercise-and-fitness', 'food-and-beverage',
#        'science-and-technology', 'smoking',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'child-health-and-behaviour', 'health', 'australia',
#        'lifestyle-and-leisure', 'medical-research', 'diseases-and-disorders',
#        'states-and-territories', 'united-kingdom', 'sa',
#        'federal---state-issues', 'schools', 'industry'],
#       dtype='object')
# Order of the chain: Index(['sa', 'act', 'industry', 'healthcare-facilities', 'family-and-children',
#        'cancer', 'indigenous-aboriginal-and-torres-strait-islander',
#        'heart-disease', 'doctors-and-medical-professionals', 'advertising',
#        'health', 'qld', 'federal---state-issues', 'advertising-and-marketing',
#        'business-economics-and-finance', 'diabetes', 'community-and-society',
#        'australia', 'research', 'diseases-and-disorders', 'medical-research',
#        'obesity', 'food-and-beverage', 'tas', 'nsw', 'children',
#        'diet-and-nutrition', 'child-health-and-behaviour', 'schools',
#        'states-and-territories', 'lifestyle-and-leisure',
#        'government-and-politics', 'education', 'smoking', 'health-policy',
#        'wa', 'science-and-technology', 'vic', 'federal-government',
#        'exercise-and-fitness', 'united-kingdom', 'united-states'],
#       dtype='object')
# Order of the chain: Index(['diabetes', 'advertising', 'states-and-territories', 'heart-disease',
#        'qld', 'exercise-and-fitness', 'healthcare-facilities',
#        'family-and-children', 'medical-research', 'diet-and-nutrition', 'sa',
#        'united-kingdom', 'obesity', 'united-states', 'science-and-technology',
#        'act', 'smoking', 'health-policy', 'schools',
#        'business-economics-and-finance', 'child-health-and-behaviour',
#        'doctors-and-medical-professionals', 'australia',
#        'diseases-and-disorders', 'lifestyle-and-leisure', 'industry',
#        'indigenous-aboriginal-and-torres-strait-islander', 'tas', 'research',
#        'federal-government', 'community-and-society', 'education', 'health',
#        'food-and-beverage', 'federal---state-issues', 'nsw', 'cancer',
#        'government-and-politics', 'wa', 'advertising-and-marketing', 'vic',
#        'children'],
#       dtype='object')
# Order of the chain: Index(['diet-and-nutrition', 'medical-research', 'research', 'australia',
#        'federal---state-issues', 'health-policy', 'child-health-and-behaviour',
#        'schools', 'wa', 'states-and-territories',
#        'indigenous-aboriginal-and-torres-strait-islander', 'vic',
#        'united-states', 'diseases-and-disorders',
#        'business-economics-and-finance', 'united-kingdom',
#        'healthcare-facilities', 'cancer', 'community-and-society', 'diabetes',
#        'exercise-and-fitness', 'sa', 'government-and-politics', 'industry',
#        'advertising', 'tas', 'obesity', 'science-and-technology', 'education',
#        'food-and-beverage', 'heart-disease', 'children', 'health', 'smoking',
#        'advertising-and-marketing', 'family-and-children', 'nsw',
#        'federal-government', 'lifestyle-and-leisure', 'qld',
#        'doctors-and-medical-professionals', 'act'],
#       dtype='object')
# Order of the chain: Index(['sa', 'united-kingdom', 'diet-and-nutrition', 'health-policy',
#        'education', 'act', 'federal---state-issues', 'food-and-beverage',
#        'research', 'exercise-and-fitness', 'qld', 'advertising', 'nsw',
#        'lifestyle-and-leisure', 'doctors-and-medical-professionals', 'vic',
#        'heart-disease', 'healthcare-facilities', 'advertising-and-marketing',
#        'united-states', 'diseases-and-disorders', 'medical-research',
#        'community-and-society', 'smoking', 'science-and-technology', 'wa',
#        'government-and-politics', 'federal-government',
#        'business-economics-and-finance', 'family-and-children',
#        'child-health-and-behaviour', 'diabetes', 'health', 'australia',
#        'industry', 'tas', 'children', 'cancer', 'schools',
#        'states-and-territories', 'obesity',
#        'indigenous-aboriginal-and-torres-strait-islander'],
#       dtype='object')
# Order of the chain: Index(['sa', 'qld', 'united-states', 'nsw', 'diet-and-nutrition', 'wa',
#        'child-health-and-behaviour', 'schools', 'advertising',
#        'exercise-and-fitness', 'cancer', 'medical-research',
#        'federal---state-issues', 'health', 'united-kingdom',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'advertising-and-marketing', 'tas', 'health-policy', 'education', 'act',
#        'research', 'industry', 'community-and-society',
#        'doctors-and-medical-professionals', 'smoking', 'diabetes',
#        'science-and-technology', 'federal-government', 'australia', 'children',
#        'lifestyle-and-leisure', 'heart-disease', 'food-and-beverage',
#        'obesity', 'diseases-and-disorders', 'business-economics-and-finance',
#        'government-and-politics', 'healthcare-facilities',
#        'family-and-children', 'states-and-territories', 'vic'],
#       dtype='object')
# Order of the chain: Index(['child-health-and-behaviour', 'advertising-and-marketing',
#        'advertising', 'united-kingdom', 'research', 'health', 'australia',
#        'community-and-society', 'doctors-and-medical-professionals',
#        'states-and-territories', 'united-states', 'sa',
#        'diseases-and-disorders', 'health-policy', 'education',
#        'government-and-politics', 'children', 'lifestyle-and-leisure',
#        'food-and-beverage', 'qld', 'family-and-children', 'vic',
#        'indigenous-aboriginal-and-torres-strait-islander', 'diabetes',
#        'heart-disease', 'wa', 'diet-and-nutrition',
#        'business-economics-and-finance', 'act', 'healthcare-facilities',
#        'obesity', 'nsw', 'schools', 'federal-government', 'tas', 'industry',
#        'medical-research', 'federal---state-issues', 'cancer',
#        'exercise-and-fitness', 'science-and-technology', 'smoking'],
#       dtype='object')
# Order of the chain: Index(['family-and-children', 'federal---state-issues', 'obesity', 'cancer',
#        'government-and-politics', 'united-states', 'industry', 'health-policy',
#        'vic', 'act', 'science-and-technology', 'food-and-beverage',
#        'community-and-society', 'tas', 'schools', 'child-health-and-behaviour',
#        'qld', 'smoking', 'sa', 'wa', 'diseases-and-disorders',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'federal-government', 'healthcare-facilities',
#        'advertising-and-marketing', 'diet-and-nutrition',
#        'business-economics-and-finance', 'united-kingdom', 'research',
#        'education', 'states-and-territories',
#        'doctors-and-medical-professionals', 'lifestyle-and-leisure',
#        'exercise-and-fitness', 'health', 'diabetes', 'heart-disease',
#        'medical-research', 'nsw', 'australia', 'advertising', 'children'],
#       dtype='object')
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
#
# --- Order of the chain ---
# Index(['family-and-children', 'federal---state-issues', 'obesity', 'cancer',
#        'government-and-politics', 'united-states', 'industry', 'health-policy',
#        'vic', 'act', 'science-and-technology', 'food-and-beverage',
#        'community-and-society', 'tas', 'schools', 'child-health-and-behaviour',
#        'qld', 'smoking', 'sa', 'wa', 'diseases-and-disorders',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'federal-government', 'healthcare-facilities',
#        'advertising-and-marketing', 'diet-and-nutrition',
#        'business-economics-and-finance', 'united-kingdom', 'research',
#        'education', 'states-and-territories',
#        'doctors-and-medical-professionals', 'lifestyle-and-leisure',
#        'exercise-and-fitness', 'health', 'diabetes', 'heart-disease',
#        'medical-research', 'nsw', 'australia', 'advertising', 'children'],
#       dtype='object')
#
# --- Performance ---
# coverage_error = 13.71 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.13
# hamming_loss = 0.11
# f1_macro = 0.26
# f1_micro = 0.38
# Jaccard_Index = 0.89
# zero_one_error = 0.97
#
# - f1 for each label -
# label_act = 0.0
# label_advertising = 0.42
# label_advertising-and-marketing = 0.32
# label_australia = 0.56
# label_business-economics-and-finance = 0.37
# label_cancer = 0.31
# label_child-health-and-behaviour = 0.31
# label_children = 0.24
# label_community-and-society = 0.09
# label_diabetes = 0.46
# label_diet-and-nutrition = 0.23
# label_diseases-and-disorders = 0.22
# label_doctors-and-medical-professionals = 0.35
# label_education = 0.09
# label_exercise-and-fitness = 0.14
# label_family-and-children = 0.1
# label_federal---state-issues = 0.31
# label_federal-government = 0.44
# label_food-and-beverage = 0.33
# label_government-and-politics = 0.28
# label_health = 0.41
# label_health-policy = 0.39
# label_healthcare-facilities = 0.24
# label_heart-disease = 0.06
# label_indigenous-aboriginal-and-torres-strait-islander = 0.15
# label_industry = 0.21
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.38
# label_nsw = 0.31
# label_obesity = 0.69
# label_qld = 0.27
# label_research = 0.34
# label_sa = 0.07
# label_schools = 0.34
# label_science-and-technology = 0.06
# label_smoking = 0.17
# label_states-and-territories = 0.31
# label_tas = 0.08
# label_united-kingdom = 0.18
# label_united-states = 0.57
# label_vic = 0.18
# label_wa = 0.14

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)

ensemble=50

# data set information
n_label = label.shape[1]
n_attr = data.shape[1]
n_instance = data.shape[0]
avg_label_per_instance = label.sum(axis=1).mean()

X_train = data[data.index.isin(index)==False]
X_test = data[data.index.isin(index)==True]
y_train = label[label.index.isin(index)==False]
y_test = label[label.index.isin(index)==True]

print("-- test index --")
print(X_test.index)

# ensemble
y_pred_ensemble = pd.DataFrame(np.zeros(y_test.shape),columns=y_test.columns, index=y_test.index)
y_prob_ensemble = pd.DataFrame(np.zeros(y_test.shape),columns=y_test.columns, index=y_test.index)
for i in range(ensemble):
    # training
    #print("--- start training ---\n")
    classifier_list, training_time, order = naiveBayes_multi_label_training(X_train, y_train)

    # print orders
    print("Order of the chain:",label.columns[order])

    # testing
    #print("--- start testing ---\n")
    y_predict, y_prob, testing_time = naiveBayes_multi_label_testing(X_test, n_label, classifier_list, order)

    y_predict.columns = label.columns[order]
    y_prob.columns = label.columns[order]
    y_predict = y_predict[label.columns]
    y_prob = y_prob[label.columns]

    y_pred_ensemble = y_pred_ensemble + y_predict
    y_prob_ensemble = y_prob_ensemble + y_prob

y_pred_ensemble = (((y_pred_ensemble / ensemble) >= 0.5)*1).astype('int')
y_prob_ensemble = y_prob_ensemble / ensemble 

# evaluation
performance = evaluation(y_pred_ensemble, y_prob_ensemble, y_test)


# print data information
print("--- Data Information ---")
print("dataset:", dataPath)
print("number of label:",n_label)
print("number of attribute:",n_attr)
print("number of instance:",n_instance,"\n")

# print orders
print("\n--- Order of the chain ---")
print(label.columns[order])
print("")

# get confusion matrix
get_confusion_matrix(y_pred_ensemble, y_test, y_test.columns)

# print performance
print("--- Performance ---")
for key, value in performance.items():
    if key == "f1_each_label":
        print("\n- f1 for each label -")
        for i in range(n_label):
            print("label_"+label.columns[i],"=",round(value[i],2))
    elif key == "coverage_error":
        print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
    else:
        print(key,'=',round(value,2))
# Out:
# -- test index --
# Int64Index([  4,   5,   7,   8,  15,  16,  17,  21,  23,  24,
#             ...
#             876, 878, 879, 880, 881, 882, 884, 888, 889, 890],
#            dtype='int64', length=446)
# Order of the chain: Index(['health-policy', 'healthcare-facilities', 'federal---state-issues',
#        'government-and-politics', 'lifestyle-and-leisure', 'health',
#        'food-and-beverage', 'science-and-technology', 'advertising',
#        'diseases-and-disorders', 'act', 'heart-disease',
#        'exercise-and-fitness', 'industry', 'sa', 'child-health-and-behaviour',
#        'qld', 'united-states', 'schools', 'business-economics-and-finance',
#        'states-and-territories', 'family-and-children', 'diabetes',
#        'education', 'research', 'vic', 'tas', 'federal-government', 'wa',
#        'community-and-society', 'smoking', 'doctors-and-medical-professionals',
#        'indigenous-aboriginal-and-torres-strait-islander', 'children',
#        'united-kingdom', 'cancer', 'advertising-and-marketing',
#        'medical-research', 'australia', 'diet-and-nutrition', 'obesity',
#        'nsw'],
#       dtype='object')
# Order of the chain: Index(['united-kingdom', 'child-health-and-behaviour', 'sa',
#        'business-economics-and-finance', 'qld', 'health-policy',
#        'federal---state-issues', 'education', 'children', 'diet-and-nutrition',
#        'obesity', 'exercise-and-fitness', 'research',
#        'government-and-politics', 'schools', 'health', 'healthcare-facilities',
#        'act', 'vic', 'nsw', 'heart-disease', 'industry',
#        'doctors-and-medical-professionals', 'tas', 'australia',
#        'science-and-technology', 'advertising',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'community-and-society', 'federal-government', 'smoking', 'cancer',
#        'diabetes', 'medical-research', 'states-and-territories',
#        'diseases-and-disorders', 'advertising-and-marketing',
#        'food-and-beverage', 'united-states', 'family-and-children',
#        'lifestyle-and-leisure', 'wa'],
#       dtype='object')
# Order of the chain: Index(['community-and-society', 'research', 'medical-research', 'diabetes',
#        'wa', 'cancer', 'schools', 'nsw', 'business-economics-and-finance',
#        'science-and-technology', 'vic',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'doctors-and-medical-professionals', 'states-and-territories',
#        'education', 'food-and-beverage', 'qld', 'health',
#        'diseases-and-disorders', 'diet-and-nutrition', 'act', 'children', 'sa',
#        'federal---state-issues', 'health-policy', 'exercise-and-fitness',
#        'heart-disease', 'child-health-and-behaviour', 'federal-government',
#        'advertising-and-marketing', 'healthcare-facilities', 'obesity',
#        'family-and-children', 'lifestyle-and-leisure', 'advertising', 'tas',
#        'australia', 'united-kingdom', 'government-and-politics',
#        'united-states', 'smoking', 'industry'],
#       dtype='object')
# Order of the chain: Index(['diet-and-nutrition', 'sa', 'research', 'cancer', 'health', 'diabetes',
#        'medical-research', 'government-and-politics', 'federal-government',
#        'indigenous-aboriginal-and-torres-strait-islander', 'vic', 'act',
#        'science-and-technology', 'lifestyle-and-leisure', 'food-and-beverage',
#        'smoking', 'tas', 'heart-disease', 'federal---state-issues',
#        'exercise-and-fitness', 'education', 'healthcare-facilities',
#        'united-kingdom', 'qld', 'diseases-and-disorders', 'obesity',
#        'states-and-territories', 'nsw', 'united-states', 'australia',
#        'child-health-and-behaviour', 'health-policy', 'children', 'wa',
#        'doctors-and-medical-professionals', 'advertising-and-marketing',
#        'community-and-society', 'schools', 'family-and-children', 'industry',
#        'business-economics-and-finance', 'advertising'],
#       dtype='object')
# Order of the chain: Index(['food-and-beverage', 'science-and-technology', 'tas', 'advertising',
#        'wa', 'children', 'advertising-and-marketing', 'act', 'diabetes',
#        'united-kingdom', 'diseases-and-disorders', 'health',
#        'exercise-and-fitness', 'doctors-and-medical-professionals',
#        'education', 'united-states',
#        'indigenous-aboriginal-and-torres-strait-islander', 'research',
#        'healthcare-facilities', 'community-and-society', 'heart-disease',
#        'medical-research', 'federal-government', 'smoking', 'vic',
#        'government-and-politics', 'family-and-children', 'industry',
#        'federal---state-issues', 'cancer', 'qld', 'sa', 'australia', 'nsw',
#        'states-and-territories', 'diet-and-nutrition', 'obesity',
#        'health-policy', 'schools', 'child-health-and-behaviour',
#        'lifestyle-and-leisure', 'business-economics-and-finance'],
#       dtype='object')
# Order of the chain: Index(['industry', 'wa', 'exercise-and-fitness', 'research',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'business-economics-and-finance', 'vic', 'health', 'federal-government',
#        'federal---state-issues', 'united-kingdom', 'advertising', 'obesity',
#        'smoking', 'schools', 'community-and-society', 'cancer',
#        'diseases-and-disorders', 'advertising-and-marketing', 'australia',
#        'medical-research', 'sa', 'diet-and-nutrition', 'heart-disease', 'act',
#        'education', 'children', 'health-policy', 'united-states',
#        'science-and-technology', 'tas', 'qld', 'states-and-territories',
#        'child-health-and-behaviour', 'nsw', 'food-and-beverage',
#        'family-and-children', 'lifestyle-and-leisure', 'healthcare-facilities',
#        'doctors-and-medical-professionals', 'government-and-politics',
#        'diabetes'],
#       dtype='object')
# Order of the chain: Index(['diet-and-nutrition', 'science-and-technology', 'industry', 'nsw', 'sa',
#        'research', 'community-and-society', 'medical-research',
#        'lifestyle-and-leisure', 'obesity', 'federal-government',
#        'government-and-politics', 'smoking', 'states-and-territories',
#        'united-states', 'diabetes', 'doctors-and-medical-professionals',
#        'child-health-and-behaviour', 'education', 'advertising',
#        'federal---state-issues', 'food-and-beverage',
#        'business-economics-and-finance', 'cancer', 'vic', 'children',
#        'schools', 'australia',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'family-and-children', 'exercise-and-fitness', 'qld',
#        'advertising-and-marketing', 'tas', 'healthcare-facilities', 'act',
#        'health-policy', 'health', 'united-kingdom', 'diseases-and-disorders',
#        'heart-disease', 'wa'],
#       dtype='object')
# Order of the chain: Index(['wa', 'research', 'business-economics-and-finance',
#        'doctors-and-medical-professionals', 'schools', 'heart-disease',
#        'child-health-and-behaviour', 'health-policy', 'vic', 'qld',
#        'united-kingdom', 'australia', 'obesity', 'diet-and-nutrition',
#        'industry', 'lifestyle-and-leisure', 'advertising',
#        'science-and-technology', 'tas', 'united-states', 'children', 'smoking',
#        'community-and-society', 'sa', 'federal---state-issues', 'diabetes',
#        'family-and-children', 'advertising-and-marketing',
#        'states-and-territories', 'medical-research', 'food-and-beverage',
#        'federal-government',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'government-and-politics', 'health', 'nsw', 'cancer', 'education',
#        'healthcare-facilities', 'exercise-and-fitness', 'act',
#        'diseases-and-disorders'],
#       dtype='object')
# Order of the chain: Index(['qld', 'nsw', 'healthcare-facilities', 'exercise-and-fitness', 'health',
#        'schools', 'cancer', 'diabetes', 'industry', 'medical-research',
#        'states-and-territories', 'doctors-and-medical-professionals',
#        'australia', 'advertising-and-marketing', 'children',
#        'food-and-beverage', 'united-kingdom', 'vic', 'diseases-and-disorders',
#        'family-and-children', 'federal-government', 'education',
#        'government-and-politics', 'act', 'health-policy', 'wa', 'obesity',
#        'smoking', 'business-economics-and-finance', 'research',
#        'federal---state-issues', 'sa', 'science-and-technology', 'advertising',
#        'diet-and-nutrition', 'child-health-and-behaviour',
#        'community-and-society', 'united-states', 'lifestyle-and-leisure',
#        'indigenous-aboriginal-and-torres-strait-islander', 'heart-disease',
#        'tas'],
#       dtype='object')
# Order of the chain: Index(['heart-disease', 'obesity', 'sa', 'advertising-and-marketing', 'vic',
#        'education', 'child-health-and-behaviour', 'act', 'health-policy',
#        'cancer', 'nsw', 'schools', 'diet-and-nutrition',
#        'states-and-territories', 'medical-research', 'family-and-children',
#        'children', 'federal-government', 'food-and-beverage', 'qld',
#        'diseases-and-disorders', 'exercise-and-fitness',
#        'doctors-and-medical-professionals', 'australia',
#        'business-economics-and-finance', 'research', 'wa', 'united-states',
#        'industry', 'healthcare-facilities', 'federal---state-issues',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'health', 'smoking', 'advertising',
#        'united-kingdom', 'tas', 'diabetes', 'community-and-society',
#        'government-and-politics', 'science-and-technology'],
#       dtype='object')
# Order of the chain: Index(['science-and-technology', 'federal-government',
#        'advertising-and-marketing', 'diseases-and-disorders',
#        'business-economics-and-finance', 'diet-and-nutrition', 'sa', 'vic',
#        'government-and-politics', 'children', 'research', 'smoking', 'schools',
#        'united-kingdom', 'child-health-and-behaviour', 'lifestyle-and-leisure',
#        'states-and-territories', 'tas', 'community-and-society', 'act',
#        'advertising', 'diabetes', 'federal---state-issues',
#        'exercise-and-fitness', 'heart-disease', 'australia', 'united-states',
#        'food-and-beverage', 'doctors-and-medical-professionals', 'nsw', 'qld',
#        'family-and-children',
#        'indigenous-aboriginal-and-torres-strait-islander', 'health-policy',
#        'health', 'education', 'healthcare-facilities', 'industry', 'wa',
#        'medical-research', 'obesity', 'cancer'],
#       dtype='object')
# Order of the chain: Index(['family-and-children', 'advertising', 'diseases-and-disorders', 'qld',
#        'indigenous-aboriginal-and-torres-strait-islander', 'medical-research',
#        'health', 'diet-and-nutrition', 'wa', 'federal---state-issues',
#        'research', 'industry', 'cancer', 'schools', 'tas',
#        'federal-government', 'states-and-territories',
#        'child-health-and-behaviour', 'australia', 'act', 'food-and-beverage',
#        'vic', 'exercise-and-fitness', 'healthcare-facilities', 'education',
#        'advertising-and-marketing', 'business-economics-and-finance',
#        'heart-disease', 'sa', 'smoking', 'government-and-politics', 'diabetes',
#        'community-and-society', 'united-states', 'science-and-technology',
#        'children', 'health-policy', 'nsw', 'obesity', 'united-kingdom',
#        'doctors-and-medical-professionals', 'lifestyle-and-leisure'],
#       dtype='object')
# Order of the chain: Index(['sa', 'exercise-and-fitness', 'medical-research', 'research', 'vic',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'community-and-society', 'healthcare-facilities', 'health',
#        'federal-government', 'diabetes', 'child-health-and-behaviour',
#        'children', 'qld', 'federal---state-issues', 'diseases-and-disorders',
#        'act', 'heart-disease', 'wa', 'australia', 'diet-and-nutrition',
#        'advertising-and-marketing', 'food-and-beverage', 'tas', 'cancer',
#        'obesity', 'advertising', 'family-and-children',
#        'lifestyle-and-leisure', 'science-and-technology',
#        'government-and-politics', 'health-policy', 'states-and-territories',
#        'business-economics-and-finance', 'united-states', 'industry',
#        'smoking', 'schools', 'education', 'united-kingdom', 'nsw',
#        'doctors-and-medical-professionals'],
#       dtype='object')
# Order of the chain: Index(['community-and-society', 'food-and-beverage', 'vic', 'australia', 'tas',
#        'smoking', 'lifestyle-and-leisure', 'sa', 'healthcare-facilities',
#        'education', 'children', 'federal-government', 'nsw',
#        'diseases-and-disorders', 'united-states',
#        'business-economics-and-finance', 'science-and-technology', 'diabetes',
#        'exercise-and-fitness', 'wa', 'family-and-children',
#        'child-health-and-behaviour', 'industry', 'states-and-territories',
#        'health-policy', 'health', 'federal---state-issues', 'act',
#        'diet-and-nutrition', 'obesity', 'medical-research',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'advertising-and-marketing', 'doctors-and-medical-professionals',
#        'advertising', 'schools', 'research', 'heart-disease', 'united-kingdom',
#        'qld', 'cancer', 'government-and-politics'],
#       dtype='object')
# Order of the chain: Index(['united-kingdom', 'exercise-and-fitness', 'family-and-children',
#        'medical-research', 'science-and-technology', 'nsw', 'health-policy',
#        'advertising', 'government-and-politics', 'united-states',
#        'healthcare-facilities', 'obesity', 'research', 'cancer', 'australia',
#        'tas', 'federal---state-issues', 'community-and-society',
#        'doctors-and-medical-professionals', 'food-and-beverage', 'diabetes',
#        'diet-and-nutrition', 'states-and-territories', 'schools',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'business-economics-and-finance', 'federal-government',
#        'lifestyle-and-leisure', 'wa', 'industry', 'qld', 'vic',
#        'advertising-and-marketing', 'diseases-and-disorders', 'education',
#        'health', 'children', 'heart-disease', 'act', 'sa', 'smoking',
#        'child-health-and-behaviour'],
#       dtype='object')
# Order of the chain: Index(['family-and-children', 'lifestyle-and-leisure', 'health-policy', 'wa',
#        'diseases-and-disorders', 'diabetes', 'children', 'education',
#        'child-health-and-behaviour', 'industry', 'science-and-technology',
#        'food-and-beverage', 'doctors-and-medical-professionals', 'vic',
#        'federal-government', 'sa', 'advertising', 'smoking', 'nsw', 'schools',
#        'heart-disease', 'united-kingdom', 'obesity', 'community-and-society',
#        'states-and-territories', 'united-states', 'act',
#        'business-economics-and-finance', 'diet-and-nutrition', 'cancer', 'qld',
#        'tas', 'research', 'healthcare-facilities', 'government-and-politics',
#        'australia', 'advertising-and-marketing', 'health',
#        'exercise-and-fitness', 'federal---state-issues', 'medical-research',
#        'indigenous-aboriginal-and-torres-strait-islander'],
#       dtype='object')
# Order of the chain: Index(['federal---state-issues', 'schools', 'medical-research', 'research',
#        'government-and-politics', 'advertising-and-marketing', 'nsw',
#        'federal-government', 'lifestyle-and-leisure', 'obesity', 'qld',
#        'cancer', 'sa', 'united-kingdom', 'vic', 'diseases-and-disorders',
#        'exercise-and-fitness', 'act', 'tas', 'australia',
#        'science-and-technology', 'community-and-society', 'united-states',
#        'child-health-and-behaviour', 'advertising', 'health',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'business-economics-and-finance', 'food-and-beverage', 'children',
#        'industry', 'diabetes', 'healthcare-facilities',
#        'states-and-territories', 'diet-and-nutrition',
#        'doctors-and-medical-professionals', 'education', 'heart-disease',
#        'smoking', 'health-policy', 'wa', 'family-and-children'],
#       dtype='object')
# Order of the chain: Index(['health', 'exercise-and-fitness', 'nsw', 'australia',
#        'child-health-and-behaviour', 'federal---state-issues',
#        'united-kingdom', 'food-and-beverage', 'cancer', 'diet-and-nutrition',
#        'healthcare-facilities', 'vic',
#        'indigenous-aboriginal-and-torres-strait-islander', 'united-states',
#        'sa', 'federal-government', 'family-and-children', 'qld',
#        'government-and-politics', 'diseases-and-disorders', 'medical-research',
#        'wa', 'act', 'smoking', 'states-and-territories', 'research',
#        'business-economics-and-finance', 'doctors-and-medical-professionals',
#        'heart-disease', 'advertising-and-marketing', 'education',
#        'science-and-technology', 'diabetes', 'health-policy', 'advertising',
#        'community-and-society', 'lifestyle-and-leisure', 'tas', 'industry',
#        'children', 'obesity', 'schools'],
#       dtype='object')
# Order of the chain: Index(['united-states', 'lifestyle-and-leisure', 'smoking', 'tas',
#        'diseases-and-disorders', 'health-policy',
#        'indigenous-aboriginal-and-torres-strait-islander', 'cancer',
#        'united-kingdom', 'wa', 'children', 'health', 'diet-and-nutrition',
#        'qld', 'industry', 'australia', 'nsw', 'federal-government',
#        'federal---state-issues', 'sa', 'advertising-and-marketing', 'research',
#        'obesity', 'schools', 'heart-disease', 'states-and-territories',
#        'government-and-politics', 'business-economics-and-finance', 'vic',
#        'family-and-children', 'education', 'advertising',
#        'exercise-and-fitness', 'healthcare-facilities',
#        'community-and-society', 'child-health-and-behaviour',
#        'science-and-technology', 'doctors-and-medical-professionals',
#        'diabetes', 'medical-research', 'act', 'food-and-beverage'],
#       dtype='object')
# Order of the chain: Index(['wa', 'schools', 'united-states', 'lifestyle-and-leisure', 'health',
#        'doctors-and-medical-professionals', 'states-and-territories', 'tas',
#        'children', 'business-economics-and-finance',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'science-and-technology', 'advertising', 'industry',
#        'advertising-and-marketing', 'federal---state-issues', 'australia',
#        'health-policy', 'nsw', 'federal-government', 'smoking',
#        'family-and-children', 'child-health-and-behaviour',
#        'food-and-beverage', 'obesity', 'cancer', 'community-and-society',
#        'government-and-politics', 'qld', 'act', 'sa', 'healthcare-facilities',
#        'medical-research', 'exercise-and-fitness', 'heart-disease',
#        'education', 'diseases-and-disorders', 'diabetes', 'vic', 'research',
#        'diet-and-nutrition', 'united-kingdom'],
#       dtype='object')
# Order of the chain: Index(['tas', 'diseases-and-disorders', 'united-states', 'schools',
#        'government-and-politics', 'children', 'advertising-and-marketing',
#        'united-kingdom', 'education', 'vic', 'heart-disease', 'industry',
#        'doctors-and-medical-professionals', 'act', 'medical-research',
#        'diet-and-nutrition', 'health-policy', 'smoking', 'obesity',
#        'food-and-beverage', 'states-and-territories', 'qld', 'cancer',
#        'community-and-society', 'family-and-children', 'federal-government',
#        'lifestyle-and-leisure',
#        'indigenous-aboriginal-and-torres-strait-islander', 'diabetes',
#        'exercise-and-fitness', 'health', 'healthcare-facilities',
#        'advertising', 'sa', 'nsw', 'research', 'australia', 'wa',
#        'business-economics-and-finance', 'federal---state-issues',
#        'science-and-technology', 'child-health-and-behaviour'],
#       dtype='object')
# Order of the chain: Index(['research', 'united-kingdom', 'child-health-and-behaviour', 'obesity',
#        'community-and-society', 'advertising-and-marketing',
#        'states-and-territories', 'nsw', 'science-and-technology',
#        'federal---state-issues', 'heart-disease', 'act', 'diet-and-nutrition',
#        'medical-research', 'business-economics-and-finance', 'health-policy',
#        'advertising', 'indigenous-aboriginal-and-torres-strait-islander',
#        'doctors-and-medical-professionals', 'exercise-and-fitness',
#        'australia', 'children', 'healthcare-facilities', 'vic',
#        'federal-government', 'lifestyle-and-leisure', 'schools',
#        'government-and-politics', 'tas', 'sa', 'food-and-beverage',
#        'united-states', 'education', 'diseases-and-disorders', 'smoking',
#        'industry', 'cancer', 'wa', 'diabetes', 'qld', 'family-and-children',
#        'health'],
#       dtype='object')
# Order of the chain: Index(['lifestyle-and-leisure', 'act', 'healthcare-facilities', 'schools',
#        'nsw', 'industry', 'vic', 'diet-and-nutrition', 'medical-research',
#        'doctors-and-medical-professionals', 'australia', 'federal-government',
#        'united-kingdom', 'advertising-and-marketing', 'smoking',
#        'government-and-politics', 'heart-disease',
#        'child-health-and-behaviour', 'diseases-and-disorders', 'advertising',
#        'united-states', 'sa', 'food-and-beverage', 'education',
#        'health-policy', 'children', 'federal---state-issues',
#        'family-and-children', 'diabetes', 'cancer',
#        'business-economics-and-finance', 'wa', 'community-and-society',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'exercise-and-fitness', 'tas', 'research', 'science-and-technology',
#        'obesity', 'health', 'qld', 'states-and-territories'],
#       dtype='object')
# Order of the chain: Index(['act', 'obesity', 'states-and-territories', 'wa', 'advertising',
#        'healthcare-facilities', 'education', 'cancer', 'schools', 'sa',
#        'advertising-and-marketing', 'lifestyle-and-leisure',
#        'child-health-and-behaviour', 'diabetes', 'science-and-technology',
#        'qld', 'united-kingdom', 'children', 'smoking', 'australia',
#        'exercise-and-fitness', 'nsw', 'federal-government',
#        'diseases-and-disorders', 'federal---state-issues', 'united-states',
#        'diet-and-nutrition', 'health-policy', 'research', 'industry',
#        'business-economics-and-finance', 'food-and-beverage', 'vic',
#        'indigenous-aboriginal-and-torres-strait-islander', 'medical-research',
#        'heart-disease', 'government-and-politics', 'tas',
#        'community-and-society', 'family-and-children',
#        'doctors-and-medical-professionals', 'health'],
#       dtype='object')
# Order of the chain: Index(['medical-research', 'schools', 'sa', 'diseases-and-disorders',
#        'obesity', 'family-and-children', 'education',
#        'indigenous-aboriginal-and-torres-strait-islander', 'australia', 'nsw',
#        'government-and-politics', 'exercise-and-fitness', 'united-states',
#        'federal-government', 'diet-and-nutrition', 'heart-disease', 'smoking',
#        'industry', 'tas', 'qld', 'health', 'wa', 'advertising-and-marketing',
#        'community-and-society', 'united-kingdom',
#        'doctors-and-medical-professionals', 'cancer', 'federal---state-issues',
#        'lifestyle-and-leisure', 'child-health-and-behaviour',
#        'food-and-beverage', 'states-and-territories', 'health-policy',
#        'business-economics-and-finance', 'vic', 'healthcare-facilities',
#        'research', 'science-and-technology', 'advertising', 'act', 'children',
#        'diabetes'],
#       dtype='object')
# Order of the chain: Index(['federal-government', 'children', 'act', 'united-kingdom', 'diabetes',
#        'states-and-territories', 'wa', 'government-and-politics',
#        'science-and-technology', 'vic', 'health', 'sa', 'australia', 'qld',
#        'education', 'tas', 'healthcare-facilities', 'community-and-society',
#        'diet-and-nutrition', 'business-economics-and-finance',
#        'diseases-and-disorders', 'lifestyle-and-leisure',
#        'advertising-and-marketing', 'heart-disease', 'food-and-beverage',
#        'smoking', 'cancer', 'industry', 'nsw', 'united-states',
#        'family-and-children', 'advertising',
#        'doctors-and-medical-professionals', 'research', 'obesity',
#        'exercise-and-fitness', 'schools', 'medical-research',
#        'child-health-and-behaviour', 'federal---state-issues', 'health-policy',
#        'indigenous-aboriginal-and-torres-strait-islander'],
#       dtype='object')
# Order of the chain: Index(['indigenous-aboriginal-and-torres-strait-islander', 'obesity',
#        'industry', 'united-kingdom', 'united-states', 'federal---state-issues',
#        'smoking', 'advertising', 'doctors-and-medical-professionals',
#        'child-health-and-behaviour', 'education', 'research', 'health',
#        'healthcare-facilities', 'nsw', 'children', 'government-and-politics',
#        'medical-research', 'health-policy', 'diabetes', 'food-and-beverage',
#        'tas', 'states-and-territories', 'cancer', 'science-and-technology',
#        'qld', 'wa', 'lifestyle-and-leisure', 'diet-and-nutrition',
#        'family-and-children', 'schools', 'vic', 'federal-government',
#        'diseases-and-disorders', 'sa', 'business-economics-and-finance',
#        'exercise-and-fitness', 'australia', 'act', 'heart-disease',
#        'advertising-and-marketing', 'community-and-society'],
#       dtype='object')
# Order of the chain: Index(['food-and-beverage', 'family-and-children', 'research',
#        'states-and-territories', 'health-policy', 'medical-research',
#        'australia', 'qld', 'cancer', 'business-economics-and-finance', 'tas',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'science-and-technology', 'advertising', 'united-states',
#        'heart-disease', 'government-and-politics', 'industry', 'nsw',
#        'doctors-and-medical-professionals', 'exercise-and-fitness',
#        'advertising-and-marketing', 'smoking', 'act', 'diet-and-nutrition',
#        'lifestyle-and-leisure', 'schools', 'education', 'sa',
#        'child-health-and-behaviour', 'diabetes', 'united-kingdom', 'children',
#        'vic', 'obesity', 'federal-government', 'health', 'wa',
#        'community-and-society', 'federal---state-issues',
#        'healthcare-facilities', 'diseases-and-disorders'],
#       dtype='object')
# Order of the chain: Index(['united-kingdom', 'food-and-beverage', 'smoking', 'cancer',
#        'exercise-and-fitness', 'industry', 'business-economics-and-finance',
#        'qld', 'federal---state-issues', 'healthcare-facilities', 'diabetes',
#        'research', 'states-and-territories', 'nsw', 'united-states',
#        'diseases-and-disorders', 'advertising', 'schools',
#        'child-health-and-behaviour', 'science-and-technology',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'advertising-and-marketing', 'health-policy', 'vic', 'heart-disease',
#        'sa', 'obesity', 'children', 'medical-research', 'australia', 'tas',
#        'act', 'government-and-politics', 'community-and-society',
#        'diet-and-nutrition', 'health', 'family-and-children',
#        'federal-government', 'lifestyle-and-leisure',
#        'doctors-and-medical-professionals', 'education', 'wa'],
#       dtype='object')
# Order of the chain: Index(['wa', 'lifestyle-and-leisure', 'sa', 'business-economics-and-finance',
#        'health', 'schools', 'child-health-and-behaviour', 'united-states',
#        'states-and-territories', 'exercise-and-fitness', 'obesity',
#        'diseases-and-disorders', 'industry', 'education', 'research',
#        'community-and-society', 'cancer', 'federal-government', 'qld',
#        'diet-and-nutrition', 'government-and-politics', 'australia',
#        'united-kingdom', 'heart-disease', 'act', 'vic', 'nsw',
#        'food-and-beverage', 'diabetes', 'federal---state-issues',
#        'doctors-and-medical-professionals', 'science-and-technology',
#        'children', 'advertising', 'medical-research',
#        'indigenous-aboriginal-and-torres-strait-islander', 'health-policy',
#        'family-and-children', 'tas', 'advertising-and-marketing',
#        'healthcare-facilities', 'smoking'],
#       dtype='object')
# Order of the chain: Index(['food-and-beverage', 'states-and-territories',
#        'indigenous-aboriginal-and-torres-strait-islander', 'advertising',
#        'health-policy', 'lifestyle-and-leisure', 'healthcare-facilities',
#        'government-and-politics', 'child-health-and-behaviour', 'sa',
#        'smoking', 'medical-research', 'united-kingdom', 'family-and-children',
#        'business-economics-and-finance', 'diabetes', 'federal-government',
#        'doctors-and-medical-professionals', 'australia', 'obesity',
#        'advertising-and-marketing', 'cancer', 'schools',
#        'diseases-and-disorders', 'children', 'research', 'act', 'qld', 'wa',
#        'education', 'heart-disease', 'exercise-and-fitness', 'tas',
#        'federal---state-issues', 'community-and-society', 'health', 'nsw',
#        'united-states', 'vic', 'science-and-technology', 'diet-and-nutrition',
#        'industry'],
#       dtype='object')
# Order of the chain: Index(['united-kingdom', 'australia', 'industry', 'healthcare-facilities',
#        'act', 'doctors-and-medical-professionals', 'cancer', 'health',
#        'advertising-and-marketing', 'community-and-society', 'nsw',
#        'advertising', 'diseases-and-disorders', 'family-and-children',
#        'government-and-politics', 'lifestyle-and-leisure', 'diabetes',
#        'diet-and-nutrition', 'food-and-beverage', 'united-states',
#        'indigenous-aboriginal-and-torres-strait-islander', 'children',
#        'business-economics-and-finance', 'exercise-and-fitness', 'schools',
#        'obesity', 'qld', 'wa', 'states-and-territories', 'research', 'vic',
#        'federal-government', 'federal---state-issues', 'smoking',
#        'medical-research', 'education', 'sa', 'science-and-technology', 'tas',
#        'heart-disease', 'health-policy', 'child-health-and-behaviour'],
#       dtype='object')
# Order of the chain: Index(['business-economics-and-finance', 'smoking', 'sa',
#        'science-and-technology', 'qld', 'advertising-and-marketing',
#        'advertising', 'lifestyle-and-leisure', 'research',
#        'child-health-and-behaviour', 'exercise-and-fitness',
#        'indigenous-aboriginal-and-torres-strait-islander', 'health-policy',
#        'federal---state-issues', 'wa', 'federal-government', 'diabetes', 'tas',
#        'government-and-politics', 'diseases-and-disorders', 'medical-research',
#        'food-and-beverage', 'family-and-children', 'heart-disease', 'vic',
#        'cancer', 'industry', 'health', 'community-and-society', 'nsw',
#        'schools', 'united-states', 'australia', 'children', 'united-kingdom',
#        'diet-and-nutrition', 'education', 'states-and-territories', 'obesity',
#        'act', 'healthcare-facilities', 'doctors-and-medical-professionals'],
#       dtype='object')
# Order of the chain: Index(['child-health-and-behaviour', 'diabetes', 'australia',
#        'indigenous-aboriginal-and-torres-strait-islander', 'research',
#        'states-and-territories', 'vic', 'united-kingdom', 'tas', 'education',
#        'sa', 'children', 'advertising-and-marketing', 'wa',
#        'healthcare-facilities', 'diet-and-nutrition', 'lifestyle-and-leisure',
#        'business-economics-and-finance', 'nsw', 'smoking', 'heart-disease',
#        'industry', 'diseases-and-disorders', 'act', 'family-and-children',
#        'cancer', 'health', 'qld', 'government-and-politics', 'advertising',
#        'health-policy', 'federal-government',
#        'doctors-and-medical-professionals', 'federal---state-issues',
#        'united-states', 'exercise-and-fitness', 'medical-research',
#        'food-and-beverage', 'obesity', 'science-and-technology', 'schools',
#        'community-and-society'],
#       dtype='object')
# Order of the chain: Index(['science-and-technology', 'government-and-politics',
#        'diseases-and-disorders', 'united-kingdom', 'research', 'advertising',
#        'children', 'doctors-and-medical-professionals',
#        'states-and-territories', 'community-and-society', 'medical-research',
#        'health-policy', 'family-and-children', 'vic',
#        'advertising-and-marketing', 'federal-government', 'smoking',
#        'industry', 'child-health-and-behaviour', 'nsw', 'wa', 'diabetes', 'sa',
#        'exercise-and-fitness', 'act', 'cancer', 'lifestyle-and-leisure',
#        'food-and-beverage', 'qld', 'tas',
#        'indigenous-aboriginal-and-torres-strait-islander', 'education',
#        'australia', 'business-economics-and-finance', 'schools', 'obesity',
#        'health', 'diet-and-nutrition', 'healthcare-facilities',
#        'federal---state-issues', 'united-states', 'heart-disease'],
#       dtype='object')
# Order of the chain: Index(['food-and-beverage', 'federal-government', 'australia', 'qld',
#        'lifestyle-and-leisure', 'act', 'smoking', 'cancer',
#        'states-and-territories', 'schools', 'obesity', 'community-and-society',
#        'wa', 'research', 'children', 'tas', 'government-and-politics',
#        'family-and-children', 'health', 'diet-and-nutrition', 'diabetes',
#        'heart-disease', 'business-economics-and-finance', 'vic', 'nsw',
#        'advertising', 'indigenous-aboriginal-and-torres-strait-islander',
#        'united-kingdom', 'sa', 'industry', 'health-policy',
#        'healthcare-facilities', 'child-health-and-behaviour', 'education',
#        'doctors-and-medical-professionals', 'science-and-technology',
#        'advertising-and-marketing', 'exercise-and-fitness',
#        'diseases-and-disorders', 'medical-research', 'federal---state-issues',
#        'united-states'],
#       dtype='object')
# Order of the chain: Index(['indigenous-aboriginal-and-torres-strait-islander', 'wa',
#        'government-and-politics', 'sa', 'federal-government',
#        'community-and-society', 'diseases-and-disorders', 'australia',
#        'schools', 'education', 'qld', 'science-and-technology', 'nsw',
#        'business-economics-and-finance', 'states-and-territories', 'research',
#        'exercise-and-fitness', 'obesity', 'medical-research',
#        'advertising-and-marketing', 'child-health-and-behaviour',
#        'lifestyle-and-leisure', 'doctors-and-medical-professionals', 'health',
#        'diabetes', 'family-and-children', 'food-and-beverage', 'smoking',
#        'tas', 'cancer', 'healthcare-facilities', 'united-kingdom',
#        'health-policy', 'advertising', 'united-states', 'children',
#        'diet-and-nutrition', 'act', 'federal---state-issues', 'industry',
#        'heart-disease', 'vic'],
#       dtype='object')
# Order of the chain: Index(['doctors-and-medical-professionals', 'united-states',
#        'business-economics-and-finance', 'research', 'healthcare-facilities',
#        'lifestyle-and-leisure', 'advertising', 'health',
#        'science-and-technology', 'medical-research', 'food-and-beverage',
#        'federal-government', 'cancer', 'diet-and-nutrition', 'nsw', 'children',
#        'smoking', 'diseases-and-disorders', 'tas', 'vic',
#        'child-health-and-behaviour', 'industry', 'health-policy', 'qld',
#        'diabetes', 'sa', 'family-and-children', 'australia', 'act',
#        'federal---state-issues', 'schools', 'exercise-and-fitness',
#        'advertising-and-marketing', 'obesity', 'united-kingdom',
#        'indigenous-aboriginal-and-torres-strait-islander', 'wa',
#        'heart-disease', 'community-and-society', 'education',
#        'states-and-territories', 'government-and-politics'],
#       dtype='object')
# Order of the chain: Index(['diseases-and-disorders', 'vic', 'united-kingdom', 'education', 'sa',
#        'government-and-politics', 'food-and-beverage', 'smoking', 'diabetes',
#        'health-policy', 'advertising', 'family-and-children', 'heart-disease',
#        'nsw', 'exercise-and-fitness', 'research', 'children', 'qld',
#        'lifestyle-and-leisure', 'schools', 'diet-and-nutrition',
#        'indigenous-aboriginal-and-torres-strait-islander', 'wa', 'health',
#        'science-and-technology', 'australia', 'child-health-and-behaviour',
#        'medical-research', 'united-states', 'cancer',
#        'business-economics-and-finance', 'doctors-and-medical-professionals',
#        'industry', 'healthcare-facilities', 'community-and-society', 'tas',
#        'obesity', 'advertising-and-marketing', 'states-and-territories', 'act',
#        'federal-government', 'federal---state-issues'],
#       dtype='object')
# Order of the chain: Index(['act', 'education', 'indigenous-aboriginal-and-torres-strait-islander',
#        'food-and-beverage', 'nsw', 'vic', 'sa', 'smoking', 'united-kingdom',
#        'lifestyle-and-leisure', 'industry', 'schools', 'united-states',
#        'federal-government', 'tas', 'advertising', 'exercise-and-fitness',
#        'research', 'advertising-and-marketing', 'science-and-technology',
#        'business-economics-and-finance', 'diseases-and-disorders', 'qld', 'wa',
#        'diabetes', 'australia', 'states-and-territories',
#        'federal---state-issues', 'health', 'heart-disease', 'health-policy',
#        'community-and-society', 'diet-and-nutrition', 'family-and-children',
#        'cancer', 'child-health-and-behaviour',
#        'doctors-and-medical-professionals', 'medical-research',
#        'healthcare-facilities', 'children', 'obesity',
#        'government-and-politics'],
#       dtype='object')
# Order of the chain: Index(['health', 'government-and-politics', 'obesity', 'act',
#        'child-health-and-behaviour', 'united-states', 'community-and-society',
#        'united-kingdom', 'vic', 'health-policy', 'nsw', 'qld', 'sa',
#        'federal---state-issues', 'exercise-and-fitness',
#        'doctors-and-medical-professionals', 'science-and-technology',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'lifestyle-and-leisure', 'schools', 'tas',
#        'business-economics-and-finance', 'advertising',
#        'states-and-territories', 'wa', 'healthcare-facilities', 'diabetes',
#        'research', 'family-and-children', 'children', 'smoking', 'australia',
#        'diet-and-nutrition', 'medical-research', 'advertising-and-marketing',
#        'food-and-beverage', 'cancer', 'federal-government', 'education',
#        'industry', 'diseases-and-disorders', 'heart-disease'],
#       dtype='object')
# Order of the chain: Index(['nsw', 'qld', 'act', 'united-kingdom', 'community-and-society',
#        'lifestyle-and-leisure', 'cancer', 'advertising', 'schools', 'smoking',
#        'states-and-territories', 'healthcare-facilities',
#        'exercise-and-fitness', 'tas', 'government-and-politics',
#        'diseases-and-disorders', 'federal-government',
#        'indigenous-aboriginal-and-torres-strait-islander', 'medical-research',
#        'sa', 'food-and-beverage', 'diet-and-nutrition', 'education',
#        'federal---state-issues', 'doctors-and-medical-professionals',
#        'research', 'vic', 'heart-disease', 'science-and-technology',
#        'business-economics-and-finance', 'wa', 'child-health-and-behaviour',
#        'obesity', 'diabetes', 'industry', 'children',
#        'advertising-and-marketing', 'health-policy', 'health', 'united-states',
#        'australia', 'family-and-children'],
#       dtype='object')
# Order of the chain: Index(['child-health-and-behaviour', 'sa', 'obesity', 'australia',
#        'lifestyle-and-leisure', 'education', 'children',
#        'diseases-and-disorders', 'government-and-politics', 'act', 'research',
#        'diet-and-nutrition', 'united-kingdom', 'diabetes',
#        'advertising-and-marketing', 'health-policy', 'schools',
#        'united-states', 'smoking', 'community-and-society',
#        'states-and-territories', 'federal-government', 'medical-research',
#        'food-and-beverage', 'science-and-technology',
#        'doctors-and-medical-professionals', 'vic', 'wa', 'tas', 'industry',
#        'federal---state-issues', 'health', 'business-economics-and-finance',
#        'family-and-children',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'healthcare-facilities', 'heart-disease', 'cancer', 'qld',
#        'exercise-and-fitness', 'advertising', 'nsw'],
#       dtype='object')
# Order of the chain: Index(['lifestyle-and-leisure', 'qld', 'act', 'vic', 'federal---state-issues',
#        'united-states', 'schools', 'federal-government',
#        'advertising-and-marketing', 'children', 'smoking',
#        'states-and-territories', 'obesity', 'advertising', 'health-policy',
#        'nsw', 'food-and-beverage', 'family-and-children', 'health', 'diabetes',
#        'cancer', 'united-kingdom', 'australia', 'tas', 'research',
#        'medical-research', 'wa', 'community-and-society', 'diet-and-nutrition',
#        'industry', 'education', 'heart-disease', 'diseases-and-disorders',
#        'business-economics-and-finance', 'science-and-technology',
#        'healthcare-facilities', 'child-health-and-behaviour',
#        'exercise-and-fitness', 'government-and-politics',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'doctors-and-medical-professionals', 'sa'],
#       dtype='object')
# Order of the chain: Index(['united-states', 'schools', 'nsw', 'advertising-and-marketing',
#        'indigenous-aboriginal-and-torres-strait-islander', 'united-kingdom',
#        'food-and-beverage', 'states-and-territories', 'science-and-technology',
#        'health', 'healthcare-facilities', 'advertising', 'research',
#        'diseases-and-disorders', 'doctors-and-medical-professionals',
#        'diet-and-nutrition', 'sa', 'tas', 'smoking', 'federal-government',
#        'cancer', 'industry', 'obesity', 'community-and-society',
#        'lifestyle-and-leisure', 'qld', 'act', 'australia',
#        'government-and-politics', 'medical-research',
#        'business-economics-and-finance', 'exercise-and-fitness',
#        'health-policy', 'heart-disease', 'wa', 'child-health-and-behaviour',
#        'federal---state-issues', 'children', 'family-and-children',
#        'education', 'vic', 'diabetes'],
#       dtype='object')
# Order of the chain: Index(['lifestyle-and-leisure', 'united-kingdom', 'united-states', 'australia',
#        'education', 'family-and-children', 'advertising', 'obesity',
#        'community-and-society', 'heart-disease', 'cancer',
#        'doctors-and-medical-professionals', 'research', 'exercise-and-fitness',
#        'health', 'vic', 'science-and-technology', 'food-and-beverage',
#        'federal-government', 'states-and-territories', 'diet-and-nutrition',
#        'government-and-politics', 'schools', 'child-health-and-behaviour',
#        'diseases-and-disorders', 'health-policy', 'healthcare-facilities',
#        'business-economics-and-finance', 'tas', 'wa', 'diabetes',
#        'indigenous-aboriginal-and-torres-strait-islander', 'industry',
#        'children', 'smoking', 'qld', 'sa', 'nsw', 'federal---state-issues',
#        'act', 'advertising-and-marketing', 'medical-research'],
#       dtype='object')
# Order of the chain: Index(['industry', 'wa', 'child-health-and-behaviour',
#        'diseases-and-disorders', 'australia', 'healthcare-facilities',
#        'children', 'act', 'business-economics-and-finance', 'research',
#        'heart-disease', 'lifestyle-and-leisure', 'united-states',
#        'diet-and-nutrition', 'nsw', 'science-and-technology', 'smoking',
#        'health', 'schools', 'exercise-and-fitness',
#        'indigenous-aboriginal-and-torres-strait-islander', 'obesity', 'sa',
#        'qld', 'united-kingdom', 'government-and-politics',
#        'federal-government', 'federal---state-issues', 'family-and-children',
#        'advertising', 'diabetes', 'food-and-beverage',
#        'doctors-and-medical-professionals', 'advertising-and-marketing',
#        'health-policy', 'medical-research', 'vic', 'states-and-territories',
#        'tas', 'cancer', 'education', 'community-and-society'],
#       dtype='object')
# Order of the chain: Index(['sa', 'advertising-and-marketing', 'community-and-society',
#        'heart-disease', 'advertising', 'qld', 'diet-and-nutrition',
#        'diseases-and-disorders', 'exercise-and-fitness', 'wa',
#        'united-kingdom', 'vic', 'schools', 'federal---state-issues',
#        'indigenous-aboriginal-and-torres-strait-islander', 'health',
#        'family-and-children', 'healthcare-facilities', 'children', 'australia',
#        'child-health-and-behaviour', 'research',
#        'doctors-and-medical-professionals', 'nsw', 'industry',
#        'federal-government', 'tas', 'business-economics-and-finance',
#        'food-and-beverage', 'science-and-technology', 'united-states',
#        'diabetes', 'cancer', 'smoking', 'medical-research', 'education', 'act',
#        'states-and-territories', 'government-and-politics',
#        'lifestyle-and-leisure', 'obesity', 'health-policy'],
#       dtype='object')
# Order of the chain: Index(['sa', 'advertising', 'diet-and-nutrition', 'children',
#        'indigenous-aboriginal-and-torres-strait-islander', 'united-states',
#        'federal---state-issues', 'states-and-territories', 'health-policy',
#        'australia', 'schools', 'science-and-technology',
#        'exercise-and-fitness', 'healthcare-facilities', 'smoking',
#        'government-and-politics', 'wa', 'tas', 'act', 'medical-research',
#        'lifestyle-and-leisure', 'advertising-and-marketing', 'united-kingdom',
#        'doctors-and-medical-professionals', 'heart-disease', 'qld',
#        'education', 'business-economics-and-finance', 'obesity',
#        'diseases-and-disorders', 'research', 'industry', 'family-and-children',
#        'health', 'food-and-beverage', 'diabetes', 'community-and-society',
#        'child-health-and-behaviour', 'nsw', 'cancer', 'vic',
#        'federal-government'],
#       dtype='object')
# Order of the chain: Index(['act', 'schools', 'qld', 'smoking', 'federal-government',
#        'lifestyle-and-leisure', 'exercise-and-fitness',
#        'science-and-technology', 'community-and-society',
#        'family-and-children', 'united-kingdom', 'food-and-beverage',
#        'diet-and-nutrition', 'nsw', 'federal---state-issues',
#        'advertising-and-marketing', 'doctors-and-medical-professionals',
#        'diabetes', 'united-states', 'health', 'heart-disease',
#        'healthcare-facilities', 'advertising', 'industry', 'vic',
#        'business-economics-and-finance', 'wa', 'states-and-territories', 'tas',
#        'diseases-and-disorders', 'education', 'medical-research',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'government-and-politics', 'obesity', 'child-health-and-behaviour',
#        'australia', 'children', 'research', 'sa', 'health-policy', 'cancer'],
#       dtype='object')
# /Users/jiangjunhao/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# --- Data Information ---
# dataset: /Volumes/Samsung_T5/research/data/ABC_news_data/obesity/
# number of label: 42
# number of attribute: 335
# number of instance: 891
#
#
# --- Order of the chain ---
# Index(['act', 'schools', 'qld', 'smoking', 'federal-government',
#        'lifestyle-and-leisure', 'exercise-and-fitness',
#        'science-and-technology', 'community-and-society',
#        'family-and-children', 'united-kingdom', 'food-and-beverage',
#        'diet-and-nutrition', 'nsw', 'federal---state-issues',
#        'advertising-and-marketing', 'doctors-and-medical-professionals',
#        'diabetes', 'united-states', 'health', 'heart-disease',
#        'healthcare-facilities', 'advertising', 'industry', 'vic',
#        'business-economics-and-finance', 'wa', 'states-and-territories', 'tas',
#        'diseases-and-disorders', 'education', 'medical-research',
#        'indigenous-aboriginal-and-torres-strait-islander',
#        'government-and-politics', 'obesity', 'child-health-and-behaviour',
#        'australia', 'children', 'research', 'sa', 'health-policy', 'cancer'],
#       dtype='object')
#
# act: TP:1, TN:419, FP:19, FN:7
# advertising: TP:9, TN:416, FP:19, FN:2
# advertising-and-marketing: TP:9, TN:408, FP:25, FN:4
# australia: TP:101, TN:207, FP:63, FN:75
# business-economics-and-finance: TP:6, TN:399, FP:34, FN:7
# cancer: TP:3, TN:424, FP:8, FN:11
# child-health-and-behaviour: TP:23, TN:334, FP:54, FN:35
# children: TP:8, TN:381, FP:28, FN:29
# community-and-society: TP:1, TN:405, FP:14, FN:26
# diabetes: TP:10, TN:384, FP:32, FN:20
# diet-and-nutrition: TP:17, TN:336, FP:55, FN:38
# diseases-and-disorders: TP:9, TN:384, FP:28, FN:25
# doctors-and-medical-professionals: TP:5, TN:411, FP:11, FN:19
# education: TP:1, TN:430, FP:8, FN:7
# exercise-and-fitness: TP:4, TN:405, FP:13, FN:24
# family-and-children: TP:1, TN:414, FP:14, FN:17
# federal---state-issues: TP:5, TN:409, FP:27, FN:5
# federal-government: TP:17, TN:368, FP:39, FN:22
# food-and-beverage: TP:9, TN:388, FP:37, FN:12
# government-and-politics: TP:9, TN:363, FP:49, FN:25
# health: TP:61, TN:211, FP:90, FN:84
# health-policy: TP:9, TN:405, FP:17, FN:15
# healthcare-facilities: TP:4, TN:416, FP:14, FN:12
# heart-disease: TP:4, TN:417, FP:17, FN:8
# indigenous-aboriginal-and-torres-strait-islander: TP:2, TN:427, FP:7, FN:10
# industry: TP:4, TN:406, FP:30, FN:6
# lifestyle-and-leisure: TP:0, TN:437, FP:0, FN:9
# medical-research: TP:27, TN:358, FP:43, FN:18
# nsw: TP:4, TN:397, FP:16, FN:29
# obesity: TP:168, TN:140, FP:78, FN:60
# qld: TP:5, TN:417, FP:11, FN:13
# research: TP:17, TN:383, FP:30, FN:16
# sa: TP:3, TN:410, FP:18, FN:15
# schools: TP:9, TN:411, FP:16, FN:10
# science-and-technology: TP:3, TN:416, FP:17, FN:10
# smoking: TP:1, TN:427, FP:11, FN:7
# states-and-territories: TP:15, TN:350, FP:52, FN:29
# tas: TP:0, TN:427, FP:7, FN:12
# united-kingdom: TP:7, TN:411, FP:19, FN:9
# united-states: TP:36, TN:358, FP:38, FN:14
# vic: TP:2, TN:418, FP:11, FN:15
# wa: TP:1, TN:417, FP:9, FN:19
# --- Performance ---
# coverage_error = 14.18 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.14
# hamming_loss = 0.1
# f1_macro = 0.26
# f1_micro = 0.39
# Jaccard_Index = 0.9
# zero_one_error = 0.98
#
# - f1 for each label -
# label_act = 0.07
# label_advertising = 0.46
# label_advertising-and-marketing = 0.38
# label_australia = 0.59
# label_business-economics-and-finance = 0.23
# label_cancer = 0.24
# label_child-health-and-behaviour = 0.34
# label_children = 0.22
# label_community-and-society = 0.05
# label_diabetes = 0.28
# label_diet-and-nutrition = 0.27
# label_diseases-and-disorders = 0.25
# label_doctors-and-medical-professionals = 0.25
# label_education = 0.12
# label_exercise-and-fitness = 0.18
# label_family-and-children = 0.06
# label_federal---state-issues = 0.24
# label_federal-government = 0.36
# label_food-and-beverage = 0.27
# label_government-and-politics = 0.2
# label_health = 0.41
# label_health-policy = 0.36
# label_healthcare-facilities = 0.24
# label_heart-disease = 0.24
# label_indigenous-aboriginal-and-torres-strait-islander = 0.19
# label_industry = 0.18
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.47
# label_nsw = 0.15
# label_obesity = 0.71
# label_qld = 0.29
# label_research = 0.43
# label_sa = 0.15
# label_schools = 0.41
# label_science-and-technology = 0.18
# label_smoking = 0.1
# label_states-and-territories = 0.27
# label_tas = 0.0
# label_united-kingdom = 0.33
# label_united-states = 0.58
# label_vic = 0.13
# label_wa = 0.07

# %% [markdown]
# ## CC using ESKDB

# %%
# prepare data
def csv_to_arff(X, label_i, savePath):
    # get attributes
    attributes=[(X.columns[i],['0', '1']) for i in range(len(X.columns))]
    attributes.append(('label_'+label_i.name,['0', '1']))

    data=[]
    i = 0
    while i < len(label_i):
        attr_data = [str(j) for j in list(X.iloc[i,:])]
        label_data = [str(label_i[i])]
        row_data = attr_data+label_data
        data.append(row_data) 
        i+=1
    # set obj
    obj = {
       'description': u'',
       'relation': 'relation',
       'attributes': attributes,
       'data': data,
    }
    arff_data = arff.dumps(obj)
    w_file = open(savePath+label_i.name+".arff", "w")
    w_file.write(arff_data)
    w_file.close()

def get_arff(X, label, savePath):
    
    n_label = label.shape[1]
    # get orders
    order = random.sample(list(range(n_label)),n_label) # get orders
    
    #  get all arff files, one for each label
    for i in range(n_label):
        label_i = label.iloc[:,order[i]]
        print("--Running label:",label_i.name)
        csv_to_arff(X, label_i, savePath)
        
        label_i.name = 'label_' + label_i.name
        X = pd.concat([X, label_i], axis=1)
    print("--finished getting arff files")
    return order

def run_eskdb(label_arff, resultFile, k, l, e, i):
    command = "./run_ECC.sh "+resultFile+" "+k+" "+i+" "+l+" "+e+" "+label_arff
    subprocess.call("cd /Volumes/Samsung_T5/research/programme/research_python/", shell=True)
    #print(command)
    return subprocess.call(command, shell=True)

def get_result(resultPath):

    y_pred = pd.DataFrame()
    y_true = pd.DataFrame()
    y_prob = pd.DataFrame()
    names = []
    for file in os.listdir(resultPath):
        with open(os.path.join(resultPath,file), 'r') as f:
            try:
                lines = f.readlines()
            except:
                print(file)
            else:
                names.append(file[:-4])
                pred = []
                true = []
                prob = []
                train_time_total = 0
                test_time_total = 0
                error_marco = 0
                for line in lines:
                    if line.startswith('pred'):
                        pred.append(int(re.search('pred :\t(.)',line).group(1)))
                        true.append(int(re.search('true :\t(.)',line).group(1)))
                        prob.append(float(re.search('prob :\t(.*)',line).group(1)))
                    elif line.startswith('RSME'):
                        rsme = float(re.search('RSME :\t\t(.*)',line).group(1))
                    elif line.startswith('Error'):
                        error = float(re.search('Error :\t\t(.*)',line).group(1))
                    elif line.startswith("Training time"):
                        train_time = float(re.search('Training time :\s{1,}(.*)',line).group(1))
                        train_time_total = train_time_total + train_time
                    elif line.startswith("Testing time"):
                        test_time = float(re.search('Testing time :\s{1,}(.*)',line).group(1))
                        test_time_total = test_time_total + test_time
                    elif line.startswith("["):
                        para = line
                    elif line.startswith("test0Indexes"):
                        index = list(map(int,re.search('test0Indexes: {(.*)}',line).group(1).split(', ')))
                        
                y_pred = pd.concat([y_pred,pd.DataFrame(pred)],axis=1)
                y_true = pd.concat([y_true,pd.DataFrame(true)],axis=1)
                y_prob = pd.concat([y_prob,pd.DataFrame(prob)],axis=1)
    y_pred.columns = names
    y_true.columns = names
    print(para)
    print("number of label:", y_pred.shape[1])
    print("training time:",train_time_total)
    print("testing time:",test_time_total)
    return y_pred,y_true,y_prob

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)
n_label = label.shape[1]

# data set information
n_label = label.shape[1]
n_attr = data.shape[1]
n_instance = data.shape[0]
avg_label_per_instance = label.sum(axis=1).mean()

# get orders
order = random.sample(list(range(n_label)),n_label) # get orders

# train and test on the first label
savePath = '/Users/jiangjunhao/Desktop/test/'
## prepare data, get the arff file
for i in range(n_label):
    label_i = label.iloc[:,order[i]]
    #print("--Running label:",label_i.name)
    csv_to_arff(data, label_i, savePath)

    # run eskdb
    label_arff = os.path.join(savePath,label_i.name+'.arff')
    resultFile = 'a' # /Volumes/Samsung_T5/research/programme/ESKDB_HDP/result/resultFile
    k = '5'
    i = '5000'
    l = '2'
    e = '20'

    run_eskdb(label_arff, resultFile, k, l, e, i)

    result = os.path.join("/Volumes/Samsung_T5/research/programme/ESKDB_HDP/result",resultFile, label_i.name+'.txt')
    with open(result, 'r') as f:
        try:
            lines = f.readlines()
        except:
            print(file)
        else:
            pred = []
            for line in lines:
                if line.startswith('pred'):
                    pred.append(int(re.search('pred :\t(.)',line).group(1)))
                elif line.startswith("test0Indexes"):
                    index = list(map(int,re.search('test0Indexes: {(.*)}',line).group(1).split(', ')))

            label.loc[index,label_i.name] = pred
            temp = label.loc[:,label_i.name]
            temp.name = 'label_'+label_i.name
            data = pd.concat([data, label.loc[:,label_i.name]],axis=1)

# get result
resultPath = '/Volumes/Samsung_T5/research/programme/ESKDB_HDP/result/'+resultFile+'/'
y_pred,y_true,y_prob = get_result(resultPath)
performance = evaluation(y_pred=y_pred, y_true=y_true, y_prob=y_prob)

# print orders:
print(label.columns[order])

# get confusion matrix
print("\n--- Confusion matrix ---")
get_confusion_matrix(y_pred, y_true, y_pred.columns)

# print performance
print("--- Performance ---")
for key, value in performance.items():
    if key == "f1_each_label":
        print("\n- f1 for each label -")
        for i in range(n_label):
            print("label_"+label.columns[i],"=",round(value[i],2))
    elif key == "coverage_error":
        print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
    else:
        print(key,'=',round(value,2))
# Out:
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2682.0
# testing time: 2210.0
# /Users/jiangjunhao/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Index(['advertising-and-marketing', 'act', 'lifestyle-and-leisure',
#        'food-and-beverage', 'heart-disease', 'children', 'health',
#        'medical-research', 'doctors-and-medical-professionals',
#        'federal---state-issues', 'advertising', 'united-states', 'industry',
#        'healthcare-facilities', 'government-and-politics', 'qld',
#        'family-and-children', 'exercise-and-fitness', 'federal-government',
#        'cancer', 'research', 'diet-and-nutrition', 'vic', 'smoking', 'wa',
#        'diseases-and-disorders', 'sa', 'obesity', 'schools', 'health-policy',
#        'education', 'diabetes', 'nsw', 'child-health-and-behaviour',
#        'australia', 'community-and-society', 'states-and-territories',
#        'science-and-technology',
#        'indigenous-aboriginal-and-torres-strait-islander', 'tas',
#        'united-kingdom', 'business-economics-and-finance'],
#       dtype='object')
#
# --- Confusion matrix ---
# united-states: TP:29, TN:389, FP:7, FN:21
# australia: TP:84, TN:229, FP:41, FN:92
# government-and-politics: TP:0, TN:409, FP:3, FN:34
# health-policy: TP:3, TN:419, FP:3, FN:21
# lifestyle-and-leisure: TP:0, TN:437, FP:0, FN:9
# child-health-and-behaviour: TP:3, TN:384, FP:4, FN:55
# health: TP:50, TN:215, FP:86, FN:95
# children: TP:2, TN:405, FP:4, FN:35
# united-kingdom: TP:2, TN:421, FP:9, FN:14
# healthcare-facilities: TP:1, TN:426, FP:4, FN:15
# vic: TP:1, TN:429, FP:0, FN:16
# medical-research: TP:6, TN:389, FP:12, FN:39
# industry: TP:0, TN:435, FP:1, FN:10
# advertising: TP:2, TN:433, FP:2, FN:9
# advertising-and-marketing: TP:5, TN:429, FP:4, FN:8
# education: TP:0, TN:438, FP:0, FN:8
# cancer: TP:3, TN:432, FP:0, FN:11
# sa: TP:1, TN:425, FP:3, FN:17
# wa: TP:1, TN:426, FP:0, FN:19
# states-and-territories: TP:4, TN:400, FP:2, FN:40
# family-and-children: TP:0, TN:426, FP:2, FN:18
# doctors-and-medical-professionals: TP:1, TN:421, FP:1, FN:23
# diabetes: TP:3, TN:412, FP:4, FN:27
# obesity: TP:147, TN:150, FP:68, FN:81
# science-and-technology: TP:0, TN:431, FP:2, FN:13
# smoking: TP:0, TN:437, FP:1, FN:8
# heart-disease: TP:0, TN:433, FP:1, FN:12
# diet-and-nutrition: TP:2, TN:386, FP:5, FN:53
# federal---state-issues: TP:2, TN:432, FP:4, FN:8
# act: TP:0, TN:435, FP:3, FN:8
# tas: TP:0, TN:433, FP:1, FN:12
# diseases-and-disorders: TP:3, TN:403, FP:9, FN:31
# federal-government: TP:5, TN:405, FP:2, FN:34
# research: TP:3, TN:402, FP:11, FN:30
# schools: TP:2, TN:424, FP:3, FN:17
# qld: TP:2, TN:425, FP:3, FN:16
# indigenous-aboriginal-and-torres-strait-islander: TP:1, TN:429, FP:5, FN:11
# nsw: TP:2, TN:412, FP:1, FN:31
# community-and-society: TP:0, TN:417, FP:2, FN:27
# exercise-and-fitness: TP:3, TN:415, FP:3, FN:25
# business-economics-and-finance: TP:0, TN:429, FP:4, FN:13
# food-and-beverage: TP:5, TN:423, FP:2, FN:16
# --- Performance ---
# coverage_error = 15.7 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.15
# hamming_loss = 0.07
# f1_macro = 0.16
# f1_micro = 0.35
# Jaccard_Index = 0.93
# zero_one_error = 0.95
#
# - f1 for each label -
# label_act = 0.67
# label_advertising = 0.56
# label_advertising-and-marketing = 0.0
# label_australia = 0.2
# label_business-economics-and-finance = 0.0
# label_cancer = 0.09
# label_child-health-and-behaviour = 0.36
# label_children = 0.09
# label_community-and-society = 0.15
# label_diabetes = 0.1
# label_diet-and-nutrition = 0.11
# label_diseases-and-disorders = 0.19
# label_doctors-and-medical-professionals = 0.0
# label_education = 0.27
# label_exercise-and-fitness = 0.45
# label_family-and-children = 0.0
# label_federal---state-issues = 0.35
# label_federal-government = 0.09
# label_food-and-beverage = 0.1
# label_government-and-politics = 0.16
# label_health = 0.0
# label_health-policy = 0.08
# label_healthcare-facilities = 0.16
# label_heart-disease = 0.66
# label_indigenous-aboriginal-and-torres-strait-islander = 0.0
# label_industry = 0.0
# label_lifestyle-and-leisure = 0.0
# label_medical-research = 0.06
# label_nsw = 0.25
# label_obesity = 0.0
# label_qld = 0.0
# label_research = 0.13
# label_sa = 0.22
# label_schools = 0.13
# label_science-and-technology = 0.17
# label_smoking = 0.17
# label_states-and-territories = 0.11
# label_tas = 0.11
# label_united-kingdom = 0.0
# label_united-states = 0.18
# label_vic = 0.0
# label_wa = 0.36

# %% [markdown]
# ## Ensemble CC using ESKDB(E=10)

# %%
dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

# read data
data, label = read_data(dataPath)
n_label = label.shape[1]

# data set information
n_label = label.shape[1]
n_attr = data.shape[1]
n_instance = data.shape[0]
avg_label_per_instance = label.sum(axis=1).mean()

# ensemble
ensemble = 10

y_pred_ensemble = pd.DataFrame(np.zeros((int(label.shape[0]/2),label.shape[1])),columns=label.columns)
y_prob_ensemble = pd.DataFrame(np.zeros((int(label.shape[0]/2),label.shape[1])),columns=label.columns)
    
    
for i in range(ensemble):
    dataPath = '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'

    # read data
    data, label = read_data(dataPath)
    n_label = label.shape[1]

    # data set information
    n_label = label.shape[1]
    n_attr = data.shape[1]
    n_instance = data.shape[0]
    avg_label_per_instance = label.sum(axis=1).mean()

    # get orders
    order = random.sample(list(range(n_label)),n_label) # get orders

    # train and test on the first label
    savePath = '/Users/jiangjunhao/Desktop/test/'
    ## prepare data, get the arff file
    for i in range(n_label):
        label_i = label.iloc[:,order[i]]
        print("--Running label:",label_i.name)
        csv_to_arff(data, label_i, savePath)

        # run eskdb
        label_arff = os.path.join(savePath,label_i.name+'.arff')
        resultFile = 'a' # /Volumes/Samsung_T5/research/programme/ESKDB_HDP/result/resultFile
        k = '5'
        i = '5000'
        l = '2'
        e = '20'

        run_eskdb(label_arff, resultFile, k, l, e, i)

        result = os.path.join("/Volumes/Samsung_T5/research/programme/ESKDB_HDP/result",resultFile, label_i.name+'.txt')
        with open(result, 'r') as f:
            try:
                lines = f.readlines()
            except:
                print(file)
            else:
                pred = []
                for line in lines:
                    if line.startswith('pred'):
                        pred.append(int(re.search('pred :\t(.)',line).group(1)))
                    elif line.startswith("test0Indexes"):
                        index = list(map(int,re.search('test0Indexes: {(.*)}',line).group(1).split(', ')))

                label.loc[index,label_i.name] = pred
                temp = label.loc[:,label_i.name]
                temp.name = 'label_'+label_i.name
                data = pd.concat([data, label.loc[:,label_i.name]],axis=1)

    # get result
    resultPath = '/Volumes/Samsung_T5/research/programme/ESKDB_HDP/result/'+resultFile+'/'
    y_pred,y_true,y_prob = get_result(resultPath)
    
    y_pred.columns = label.columns
    y_prob.columns = label.columns
    
    y_pred_ensemble = y_pred_ensemble + y_pred
    y_prob_ensemble = y_prob_ensemble + y_prob
    
    
y_pred_ensemble = (((y_pred_ensemble / ensemble) >= 0.5)*1).astype('int')
y_prob_ensemble = y_prob_ensemble / ensemble
# Out:
# --Running label: doctors-and-medical-professionals
# --Running label: heart-disease
# --Running label: health-policy
# --Running label: united-states
# --Running label: lifestyle-and-leisure
# --Running label: smoking
# --Running label: advertising-and-marketing
# --Running label: food-and-beverage
# --Running label: healthcare-facilities
# --Running label: sa
# --Running label: family-and-children
# --Running label: schools
# --Running label: qld
# --Running label: diseases-and-disorders
# --Running label: research
# --Running label: australia
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: wa
# --Running label: united-kingdom
# --Running label: industry
# --Running label: federal---state-issues
# --Running label: community-and-society
# --Running label: tas
# --Running label: cancer
# --Running label: advertising
# --Running label: federal-government
# --Running label: diabetes
# --Running label: children
# --Running label: science-and-technology
# --Running label: exercise-and-fitness
# --Running label: act
# --Running label: business-economics-and-finance
# --Running label: health
# --Running label: government-and-politics
# --Running label: obesity
# --Running label: diet-and-nutrition
# --Running label: vic
# --Running label: education
# --Running label: nsw
# --Running label: child-health-and-behaviour
# --Running label: medical-research
# --Running label: states-and-territories
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2469.0
# testing time: 1511.0
# --Running label: lifestyle-and-leisure
# --Running label: diet-and-nutrition
# --Running label: vic
# --Running label: exercise-and-fitness
# --Running label: medical-research
# --Running label: education
# --Running label: federal-government
# --Running label: health-policy
# --Running label: obesity
# --Running label: heart-disease
# --Running label: united-kingdom
# --Running label: wa
# --Running label: family-and-children
# --Running label: australia
# --Running label: act
# --Running label: diseases-and-disorders
# --Running label: tas
# --Running label: child-health-and-behaviour
# --Running label: industry
# --Running label: smoking
# --Running label: nsw
# --Running label: food-and-beverage
# --Running label: united-states
# --Running label: business-economics-and-finance
# --Running label: cancer
# --Running label: diabetes
# --Running label: qld
# --Running label: government-and-politics
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: research
# --Running label: states-and-territories
# --Running label: federal---state-issues
# --Running label: health
# --Running label: community-and-society
# --Running label: healthcare-facilities
# --Running label: sa
# --Running label: advertising
# --Running label: doctors-and-medical-professionals
# --Running label: children
# --Running label: science-and-technology
# --Running label: advertising-and-marketing
# --Running label: schools
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2427.0
# testing time: 1895.0
# --Running label: diseases-and-disorders
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: education
# --Running label: qld
# --Running label: doctors-and-medical-professionals
# --Running label: nsw
# --Running label: health-policy
# --Running label: wa
# --Running label: diet-and-nutrition
# --Running label: united-states
# --Running label: federal---state-issues
# --Running label: lifestyle-and-leisure
# --Running label: exercise-and-fitness
# --Running label: child-health-and-behaviour
# --Running label: children
# --Running label: food-and-beverage
# --Running label: tas
# --Running label: advertising-and-marketing
# --Running label: heart-disease
# --Running label: medical-research
# --Running label: federal-government
# --Running label: australia
# --Running label: smoking
# --Running label: health
# --Running label: united-kingdom
# --Running label: act
# --Running label: government-and-politics
# --Running label: science-and-technology
# --Running label: vic
# --Running label: diabetes
# --Running label: community-and-society
# --Running label: sa
# --Running label: industry
# --Running label: states-and-territories
# --Running label: business-economics-and-finance
# --Running label: research
# --Running label: schools
# --Running label: healthcare-facilities
# --Running label: cancer
# --Running label: advertising
# --Running label: family-and-children
# --Running label: obesity
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2327.0
# testing time: 1588.0
# --Running label: advertising-and-marketing
# --Running label: government-and-politics
# --Running label: research
# --Running label: medical-research
# --Running label: federal---state-issues
# --Running label: tas
# --Running label: health
# --Running label: advertising
# --Running label: science-and-technology
# --Running label: diseases-and-disorders
# --Running label: vic
# --Running label: education
# --Running label: community-and-society
# --Running label: doctors-and-medical-professionals
# --Running label: diet-and-nutrition
# --Running label: lifestyle-and-leisure
# --Running label: healthcare-facilities
# --Running label: health-policy
# --Running label: cancer
# --Running label: nsw
# --Running label: exercise-and-fitness
# --Running label: schools
# --Running label: food-and-beverage
# --Running label: federal-government
# --Running label: diabetes
# --Running label: act
# --Running label: qld
# --Running label: industry
# --Running label: child-health-and-behaviour
# --Running label: smoking
# --Running label: business-economics-and-finance
# --Running label: obesity
# --Running label: heart-disease
# --Running label: united-states
# --Running label: sa
# --Running label: united-kingdom
# --Running label: australia
# --Running label: wa
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: states-and-territories
# --Running label: family-and-children
# --Running label: children
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2379.0
# testing time: 1803.0
# --Running label: community-and-society
# --Running label: health
# --Running label: industry
# --Running label: qld
# --Running label: healthcare-facilities
# --Running label: smoking
# --Running label: nsw
# --Running label: health-policy
# --Running label: research
# --Running label: federal-government
# --Running label: sa
# --Running label: business-economics-and-finance
# --Running label: obesity
# --Running label: medical-research
# --Running label: wa
# --Running label: act
# --Running label: united-states
# --Running label: advertising-and-marketing
# --Running label: family-and-children
# --Running label: doctors-and-medical-professionals
# --Running label: diabetes
# --Running label: diet-and-nutrition
# --Running label: science-and-technology
# --Running label: food-and-beverage
# --Running label: tas
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: government-and-politics
# --Running label: diseases-and-disorders
# --Running label: schools
# --Running label: exercise-and-fitness
# --Running label: child-health-and-behaviour
# --Running label: vic
# --Running label: education
# --Running label: federal---state-issues
# --Running label: united-kingdom
# --Running label: states-and-territories
# --Running label: heart-disease
# --Running label: children
# --Running label: lifestyle-and-leisure
# --Running label: advertising
# --Running label: australia
# --Running label: cancer
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2298.0
# testing time: 1877.0
# --Running label: diet-and-nutrition
# --Running label: industry
# --Running label: healthcare-facilities
# --Running label: exercise-and-fitness
# --Running label: health
# --Running label: business-economics-and-finance
# --Running label: medical-research
# --Running label: doctors-and-medical-professionals
# --Running label: child-health-and-behaviour
# --Running label: education
# --Running label: qld
# --Running label: diabetes
# --Running label: food-and-beverage
# --Running label: advertising
# --Running label: cancer
# --Running label: act
# --Running label: wa
# --Running label: research
# --Running label: family-and-children
# --Running label: science-and-technology
# --Running label: health-policy
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: federal---state-issues
# --Running label: community-and-society
# --Running label: children
# --Running label: federal-government
# --Running label: sa
# --Running label: united-kingdom
# --Running label: united-states
# --Running label: heart-disease
# --Running label: nsw
# --Running label: diseases-and-disorders
# --Running label: government-and-politics
# --Running label: smoking
# --Running label: advertising-and-marketing
# --Running label: obesity
# --Running label: lifestyle-and-leisure
# --Running label: australia
# --Running label: states-and-territories
# --Running label: tas
# --Running label: schools
# --Running label: vic
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2321.0
# testing time: 1733.0
# --Running label: heart-disease
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: research
# --Running label: business-economics-and-finance
# --Running label: exercise-and-fitness
# --Running label: diabetes
# --Running label: government-and-politics
# --Running label: advertising
# --Running label: smoking
# --Running label: diet-and-nutrition
# --Running label: sa
# --Running label: healthcare-facilities
# --Running label: food-and-beverage
# --Running label: family-and-children
# --Running label: qld
# --Running label: education
# --Running label: federal-government
# --Running label: doctors-and-medical-professionals
# --Running label: vic
# --Running label: cancer
# --Running label: obesity
# --Running label: tas
# --Running label: schools
# --Running label: medical-research
# --Running label: community-and-society
# --Running label: united-states
# --Running label: nsw
# --Running label: science-and-technology
# --Running label: wa
# --Running label: diseases-and-disorders
# --Running label: federal---state-issues
# --Running label: children
# --Running label: united-kingdom
# --Running label: child-health-and-behaviour
# --Running label: health-policy
# --Running label: act
# --Running label: australia
# --Running label: lifestyle-and-leisure
# --Running label: health
# --Running label: states-and-territories
# --Running label: advertising-and-marketing
# --Running label: industry
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2209.0
# testing time: 1248.0
# --Running label: advertising
# --Running label: research
# --Running label: cancer
# --Running label: diet-and-nutrition
# --Running label: smoking
# --Running label: business-economics-and-finance
# --Running label: vic
# --Running label: federal-government
# --Running label: industry
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: health-policy
# --Running label: food-and-beverage
# --Running label: diseases-and-disorders
# --Running label: wa
# --Running label: advertising-and-marketing
# --Running label: nsw
# --Running label: government-and-politics
# --Running label: children
# --Running label: schools
# --Running label: healthcare-facilities
# --Running label: doctors-and-medical-professionals
# --Running label: states-and-territories
# --Running label: family-and-children
# --Running label: act
# --Running label: qld
# --Running label: community-and-society
# --Running label: science-and-technology
# --Running label: obesity
# --Running label: united-states
# --Running label: federal---state-issues
# --Running label: heart-disease
# --Running label: education
# --Running label: sa
# --Running label: australia
# --Running label: tas
# --Running label: medical-research
# --Running label: health
# --Running label: exercise-and-fitness
# --Running label: child-health-and-behaviour
# --Running label: diabetes
# --Running label: lifestyle-and-leisure
# --Running label: united-kingdom
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2548.0
# testing time: 1831.0
# --Running label: education
# --Running label: lifestyle-and-leisure
# --Running label: food-and-beverage
# --Running label: qld
# --Running label: health-policy
# --Running label: advertising-and-marketing
# --Running label: diabetes
# --Running label: vic
# --Running label: exercise-and-fitness
# --Running label: sa
# --Running label: united-kingdom
# --Running label: diet-and-nutrition
# --Running label: industry
# --Running label: federal---state-issues
# --Running label: federal-government
# --Running label: research
# --Running label: diseases-and-disorders
# --Running label: healthcare-facilities
# --Running label: child-health-and-behaviour
# --Running label: smoking
# --Running label: states-and-territories
# --Running label: science-and-technology
# --Running label: australia
# --Running label: wa
# --Running label: health
# --Running label: doctors-and-medical-professionals
# --Running label: government-and-politics
# --Running label: cancer
# --Running label: community-and-society
# --Running label: tas
# --Running label: obesity
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: advertising
# --Running label: family-and-children
# --Running label: united-states
# --Running label: business-economics-and-finance
# --Running label: nsw
# --Running label: act
# --Running label: heart-disease
# --Running label: children
# --Running label: schools
# --Running label: medical-research
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2116.0
# testing time: 1365.0
# --Running label: exercise-and-fitness
# --Running label: obesity
# --Running label: sa
# --Running label: medical-research
# --Running label: act
# --Running label: heart-disease
# --Running label: diet-and-nutrition
# --Running label: diabetes
# --Running label: industry
# --Running label: child-health-and-behaviour
# --Running label: qld
# --Running label: wa
# --Running label: diseases-and-disorders
# --Running label: family-and-children
# --Running label: science-and-technology
# --Running label: community-and-society
# --Running label: food-and-beverage
# --Running label: states-and-territories
# --Running label: lifestyle-and-leisure
# --Running label: advertising-and-marketing
# --Running label: cancer
# --Running label: tas
# --Running label: smoking
# --Running label: research
# --Running label: advertising
# --Running label: doctors-and-medical-professionals
# --Running label: australia
# --Running label: children
# --Running label: federal-government
# --Running label: health
# --Running label: federal---state-issues
# --Running label: indigenous-aboriginal-and-torres-strait-islander
# --Running label: nsw
# --Running label: business-economics-and-finance
# --Running label: government-and-politics
# --Running label: schools
# --Running label: healthcare-facilities
# --Running label: united-states
# --Running label: education
# --Running label: vic
# --Running label: united-kingdom
# --Running label: health-policy
# [-t, /Users/jiangjunhao/Desktop/test/food-and-beverage.arff, -S, ESKDB, -K, 5, -I, 5000, -L, 2, -E, 20, -V, -M]
#
# number of label: 42
# training time: 2281.0
# testing time: 1625.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-fba81b626dd9> in <module>()
#      85 y_prob_ensemble = y_prob_ensemble / ensemble
#      86
# ---> 87 performance = evaluation(y_pred=y_pred_ensemble, y_true=y_true, y_prob=y_prob_ensemble)
#      88
#      89 # print orders:
#
# <ipython-input-2-8f3cdf4aca78> in evaluation(y_pred, y_prob, y_true)
#       7
#       8 def evaluation(y_pred, y_prob, y_true):
# ----> 9     coverage = coverage_error(y_true, y_prob)
#      10     hamming = hamming_loss(y_true, y_pred)
#      11     ranking_loss = label_ranking_loss(y_true, y_prob)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/ranking.py in coverage_error(y_true, y_score, sample_weight)
#     694     """
#     695     y_true = check_array(y_true, ensure_2d=False)
# --> 696     y_score = check_array(y_score, ensure_2d=False)
#     697     check_consistent_length(y_true, y_score, sample_weight)
#     698
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
performance = evaluation(y_pred=y_pred_ensemble, y_true=y_true, y_prob=y_prob_ensemble)

# print orders:
print(label.columns[order])

# get confusion matrix
print("\n--- Confusion matrix ---")
get_confusion_matrix(y_pred, y_true, y_pred.columns)

# print performance
print("--- Performance ---")
for key, value in performance.items():
    if key == "f1_each_label":
        print("\n- f1 for each label -")
        for i in range(n_label):
            print("label_"+label.columns[i],"=",round(value[i],2))
    elif key == "coverage_error":
        print(key,'=',round(value,2),"( avg_label_per_instance =",round(avg_label_per_instance,2),")")
    else:
        print(key,'=',round(value,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bf1b11e036d0> in <module>()
# ----> 1 performance = evaluation(y_pred=y_pred_ensemble, y_true=y_true, y_prob=y_prob_ensemble)
#       2
#       3 # print orders:
#       4 print(label.columns[order])
#       5
#
# NameError: name 'y_pred_ensemble' is not defined

# %% [markdown]
# # Result

# %% [markdown]
# `
# **Performance of BR_naive Bayes**
# coverage_error = 13.6 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.13
# hamming_loss = 0.1
# f1_macro = 0.26
# f1_micro = 0.4
# Jaccard_Index = 0.26
# zero_one_error = 0.98
# `
#
# `
# **Performance of BR_ESKDB**
# coverage_error = 14.76 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.15
# hamming_loss = 0.08
# f1_macro = 0.15
# f1_micro = 0.33
# jaccard_index = 0.23
# zero_one_error = 0.94
# `
#
# `
# **Performance of Ensemble Classifier Chain using naive Bayes**
# coverage_error = 13.63 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.13
# hamming_loss = 0.11
# f1_macro = 0.26
# f1_micro = 0.38
# Jaccard_Index = 0.25
# zero_one_error = 0.97
# `
#
# `
# **Performance of Ensemble Classifier Chain using ESKDB(E=2)**
# coverage_error = 15.87 ( avg_label_per_instance = 3.25 )
# ranking_loss = 0.16
# hamming_loss = 0.08
# f1_macro = 0.22
# f1_micro = 0.38
# Jaccard_Index = 0.25
# zero_one_error = 0.95
# `

# %% [markdown]
# recall 体现了分类模型H对正样本的识别能力，recall 越高，说明模型对正样本的识别能力越强.
#
# precision 体现了模型对负样本的区分能力，precision越高，说明模型对负样本的区分能力越强。F1-score 是两者的综合。F1-score 越高，说明分类模型越稳健。
