# %%
import pandas as pd
import numpy as np
import nltk
import re
import os
from nltk.tokenize import RegexpTokenizer 
from collections import Counter
import arff
from bs4 import BeautifulSoup
import subprocess
import random
from mdlp.discretization import MDLP

# %%
# get label
def get_label(file):
    with open(file, 'r') as f:
        lines = f.read()
        soup = BeautifulSoup(lines, 'lxml')
        n_label = len(soup.find_all('label'))
        
        label_list = []
        for label in soup.find_all('label'): 
            label_list.append(label.attrs['name'])
        
    return n_label, label_list

def get_data_label(filePath, dataset):


    # get label
    file = os.path.join(filePath+dataset,dataset+'.xml')
    n_label, label_list = get_label(file)

    # get X, y
    file = os.path.join(filePath,dataset,dataset+'.csv')
    data = pd.read_csv(file)
    X = data.iloc[:,:-n_label]
    y = data.iloc[:,-n_label:]
    
    return X,y

def calculate_LAIM(interval, feature_data, label):
    # discrete
    feature_data = pd.cut(feature_data, bins = interval, include_lowest=True)
    
    quanta_matrix = pd.concat([feature_data, label],axis=1).groupby(feature_data.name).sum()
    
    max_r = quanta_matrix.max(axis=1)**2
    
    M_r = quanta_matrix.sum(axis=1)
    
    total_pos = y.values.sum()
    
    n = len(interval) - 1
    
    LAIM = (max_r/M_r).sum() / (n*total_pos)
    
    return LAIM

def perform_LAIM(data, label):
    
    data_dis = pd.DataFrame()
    for i in range(data.shape[1]):
        
        # step 1: intialization
        attr = data.iloc[:,i]
        print("Performing attribute:",attr.name)
        max_value = attr.max()
        min_value = attr.min()
        sort_attr = attr.sort_values(ascending=True)
        
        # form B, the set of candidate interval boundaries, 
        # with min, max and 
        # all the mid points of all the adjacent pairs
        B = set()
        for i in range(len(sort_attr)):
            if i == 0:
                B.add(sort_attr[i])
                B.add((sort_attr[i] + sort_attr[i+1])/2)
            elif i == len(sort_attr)-1:
                B.add(sort_attr[i])
                break
            else:
                B.add((sort_attr[i] + sort_attr[i+1])/2) 
        len_b = len(B)
        
        D_i = [min_value, max_value] # initial interval
        globalLAIM = 0
        
        if len(B) == 2:
            feature_data = pd.cut(list(attr), bins = [min_value, max_value/2, max_value], include_lowest=True).codes
            data_dis = pd.concat([data_dis, pd.Series(feature_data)],axis=1)
            print("bins:",D_i)
        
        else:
            # step 2: Discretization
            nIntervals = 1
            while True:
                midpoint_LAIM = []
                for b_j in B:

                    D = list(D_i)
                    # Add a midpoint, b_j, into C which is not still in D_i
                    if b_j not in D:
                        D.append(b_j)
                        D.sort()
                        # calculate LAIM value
                        LAIM = calculate_LAIM(D, attr, label)
                        midpoint_LAIM.append((b_j, LAIM))       
                # Accept the midpoint, bj, with highest value of LAIM
                midpoint_max = max(midpoint_LAIM, key=lambda x: x[1])

                if midpoint_max[1] > globalLAIM:
                    D_i.append(midpoint_max[0])
                    D_i.sort()
                    B.remove(midpoint_max[0])
                    globalLAIM = midpoint_max[1]

                else:
                    feature_data = pd.cut(list(attr), bins = D_i, include_lowest=True).codes
                    data_dis = pd.concat([data_dis, pd.Series(feature_data)],axis=1)
                    print("nInterval:",nIntervals, "bins:",D_i)
                    break

                nIntervals += 1
                if len(D_i) == len_b:
                    feature_data = pd.cut(list(attr), bins = D_i, include_lowest=True).codes
                    data_dis = pd.concat([data_dis, pd.Series(feature_data)],axis=1)
                    print("nInterval:",nIntervals, "bins:",D_i)
                    break
    
    
    data_dis.columns = data.columns
    
    return data_dis

# %% [markdown]
# # small datasets

# %%
filePath = '/Volumes/Samsung_T5/research/data/small_datasets/'
for dataset in ['emotions','yeast','scene']:
    X, y = get_data_label(filePath, dataset)
    X_dis = perform_LAIM(X, y)
    y.to_csv(os.path.join(filePath,dataset,'y.csv'), index=False)
    X_dis.to_csv(os.path.join(filePath,dataset,'X.csv'), index=False)
# Out:
# Performing attribute: Mean_Acc1298_Mean_Mem40_Centroid
# nInterval: 2 bins: [0.010201, 0.085428000000000004, 0.195412]
# Performing attribute: Mean_Acc1298_Mean_Mem40_Rolloff
# nInterval: 2 bins: [0.038286000000000001, 0.177256, 0.69827700000000004]
# Performing attribute: Mean_Acc1298_Mean_Mem40_Flux
# nInterval: 2 bins: [0.070932000000000009, 0.088305500000000009, 0.15945999999999999]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_0
# nInterval: 2 bins: [-99.090801999999996, -70.85131100000001, -56.297651999999999]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_1
# nInterval: 2 bins: [0.051473999999999999, 3.6759235000000001, 12.069754]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_2
# nInterval: 2 bins: [-2.277307, 2.7672185000000002, 3.9108730000000005]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_3
# nInterval: 2 bins: [-0.60460900000000006, 1.365394, 4.3823699999999999]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_4
# nInterval: 2 bins: [-1.143864, -0.74528649999999996, 2.25271]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_5
# nInterval: 2 bins: [-0.23711399999999999, 0.51710300000000009, 2.358098]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_6
# nInterval: 2 bins: [-0.44462299999999993, -0.065301500000000012, 1.4844889999999999]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_7
# nInterval: 2 bins: [-0.89596600000000004, 0.76016250000000007, 1.7224200000000001]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_8
# nInterval: 2 bins: [-0.45191899999999996, 1.0721974999999999, 1.8462209999999999]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_9
# nInterval: 2 bins: [-0.29476999999999998, 0.87689349999999999, 1.064865]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_10
# nInterval: 2 bins: [-0.258025, 0.061359999999999998, 1.290063]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_11
# nInterval: 2 bins: [-0.394065, 0.096777500000000016, 1.8767040000000001]
# Performing attribute: Mean_Acc1298_Mean_Mem40_MFCC_12
# nInterval: 2 bins: [-0.12951500000000002, 0.97621600000000008, 1.246864]
# Performing attribute: Mean_Acc1298_Std_Mem40_Centroid
# nInterval: 2 bins: [0.0069180000000000005, 0.031170999999999997, 0.16839899999999999]
# Performing attribute: Mean_Acc1298_Std_Mem40_Rolloff
# nInterval: 2 bins: [0.017434000000000002, 0.2080775, 0.47179499999999996]
# Performing attribute: Mean_Acc1298_Std_Mem40_Flux
# nInterval: 2 bins: [0.025297, 0.047945500000000002, 0.11619000000000002]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_0
# nInterval: 2 bins: [1.665689, 2.8321395000000003, 15.262381]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_1
# nInterval: 2 bins: [0.54448999999999992, 0.85936099999999993, 3.6644760000000001]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_2
# nInterval: 2 bins: [0.42608500000000005, 1.1568364999999998, 2.04521]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_3
# nInterval: 2 bins: [0.43635499999999999, 1.1821225, 1.4910159999999999]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_4
# nInterval: 2 bins: [0.34397300000000003, 0.92743599999999993, 1.3210379999999999]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_5
# nInterval: 2 bins: [0.376085, 0.74817299999999998, 1.0166930000000001]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_6
# nInterval: 2 bins: [0.32947900000000002, 0.67727500000000007, 0.82506399999999991]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_7
# nInterval: 2 bins: [0.32225399999999998, 0.46686, 0.87077800000000005]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_8
# nInterval: 2 bins: [0.32797500000000002, 0.48490250000000001, 1.0981110000000001]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_9
# nInterval: 2 bins: [0.29685500000000004, 0.46615149999999994, 0.84269699999999992]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_10
# nInterval: 2 bins: [0.29783200000000004, 0.45246700000000001, 0.85248799999999991]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_11
# nInterval: 2 bins: [0.28162500000000001, 0.42805349999999998, 0.77249599999999996]
# Performing attribute: Mean_Acc1298_Std_Mem40_MFCC_12
# nInterval: 2 bins: [0.27326400000000001, 0.40319400000000005, 1.0011840000000001]
# Performing attribute: Std_Acc1298_Mean_Mem40_Centroid
# nInterval: 2 bins: [0.010574, 0.034887500000000002, 0.11743699999999999]
# Performing attribute: Std_Acc1298_Mean_Mem40_Rolloff
# nInterval: 2 bins: [0.018333000000000002, 0.065496499999999999, 0.23471799999999998]
# Performing attribute: Std_Acc1298_Mean_Mem40_Flux
# nInterval: 2 bins: [0.0056959999999999997, 0.011140500000000001, 0.02273]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_0
# nInterval: 2 bins: [1.103874, 2.6260414999999999, 13.447154000000001]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_1
# nInterval: 2 bins: [0.181559, 0.636791, 2.9254250000000002]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_2
# nInterval: 2 bins: [0.10783599999999999, 0.532999, 2.2026089999999998]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_3
# nInterval: 2 bins: [0.079272999999999996, 0.36096600000000001, 1.4725409999999999]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_4
# nInterval: 2 bins: [0.055488999999999997, 0.28902450000000002, 1.025277]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_5
# nInterval: 2 bins: [0.040191999999999999, 0.26227499999999998, 1.0381579999999999]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_6
# nInterval: 2 bins: [0.048814999999999997, 0.24460999999999999, 1.1556249999999999]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_7
# nInterval: 2 bins: [0.068473000000000006, 0.21865800000000002, 1.3348329999999999]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_8
# nInterval: 2 bins: [0.055300999999999996, 0.2401375, 1.729741]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_9
# nInterval: 2 bins: [0.057608000000000006, 0.20535999999999999, 1.1694770000000001]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_10
# nInterval: 2 bins: [0.048231000000000003, 0.19771250000000001, 1.2818399999999999]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_11
# nInterval: 2 bins: [0.041973000000000003, 0.197964, 1.181478]
# Performing attribute: Std_Acc1298_Mean_Mem40_MFCC_12
# nInterval: 2 bins: [0.033738999999999998, 0.20355299999999998, 1.809666]
# Performing attribute: Std_Acc1298_Std_Mem40_Centroid
# nInterval: 2 bins: [0.008712000000000001, 0.024074999999999999, 0.063173000000000007]
# Performing attribute: Std_Acc1298_Std_Mem40_Rolloff
# nInterval: 2 bins: [0.015678000000000001, 0.050087999999999994, 0.18613399999999999]
# Performing attribute: Std_Acc1298_Std_Mem40_Flux
# nInterval: 2 bins: [0.0090900000000000009, 0.029484000000000003, 0.032048]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_0
# nInterval: 2 bins: [1.90852, 3.9354065000000005, 6.5369279999999996]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_1
# nInterval: 2 bins: [0.10501400000000001, 0.30277350000000003, 1.0462120000000001]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_2
# nInterval: 2 bins: [0.048375000000000001, 0.17637399999999998, 0.61870400000000003]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_3
# nInterval: 2 bins: [0.052660000000000005, 0.11072400000000002, 0.54392700000000005]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_4
# nInterval: 2 bins: [0.034480000000000004, 0.10267950000000001, 0.41579799999999995]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_5
# nInterval: 2 bins: [0.039299000000000001, 0.10263900000000001, 0.27108499999999996]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_6
# nInterval: 2 bins: [0.024209999999999999, 0.094672500000000007, 0.24143200000000001]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_7
# nInterval: 2 bins: [0.036152999999999998, 0.088385999999999992, 0.30441699999999999]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_8
# nInterval: 2 bins: [0.032399000000000004, 0.100523, 0.41103299999999998]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_9
# nInterval: 2 bins: [0.035843, 0.079477499999999993, 0.29655599999999999]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_10
# nInterval: 2 bins: [0.038015, 0.080749000000000001, 0.355242]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_11
# nInterval: 2 bins: [0.032472000000000001, 0.096567500000000001, 0.47150600000000004]
# Performing attribute: Std_Acc1298_Std_Mem40_MFCC_12
# nInterval: 2 bins: [0.031945000000000001, 0.078068499999999999, 0.41520200000000007]
# Performing attribute: BH_LowPeakAmp
# nInterval: 2 bins: [0.0, 0.40480850000000002, 1.598533]
# Performing attribute: BH_LowPeakBPM
# nInterval: 2 bins: [0.0, 69.0, 115.0]
# Performing attribute: BH_HighPeakAmp
# nInterval: 2 bins: [0.0, 0.227072, 1.762948]
# Performing attribute: BH_HighPeakBPM
# nInterval: 2 bins: [0.0, 138.0, 237.0]
# Performing attribute: BH_HighLowRatio
# nInterval: 2 bins: [0.0, 2.0, 3.0]
# Performing attribute: BHSUM1
# nInterval: 2 bins: [0.0, 0.58176549999999994, 1.7951279999999998]
# Performing attribute: BHSUM2
# nInterval: 2 bins: [0.0, 0.6421095, 1.7977650000000001]
# Performing attribute: BHSUM3
# nInterval: 2 bins: [0.0, 1.1753045, 3.4228989999999997]
# Performing attribute: Att1
# nInterval: 2 bins: [-0.37114599999999998, 0.27813300000000002, 0.52027200000000007]
# Performing attribute: Att2
# nInterval: 2 bins: [-0.472632, -0.186832, 0.61411400000000005]
# Performing attribute: Att3
# nInterval: 2 bins: [-0.33919499999999997, -0.19344349999999999, 0.35324099999999997]
# Performing attribute: Att4
# nInterval: 2 bins: [-0.467945, -0.31533149999999999, 0.56896000000000002]
# Performing attribute: Att5
# nInterval: 2 bins: [-0.36704399999999998, -0.11649, 0.30764900000000001]
# Performing attribute: Att6
# nInterval: 2 bins: [-0.50944699999999998, 0.093772999999999995, 0.33697100000000002]
# Performing attribute: Att7
# nInterval: 2 bins: [-0.31992800000000005, 0.088079500000000005, 0.35140100000000002]
# Performing attribute: Att8
# nInterval: 2 bins: [-0.59449799999999997, -0.30101600000000001, 0.45459099999999997]
# Performing attribute: Att9
# nInterval: 2 bins: [-0.36971199999999999, -0.28023000000000003, 0.41985200000000006]
# Performing attribute: Att10
# nInterval: 2 bins: [-0.76712799999999992, 0.0022579999999999961, 0.42087600000000003]
# Performing attribute: Att11
# nInterval: 2 bins: [-0.29233500000000001, -0.033450499999999994, 0.47570600000000002]
# Performing attribute: Att12
# nInterval: 2 bins: [-0.36949599999999999, 0.00040499999999999911, 0.420541]
# Performing attribute: Att13
# nInterval: 2 bins: [-0.53727999999999998, 0.028449000000000002, 0.63909499999999997]
# Performing attribute: Att14
# nInterval: 2 bins: [-0.39225500000000002, 0.034689499999999998, 0.57692299999999996]
# Performing attribute: Att15
# nInterval: 2 bins: [-0.39466899999999999, 0.081189499999999998, 0.34478300000000001]
# Performing attribute: Att16
# nInterval: 2 bins: [-0.34794599999999998, 0.038290499999999998, 0.38556599999999996]
# Performing attribute: Att17
# nInterval: 2 bins: [-0.58857599999999999, -0.36625950000000002, 0.34516599999999997]
# Performing attribute: Att18
# nInterval: 2 bins: [-0.354161, 0.046780000000000002, 0.60628599999999999]
# Performing attribute: Att19
# nInterval: 2 bins: [-0.26464399999999999, -0.020406499999999994, 0.46162799999999998]
# Performing attribute: Att20
# nInterval: 2 bins: [-0.29774600000000001, 0.041704999999999999, 0.58755200000000007]
# Performing attribute: Att21
# nInterval: 2 bins: [-0.59288599999999991, 0.063319500000000001, 0.45357600000000003]
# Performing attribute: Att22
# nInterval: 2 bins: [-0.34222900000000001, 0.0127035, 0.39791799999999999]
# Performing attribute: Att23
# nInterval: 2 bins: [-0.31349099999999996, 0.078224000000000002, 0.33618700000000001]
# Performing attribute: Att24
# nInterval: 2 bins: [-0.33407199999999998, 0.059371500000000008, 0.349468]
# Performing attribute: Att25
# nInterval: 2 bins: [-0.35655700000000001, -0.22775000000000001, 0.39732000000000001]
# Performing attribute: Att26
# nInterval: 2 bins: [-0.40381500000000004, 0.073158000000000001, 0.30159799999999998]
# Performing attribute: Att27
# nInterval: 2 bins: [-0.58712200000000003, 0.023482000000000003, 0.30975399999999997]
# Performing attribute: Att28
# nInterval: 2 bins: [-0.57982, -0.015447499999999999, 0.28707699999999997]
# Performing attribute: Att29
# nInterval: 2 bins: [-0.36434, 0.30639550000000004, 0.45873100000000006]
# Performing attribute: Att30
# nInterval: 2 bins: [-0.38220199999999999, -0.15731849999999997, 0.26891900000000002]
# Performing attribute: Att31
# nInterval: 2 bins: [-0.56002600000000002, -0.21847549999999999, 0.28483999999999998]
# Performing attribute: Att32
# nInterval: 2 bins: [-0.41638800000000004, 0.031517499999999997, 0.333561]
# Performing attribute: Att33
# nInterval: 2 bins: [-0.66061499999999995, -0.34592599999999996, 0.34567300000000001]
# Performing attribute: Att34
# nInterval: 2 bins: [-0.37801799999999997, 0.24136150000000001, 0.34576999999999997]
# Performing attribute: Att35
# nInterval: 2 bins: [-0.36399399999999998, -0.098731500000000014, 0.38368200000000002]
# Performing attribute: Att36
# nInterval: 2 bins: [-0.70546600000000004, -0.088910500000000003, 0.57867200000000008]
# Performing attribute: Att37
# nInterval: 2 bins: [-0.46168400000000004, -0.050803500000000001, 0.44883299999999998]
# Performing attribute: Att38
# nInterval: 2 bins: [-0.62385400000000002, 0.3437095, 0.59959099999999999]
# Performing attribute: Att39
# nInterval: 2 bins: [-0.79743599999999992, -0.033752499999999998, 0.27894099999999999]
# Performing attribute: Att40
# nInterval: 2 bins: [-0.48103299999999999, -0.018256500000000002, 0.48633399999999999]
# Performing attribute: Att41
# nInterval: 2 bins: [-0.58582000000000001, -0.058687500000000004, 0.56717299999999993]
# Performing attribute: Att42
# nInterval: 2 bins: [-0.61015600000000003, -0.047864999999999998, 0.48992700000000006]
# Performing attribute: Att43
# nInterval: 2 bins: [-0.77329899999999996, 0.0048255000000000017, 0.45823400000000003]
# Performing attribute: Att44
# nInterval: 2 bins: [-0.414991, 0.13263449999999999, 0.41413800000000001]
# Performing attribute: Att45
# nInterval: 2 bins: [-0.54122399999999993, -0.045669999999999995, 0.30840700000000004]
# Performing attribute: Att46
# nInterval: 2 bins: [-0.55111699999999997, -0.093981500000000009, 0.50626099999999996]
# Performing attribute: Att47
# nInterval: 2 bins: [-0.48114799999999996, -0.0079364999999999991, 0.39369799999999999]
# Performing attribute: Att48
# nInterval: 2 bins: [-0.33630100000000002, 0.054639500000000001, 0.52379500000000001]
# Performing attribute: Att49
# nInterval: 2 bins: [-0.27669199999999999, -0.089877499999999999, 0.39688299999999999]
# Performing attribute: Att50
# nInterval: 2 bins: [-0.33263300000000001, 0.22747800000000001, 0.38163600000000003]
# Performing attribute: Att51
# nInterval: 2 bins: [-0.28400300000000001, 0.236178, 0.34357199999999999]
# Performing attribute: Att52
# nInterval: 2 bins: [-0.32599, 0.22298050000000003, 0.36091499999999999]
# Performing attribute: Att53
# nInterval: 2 bins: [-0.34567700000000001, 0.24844649999999999, 0.38351199999999996]
# Performing attribute: Att54
# nInterval: 2 bins: [-0.43281199999999997, -0.0076644999999999994, 0.41435]
# Performing attribute: Att55
# nInterval: 2 bins: [-0.48246600000000001, -0.14045750000000001, 0.43623000000000001]
# Performing attribute: Att56
# nInterval: 2 bins: [-0.34719099999999997, 0.15449350000000001, 0.304618]
# Performing attribute: Att57
# nInterval: 2 bins: [-0.30692700000000001, 0.17894350000000001, 0.34245900000000001]
# Performing attribute: Att58
# nInterval: 2 bins: [-0.329013, -0.1181415, 0.31125799999999998]
# Performing attribute: Att59
# nInterval: 2 bins: [-0.352298, 0.070788500000000004, 0.599997]
# Performing attribute: Att60
# nInterval: 2 bins: [-0.42318999999999996, -0.25871299999999997, 0.43719600000000003]
# Performing attribute: Att61
# nInterval: 2 bins: [-0.36477999999999999, -0.182474, 0.414078]
# Performing attribute: Att62
# nInterval: 2 bins: [-0.319712, -0.092815499999999995, 0.40022600000000003]
# Performing attribute: Att63
# nInterval: 2 bins: [-0.47689999999999999, 0.0034674999999999997, 0.34745799999999999]
# Performing attribute: Att64
# nInterval: 2 bins: [-0.34095199999999998, -0.046731000000000002, 0.54057200000000005]
# Performing attribute: Att65
# nInterval: 2 bins: [-0.410105, 0.067233000000000001, 0.37383]
# Performing attribute: Att66
# nInterval: 2 bins: [-0.46351499999999995, 0.071123999999999993, 0.37934200000000001]
# Performing attribute: Att67
# nInterval: 2 bins: [-0.58622099999999999, -0.050095000000000001, 0.42088100000000006]
# Performing attribute: Att68
# nInterval: 2 bins: [-0.63994499999999999, -0.016292500000000001, 0.377162]
# Performing attribute: Att69
# nInterval: 2 bins: [-0.35742299999999999, 0.010272999999999999, 0.58668599999999993]
# Performing attribute: Att70
# nInterval: 2 bins: [-0.53482200000000002, 0.34089349999999996, 0.72962099999999996]
# Performing attribute: Att71
# nInterval: 2 bins: [-0.35533799999999999, 0.076647500000000007, 0.43108000000000002]
# Performing attribute: Att72
# nInterval: 2 bins: [-0.31593699999999997, -0.073661499999999991, 0.34933200000000003]
# Performing attribute: Att73
# nInterval: 2 bins: [-0.44144499999999998, -0.086526000000000006, 0.30306900000000003]
# Performing attribute: Att74
# nInterval: 2 bins: [-0.46675299999999997, -0.100383, 0.39474499999999996]
# Performing attribute: Att75
# nInterval: 2 bins: [-0.38469399999999998, 0.25953799999999999, 0.49895699999999998]
# Performing attribute: Att76
# nInterval: 2 bins: [-0.38152600000000003, -0.058276499999999995, 0.33700799999999997]
# Performing attribute: Att77
# nInterval: 2 bins: [-0.339814, -0.1850175, 0.41170800000000002]
# Performing attribute: Att78
# nInterval: 2 bins: [-0.31355500000000003, -0.11172899999999999, 0.32793600000000001]
# Performing attribute: Att79
# nInterval: 2 bins: [-0.34031400000000001, -0.096530500000000005, 0.46023100000000006]
# Performing attribute: Att80
# nInterval: 2 bins: [-0.37492199999999998, 0.101284, 0.477746]
# Performing attribute: Att81
# nInterval: 2 bins: [-0.24023200000000003, 0.060083499999999998, 0.47487499999999999]
# Performing attribute: Att82
# nInterval: 2 bins: [-0.206148, -0.13922599999999999, 0.51250399999999996]
# Performing attribute: Att83
# nInterval: 2 bins: [-0.21615599999999999, -0.027511000000000001, 0.50268699999999999]
# Performing attribute: Att84
# nInterval: 2 bins: [-0.15887399999999999, 0.31325950000000002, 0.54205400000000004]
# Performing attribute: Att85
# nInterval: 2 bins: [-0.22790900000000003, -0.025115999999999999, 0.64297899999999997]
# Performing attribute: Att86
# nInterval: 2 bins: [-0.240227, 0.32074999999999998, 0.54831200000000002]
# Performing attribute: Att87
# nInterval: 2 bins: [-0.25389800000000001, -0.050133499999999998, 0.50323600000000002]
# Performing attribute: Att88
# nInterval: 2 bins: [-0.20729800000000001, 0.20292200000000002, 0.54798000000000002]
# Performing attribute: Att89
# nInterval: 2 bins: [-0.23285600000000001, 0.26437300000000002, 0.46915699999999999]
# Performing attribute: Att90
# nInterval: 2 bins: [-0.22148899999999999, -0.074044499999999999, 0.44519700000000001]
# Performing attribute: Att91
# nInterval: 2 bins: [-0.21056100000000003, -0.075085499999999999, 0.55898999999999999]
# Performing attribute: Att92
# nInterval: 2 bins: [-0.39853899999999998, -0.115818, 0.60113700000000003]
# Performing attribute: Att93
# nInterval: 2 bins: [-0.270397, 0.0388895, 0.54233999999999993]
# Performing attribute: Att94
# nInterval: 2 bins: [-0.45519100000000001, -0.14737349999999999, 0.60917500000000002]
# Performing attribute: Att95
# nInterval: 2 bins: [-0.28359400000000001, 0.087853500000000001, 0.54286699999999999]
# Performing attribute: Att96
# nInterval: 2 bins: [-0.27940799999999999, -0.035307999999999999, 0.54713400000000001]
# Performing attribute: Att97
# nInterval: 2 bins: [-0.22641999999999998, 0.0298275, 0.38592799999999999]
# Performing attribute: Att98
# nInterval: 2 bins: [-0.22537399999999999, 0.075702000000000005, 0.540493]
# Performing attribute: Att99
# nInterval: 2 bins: [-0.50157200000000002, -0.040851499999999999, 0.56925000000000003]
# Performing attribute: Att100
# nInterval: 2 bins: [-0.23658899999999999, -0.18108399999999999, 0.50996300000000006]
# Performing attribute: Att101
# nInterval: 2 bins: [-0.26705200000000001, -0.19829950000000002, 0.58735800000000005]
# Performing attribute: Att102
# nInterval: 2 bins: [-0.194079, -0.15971849999999999, 0.70033999999999996]
# Performing attribute: Att103
# nInterval: 2 bins: [-0.23775199999999999, 0.091206999999999996, 0.16343099999999999]
# Performing attribute: Att1
# nInterval: 2 bins: [0.0, 0.52405199999999996, 1.0]
# Performing attribute: Att2
# nInterval: 2 bins: [0.0, 0.54203849999999998, 1.0]
# Performing attribute: Att3
# nInterval: 2 bins: [0.0, 0.43093199999999998, 1.0]
# Performing attribute: Att4
# nInterval: 2 bins: [0.0, 0.48601900000000003, 1.0]
# Performing attribute: Att5
# nInterval: 2 bins: [0.0, 0.48534349999999998, 1.0]
# Performing attribute: Att6
# nInterval: 2 bins: [0.0, 0.59486600000000001, 1.0]
# Performing attribute: Att7
# nInterval: 2 bins: [0.0, 0.49984399999999996, 1.0]
# Performing attribute: Att8
# nInterval: 2 bins: [0.0, 0.46253650000000002, 1.0]
# Performing attribute: Att9
# nInterval: 2 bins: [0.0, 0.49288699999999996, 1.0]
# Performing attribute: Att10
# nInterval: 2 bins: [0.0, 0.49203249999999998, 1.0]
# Performing attribute: Att11
# nInterval: 2 bins: [0.0, 0.71338550000000001, 1.0]
# Performing attribute: Att12
# nInterval: 2 bins: [0.0, 0.73679199999999989, 1.0]
# Performing attribute: Att13
# nInterval: 2 bins: [0.0, 0.63617800000000002, 1.0]
# Performing attribute: Att14
# nInterval: 2 bins: [0.0, 0.56539249999999996, 1.0]
# Performing attribute: Att15
# nInterval: 2 bins: [0.0, 0.646038, 1.0]
# Performing attribute: Att16
# nInterval: 2 bins: [0.0, 0.19552849999999999, 1.0]
# Performing attribute: Att17
# nInterval: 2 bins: [0.0, 0.31867400000000001, 1.0]
# Performing attribute: Att18
# nInterval: 2 bins: [0.0, 0.28210800000000003, 1.0]
# Performing attribute: Att19
# nInterval: 2 bins: [0.0, 0.33438400000000001, 1.0]
# Performing attribute: Att20
# nInterval: 2 bins: [0.0, 0.3634385, 1.0]
# Performing attribute: Att21
# nInterval: 2 bins: [0.0, 0.60565350000000007, 1.0]
# Performing attribute: Att22
# nInterval: 2 bins: [0.0, 0.59220799999999996, 1.0]
# Performing attribute: Att23
# nInterval: 2 bins: [0.0, 0.63143000000000005, 1.0]
# Performing attribute: Att24
# nInterval: 2 bins: [0.0, 0.60212749999999993, 1.0]
# Performing attribute: Att25
# nInterval: 2 bins: [0.0, 0.63742699999999997, 1.0]
# Performing attribute: Att26
# nInterval: 2 bins: [0.0, 0.64512950000000002, 1.0]
# Performing attribute: Att27
# nInterval: 2 bins: [0.0, 0.62204450000000011, 1.0]
# Performing attribute: Att28
# nInterval: 2 bins: [0.0, 0.64687000000000006, 1.0]
# Performing attribute: Att29
# nInterval: 2 bins: [0.0, 0.61614400000000002, 1.0]
# Performing attribute: Att30
# nInterval: 2 bins: [0.0, 0.69413550000000002, 0.99763999999999997]
# Performing attribute: Att31
# nInterval: 2 bins: [0.0, 0.69518750000000007, 1.0]
# Performing attribute: Att32
# nInterval: 2 bins: [0.0, 0.69601299999999999, 0.98659799999999997]
# Performing attribute: Att33
# nInterval: 2 bins: [0.0, 0.66365950000000007, 0.99788399999999999]
# Performing attribute: Att34
# nInterval: 2 bins: [0.0, 0.667543, 1.0]
# Performing attribute: Att35
# nInterval: 2 bins: [0.0, 0.63924400000000003, 1.0]
# Performing attribute: Att36
# nInterval: 2 bins: [0.0, 0.64528150000000006, 0.99552399999999996]
# Performing attribute: Att37
# nInterval: 2 bins: [0.0, 0.68291049999999998, 1.0]
# Performing attribute: Att38
# nInterval: 2 bins: [0.0, 0.67688799999999993, 0.99661900000000003]
# Performing attribute: Att39
# nInterval: 2 bins: [0.0, 0.67413649999999992, 1.0]
# Performing attribute: Att40
# nInterval: 2 bins: [0.0, 0.706538, 1.0]
# Performing attribute: Att41
# nInterval: 2 bins: [0.0, 0.63343250000000006, 1.0]
# Performing attribute: Att42
# nInterval: 2 bins: [0.0, 0.62907299999999999, 1.0]
# Performing attribute: Att43
# nInterval: 2 bins: [0.0, 0.6630910000000001, 1.0]
# Performing attribute: Att44
# nInterval: 2 bins: [0.0, 0.68590149999999994, 0.98943600000000009]
# Performing attribute: Att45
# nInterval: 2 bins: [0.0, 0.72497100000000003, 1.0]
# Performing attribute: Att46
# nInterval: 2 bins: [0.0, 0.75387199999999999, 1.0]
# Performing attribute: Att47
# nInterval: 2 bins: [0.0, 0.739703, 0.99187800000000004]
# Performing attribute: Att48
# nInterval: 2 bins: [0.0, 0.70972500000000005, 0.98236299999999988]
# Performing attribute: Att49
# nInterval: 2 bins: [0.0, 0.70263450000000005, 1.0]
# Performing attribute: Att50
# nInterval: 2 bins: [0.0, 0.060079999999999995, 1.0]
# Performing attribute: Att51
# nInterval: 2 bins: [0.0, 0.069178500000000004, 1.0]
# Performing attribute: Att52
# nInterval: 2 bins: [0.0, 0.059593, 1.0]
# Performing attribute: Att53
# nInterval: 2 bins: [0.0, 0.064852999999999994, 1.0]
# Performing attribute: Att54
# nInterval: 2 bins: [0.0, 0.056946000000000004, 1.0]
# Performing attribute: Att55
# nInterval: 2 bins: [0.0, 0.046948499999999997, 1.0]
# Performing attribute: Att56
# nInterval: 2 bins: [0.0, 0.058740000000000007, 1.0]
# Performing attribute: Att57
# nInterval: 2 bins: [0.0, 0.084491499999999997, 1.0]
# Performing attribute: Att58
# nInterval: 2 bins: [0.0, 0.059442500000000009, 1.0]
# Performing attribute: Att59
# nInterval: 2 bins: [0.0, 0.089613499999999999, 1.0]
# Performing attribute: Att60
# nInterval: 2 bins: [0.0, 0.081787500000000013, 1.0]
# Performing attribute: Att61
# nInterval: 2 bins: [0.0, 0.064680000000000001, 1.0]
# Performing attribute: Att62
# nInterval: 2 bins: [0.0, 0.066834000000000005, 1.0]
# Performing attribute: Att63
# nInterval: 2 bins: [0.0, 0.079201500000000008, 1.0]
# Performing attribute: Att64
# nInterval: 2 bins: [0.0, 0.026053, 1.0]
# Performing attribute: Att65
# nInterval: 2 bins: [0.0, 0.021614500000000002, 1.0]
# Performing attribute: Att66
# nInterval: 2 bins: [0.0, 0.017016, 1.0]
# Performing attribute: Att67
# nInterval: 2 bins: [0.0, 0.021541000000000001, 1.0]
# Performing attribute: Att68
# nInterval: 2 bins: [0.0, 0.0209295, 1.0]
# Performing attribute: Att69
# nInterval: 2 bins: [0.0, 0.025481, 1.0]
# Performing attribute: Att70
# nInterval: 2 bins: [0.0, 0.029378500000000002, 1.0]
# Performing attribute: Att71
# nInterval: 2 bins: [0.0, 0.038176000000000002, 1.0]
# Performing attribute: Att72
# nInterval: 2 bins: [0.0, 0.0498585, 1.0]
# Performing attribute: Att73
# nInterval: 2 bins: [0.0, 0.030828000000000001, 1.0]
# Performing attribute: Att74
# nInterval: 2 bins: [0.0, 0.0197325, 1.0]
# Performing attribute: Att75
# nInterval: 2 bins: [0.0, 0.038152999999999999, 1.0]
# Performing attribute: Att76
# nInterval: 2 bins: [0.0, 0.052237000000000006, 1.0]
# Performing attribute: Att77
# nInterval: 2 bins: [0.0, 0.036692999999999996, 1.0]
# Performing attribute: Att78
# nInterval: 2 bins: [0.0, 0.0487345, 1.0]
# Performing attribute: Att79
# nInterval: 2 bins: [0.0, 0.30870350000000002, 1.0]
# Performing attribute: Att80
# nInterval: 2 bins: [0.0, 0.20360149999999999, 1.0]
# Performing attribute: Att81
# nInterval: 2 bins: [0.0, 0.26525199999999999, 1.0]
# Performing attribute: Att82
# nInterval: 2 bins: [0.0, 0.23875099999999999, 1.0]
# Performing attribute: Att83
# nInterval: 2 bins: [0.0, 0.13993549999999999, 1.0]
# Performing attribute: Att84
# nInterval: 2 bins: [0.0, 0.0582265, 1.0]
# Performing attribute: Att85
# nInterval: 2 bins: [0.0, 0.1297585, 1.0]
# Performing attribute: Att86
# nInterval: 2 bins: [0.0, 0.27397199999999999, 1.0]
# Performing attribute: Att87
# nInterval: 2 bins: [0.0, 0.22228149999999997, 1.0]
# Performing attribute: Att88
# nInterval: 2 bins: [0.0, 0.27097900000000003, 1.0]
# Performing attribute: Att89
# nInterval: 2 bins: [0.0, 0.29173199999999999, 1.0]
# Performing attribute: Att90
# nInterval: 2 bins: [0.0, 0.28625650000000002, 1.0]
# Performing attribute: Att91
# nInterval: 2 bins: [0.0, 0.1326415, 1.0]
# Performing attribute: Att92
# nInterval: 2 bins: [0.0, 0.0033435000000000001, 1.0]
# Performing attribute: Att93
# nInterval: 2 bins: [0.0, 0.339111, 1.0]
# Performing attribute: Att94
# nInterval: 2 bins: [0.0, 0.3494855, 1.0]
# Performing attribute: Att95
# nInterval: 2 bins: [0.0, 0.18131, 1.0]
# Performing attribute: Att96
# nInterval: 2 bins: [0.0, 0.3318295, 1.0]
# Performing attribute: Att97
# nInterval: 2 bins: [0.0, 0.33125649999999995, 1.0]
# Performing attribute: Att98
# nInterval: 2 bins: [0.0, 0.0078114999999999999, 1.0]
# Performing attribute: Att99
# nInterval: 2 bins: [0.0, 0.37767450000000002, 1.0]
# Performing attribute: Att100
# nInterval: 2 bins: [0.0, 0.37429699999999999, 1.0]
# Performing attribute: Att101
# nInterval: 2 bins: [0.0, 0.38300449999999997, 1.0]
# Performing attribute: Att102
# nInterval: 2 bins: [0.0, 0.36939949999999999, 1.0]
# Performing attribute: Att103
# nInterval: 2 bins: [0.0, 0.35911850000000001, 1.0]
# Performing attribute: Att104
# nInterval: 2 bins: [0.0, 0.35664950000000001, 1.0]
# Performing attribute: Att105
# nInterval: 2 bins: [0.0, 0.36649200000000004, 1.0]
# Performing attribute: Att106
# nInterval: 2 bins: [0.0, 0.42578149999999998, 1.0]
# Performing attribute: Att107
# nInterval: 2 bins: [0.0, 0.37137500000000001, 1.0]
# Performing attribute: Att108
# nInterval: 2 bins: [0.0, 0.38094, 1.0]
# Performing attribute: Att109
# nInterval: 2 bins: [0.0, 0.39611099999999999, 1.0]
# Performing attribute: Att110
# nInterval: 2 bins: [0.0, 0.36228950000000004, 1.0]
# Performing attribute: Att111
# nInterval: 2 bins: [0.0, 0.43585749999999995, 1.0]
# Performing attribute: Att112
# nInterval: 2 bins: [0.0, 0.42947649999999998, 1.0]
# Performing attribute: Att113
# nInterval: 2 bins: [0.0, 0.47926250000000004, 1.0]
# Performing attribute: Att114
# nInterval: 2 bins: [0.0, 0.41047349999999999, 1.0]
# Performing attribute: Att115
# nInterval: 2 bins: [0.0, 0.43381700000000001, 1.0]
# Performing attribute: Att116
# nInterval: 2 bins: [0.0, 0.44819249999999999, 1.0]
# Performing attribute: Att117
# nInterval: 2 bins: [0.0, 0.40626899999999999, 1.0]
# Performing attribute: Att118
# nInterval: 2 bins: [0.0, 0.42873950000000005, 1.0]
# Performing attribute: Att119
# nInterval: 2 bins: [0.0, 0.46536, 1.0]
# Performing attribute: Att120
# nInterval: 2 bins: [0.0, 0.51829799999999993, 1.0]
# Performing attribute: Att121
# nInterval: 2 bins: [0.0, 0.43216399999999999, 1.0]
# Performing attribute: Att122
# nInterval: 2 bins: [0.0, 0.47332000000000002, 1.0]
# Performing attribute: Att123
# nInterval: 2 bins: [0.0, 0.447764, 1.0]
# Performing attribute: Att124
# nInterval: 2 bins: [0.0, 0.43885449999999998, 1.0]
# Performing attribute: Att125
# nInterval: 2 bins: [0.0, 0.44869300000000001, 1.0]
# Performing attribute: Att126
# nInterval: 2 bins: [0.0, 0.47361900000000001, 1.0]
# Performing attribute: Att127
# nInterval: 2 bins: [0.0, 0.48957049999999996, 1.0]
# Performing attribute: Att128
# nInterval: 2 bins: [0.0, 0.48052800000000001, 1.0]
# Performing attribute: Att129
# nInterval: 2 bins: [0.0, 0.467891, 1.0]
# Performing attribute: Att130
# nInterval: 2 bins: [0.0, 0.45723900000000001, 1.0]
# Performing attribute: Att131
# nInterval: 2 bins: [0.0, 0.45993450000000002, 1.0]
# Performing attribute: Att132
# nInterval: 2 bins: [0.0, 0.49850799999999995, 1.0]
# Performing attribute: Att133
# nInterval: 2 bins: [0.0, 0.5443245000000001, 1.0]
# Performing attribute: Att134
# nInterval: 2 bins: [0.0, 0.48127549999999997, 1.0]
# Performing attribute: Att135
# nInterval: 2 bins: [0.0, 0.51212299999999999, 1.0]
# Performing attribute: Att136
# nInterval: 2 bins: [0.0, 0.51950550000000006, 1.0]
# Performing attribute: Att137
# nInterval: 2 bins: [0.0, 0.49629599999999996, 1.0]
# Performing attribute: Att138
# nInterval: 2 bins: [0.0, 0.49478899999999998, 1.0]
# Performing attribute: Att139
# nInterval: 2 bins: [0.0, 0.57492799999999988, 1.0]
# Performing attribute: Att140
# nInterval: 2 bins: [0.0, 0.2606, 1.0]
# Performing attribute: Att141
# nInterval: 2 bins: [0.0, 0.28295300000000001, 1.0]
# Performing attribute: Att142
# nInterval: 2 bins: [0.0, 0.30013000000000001, 1.0]
# Performing attribute: Att143
# nInterval: 2 bins: [0.0, 0.30846399999999996, 1.0]
# Performing attribute: Att144
# nInterval: 2 bins: [0.0, 0.30490149999999999, 1.0]
# Performing attribute: Att145
# nInterval: 2 bins: [0.0, 0.29779149999999999, 1.0]
# Performing attribute: Att146
# nInterval: 2 bins: [0.0, 0.2757715, 1.0]
# Performing attribute: Att147
# nInterval: 2 bins: [0.0, 0.2725785, 1.0]
# Performing attribute: Att148
# nInterval: 2 bins: [0.0, 0.030481500000000002, 1.0]
# Performing attribute: Att149
# nInterval: 2 bins: [0.0, 0.020919499999999997, 0.97143600000000008]
# Performing attribute: Att150
# nInterval: 2 bins: [0.0, 0.034380499999999994, 1.0]
# Performing attribute: Att151
# nInterval: 2 bins: [0.0, 0.021728000000000001, 1.0]
# Performing attribute: Att152
# nInterval: 2 bins: [0.0, 0.025827999999999997, 1.0]
# Performing attribute: Att153
# nInterval: 2 bins: [0.0, 0.015613499999999999, 1.0]
# Performing attribute: Att154
# nInterval: 2 bins: [0.0, 0.022241499999999997, 1.0]
# Performing attribute: Att155
# nInterval: 2 bins: [0.0, 0.031890500000000002, 1.0]
# Performing attribute: Att156
# nInterval: 2 bins: [0.0, 0.0307055, 1.0]
# Performing attribute: Att157
# nInterval: 2 bins: [0.0, 0.033681000000000003, 1.0]
# Performing attribute: Att158
# nInterval: 2 bins: [0.0, 0.031215999999999997, 1.0]
# Performing attribute: Att159
# nInterval: 2 bins: [0.0, 0.028688000000000002, 1.0]
# Performing attribute: Att160
# nInterval: 2 bins: [0.0, 0.028881999999999998, 1.0]
# Performing attribute: Att161
# nInterval: 2 bins: [0.0, 0.020279999999999999, 1.0]
# Performing attribute: Att162
# nInterval: 2 bins: [0.0, 0.029447999999999998, 1.0]
# Performing attribute: Att163
# nInterval: 2 bins: [0.0, 0.048994999999999997, 1.0]
# Performing attribute: Att164
# nInterval: 2 bins: [0.0, 0.044063000000000005, 1.0]
# Performing attribute: Att165
# nInterval: 2 bins: [0.0, 0.041326000000000002, 1.0]
# Performing attribute: Att166
# nInterval: 2 bins: [0.0, 0.050896999999999998, 1.0]
# Performing attribute: Att167
# nInterval: 2 bins: [6.0000000000000002e-06, 0.027363499999999999, 1.0]
# Performing attribute: Att168
# nInterval: 2 bins: [0.0, 0.025412999999999998, 1.0]
# Performing attribute: Att169
# nInterval: 2 bins: [0.0, 0.026495500000000002, 1.0]
# Performing attribute: Att170
# nInterval: 2 bins: [0.0, 0.042990499999999994, 1.0]
# Performing attribute: Att171
# nInterval: 2 bins: [0.0, 0.025457500000000001, 1.0]
# Performing attribute: Att172
# nInterval: 2 bins: [0.0, 0.030185, 1.0]
# Performing attribute: Att173
# nInterval: 2 bins: [9.9999999999999995e-07, 0.0269555, 1.0]
# Performing attribute: Att174
# nInterval: 2 bins: [9.0000000000000002e-06, 0.019901499999999999, 1.0]
# Performing attribute: Att175
# nInterval: 2 bins: [0.0, 0.036983000000000002, 1.0]
# Performing attribute: Att176
# nInterval: 2 bins: [0.0, 0.0324365, 1.0]
# Performing attribute: Att177
# nInterval: 2 bins: [0.0, 0.0431495, 1.0]
# Performing attribute: Att178
# nInterval: 2 bins: [0.0, 0.027935000000000001, 1.0]
# Performing attribute: Att179
# nInterval: 2 bins: [0.0, 0.027066999999999997, 1.0]
# Performing attribute: Att180
# nInterval: 2 bins: [0.0, 0.038943000000000005, 1.0]
# Performing attribute: Att181
# nInterval: 2 bins: [0.0, 0.034391499999999998, 1.0]
# Performing attribute: Att182
# nInterval: 2 bins: [0.0, 0.026819999999999997, 1.0]
# Performing attribute: Att183
# nInterval: 2 bins: [0.0, 0.0345875, 1.0]
# Performing attribute: Att184
# nInterval: 2 bins: [0.0, 0.050896999999999998, 1.0]
# Performing attribute: Att185
# nInterval: 2 bins: [0.0, 0.035525500000000002, 1.0]
# Performing attribute: Att186
# nInterval: 2 bins: [0.0, 0.042626999999999998, 1.0]
# Performing attribute: Att187
# nInterval: 2 bins: [0.0, 0.050128000000000006, 1.0]
# Performing attribute: Att188
# nInterval: 2 bins: [0.0, 0.029807499999999997, 1.0]
# Performing attribute: Att189
# nInterval: 2 bins: [0.0, 0.0417195, 1.0]
# Performing attribute: Att190
# nInterval: 2 bins: [0.0, 0.001586, 1.0]
# Performing attribute: Att191
# nInterval: 2 bins: [0.0, 0.001441, 1.0]
# Performing attribute: Att192
# nInterval: 2 bins: [0.0, 0.0011180000000000001, 1.0]
# Performing attribute: Att193
# nInterval: 2 bins: [0.0, 0.0020349999999999999, 1.0]
# Performing attribute: Att194
# nInterval: 2 bins: [0.0, 0.0016845000000000002, 1.0]
# Performing attribute: Att195
# nInterval: 2 bins: [0.0, 0.0022920000000000002, 1.0]
# Performing attribute: Att196
# nInterval: 2 bins: [0.0, 0.0031709999999999998, 1.0]
# Performing attribute: Att197
# nInterval: 2 bins: [0.0, 0.52242699999999997, 1.0]
# Performing attribute: Att198
# nInterval: 2 bins: [0.0, 0.49606799999999995, 1.0]
# Performing attribute: Att199
# nInterval: 2 bins: [0.0, 0.49987249999999994, 1.0]
# Performing attribute: Att200
# nInterval: 2 bins: [0.0, 0.49963099999999994, 1.0]
# Performing attribute: Att201
# nInterval: 2 bins: [0.0, 0.4988205, 1.0]
# Performing attribute: Att202
# nInterval: 2 bins: [0.0, 0.49710949999999998, 1.0]
# Performing attribute: Att203
# nInterval: 2 bins: [0.0, 0.48798600000000003, 1.0]
# Performing attribute: Att204
# nInterval: 2 bins: [0.0, 0.49835750000000001, 1.0]
# Performing attribute: Att205
# nInterval: 2 bins: [0.0, 0.49637700000000001, 1.0]
# Performing attribute: Att206
# nInterval: 2 bins: [0.0, 0.53013149999999998, 1.0]
# Performing attribute: Att207
# nInterval: 2 bins: [0.0, 0.55861099999999997, 1.0]
# Performing attribute: Att208
# nInterval: 2 bins: [0.0, 0.49392800000000003, 1.0]
# Performing attribute: Att209
# nInterval: 2 bins: [0.0, 0.501197, 1.0]
# Performing attribute: Att210
# nInterval: 2 bins: [0.0, 0.52137549999999999, 1.0]
# Performing attribute: Att211
# nInterval: 2 bins: [0.0, 0.62047649999999999, 1.0]
# Performing attribute: Att212
# nInterval: 2 bins: [0.0, 0.56338350000000004, 1.0]
# Performing attribute: Att213
# nInterval: 2 bins: [0.0, 0.57439299999999993, 1.0]
# Performing attribute: Att214
# nInterval: 2 bins: [0.0, 0.58368599999999993, 1.0]
# Performing attribute: Att215
# nInterval: 2 bins: [0.0, 0.64754149999999999, 1.0]
# Performing attribute: Att216
# nInterval: 2 bins: [0.0, 0.57955350000000005, 1.0]
# Performing attribute: Att217
# nInterval: 2 bins: [0.0, 0.59116100000000005, 1.0]
# Performing attribute: Att218
# nInterval: 2 bins: [0.0, 0.55418000000000001, 1.0]
# Performing attribute: Att219
# nInterval: 2 bins: [0.0, 0.63430399999999998, 1.0]
# Performing attribute: Att220
# nInterval: 2 bins: [0.0, 0.62086249999999998, 1.0]
# Performing attribute: Att221
# nInterval: 2 bins: [0.0, 0.62295349999999994, 1.0]
# Performing attribute: Att222
# nInterval: 2 bins: [0.0, 0.60311549999999992, 1.0]
# Performing attribute: Att223
# nInterval: 2 bins: [0.0, 0.65700599999999998, 1.0]
# Performing attribute: Att224
# nInterval: 2 bins: [0.0, 0.57428349999999995, 1.0]
# Performing attribute: Att225
# nInterval: 2 bins: [0.0, 0.73457349999999999, 1.0]
# Performing attribute: Att226
# nInterval: 2 bins: [0.0, 0.66057199999999994, 1.0]
# Performing attribute: Att227
# nInterval: 2 bins: [0.0, 0.74895149999999999, 1.0]
# Performing attribute: Att228
# nInterval: 2 bins: [0.0, 0.73619499999999993, 1.0]
# Performing attribute: Att229
# nInterval: 2 bins: [0.0, 0.72572949999999992, 1.0]
# Performing attribute: Att230
# nInterval: 2 bins: [0.0, 0.75376849999999995, 1.0]
# Performing attribute: Att231
# nInterval: 2 bins: [0.0, 0.69072650000000002, 1.0]
# Performing attribute: Att232
# nInterval: 2 bins: [0.0, 0.76708100000000001, 1.0]
# Performing attribute: Att233
# nInterval: 2 bins: [0.0, 0.73831950000000002, 1.0]
# Performing attribute: Att234
# nInterval: 2 bins: [0.0, 0.73141350000000005, 1.0]
# Performing attribute: Att235
# nInterval: 2 bins: [0.0, 0.763324, 1.0]
# Performing attribute: Att236
# nInterval: 2 bins: [0.0, 0.75675950000000003, 1.0]
# Performing attribute: Att237
# nInterval: 2 bins: [0.0, 0.74617549999999999, 1.0]
# Performing attribute: Att238
# nInterval: 2 bins: [0.0, 0.76086950000000009, 1.0]
# Performing attribute: Att239
# nInterval: 2 bins: [0.0, 0.73108449999999991, 1.0]
# Performing attribute: Att240
# nInterval: 2 bins: [0.0, 0.75779949999999996, 1.0]
# Performing attribute: Att241
# nInterval: 2 bins: [0.0, 0.73406450000000001, 1.0]
# Performing attribute: Att242
# nInterval: 2 bins: [0.0, 0.728043, 1.0]
# Performing attribute: Att243
# nInterval: 2 bins: [0.0, 0.79806599999999994, 1.0]
# Performing attribute: Att244
# nInterval: 2 bins: [0.0, 0.79177299999999995, 1.0]
# Performing attribute: Att245
# nInterval: 2 bins: [0.0, 0.72112100000000001, 1.0]
# Performing attribute: Att246
# nInterval: 2 bins: [0.0, 0.11458299999999999, 1.0]
# Performing attribute: Att247
# nInterval: 2 bins: [0.0, 0.13016900000000001, 1.0]
# Performing attribute: Att248
# nInterval: 2 bins: [0.0, 0.10552399999999999, 1.0]
# Performing attribute: Att249
# nInterval: 2 bins: [0.0, 0.086834000000000008, 1.0]
# Performing attribute: Att250
# nInterval: 2 bins: [0.0, 0.081034500000000009, 1.0]
# Performing attribute: Att251
# nInterval: 2 bins: [0.0, 0.080023499999999984, 1.0]
# Performing attribute: Att252
# nInterval: 2 bins: [0.0, 0.094293500000000002, 1.0]
# Performing attribute: Att253
# nInterval: 2 bins: [0.0, 0.12270000000000002, 1.0]
# Performing attribute: Att254
# nInterval: 2 bins: [0.0, 0.1214295, 1.0]
# Performing attribute: Att255
# nInterval: 2 bins: [0.0, 0.091013499999999997, 1.0]
# Performing attribute: Att256
# nInterval: 2 bins: [0.0, 0.10435099999999999, 1.0]
# Performing attribute: Att257
# nInterval: 2 bins: [0.0, 0.097370999999999999, 1.0]
# Performing attribute: Att258
# nInterval: 2 bins: [0.0, 0.13360349999999999, 1.0]
# Performing attribute: Att259
# nInterval: 2 bins: [0.0, 0.096144000000000007, 1.0]
# Performing attribute: Att260
# nInterval: 2 bins: [0.0, 0.11976500000000001, 1.0]
# Performing attribute: Att261
# nInterval: 2 bins: [0.0, 0.11499899999999999, 1.0]
# Performing attribute: Att262
# nInterval: 2 bins: [0.0, 0.17461200000000002, 1.0]
# Performing attribute: Att263
# nInterval: 2 bins: [0.0, 0.098080000000000001, 1.0]
# Performing attribute: Att264
# nInterval: 2 bins: [2.0000000000000002e-05, 0.114314, 1.0]
# Performing attribute: Att265
# nInterval: 2 bins: [2.0000000000000002e-05, 0.13101550000000001, 1.0]
# Performing attribute: Att266
# nInterval: 2 bins: [7.7999999999999999e-05, 0.13012599999999999, 1.0]
# Performing attribute: Att267
# nInterval: 2 bins: [0.0, 0.20394899999999999, 1.0]
# Performing attribute: Att268
# nInterval: 2 bins: [0.0, 0.14156150000000001, 1.0]
# Performing attribute: Att269
# nInterval: 2 bins: [0.00026200000000000003, 0.16023950000000001, 1.0]
# Performing attribute: Att270
# nInterval: 2 bins: [0.000154, 0.12940299999999999, 1.0]
# Performing attribute: Att271
# nInterval: 2 bins: [7.0000000000000007e-06, 0.1197925, 1.0]
# Performing attribute: Att272
# nInterval: 2 bins: [0.0, 0.1409745, 1.0]
# Performing attribute: Att273
# nInterval: 2 bins: [0.0, 0.12997150000000002, 1.0]
# Performing attribute: Att274
# nInterval: 2 bins: [0.0, 0.098815500000000001, 1.0]
# Performing attribute: Att275
# nInterval: 2 bins: [0.0, 0.1416085, 1.0]
# Performing attribute: Att276
# nInterval: 2 bins: [0.0, 0.13175450000000002, 1.0]
# Performing attribute: Att277
# nInterval: 2 bins: [3.0000000000000001e-06, 0.10399499999999999, 1.0]
# Performing attribute: Att278
# nInterval: 2 bins: [0.0, 0.13715650000000001, 1.0]
# Performing attribute: Att279
# nInterval: 2 bins: [0.0, 0.14238699999999999, 1.0]
# Performing attribute: Att280
# nInterval: 2 bins: [0.0, 0.14949450000000003, 1.0]
# Performing attribute: Att281
# nInterval: 2 bins: [0.0, 0.0092780000000000015, 1.0]
# Performing attribute: Att282
# nInterval: 2 bins: [0.0, 0.15750649999999999, 1.0]
# Performing attribute: Att283
# nInterval: 2 bins: [0.0, 0.0077315000000000005, 1.0]
# Performing attribute: Att284
# nInterval: 2 bins: [0.0, 0.012531500000000001, 1.0]
# Performing attribute: Att285
# nInterval: 2 bins: [0.0, 0.014900499999999999, 1.0]
# Performing attribute: Att286
# nInterval: 2 bins: [0.0, 0.020004999999999998, 1.0]
# Performing attribute: Att287
# nInterval: 2 bins: [0.0, 0.0093959999999999998, 1.0]
# Performing attribute: Att288
# nInterval: 2 bins: [0.0, 0.013436999999999999, 1.0]
# Performing attribute: Att289
# nInterval: 2 bins: [0.0, 0.0081814999999999995, 1.0]
# Performing attribute: Att290
# nInterval: 2 bins: [0.0, 0.0093904999999999995, 1.0]
# Performing attribute: Att291
# nInterval: 2 bins: [0.0, 0.013957000000000001, 1.0]
# Performing attribute: Att292
# nInterval: 2 bins: [0.0, 0.010337000000000001, 1.0]
# Performing attribute: Att293
# nInterval: 2 bins: [0.0, 0.0100505, 1.0]
# Performing attribute: Att294
# nInterval: 2 bins: [0.0, 0.016056500000000001, 1.0]

# %% [markdown]
# # large dataset

# %%
def read_data(dataPath):
    # input: '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'
    # read data
    data = pd.read_csv(os.path.join(dataPath,'X_1500.csv'))
    label = pd.read_csv(os.path.join(dataPath,'y.csv'))
    return data,label

filePath = '/Volumes/Samsung_T5/research/data/large_datasets/'
for dataset in ['rcv1subset5']:
    print(filePath+dataset)
    X, y = read_data(filePath+dataset)
    X_dis = perform_LAIM(X, y)
    # y.to_csv(os.path.join(filePath,dataset,'y.csv'), index=False)
    X_dis.to_csv(os.path.join(filePath,dataset,'X_dis_1500.csv'), index=False)
# Out:
# /Volumes/Samsung_T5/research/data/large_datasets/rcv1subset5
# Performing attribute: Att19
# bins: [0.0, 0.21142800000000006]
# Performing attribute: Att25
# bins: [0.0, 0.28212800000000005]
# Performing attribute: Att28
# nInterval: 2 bins: [0.0, 0.07748, 0.398938]
# Performing attribute: Att30
# nInterval: 2 bins: [0.0, 0.0992375, 0.276069]
# Performing attribute: Att31
# nInterval: 2 bins: [0.0, 0.09, 0.390205]
# Performing attribute: Att32
# nInterval: 2 bins: [0.0, 0.1199825, 0.37455]
# Performing attribute: Att46
# bins: [0.0, 0.173209]
# Performing attribute: Att87
# bins: [0.0, 0.147427]
# Performing attribute: Att274
# nInterval: 2 bins: [0.0, 0.05404, 0.409281]
# Performing attribute: Att305
# nInterval: 2 bins: [0.0, 0.2297655, 0.460596]
# Performing attribute: Att370
# nInterval: 2 bins: [0.0, 0.093041, 0.336285]
# Performing attribute: Att430
# bins: [0.0, 0.100762]
# Performing attribute: Att467
# bins: [0.0, 0.641472]
# Performing attribute: Att478
# nInterval: 2 bins: [0.0, 0.042794, 0.198296]
# Performing attribute: Att501
# nInterval: 2 bins: [0.0, 0.1669765, 0.377001]
# Performing attribute: Att554
# bins: [0.0, 0.167476]
# Performing attribute: Att563
# bins: [0.0, 0.150359]
# Performing attribute: Att568
# nInterval: 2 bins: [0.0, 0.1209945, 0.5854659999999999]
# Performing attribute: Att584
# nInterval: 2 bins: [0.0, 0.129385, 0.4386890000000001]
# Performing attribute: Att610
# nInterval: 2 bins: [0.0, 0.2399825, 0.479965]
# Performing attribute: Att659
# bins: [0.0, 0.257493]
# Performing attribute: Att812
# bins: [0.0, 0.081842]
# Performing attribute: Att826
# nInterval: 2 bins: [0.0, 0.1039495, 0.207899]
# Performing attribute: Att905
# nInterval: 2 bins: [0.0, 0.0470655, 0.229859]
# Performing attribute: Att914
# nInterval: 2 bins: [0.0, 0.0510655, 0.218688]
# Performing attribute: Att926
# nInterval: 2 bins: [0.0, 0.095029, 0.190058]
# Performing attribute: Att1054
# nInterval: 2 bins: [0.0, 0.3130805, 0.626161]
# Performing attribute: Att1104
# nInterval: 2 bins: [0.0, 0.085289, 0.467559]
# Performing attribute: Att1107
# nInterval: 2 bins: [0.0, 0.108143, 0.512278]
# Performing attribute: Att1156
# nInterval: 2 bins: [0.0, 0.078287, 0.309569]
# Performing attribute: Att1220
# bins: [0.0, 0.136845]
# Performing attribute: Att1276
# nInterval: 2 bins: [0.0, 0.031053, 0.33734699999999995]
# Performing attribute: Att1298
# nInterval: 2 bins: [0.0, 0.040921, 0.518638]
# Performing attribute: Att1304
# nInterval: 2 bins: [0.0, 0.242592, 0.485184]
# Performing attribute: Att1389
# nInterval: 2 bins: [0.0, 0.2145125, 0.429025]
# Performing attribute: Att1417
# nInterval: 2 bins: [0.0, 0.08053400000000001, 0.4187270000000001]
# Performing attribute: Att1630
# nInterval: 2 bins: [0.0, 0.13177850000000002, 0.26355700000000004]
# Performing attribute: Att1650
# nInterval: 2 bins: [0.0, 0.0946475, 0.26015]
# Performing attribute: Att1696
# bins: [0.0, 0.193945]
# Performing attribute: Att1697
# bins: [0.0, 0.235937]
# Performing attribute: Att1743
# bins: [0.0, 0.453471]
# Performing attribute: Att1816
# nInterval: 2 bins: [0.0, 0.0687065, 0.226763]
# Performing attribute: Att1928
# nInterval: 2 bins: [0.0, 0.079913, 0.225189]
# Performing attribute: Att1944
# nInterval: 2 bins: [0.0, 0.0515335, 0.252106]
# Performing attribute: Att1958
# nInterval: 2 bins: [0.0, 0.082738, 0.165476]
# Performing attribute: Att1972
# bins: [0.0, 0.286932]
# Performing attribute: Att1980
# nInterval: 2 bins: [0.0, 0.111117, 0.315217]
# Performing attribute: Att2047
# nInterval: 2 bins: [0.0, 0.2074855, 0.414971]
# Performing attribute: Att2063
# bins: [0.0, 0.12846]
# Performing attribute: Att2081
# bins: [0.0, 0.089894]
# Performing attribute: Att2134
# bins: [0.0, 0.166482]
# Performing attribute: Att2142
# nInterval: 2 bins: [0.0, 0.094032, 0.535932]
# Performing attribute: Att2148
# nInterval: 2 bins: [0.0, 0.060186, 0.474033]
# Performing attribute: Att2160
# nInterval: 2 bins: [0.0, 0.2220835, 0.444167]
# Performing attribute: Att2173
# bins: [0.0, 0.25464499999999995]
# Performing attribute: Att2312
# bins: [0.0, 0.356394]
# Performing attribute: Att2350
# nInterval: 2 bins: [0.0, 0.134195, 0.26839]
# Performing attribute: Att2371
# nInterval: 2 bins: [0.0, 0.035519999999999996, 0.312935]
# Performing attribute: Att2434
# nInterval: 2 bins: [0.0, 0.100884, 0.238994]
# Performing attribute: Att2439
# nInterval: 2 bins: [0.0, 0.071603, 0.272666]
# Performing attribute: Att2453
# nInterval: 2 bins: [0.0, 0.069084, 0.459423]
# Performing attribute: Att2536
# bins: [0.0, 0.6041890000000001]
# Performing attribute: Att2553
# bins: [0.0, 0.29684]
# Performing attribute: Att2567
# bins: [0.0, 0.474033]
# Performing attribute: Att2593
# bins: [0.0, 0.542673]
# Performing attribute: Att2626
# nInterval: 2 bins: [0.0, 0.0690025, 0.220006]
# Performing attribute: Att2675
# bins: [0.0, 0.321808]
# Performing attribute: Att2713
# bins: [0.0, 0.164971]
# Performing attribute: Att2761
# nInterval: 2 bins: [0.0, 0.2015065, 0.41439]
# Performing attribute: Att2762
# nInterval: 2 bins: [0.0, 0.292017, 0.584034]
# Performing attribute: Att2764
# nInterval: 2 bins: [0.0, 0.0528515, 0.26891]
# Performing attribute: Att2776
# nInterval: 2 bins: [0.0, 0.075515, 0.403849]
# Performing attribute: Att2798
# nInterval: 2 bins: [0.0, 0.1121225, 0.224245]
# Performing attribute: Att2843
# nInterval: 2 bins: [0.0, 0.043628, 0.255209]
# Performing attribute: Att2861
# bins: [0.0, 0.4960640000000001]
# Performing attribute: Att2867
# nInterval: 2 bins: [0.0, 0.1222955, 0.405034]
# Performing attribute: Att2876
# nInterval: 2 bins: [0.0, 0.128849, 0.456919]
# Performing attribute: Att3024
# nInterval: 2 bins: [0.0, 0.08886799999999999, 0.472687]
# Performing attribute: Att3043
# nInterval: 2 bins: [0.0, 0.1651515, 0.330303]
# Performing attribute: Att3092
# nInterval: 2 bins: [0.0, 0.17484, 0.34968]
# Performing attribute: Att3096
# nInterval: 2 bins: [0.0, 0.1354185, 0.482126]
# Performing attribute: Att3105
# bins: [0.0, 0.124411]
# Performing attribute: Att3125
# bins: [0.0, 0.144817]
# Performing attribute: Att3189
# nInterval: 2 bins: [0.0, 0.067277, 0.31195900000000004]
# Performing attribute: Att3194
# nInterval: 2 bins: [0.0, 0.0815015, 0.206619]
# Performing attribute: Att3231
# bins: [0.0, 0.231548]
# Performing attribute: Att3274
# nInterval: 2 bins: [0.0, 0.1097685, 0.413537]
# Performing attribute: Att3315
# nInterval: 2 bins: [0.0, 0.1788405, 0.400226]
# Performing attribute: Att3337
# nInterval: 2 bins: [0.0, 0.061943499999999985, 0.12388699999999997]
# Performing attribute: Att3370
# nInterval: 2 bins: [0.0, 0.095997, 0.330234]
# Performing attribute: Att3406
# nInterval: 2 bins: [0.0, 0.031439, 0.276865]
# Performing attribute: Att3422
# nInterval: 2 bins: [0.0, 0.0735, 0.57387]
# Performing attribute: Att3447
# nInterval: 2 bins: [0.0, 0.057761, 0.615356]
# Performing attribute: Att3457
# nInterval: 2 bins: [0.0, 0.054191, 0.338953]
# Performing attribute: Att3506
# bins: [0.0, 0.255186]
# Performing attribute: Att3524
# nInterval: 2 bins: [0.0, 0.122957, 0.593154]
# Performing attribute: Att3549
# bins: [0.0, 0.174625]
# Performing attribute: Att3550
# nInterval: 2 bins: [0.0, 0.208163, 0.439162]
# Performing attribute: Att3583
# nInterval: 2 bins: [0.0, 0.0300765, 0.274936]
# Performing attribute: Att3597
# nInterval: 2 bins: [0.0, 0.304392, 0.608784]
# Performing attribute: Att3605
# nInterval: 2 bins: [0.0, 0.07939349999999999, 0.300399]
# Performing attribute: Att3608
# bins: [0.0, 0.289829]
# Performing attribute: Att3688
# bins: [0.0, 0.239833]
# Performing attribute: Att3703
# nInterval: 2 bins: [0.0, 0.073877, 0.183838]
# Performing attribute: Att3761
# nInterval: 2 bins: [0.0, 0.1426735, 0.368929]
# Performing attribute: Att3786
# nInterval: 2 bins: [0.0, 0.06818049999999999, 0.13636099999999998]
# Performing attribute: Att3829
# nInterval: 2 bins: [0.0, 0.07234249999999999, 0.332775]
# Performing attribute: Att3888
# nInterval: 2 bins: [0.0, 0.180202, 0.360404]
# Performing attribute: Att3933
# nInterval: 2 bins: [0.0, 0.09149, 0.294117]
# Performing attribute: Att3959
# bins: [0.0, 0.136756]
# Performing attribute: Att3973
# nInterval: 2 bins: [0.0, 0.160722, 0.321444]
# Performing attribute: Att3977
# nInterval: 2 bins: [0.0, 0.0700615, 0.158019]
# Performing attribute: Att3987
# nInterval: 2 bins: [0.0, 0.1596245, 0.319249]
# Performing attribute: Att4004
# bins: [0.0, 0.661222]
# Performing attribute: Att4009
# nInterval: 2 bins: [0.0, 0.1786605, 0.357321]
# Performing attribute: Att4010
# nInterval: 2 bins: [0.0, 0.03802, 0.269385]
# Performing attribute: Att4012
# bins: [0.0, 0.099408]
# Performing attribute: Att4043
# nInterval: 2 bins: [0.0, 0.0648225, 0.459796]
# Performing attribute: Att4087
# nInterval: 2 bins: [0.0, 0.068899, 0.304468]
# Performing attribute: Att4108
# nInterval: 2 bins: [0.0, 0.2410065, 0.482013]
# Performing attribute: Att4124
# nInterval: 2 bins: [0.0, 0.085171, 0.683297]
# Performing attribute: Att4249
# nInterval: 2 bins: [0.0, 0.10816700000000003, 0.3377]
# Performing attribute: Att4273
# nInterval: 2 bins: [0.0, 0.11004000000000003, 0.434562]
# Performing attribute: Att4469
# bins: [0.0, 0.28939000000000004]
# Performing attribute: Att4545
# bins: [0.0, 0.668955]
# Performing attribute: Att4574
# nInterval: 2 bins: [0.0, 0.127123, 0.254246]
# Performing attribute: Att4592
# bins: [0.0, 0.184962]
# Performing attribute: Att4665
# nInterval: 2 bins: [0.0, 0.027964, 0.384828]
# Performing attribute: Att4760
# nInterval: 2 bins: [0.0, 0.34832399999999997, 0.6966479999999999]
# Performing attribute: Att4805
# nInterval: 2 bins: [0.0, 0.156285, 0.31257]
# Performing attribute: Att4847
# bins: [0.0, 0.148999]
# Performing attribute: Att4891
# bins: [0.0, 0.503292]
# Performing attribute: Att4946
# nInterval: 2 bins: [0.0, 0.1008, 0.394624]
# Performing attribute: Att4960
# bins: [0.0, 0.433199]
# Performing attribute: Att4972
# nInterval: 2 bins: [0.0, 0.0882785, 0.191899]
# Performing attribute: Att4984
# bins: [0.0, 0.090395]
# Performing attribute: Att4990
# nInterval: 2 bins: [0.0, 0.0607955, 0.321449]
# Performing attribute: Att4993
# bins: [0.0, 0.383029]
# Performing attribute: Att5015
# bins: [0.0, 0.308049]
# Performing attribute: Att5037
# nInterval: 2 bins: [0.0, 0.181296, 0.453517]
# Performing attribute: Att5092
# nInterval: 2 bins: [0.0, 0.19076500000000002, 0.377418]
# Performing attribute: Att5096
# bins: [0.0, 0.187706]
# Performing attribute: Att5119
# bins: [0.0, 0.296725]
# Performing attribute: Att5156
# bins: [0.0, 0.190204]
# Performing attribute: Att5158
# nInterval: 2 bins: [0.0, 0.0551425, 0.459494]
# Performing attribute: Att5199
# nInterval: 2 bins: [0.0, 0.0435375, 0.354489]
# Performing attribute: Att5206
# nInterval: 2 bins: [0.0, 0.1297415, 0.288193]
# Performing attribute: Att5220
# nInterval: 2 bins: [0.0, 0.241765, 0.48353]
# Performing attribute: Att5255
# bins: [0.0, 0.134267]
# Performing attribute: Att5269
# nInterval: 2 bins: [0.0, 0.0941065, 0.262379]
# Performing attribute: Att5310
# bins: [0.0, 0.142741]
# Performing attribute: Att5355
# bins: [0.0, 0.39458]
# Performing attribute: Att5366
# nInterval: 2 bins: [0.0, 0.08469, 0.16938]
# Performing attribute: Att5393
# nInterval: 2 bins: [0.0, 0.1504565, 0.533289]
# Performing attribute: Att5429
# nInterval: 2 bins: [0.0, 0.0503155, 0.315855]
# Performing attribute: Att5433
# nInterval: 2 bins: [0.0, 0.1126235, 0.225247]
# Performing attribute: Att5438
# nInterval: 2 bins: [0.0, 0.080314, 0.545564]
# Performing attribute: Att5463
# nInterval: 2 bins: [0.0, 0.226625, 0.45325]
# Performing attribute: Att5498
# bins: [0.0, 0.306505]
# Performing attribute: Att5545
# bins: [0.0, 0.278443]
# Performing attribute: Att5572
# nInterval: 2 bins: [0.0, 0.0571845, 0.5362239999999999]
# Performing attribute: Att5576
# nInterval: 2 bins: [0.0, 0.1463265, 0.485832]
# Performing attribute: Att5600
# nInterval: 2 bins: [0.0, 0.0620725, 0.421638]
# Performing attribute: Att5631
# nInterval: 2 bins: [0.0, 0.1211, 0.449592]
# Performing attribute: Att5716
# nInterval: 2 bins: [0.0, 0.2144425, 0.476322]
# Performing attribute: Att5888
# bins: [0.0, 0.206265]
# Performing attribute: Att5890
# nInterval: 2 bins: [0.0, 0.1477425, 0.534173]
# Performing attribute: Att5902
# nInterval: 2 bins: [0.0, 0.3186285, 0.637257]
# Performing attribute: Att5922
# nInterval: 2 bins: [0.0, 0.202347, 0.404694]
# Performing attribute: Att5945
# nInterval: 2 bins: [0.0, 0.035477, 0.289698]
# Performing attribute: Att6023
# bins: [0.0, 0.108021]
# Performing attribute: Att6048
# nInterval: 2 bins: [0.0, 0.192984, 0.541475]
# Performing attribute: Att6062
# bins: [0.0, 0.220584]
# Performing attribute: Att6084
# bins: [0.0, 0.104342]
# Performing attribute: Att6150
# nInterval: 2 bins: [0.0, 0.0473295, 0.387381]
# Performing attribute: Att6158
# bins: [0.0, 0.337979]
# Performing attribute: Att6159
# nInterval: 2 bins: [0.0, 0.08225299999999999, 0.32513800000000004]
# Performing attribute: Att6229
# nInterval: 2 bins: [0.0, 0.272325, 0.54465]
# Performing attribute: Att6247
# bins: [0.0, 0.266647]
# Performing attribute: Att6292
# nInterval: 2 bins: [0.0, 0.06832200000000001, 0.42873]
# Performing attribute: Att6341
# nInterval: 2 bins: [0.0, 0.0957575, 0.191515]
# Performing attribute: Att6348
# nInterval: 2 bins: [0.0, 0.082513, 0.292223]
# Performing attribute: Att6355
# nInterval: 2 bins: [0.0, 0.2068815, 0.413763]
# Performing attribute: Att6366
# bins: [0.0, 0.45542]
# Performing attribute: Att6381
# nInterval: 2 bins: [0.0, 0.1117305, 0.223461]
# Performing attribute: Att6398
# nInterval: 2 bins: [0.0, 0.255069, 0.6390819999999999]
# Performing attribute: Att6403
# nInterval: 2 bins: [0.0, 0.0524125, 0.405977]
# Performing attribute: Att6448
# nInterval: 2 bins: [0.0, 0.084961, 0.394757]
# Performing attribute: Att6524
# nInterval: 2 bins: [0.0, 0.03898, 0.175342]
# Performing attribute: Att6567
# nInterval: 2 bins: [0.0, 0.264282, 0.528564]
# Performing attribute: Att6644
# nInterval: 2 bins: [0.0, 0.17084000000000002, 0.34168000000000004]
# Performing attribute: Att6658
# nInterval: 2 bins: [0.0, 0.095684, 0.448578]
# Performing attribute: Att6665
# nInterval: 2 bins: [0.0, 0.1915285, 0.383057]
# Performing attribute: Att6693
# nInterval: 2 bins: [0.0, 0.1147235, 0.229447]
# Performing attribute: Att6769
# nInterval: 2 bins: [0.0, 0.039697, 0.290725]
# Performing attribute: Att6816
# nInterval: 2 bins: [0.0, 0.0705365, 0.155554]
# Performing attribute: Att6835
# nInterval: 2 bins: [0.0, 0.0719865, 0.216715]
# Performing attribute: Att6841
# bins: [0.0, 0.190817]
# Performing attribute: Att6846
# bins: [0.0, 0.378716]
# Performing attribute: Att6896
# nInterval: 2 bins: [0.0, 0.0518265, 0.399742]
# Performing attribute: Att6902
# nInterval: 2 bins: [0.0, 0.155984, 0.312717]
# Performing attribute: Att6914
# nInterval: 2 bins: [0.0, 0.1772935, 0.434404]
# Performing attribute: Att6916
# bins: [0.0, 0.233309]
# Performing attribute: Att6931
# nInterval: 2 bins: [0.0, 0.187427, 0.374854]
# Performing attribute: Att6944
# nInterval: 2 bins: [0.0, 0.182284, 0.364568]
# Performing attribute: Att6946
# nInterval: 2 bins: [0.0, 0.1657525, 0.331505]
# Performing attribute: Att6972
# nInterval: 2 bins: [0.0, 0.075706, 0.17570999999999998]
# Performing attribute: Att6973
# bins: [0.0, 0.237435]
# Performing attribute: Att6976
# bins: [0.0, 0.21851]
# Performing attribute: Att6978
# nInterval: 2 bins: [0.0, 0.097804, 0.423615]
# Performing attribute: Att6987
# bins: [0.0, 0.311539]
# Performing attribute: Att6989
# nInterval: 2 bins: [0.0, 0.0923475, 0.460458]
# Performing attribute: Att7078
# nInterval: 2 bins: [0.0, 0.0549515, 0.26973600000000003]
# Performing attribute: Att7088
# nInterval: 2 bins: [0.0, 0.1282055, 0.256411]
# Performing attribute: Att7095
# nInterval: 2 bins: [0.0, 0.0469585, 0.384347]
# Performing attribute: Att7103
# nInterval: 2 bins: [0.0, 0.03913, 0.172738]
# Performing attribute: Att7153
# nInterval: 2 bins: [0.0, 0.1635135, 0.327027]
# Performing attribute: Att7164
# nInterval: 2 bins: [0.0, 0.1057165, 0.211433]
# Performing attribute: Att7174
# nInterval: 2 bins: [0.0, 0.1745385, 0.349077]
# Performing attribute: Att7193
# nInterval: 2 bins: [0.0, 0.044015, 0.23531]
# Performing attribute: Att7259
# bins: [0.0, 0.6300859999999999]
# Performing attribute: Att7261
# nInterval: 2 bins: [0.0, 0.085155, 0.271321]
# Performing attribute: Att7288
# bins: [0.0, 0.13596]
# Performing attribute: Att7301
# nInterval: 2 bins: [0.0, 0.047561, 0.292131]
# Performing attribute: Att7333
# nInterval: 2 bins: [0.0, 0.039612, 0.370078]
# Performing attribute: Att7344
# nInterval: 2 bins: [0.0, 0.128005, 0.25601]
# Performing attribute: Att7349
# nInterval: 2 bins: [0.0, 0.2425495, 0.485099]
# Performing attribute: Att7373
# nInterval: 2 bins: [0.0, 0.044629, 0.186651]
# Performing attribute: Att7382
# nInterval: 2 bins: [0.0, 0.0167565, 0.396935]
# Performing attribute: Att7442
# nInterval: 2 bins: [0.0, 0.282951, 0.565902]
# Performing attribute: Att7498
# nInterval: 2 bins: [0.0, 0.24104650000000005, 0.4820930000000001]
# Performing attribute: Att7500
# bins: [0.0, 0.13877799999999998]
# Performing attribute: Att7548
# bins: [0.0, 0.164363]
# Performing attribute: Att7565
# nInterval: 2 bins: [0.0, 0.074662, 0.337445]
# Performing attribute: Att7599
# bins: [0.0, 0.184129]
# Performing attribute: Att7654
# bins: [0.0, 0.345577]
# Performing attribute: Att7677
# nInterval: 2 bins: [0.0, 0.050166, 0.325291]
# Performing attribute: Att7716
# bins: [0.0, 0.373802]
# Performing attribute: Att7807
# bins: [0.0, 0.297316]
# Performing attribute: Att7808
# nInterval: 2 bins: [0.0, 0.1446695, 0.289339]
# Performing attribute: Att7852
# nInterval: 2 bins: [0.0, 0.089076, 0.587753]
# Performing attribute: Att7949
# nInterval: 2 bins: [0.0, 0.126845, 0.286851]
# Performing attribute: Att7970
# nInterval: 2 bins: [0.0, 0.133602, 0.360929]
# Performing attribute: Att8001
# bins: [0.0, 0.55799]
# Performing attribute: Att8005
# bins: [0.0, 0.164679]
# Performing attribute: Att8042
# nInterval: 2 bins: [0.0, 0.0536595, 0.22391]
# Performing attribute: Att8051
# nInterval: 2 bins: [0.0, 0.039080500000000004, 0.173993]
# Performing attribute: Att8071
# bins: [0.0, 0.45396]
# Performing attribute: Att8085
# bins: [0.0, 0.123324]
# Performing attribute: Att8104
# nInterval: 2 bins: [0.0, 0.053441, 0.106882]
# Performing attribute: Att8117
# nInterval: 2 bins: [0.0, 0.0363995, 0.192239]
# Performing attribute: Att8140
# nInterval: 2 bins: [0.0, 0.1171685, 0.476339]
# Performing attribute: Att8153
# nInterval: 2 bins: [0.0, 0.058307, 0.262641]
# Performing attribute: Att8187
# nInterval: 2 bins: [0.0, 0.141025, 0.363365]
# Performing attribute: Att8195
# bins: [0.0, 0.403826]
# Performing attribute: Att8198
# nInterval: 2 bins: [0.0, 0.0670355, 0.134071]
# Performing attribute: Att8216
# bins: [0.0, 0.224873]
# Performing attribute: Att8218
# bins: [0.0, 0.141194]
# Performing attribute: Att8260
# nInterval: 2 bins: [0.0, 0.051728, 0.317764]
# Performing attribute: Att8262
# bins: [0.0, 0.28939000000000004]
# Performing attribute: Att8297
# nInterval: 2 bins: [0.0, 0.060763, 0.217792]
# Performing attribute: Att8315
# nInterval: 2 bins: [0.0, 0.20792600000000006, 0.433957]
# Performing attribute: Att8363
# nInterval: 2 bins: [0.0, 0.1190235, 0.467211]
# Performing attribute: Att8369
# nInterval: 2 bins: [0.0, 0.037239499999999995, 0.414974]
# Performing attribute: Att8377
# bins: [0.0, 0.4820100000000001]
# Performing attribute: Att8412
# nInterval: 2 bins: [0.0, 0.030841000000000007, 0.351686]
# Performing attribute: Att8447
# nInterval: 2 bins: [0.0, 0.072013, 0.190831]
# Performing attribute: Att8449
# bins: [0.0, 0.289759]
# Performing attribute: Att8478
# bins: [0.0, 0.439525]
# Performing attribute: Att8489
# nInterval: 2 bins: [0.0, 0.130061, 0.565192]
# Performing attribute: Att8500
# nInterval: 2 bins: [0.0, 0.2327995, 0.465599]
# Performing attribute: Att8526
# nInterval: 2 bins: [0.0, 0.1391155, 0.278231]
# Performing attribute: Att8536
# nInterval: 2 bins: [0.0, 0.1470665, 0.509108]
# Performing attribute: Att8545
# nInterval: 2 bins: [0.0, 0.2916945, 0.583389]
# Performing attribute: Att8559
# nInterval: 2 bins: [0.0, 0.0826655, 0.253927]
# Performing attribute: Att8569
# bins: [0.0, 0.406803]
# Performing attribute: Att8585
# nInterval: 2 bins: [0.0, 0.0530125, 0.519997]
# Performing attribute: Att8587
# nInterval: 2 bins: [0.0, 0.136177, 0.441705]
# Performing attribute: Att8602
# nInterval: 2 bins: [0.0, 0.239531, 0.479062]
# Performing attribute: Att8606
# nInterval: 2 bins: [0.0, 0.0511505, 0.259031]
# Performing attribute: Att8656
# nInterval: 2 bins: [0.0, 0.0763465, 0.278037]
# Performing attribute: Att8664
# nInterval: 2 bins: [0.0, 0.0479445, 0.30146]
# Performing attribute: Att8670
# nInterval: 2 bins: [0.0, 0.0169965, 0.451465]
# Performing attribute: Att8691
# bins: [0.0, 0.232119]
# Performing attribute: Att8695
# nInterval: 2 bins: [0.0, 0.0818835, 0.186966]
# Performing attribute: Att8716
# bins: [0.0, 0.24761100000000005]
# Performing attribute: Att8764
# bins: [0.0, 0.5197510000000001]
# Performing attribute: Att8771
# nInterval: 2 bins: [0.0, 0.05807, 0.135595]
# Performing attribute: Att8874
# nInterval: 2 bins: [0.0, 0.044268, 0.294608]
# Performing attribute: Att8884
# bins: [0.0, 0.151361]
# Performing attribute: Att8905
# nInterval: 2 bins: [0.0, 0.078928, 0.255171]
# Performing attribute: Att8936
# bins: [0.0, 0.190905]
# Performing attribute: Att9008
# nInterval: 2 bins: [0.0, 0.145781, 0.4788810000000001]
# Performing attribute: Att9083
# nInterval: 2 bins: [0.0, 0.052535, 0.390152]
# Performing attribute: Att9141
# nInterval: 2 bins: [0.0, 0.291062, 0.582124]
# Performing attribute: Att9149
# bins: [0.0, 0.275501]
# Performing attribute: Att9181
# bins: [0.0, 0.475372]
# Performing attribute: Att9187
# nInterval: 2 bins: [0.0, 0.0600325, 0.257903]
# Performing attribute: Att9215
# nInterval: 2 bins: [0.0, 0.034583499999999996, 0.710724]
# Performing attribute: Att9275
# nInterval: 2 bins: [0.0, 0.0484825, 0.26426]
# Performing attribute: Att9283
# nInterval: 2 bins: [0.0, 0.0308615, 0.238996]
# Performing attribute: Att9335
# bins: [0.0, 0.218963]
# Performing attribute: Att9340
# nInterval: 2 bins: [0.0, 0.0409775, 0.436301]
# Performing attribute: Att9344
# nInterval: 2 bins: [0.0, 0.072911, 0.209986]
# Performing attribute: Att9362
# nInterval: 2 bins: [0.0, 0.0808805, 0.161761]
# Performing attribute: Att9369
# nInterval: 2 bins: [0.0, 0.1239235, 0.25263]
# Performing attribute: Att9373
# nInterval: 2 bins: [0.0, 0.0473865, 0.094773]
# Performing attribute: Att9380
# nInterval: 2 bins: [0.0, 0.033024, 0.276034]
# Performing attribute: Att9417
# nInterval: 2 bins: [0.0, 0.143921, 0.514305]
# Performing attribute: Att9428
# bins: [0.0, 0.081845]
# Performing attribute: Att9453
# nInterval: 2 bins: [0.0, 0.0545475, 0.315017]
# Performing attribute: Att9479
# nInterval: 2 bins: [0.0, 0.1288695, 0.257739]
# Performing attribute: Att9482
# nInterval: 2 bins: [0.0, 0.044538999999999995, 0.35480900000000004]
# Performing attribute: Att9516
# nInterval: 2 bins: [0.0, 0.101305, 0.381543]
# Performing attribute: Att9546
# bins: [0.0, 0.432945]
# Performing attribute: Att9550
# nInterval: 2 bins: [0.0, 0.071631, 0.16213]
# Performing attribute: Att9557
# nInterval: 2 bins: [0.0, 0.075079, 0.301466]
# Performing attribute: Att9570
# bins: [0.0, 0.134165]
# Performing attribute: Att9606
# nInterval: 2 bins: [0.0, 0.15129949999999998, 0.348148]
# Performing attribute: Att9616
# nInterval: 2 bins: [0.0, 0.083974, 0.16910799999999998]
# Performing attribute: Att9625
# nInterval: 2 bins: [0.0, 0.240722, 0.481444]
# Performing attribute: Att9641
# bins: [0.0, 0.258595]
# Performing attribute: Att9642
# nInterval: 2 bins: [0.0, 0.0906665, 0.487053]
# Performing attribute: Att9663
# bins: [0.0, 0.338474]
# Performing attribute: Att9706
# nInterval: 2 bins: [0.0, 0.0500175, 0.437999]
# Performing attribute: Att9714
# bins: [0.0, 0.079309]
# Performing attribute: Att9728
# nInterval: 2 bins: [0.0, 0.029448500000000006, 0.254105]
# Performing attribute: Att9752
# nInterval: 2 bins: [0.0, 0.07345750000000001, 0.405396]
# Performing attribute: Att9793
# nInterval: 2 bins: [0.0, 0.063579, 0.389305]
# Performing attribute: Att9854
# bins: [0.0, 0.138897]
# Performing attribute: Att9877
# nInterval: 2 bins: [0.0, 0.0435315, 0.187486]
# Performing attribute: Att9922
# bins: [0.0, 0.497292]
# Performing attribute: Att9956
# nInterval: 2 bins: [0.0, 0.298536, 0.597072]
# Performing attribute: Att10036
# nInterval: 2 bins: [0.0, 0.14845450000000002, 0.29690900000000003]
# Performing attribute: Att10055
# bins: [0.0, 0.484328]
# Performing attribute: Att10089
# bins: [0.0, 0.514335]
# Performing attribute: Att10111
# nInterval: 2 bins: [0.0, 0.0857915, 0.482208]
# Performing attribute: Att10115
# nInterval: 2 bins: [0.0, 0.1404695, 0.644493]
# Performing attribute: Att10137
# nInterval: 2 bins: [0.0, 0.16175250000000002, 0.32350500000000004]
# Performing attribute: Att10205
# bins: [0.0, 0.275399]
# Performing attribute: Att10266
# nInterval: 2 bins: [0.0, 0.065247, 0.130494]
# Performing attribute: Att10291
# bins: [0.0, 0.276696]
# Performing attribute: Att10320
# bins: [0.0, 0.14502]
# Performing attribute: Att10322
# nInterval: 2 bins: [0.0, 0.082963, 0.385638]
# Performing attribute: Att10328
# nInterval: 2 bins: [0.0, 0.0507405, 0.115303]
# Performing attribute: Att10343
# bins: [0.0, 0.244643]
# Performing attribute: Att10357
# nInterval: 2 bins: [0.0, 0.0479155, 0.293829]
# Performing attribute: Att10361
# nInterval: 2 bins: [0.0, 0.065691, 0.37746]
# Performing attribute: Att10394
# nInterval: 2 bins: [0.0, 0.031314999999999996, 0.367383]
# Performing attribute: Att10404
# nInterval: 2 bins: [0.0, 0.054645, 0.165035]
# Performing attribute: Att10507
# bins: [0.0, 0.473347]
# Performing attribute: Att10547
# nInterval: 2 bins: [0.0, 0.024756, 0.247839]
# Performing attribute: Att10591
# nInterval: 2 bins: [0.0, 0.0544205, 0.398843]
# Performing attribute: Att10595
# nInterval: 2 bins: [0.0, 0.0725905, 0.18288]
# Performing attribute: Att10630
# nInterval: 2 bins: [0.0, 0.1978375, 0.427219]
# Performing attribute: Att10681
# nInterval: 2 bins: [0.0, 0.0489575, 0.189873]
# Performing attribute: Att10766
# bins: [0.0, 0.112066]
# Performing attribute: Att10782
# bins: [0.0, 0.125808]
# Performing attribute: Att10844
# bins: [0.0, 0.13910899999999998]
# Performing attribute: Att10908
# bins: [0.0, 0.287966]
# Performing attribute: Att10998
# nInterval: 2 bins: [0.0, 0.1814085, 0.362817]
# Performing attribute: Att11012
# nInterval: 2 bins: [0.0, 0.0612545, 0.516129]
# Performing attribute: Att11053
# bins: [0.0, 0.127995]
# Performing attribute: Att11058
# bins: [0.0, 0.227498]
# Performing attribute: Att11066
# nInterval: 2 bins: [0.0, 0.0817165, 0.175932]
# Performing attribute: Att11141
# nInterval: 2 bins: [0.0, 0.084727, 0.282168]
# Performing attribute: Att11158
# nInterval: 2 bins: [0.0, 0.0472075, 0.29168]
# Performing attribute: Att11206
# bins: [0.0, 0.124411]
# Performing attribute: Att11247
# nInterval: 2 bins: [0.0, 0.160954, 0.321908]
# Performing attribute: Att11308
# nInterval: 2 bins: [0.0, 0.1273615, 0.399607]
# Performing attribute: Att11315
# nInterval: 2 bins: [0.0, 0.1573845, 0.314769]
# Performing attribute: Att11351
# nInterval: 2 bins: [0.0, 0.190418, 0.422516]
# Performing attribute: Att11365
# nInterval: 2 bins: [0.0, 0.073924, 0.261286]
# Performing attribute: Att11433
# bins: [0.0, 0.301862]
# Performing attribute: Att11466
# nInterval: 2 bins: [0.0, 0.124227, 0.329285]
# Performing attribute: Att11472
# nInterval: 2 bins: [0.0, 0.1608675, 0.33526300000000003]
# Performing attribute: Att11505
# nInterval: 2 bins: [0.0, 0.0451975, 0.102707]
# Performing attribute: Att11538
# bins: [0.0, 0.333899]
# Performing attribute: Att11559
# bins: [0.0, 0.110059]
# Performing attribute: Att11590
# bins: [0.0, 0.58128]
# Performing attribute: Att11598
# nInterval: 2 bins: [0.0, 0.0576715, 0.407795]
# Performing attribute: Att11633
# nInterval: 2 bins: [0.0, 0.1165095, 0.4584180000000001]
# Performing attribute: Att11646
# nInterval: 2 bins: [0.0, 0.037107, 0.43021]
# Performing attribute: Att11659
# nInterval: 2 bins: [0.0, 0.039188, 0.436633]
# Performing attribute: Att11664
# bins: [0.0, 0.188586]
# Performing attribute: Att11688
# nInterval: 2 bins: [0.0, 0.0953175, 0.427938]
# Performing attribute: Att11723
# nInterval: 2 bins: [0.0, 0.087035, 0.54201]
# Performing attribute: Att11796
# bins: [0.0, 0.13241]
# Performing attribute: Att11812
# nInterval: 2 bins: [0.0, 0.189894, 0.379788]
# Performing attribute: Att11814
# nInterval: 2 bins: [0.0, 0.0385205, 0.595781]
# Performing attribute: Att11841
# nInterval: 2 bins: [0.0, 0.0698985, 0.329353]
# Performing attribute: Att11850
# bins: [0.0, 0.139995]
# Performing attribute: Att11864
# nInterval: 2 bins: [0.0, 0.082623, 0.260863]
# Performing attribute: Att11866
# nInterval: 2 bins: [0.0, 0.0862115, 0.20752]
# Performing attribute: Att11869
# nInterval: 2 bins: [0.0, 0.1163325, 0.30290700000000004]
# Performing attribute: Att11880
# nInterval: 2 bins: [0.0, 0.0992895, 0.457403]
# Performing attribute: Att11913
# nInterval: 2 bins: [0.0, 0.197392, 0.394784]
# Performing attribute: Att11926
# bins: [0.0, 0.377987]
# Performing attribute: Att11945
# bins: [0.0, 0.103067]
# Performing attribute: Att11946
# nInterval: 2 bins: [0.0, 0.052027, 0.237642]
# Performing attribute: Att11948
# bins: [0.0, 0.496121]
# Performing attribute: Att11985
# nInterval: 2 bins: [0.0, 0.259787, 0.519574]
# Performing attribute: Att11987
# nInterval: 2 bins: [0.0, 0.02947, 0.30595]
# Performing attribute: Att12070
# nInterval: 2 bins: [0.0, 0.1860505, 0.372101]
# Performing attribute: Att12071
# bins: [0.0, 0.268316]
# Performing attribute: Att12125
# nInterval: 2 bins: [0.0, 0.0513705, 0.414393]
# Performing attribute: Att12132
# nInterval: 2 bins: [0.0, 0.053317, 0.202669]
# Performing attribute: Att12136
# nInterval: 2 bins: [0.0, 0.0561585, 0.351548]
# Performing attribute: Att12151
# nInterval: 2 bins: [0.0, 0.076935, 0.244372]
# Performing attribute: Att12161
# bins: [0.0, 0.429896]
# Performing attribute: Att12205
# nInterval: 2 bins: [0.0, 0.0893895, 0.291284]
# Performing attribute: Att12211
# bins: [0.0, 0.374456]
# Performing attribute: Att12244
# nInterval: 2 bins: [0.0, 0.1879295, 0.505675]
# Performing attribute: Att12248
# nInterval: 2 bins: [0.0, 0.142954, 0.31645100000000004]
# Performing attribute: Att12252
# bins: [0.0, 0.294933]
# Performing attribute: Att12292
# nInterval: 2 bins: [0.0, 0.0595205, 0.143951]
# Performing attribute: Att12301
# nInterval: 2 bins: [0.0, 0.064751, 0.142137]
# Performing attribute: Att12373
# nInterval: 2 bins: [0.0, 0.0367165, 0.354745]
# Performing attribute: Att12393
# bins: [0.0, 0.37617]
# Performing attribute: Att12413
# bins: [0.0, 0.132157]
# Performing attribute: Att12425
# bins: [0.0, 0.265805]
# Performing attribute: Att12435
# nInterval: 2 bins: [0.0, 0.311212, 0.622424]
# Performing attribute: Att12453
# bins: [0.0, 0.307975]
# Performing attribute: Att12518
# nInterval: 2 bins: [0.0, 0.028346, 0.180442]
# Performing attribute: Att12521
# nInterval: 2 bins: [0.0, 0.0560505, 0.206274]
# Performing attribute: Att12541
# bins: [0.0, 0.216204]
# Performing attribute: Att12560
# nInterval: 2 bins: [0.0, 0.284554, 0.569108]
# Performing attribute: Att12602
# bins: [0.0, 0.352758]
# Performing attribute: Att12630
# nInterval: 2 bins: [0.0, 0.2503705, 0.500741]
# Performing attribute: Att12661
# nInterval: 2 bins: [0.0, 0.0582115, 0.116423]
# Performing attribute: Att12698
# bins: [0.0, 0.144325]
# Performing attribute: Att12720
# bins: [0.0, 0.20870100000000005]
# Performing attribute: Att12723
# bins: [0.0, 0.139921]
# Performing attribute: Att12727
# nInterval: 2 bins: [0.0, 0.151767, 0.303534]
# Performing attribute: Att12732
# bins: [0.0, 0.127148]
# Performing attribute: Att12738
# nInterval: 2 bins: [0.0, 0.0372575, 0.29175300000000004]
# Performing attribute: Att12741
# nInterval: 2 bins: [0.0, 0.1630755, 0.326151]
# Performing attribute: Att12752
# nInterval: 2 bins: [0.0, 0.044601999999999996, 0.174503]
# Performing attribute: Att12781
# nInterval: 2 bins: [0.0, 0.0339295, 0.308683]
# Performing attribute: Att12796
# bins: [0.0, 0.14540699999999998]
# Performing attribute: Att12871
# bins: [0.0, 0.349696]
# Performing attribute: Att12888
# bins: [0.0, 0.624323]
# Performing attribute: Att12901
# nInterval: 2 bins: [0.0, 0.07308300000000001, 0.317271]
# Performing attribute: Att12914
# nInterval: 2 bins: [0.0, 0.0597645, 0.281721]
# Performing attribute: Att12915
# bins: [0.0, 0.129522]
# Performing attribute: Att12953
# nInterval: 2 bins: [0.0, 0.063453, 0.206916]
# Performing attribute: Att12997
# nInterval: 2 bins: [0.0, 0.0464015, 0.178344]
# Performing attribute: Att13011
# nInterval: 2 bins: [0.0, 0.0870755, 0.257231]
# Performing attribute: Att13014
# bins: [0.0, 0.655231]
# Performing attribute: Att13016
# nInterval: 2 bins: [0.0, 0.0488305, 0.26657600000000004]
# Performing attribute: Att13034
# nInterval: 2 bins: [0.0, 0.141164, 0.468009]
# Performing attribute: Att13064
# nInterval: 2 bins: [0.0, 0.1017075, 0.461539]
# Performing attribute: Att13100
# nInterval: 2 bins: [0.0, 0.1223495, 0.29848800000000003]
# Performing attribute: Att13117
# nInterval: 2 bins: [0.0, 0.056792, 0.30582800000000004]
# Performing attribute: Att13136
# nInterval: 2 bins: [0.0, 0.1267235, 0.253447]
# Performing attribute: Att13208
# nInterval: 2 bins: [0.0, 0.09875, 0.312166]
# Performing attribute: Att13239
# nInterval: 2 bins: [0.0, 0.056133, 0.116214]
# Performing attribute: Att13315
# bins: [0.0, 0.333368]
# Performing attribute: Att13335
# bins: [0.0, 0.27334200000000003]
# Performing attribute: Att13339
# bins: [0.0, 0.408079]
# Performing attribute: Att13361
# nInterval: 2 bins: [0.0, 0.027717, 0.29488400000000003]
# Performing attribute: Att13386
# nInterval: 2 bins: [0.0, 0.049404, 0.338251]
# Performing attribute: Att13404
# nInterval: 2 bins: [0.0, 0.0666555, 0.466111]
# Performing attribute: Att13427
# nInterval: 2 bins: [0.0, 0.0287305, 0.225391]
# Performing attribute: Att13431
# bins: [0.0, 0.133831]
# Performing attribute: Att13434
# nInterval: 2 bins: [0.0, 0.148643, 0.338969]
# Performing attribute: Att13455
# nInterval: 2 bins: [0.0, 0.04024, 0.430422]
# Performing attribute: Att13508
# bins: [0.0, 0.128804]
# Performing attribute: Att13563
# bins: [0.0, 0.222119]
# Performing attribute: Att13579
# nInterval: 2 bins: [0.0, 0.0612215, 0.337943]
# Performing attribute: Att13598
# nInterval: 2 bins: [0.0, 0.077777, 0.155554]
# Performing attribute: Att13632
# nInterval: 2 bins: [0.0, 0.0906475, 0.421994]
# Performing attribute: Att13749
# bins: [0.0, 0.189533]
# Performing attribute: Att13767
# nInterval: 2 bins: [0.0, 0.06287000000000001, 0.400088]
# Performing attribute: Att13768
# bins: [0.0, 0.121721]
# Performing attribute: Att13789
# nInterval: 2 bins: [0.0, 0.050481, 0.247043]
# Performing attribute: Att13824
# bins: [0.0, 0.401276]
# Performing attribute: Att13943
# bins: [0.0, 0.095231]
# Performing attribute: Att13946
# bins: [0.0, 0.27534200000000003]
# Performing attribute: Att13961
# nInterval: 2 bins: [0.0, 0.059824, 0.311871]
# Performing attribute: Att14046
# nInterval: 2 bins: [0.0, 0.1923505, 0.384701]
# Performing attribute: Att14051
# nInterval: 2 bins: [0.0, 0.115207, 0.4415520000000001]
# Performing attribute: Att14067
# nInterval: 2 bins: [0.0, 0.031723, 0.216938]
# Performing attribute: Att14070
# nInterval: 2 bins: [0.0, 0.0325955, 0.31516900000000003]
# Performing attribute: Att14090
# bins: [0.0, 0.232511]
# Performing attribute: Att14099
# nInterval: 2 bins: [0.0, 0.1855365, 0.400155]
# Performing attribute: Att14102
# nInterval: 2 bins: [0.0, 0.14, 0.461474]
# Performing attribute: Att14124
# nInterval: 2 bins: [0.0, 0.0999975, 0.34270900000000004]
# Performing attribute: Att14138
# nInterval: 2 bins: [0.0, 0.091418, 0.182836]
# Performing attribute: Att14186
# bins: [0.0, 0.507804]
# Performing attribute: Att14206
# bins: [0.0, 0.146243]
# Performing attribute: Att14252
# nInterval: 2 bins: [0.0, 0.132179, 0.264358]
# Performing attribute: Att14266
# nInterval: 2 bins: [0.0, 0.13271, 0.26542]
# Performing attribute: Att14268
# bins: [0.0, 0.356496]
# Performing attribute: Att14272
# nInterval: 2 bins: [0.0, 0.22864050000000005, 0.462738]
# Performing attribute: Att14277
# bins: [0.0, 0.55132]
# Performing attribute: Att14452
# nInterval: 2 bins: [0.0, 0.2881205, 0.576241]
# Performing attribute: Att14486
# nInterval: 2 bins: [0.0, 0.0931215, 0.28161]
# Performing attribute: Att14489
# nInterval: 2 bins: [0.0, 0.211009, 0.422018]
# Performing attribute: Att14491
# nInterval: 2 bins: [0.0, 0.055782, 0.434235]
# Performing attribute: Att14501
# bins: [0.0, 0.144982]
# Performing attribute: Att14510
# nInterval: 2 bins: [0.0, 0.0948285, 0.244752]
# Performing attribute: Att14528
# nInterval: 2 bins: [0.0, 0.1375345, 0.430616]
# Performing attribute: Att14556
# nInterval: 2 bins: [0.0, 0.047178, 0.190477]
# Performing attribute: Att14633
# nInterval: 2 bins: [0.0, 0.031835, 0.309653]
# Performing attribute: Att14636
# nInterval: 2 bins: [0.0, 0.041824, 0.220996]
# Performing attribute: Att14659
# nInterval: 2 bins: [0.0, 0.039369, 0.232332]
# Performing attribute: Att14706
# bins: [0.0, 0.267873]
# Performing attribute: Att14712
# nInterval: 2 bins: [0.0, 0.0590675, 0.309229]
# Performing attribute: Att14725
# bins: [0.0, 0.335175]
# Performing attribute: Att14726
# bins: [0.0, 0.242249]
# Performing attribute: Att14729
# bins: [0.0, 0.467822]
# Performing attribute: Att14735
# bins: [0.0, 0.372678]
# Performing attribute: Att14774
# nInterval: 2 bins: [0.0, 0.2411045, 0.482209]
# Performing attribute: Att14775
# bins: [0.0, 0.406747]
# Performing attribute: Att14819
# bins: [0.0, 0.20711]
# Performing attribute: Att14866
# bins: [0.0, 0.15093399999999998]
# Performing attribute: Att14870
# nInterval: 2 bins: [0.0, 0.06651499999999999, 0.298525]
# Performing attribute: Att14880
# nInterval: 2 bins: [0.0, 0.0647955, 0.13153099999999998]
# Performing attribute: Att14907
# bins: [0.0, 0.432719]
# Performing attribute: Att14950
# nInterval: 2 bins: [0.0, 0.14473450000000002, 0.35012]
# Performing attribute: Att15063
# nInterval: 2 bins: [0.0, 0.0885455, 0.303782]
# Performing attribute: Att15068
# nInterval: 2 bins: [0.0, 0.068736, 0.364927]
# Performing attribute: Att15070
# nInterval: 2 bins: [0.0, 0.129045, 0.284576]
# Performing attribute: Att15098
# bins: [0.0, 0.242294]
# Performing attribute: Att15126
# nInterval: 2 bins: [0.0, 0.184539, 0.369078]
# Performing attribute: Att15132
# nInterval: 2 bins: [0.0, 0.11962950000000003, 0.23925900000000005]
# Performing attribute: Att15149
# nInterval: 2 bins: [0.0, 0.091566, 0.293796]
# Performing attribute: Att15151
# nInterval: 2 bins: [0.0, 0.035075999999999996, 0.237873]
# Performing attribute: Att15223
# bins: [0.0, 0.338966]
# Performing attribute: Att15228
# nInterval: 2 bins: [0.0, 0.0516755, 0.355208]
# Performing attribute: Att15234
# nInterval: 2 bins: [0.0, 0.0788045, 0.484334]
# Performing attribute: Att15243
# nInterval: 2 bins: [0.0, 0.0544965, 0.357229]
# Performing attribute: Att15304
# bins: [0.0, 0.183453]
# Performing attribute: Att15354
# bins: [0.0, 0.218797]
# Performing attribute: Att15419
# nInterval: 2 bins: [0.0, 0.1375335, 0.275067]
# Performing attribute: Att15489
# bins: [0.0, 0.111314]
# Performing attribute: Att15507
# nInterval: 2 bins: [0.0, 0.0609085, 0.276481]
# Performing attribute: Att15545
# nInterval: 2 bins: [0.0, 0.1793555, 0.358711]
# Performing attribute: Att15594
# bins: [0.0, 0.20776]
# Performing attribute: Att15621
# nInterval: 2 bins: [0.0, 0.190015, 0.38003]
# Performing attribute: Att15675
# nInterval: 2 bins: [0.0, 0.055479, 0.25625]
# Performing attribute: Att15676
# bins: [0.0, 0.676716]
# Performing attribute: Att15709
# nInterval: 2 bins: [0.0, 0.1372215, 0.468254]
# Performing attribute: Att15720
# nInterval: 2 bins: [0.0, 0.07949400000000001, 0.15898800000000002]
# Performing attribute: Att15722
# nInterval: 2 bins: [0.0, 0.0374795, 0.373644]
# Performing attribute: Att15804
# bins: [0.0, 0.584034]
# Performing attribute: Att15903
# bins: [0.0, 0.199794]
# Performing attribute: Att15919
# nInterval: 2 bins: [0.0, 0.0904995, 0.330164]
# Performing attribute: Att15936
# bins: [0.0, 0.31061300000000003]
# Performing attribute: Att15992
# nInterval: 2 bins: [0.0, 0.0819905, 0.252924]
# Performing attribute: Att16156
# nInterval: 2 bins: [0.0, 0.0395635, 0.196586]
# Performing attribute: Att16202
# nInterval: 2 bins: [0.0, 0.205418, 0.422138]
# Performing attribute: Att16215
# nInterval: 2 bins: [0.0, 0.0503745, 0.16831300000000002]
# Performing attribute: Att16251
# nInterval: 2 bins: [0.0, 0.1692545, 0.338509]
# Performing attribute: Att16263
# bins: [0.0, 0.137268]
# Performing attribute: Att16267
# bins: [0.0, 0.338098]
# Performing attribute: Att16285
# nInterval: 2 bins: [0.0, 0.081094, 0.19833]
# Performing attribute: Att16288
# bins: [0.0, 0.8297969999999999]
# Performing attribute: Att16327
# nInterval: 2 bins: [0.0, 0.360197, 0.725738]
# Performing attribute: Att16338
# nInterval: 2 bins: [0.0, 0.036518, 0.35229]
# Performing attribute: Att16353
# nInterval: 2 bins: [0.0, 0.086029, 0.534197]
# Performing attribute: Att16355
# bins: [0.0, 0.220896]
# Performing attribute: Att16372
# bins: [0.0, 0.285162]
# Performing attribute: Att16381
# bins: [0.0, 0.177021]
# Performing attribute: Att16438
# bins: [0.0, 0.727751]
# Performing attribute: Att16563
# nInterval: 2 bins: [0.0, 0.1313645, 0.359173]
# Performing attribute: Att16572
# nInterval: 2 bins: [0.0, 0.1474925, 0.352769]
# Performing attribute: Att16616
# nInterval: 2 bins: [0.0, 0.040808, 0.097238]
# Performing attribute: Att16628
# bins: [0.0, 0.104851]
# Performing attribute: Att16658
# nInterval: 2 bins: [0.0, 0.0633585, 0.418557]
# Performing attribute: Att16667
# bins: [0.0, 0.556874]
# Performing attribute: Att16682
# bins: [0.0, 0.101481]
# Performing attribute: Att16807
# bins: [0.0, 0.266171]
# Performing attribute: Att16878
# nInterval: 2 bins: [0.0, 0.2383265, 0.476653]
# Performing attribute: Att16893
# nInterval: 2 bins: [0.0, 0.0472035, 0.15521]
# Performing attribute: Att16928
# nInterval: 2 bins: [0.0, 0.048127, 0.284032]
# Performing attribute: Att17048
# nInterval: 2 bins: [0.0, 0.199541, 0.399082]
# Performing attribute: Att17083
# bins: [0.0, 0.175372]
# Performing attribute: Att17091
# bins: [0.0, 0.235533]
# Performing attribute: Att17128
# nInterval: 2 bins: [0.0, 0.2535195, 0.507039]
# Performing attribute: Att17132
# nInterval: 2 bins: [0.0, 0.22718200000000005, 0.4543640000000001]
# Performing attribute: Att17197
# nInterval: 2 bins: [0.0, 0.079913, 0.225189]
# Performing attribute: Att17199
# bins: [0.0, 0.112066]
# Performing attribute: Att17317
# bins: [0.0, 0.194771]
# Performing attribute: Att17353
# bins: [0.0, 0.275017]
# Performing attribute: Att17422
# bins: [0.0, 0.197551]
# Performing attribute: Att17433
# bins: [0.0, 0.5194409999999999]
# Performing attribute: Att17442
# bins: [0.0, 0.283416]
# Performing attribute: Att17532
# nInterval: 2 bins: [0.0, 0.08252050000000001, 0.16504100000000002]
# Performing attribute: Att17540
# nInterval: 2 bins: [0.0, 0.0428805, 0.438948]
# Performing attribute: Att17549
# nInterval: 2 bins: [0.0, 0.0654725, 0.603267]
# Performing attribute: Att17588
# nInterval: 2 bins: [0.0, 0.05767, 0.154887]
# Performing attribute: Att17590
# nInterval: 2 bins: [0.0, 0.064368, 0.349638]
# Performing attribute: Att17591
# nInterval: 2 bins: [0.0, 0.0483595, 0.117991]
# Performing attribute: Att17644
# bins: [0.0, 0.170875]
# Performing attribute: Att17666
# bins: [0.0, 0.489883]
# Performing attribute: Att17677
# bins: [0.0, 0.263216]
# Performing attribute: Att17685
# nInterval: 2 bins: [0.0, 0.222519, 0.445038]
# Performing attribute: Att17745
# bins: [0.0, 0.477685]
# Performing attribute: Att17827
# bins: [0.0, 0.4798270000000001]
# Performing attribute: Att17864
# nInterval: 2 bins: [0.0, 0.0679845, 0.381103]
# Performing attribute: Att17922
# nInterval: 2 bins: [0.0, 0.045014, 0.140934]
# Performing attribute: Att18009
# nInterval: 2 bins: [0.0, 0.1351765, 0.270353]
# Performing attribute: Att18038
# nInterval: 2 bins: [0.0, 0.0690915, 0.364975]
# Performing attribute: Att18179
# bins: [0.0, 0.279738]
# Performing attribute: Att18185
# nInterval: 2 bins: [0.0, 0.050911, 0.188518]
# Performing attribute: Att18228
# bins: [0.0, 0.190019]
# Performing attribute: Att18232
# bins: [0.0, 0.239656]
# Performing attribute: Att18292
# bins: [0.0, 0.231461]
# Performing attribute: Att18326
# bins: [0.0, 0.315994]
# Performing attribute: Att18345
# nInterval: 2 bins: [0.0, 0.106096, 0.458792]
# Performing attribute: Att18378
# nInterval: 2 bins: [0.0, 0.1462635, 0.472379]
# Performing attribute: Att18422
# bins: [0.0, 0.121096]
# Performing attribute: Att18478
# nInterval: 2 bins: [0.0, 0.0527215, 0.271014]
# Performing attribute: Att18489
# nInterval: 2 bins: [0.0, 0.034516000000000005, 0.720651]
# Performing attribute: Att18507
# bins: [0.0, 0.465896]
# Performing attribute: Att18526
# nInterval: 2 bins: [0.0, 0.1672555, 0.334511]
# Performing attribute: Att18597
# nInterval: 2 bins: [0.0, 0.0451975, 0.140651]
# Performing attribute: Att18611
# bins: [0.0, 0.265805]
# Performing attribute: Att18652
# bins: [0.0, 0.184526]
# Performing attribute: Att18672
# nInterval: 2 bins: [0.0, 0.1974555, 0.394911]
# Performing attribute: Att18673
# bins: [0.0, 0.12846]
# Performing attribute: Att18707
# bins: [0.0, 0.136163]
# Performing attribute: Att18710
# nInterval: 2 bins: [0.0, 0.2177085, 0.615187]
# Performing attribute: Att18798
# nInterval: 2 bins: [0.0, 0.067521, 0.36354]
# Performing attribute: Att18834
# nInterval: 2 bins: [0.0, 0.07559400000000001, 0.241433]
# Performing attribute: Att18836
# nInterval: 2 bins: [0.0, 0.1312245, 0.417574]
# Performing attribute: Att18888
# nInterval: 2 bins: [0.0, 0.0704095, 0.553147]
# Performing attribute: Att18954
# nInterval: 2 bins: [0.0, 0.222094, 0.460499]
# Performing attribute: Att19002
# bins: [0.0, 0.105743]
# Performing attribute: Att19018
# nInterval: 2 bins: [0.0, 0.0496445, 0.32266100000000003]
# Performing attribute: Att19036
# bins: [0.0, 0.4985350000000001]
# Performing attribute: Att19094
# bins: [0.0, 0.4488180000000001]
# Performing attribute: Att19099
# nInterval: 2 bins: [0.0, 0.05913, 0.389835]
# Performing attribute: Att19126
# bins: [0.0, 0.405366]
# Performing attribute: Att19245
# bins: [0.0, 0.089894]
# Performing attribute: Att19265
# nInterval: 2 bins: [0.0, 0.366886, 0.733772]
# Performing attribute: Att19424
# bins: [0.0, 0.31061300000000003]
# Performing attribute: Att19449
# nInterval: 2 bins: [0.0, 0.067978, 0.291461]
# Performing attribute: Att19451
# nInterval: 2 bins: [0.0, 0.08983, 0.426016]
# Performing attribute: Att19457
# bins: [0.0, 0.166615]
# Performing attribute: Att19466
# nInterval: 2 bins: [0.0, 0.0638215, 0.313871]
# Performing attribute: Att19514
# nInterval: 2 bins: [0.0, 0.041592000000000004, 0.46083]
# Performing attribute: Att19524
# nInterval: 2 bins: [0.0, 0.032811, 0.2103]
# Performing attribute: Att19582
# nInterval: 2 bins: [0.0, 0.1169875, 0.235854]
# Performing attribute: Att19587
# nInterval: 2 bins: [0.0, 0.045863, 0.152002]
# Performing attribute: Att19601
# nInterval: 2 bins: [0.0, 0.057565, 0.446404]
# Performing attribute: Att19628
# nInterval: 2 bins: [0.0, 0.1569355, 0.313871]
# Performing attribute: Att19632
# nInterval: 2 bins: [0.0, 0.11845050000000003, 0.251497]
# Performing attribute: Att19646
# nInterval: 2 bins: [0.0, 0.0389385, 0.36644]
# Performing attribute: Att19647
# nInterval: 2 bins: [0.0, 0.0565605, 0.18308]
# Performing attribute: Att19708
# nInterval: 2 bins: [0.0, 0.0760555, 0.294964]
# Performing attribute: Att19759
# nInterval: 2 bins: [0.0, 0.1589665, 0.364358]
# Performing attribute: Att19763
# nInterval: 2 bins: [0.0, 0.0196345, 0.330356]
# Performing attribute: Att19798
# bins: [0.0, 0.144817]
# Performing attribute: Att19812
# nInterval: 2 bins: [0.0, 0.094926, 0.21184]
# Performing attribute: Att19824
# bins: [0.0, 0.105836]
# Performing attribute: Att19826
# bins: [0.0, 0.4532060000000001]
# Performing attribute: Att19835
# nInterval: 2 bins: [0.0, 0.1002365, 0.284272]
# Performing attribute: Att19915
# bins: [0.0, 0.139995]
# Performing attribute: Att19924
# nInterval: 2 bins: [0.0, 0.0971235, 0.378361]
# Performing attribute: Att20013
# nInterval: 2 bins: [0.0, 0.043647500000000006, 0.249176]
# Performing attribute: Att20036
# nInterval: 2 bins: [0.0, 0.058612, 0.482362]
# Performing attribute: Att20038
# bins: [0.0, 0.229742]
# Performing attribute: Att20096
# nInterval: 2 bins: [0.0, 0.2537025, 0.522995]
# Performing attribute: Att20114
# bins: [0.0, 0.203374]
# Performing attribute: Att20157
# bins: [0.0, 0.356052]
# Performing attribute: Att20171
# nInterval: 2 bins: [0.0, 0.0524125, 0.287619]
# Performing attribute: Att20178
# nInterval: 2 bins: [0.0, 0.083692, 0.363985]
# Performing attribute: Att20182
# bins: [0.0, 0.6857770000000001]
# Performing attribute: Att20247
# nInterval: 2 bins: [0.0, 0.039123000000000005, 0.094149]
# Performing attribute: Att20332
# bins: [0.0, 0.221529]
# Performing attribute: Att20366
# nInterval: 2 bins: [0.0, 0.0989815, 0.35049]
# Performing attribute: Att20380
# bins: [0.0, 0.120988]
# Performing attribute: Att20432
# nInterval: 2 bins: [0.0, 0.1973725, 0.621049]
# Performing attribute: Att20451
# nInterval: 2 bins: [0.0, 0.2242855, 0.448571]
# Performing attribute: Att20459
# bins: [0.0, 0.346729]
# Performing attribute: Att20472
# bins: [0.0, 0.212767]
# Performing attribute: Att20585
# nInterval: 2 bins: [0.0, 0.1633675, 0.461486]
# Performing attribute: Att20635
# bins: [0.0, 0.13241]
# Performing attribute: Att20734
# nInterval: 2 bins: [0.0, 0.1386815, 0.403971]
# Performing attribute: Att20745
# nInterval: 2 bins: [0.0, 0.06589149999999999, 0.501679]
# Performing attribute: Att20769
# nInterval: 2 bins: [0.0, 0.184003, 0.36988]
# Performing attribute: Att20910
# bins: [0.0, 0.6547430000000001]
# Performing attribute: Att20912
# bins: [0.0, 0.110274]
# Performing attribute: Att20947
# nInterval: 2 bins: [0.0, 0.0248195, 0.246268]
# Performing attribute: Att20950
# nInterval: 2 bins: [0.0, 0.085963, 0.171926]
# Performing attribute: Att20958
# nInterval: 2 bins: [0.0, 0.044569, 0.136756]
# Performing attribute: Att21054
# bins: [0.0, 0.221914]
# ...
# bins: [0.0, 0.137268]
# Performing attribute: Att40005
# nInterval: 2 bins: [0.0, 0.196813, 0.393626]
# Performing attribute: Att40033
# nInterval: 2 bins: [0.0, 0.0271515, 0.321311]
# Performing attribute: Att40103
# nInterval: 2 bins: [0.0, 0.0900255, 0.196289]
# Performing attribute: Att40135
# nInterval: 2 bins: [0.0, 0.202752, 0.498374]
# Performing attribute: Att40143
# bins: [0.0, 0.276368]
# Performing attribute: Att40216
# nInterval: 2 bins: [0.0, 0.032902, 0.35128400000000004]
# Performing attribute: Att40260
# nInterval: 2 bins: [0.0, 0.0786275, 0.519039]
# Performing attribute: Att40264
# nInterval: 2 bins: [0.0, 0.334567, 0.669134]
# Performing attribute: Att40281
# bins: [0.0, 0.233278]
# Performing attribute: Att40325
# bins: [0.0, 0.224661]
# Performing attribute: Att40326
# nInterval: 2 bins: [0.0, 0.105448, 0.210896]
# Performing attribute: Att40328
# bins: [0.0, 0.29249]
# Performing attribute: Att40385
# nInterval: 2 bins: [0.0, 0.0634365, 0.412028]
# Performing attribute: Att40402
# nInterval: 2 bins: [0.0, 0.07916799999999999, 0.375621]
# Performing attribute: Att40406
# nInterval: 2 bins: [0.0, 0.0453605, 0.251361]
# Performing attribute: Att40432
# nInterval: 2 bins: [0.0, 0.2559085, 0.511817]
# Performing attribute: Att40467
# nInterval: 2 bins: [0.0, 0.170999, 0.490052]
# Performing attribute: Att40497
# nInterval: 2 bins: [0.0, 0.0396175, 0.10053]
# Performing attribute: Att40510
# nInterval: 2 bins: [0.0, 0.0848995, 0.19762]
# Performing attribute: Att40564
# bins: [0.0, 0.7007180000000001]
# Performing attribute: Att40579
# nInterval: 2 bins: [0.0, 0.0451975, 0.12575899999999998]
# Performing attribute: Att40594
# nInterval: 2 bins: [0.0, 0.048307, 0.228554]
# Performing attribute: Att40648
# bins: [0.0, 0.186742]
# Performing attribute: Att40774
# nInterval: 2 bins: [0.0, 0.1289985, 0.4511850000000001]
# Performing attribute: Att40795
# bins: [0.0, 0.328869]
# Performing attribute: Att40814
# bins: [0.0, 0.28967]
# Performing attribute: Att40954
# nInterval: 2 bins: [0.0, 0.2754165, 0.551778]
# Performing attribute: Att41033
# nInterval: 2 bins: [0.0, 0.067136, 0.17971199999999998]
# Performing attribute: Att41050
# bins: [0.0, 0.415142]
# Performing attribute: Att41062
# bins: [0.0, 0.12599000000000002]
# Performing attribute: Att41069
# nInterval: 2 bins: [0.0, 0.0741655, 0.472775]
# Performing attribute: Att41093
# nInterval: 2 bins: [0.0, 0.20496950000000005, 0.5477390000000001]
# Performing attribute: Att41113
# bins: [0.0, 0.260008]
# Performing attribute: Att41147
# nInterval: 2 bins: [0.0, 0.0362005, 0.26160700000000003]
# Performing attribute: Att41158
# nInterval: 2 bins: [0.0, 0.067662, 0.146322]
# Performing attribute: Att41207
# nInterval: 2 bins: [0.0, 0.0763925, 0.567954]
# Performing attribute: Att41248
# nInterval: 2 bins: [0.0, 0.1419205, 0.43893]
# Performing attribute: Att41253
# bins: [0.0, 0.102968]
# Performing attribute: Att41289
# bins: [0.0, 0.614975]
# Performing attribute: Att41297
# nInterval: 2 bins: [0.0, 0.1703935, 0.360016]
# Performing attribute: Att41346
# nInterval: 2 bins: [0.0, 0.1512215, 0.31188]
# Performing attribute: Att41361
# bins: [0.0, 0.397663]
# Performing attribute: Att41387
# nInterval: 2 bins: [0.0, 0.2510365, 0.502073]
# Performing attribute: Att41396
# nInterval: 2 bins: [0.0, 0.0613175, 0.363932]
# Performing attribute: Att41497
# nInterval: 2 bins: [0.0, 0.059422, 0.2007]
# Performing attribute: Att41504
# bins: [0.0, 0.133417]
# Performing attribute: Att41508
# nInterval: 2 bins: [0.0, 0.037038, 0.153896]
# Performing attribute: Att41523
# nInterval: 2 bins: [0.0, 0.070366, 0.598438]
# Performing attribute: Att41569
# nInterval: 2 bins: [0.0, 0.0479715, 0.362126]
# Performing attribute: Att41590
# bins: [0.0, 0.278513]
# Performing attribute: Att41623
# nInterval: 2 bins: [0.0, 0.071672, 0.340349]
# Performing attribute: Att41632
# nInterval: 2 bins: [0.0, 0.0773085, 0.215902]
# Performing attribute: Att41735
# nInterval: 2 bins: [0.0, 0.0889715, 0.26019200000000003]
# Performing attribute: Att41745
# nInterval: 2 bins: [0.0, 0.2235145, 0.447029]
# Performing attribute: Att41776
# nInterval: 2 bins: [0.0, 0.1339685, 0.452974]
# Performing attribute: Att41787
# bins: [0.0, 0.345619]
# Performing attribute: Att41788
# nInterval: 2 bins: [0.0, 0.124428, 0.281777]
# Performing attribute: Att41812
# nInterval: 2 bins: [0.0, 0.0572345, 0.436791]
# Performing attribute: Att41832
# nInterval: 2 bins: [0.0, 0.1130995, 0.388649]
# Performing attribute: Att41851
# bins: [0.0, 0.366959]
# Performing attribute: Att41855
# bins: [0.0, 0.222119]
# Performing attribute: Att41858
# nInterval: 2 bins: [0.0, 0.039485, 0.559912]
# Performing attribute: Att41873
# nInterval: 2 bins: [0.0, 0.2666625, 0.629315]
# Performing attribute: Att41904
# nInterval: 2 bins: [0.0, 0.2729975, 0.598525]
# Performing attribute: Att41933
# nInterval: 2 bins: [0.0, 0.055258, 0.589728]
# Performing attribute: Att41992
# nInterval: 2 bins: [0.0, 0.0474215, 0.307033]
# Performing attribute: Att42045
# nInterval: 2 bins: [0.0, 0.04615, 0.284849]
# Performing attribute: Att42130
# bins: [0.0, 0.192248]
# Performing attribute: Att42160
# nInterval: 2 bins: [0.0, 0.054, 0.30237]
# Performing attribute: Att42288
# nInterval: 2 bins: [0.0, 0.146609, 0.293218]
# Performing attribute: Att42308
# nInterval: 2 bins: [0.0, 0.0440315, 0.256643]
# Performing attribute: Att42326
# bins: [0.0, 0.305846]
# Performing attribute: Att42421
# bins: [0.0, 0.53717]
# Performing attribute: Att42422
# nInterval: 2 bins: [0.0, 0.1814425, 0.362885]
# Performing attribute: Att42429
# bins: [0.0, 0.119173]
# Performing attribute: Att42433
# bins: [0.0, 0.363328]
# Performing attribute: Att42505
# bins: [0.0, 0.476658]
# Performing attribute: Att42520
# nInterval: 2 bins: [0.0, 0.0314085, 0.334647]
# Performing attribute: Att42569
# bins: [0.0, 0.241157]
# Performing attribute: Att42573
# bins: [0.0, 0.26765900000000004]
# Performing attribute: Att42625
# nInterval: 2 bins: [0.0, 0.0723035, 0.144607]
# Performing attribute: Att42645
# bins: [0.0, 0.201299]
# Performing attribute: Att42679
# nInterval: 2 bins: [0.0, 0.035385, 0.17528]
# Performing attribute: Att42683
# nInterval: 2 bins: [0.0, 0.1813065, 0.362613]
# Performing attribute: Att42811
# nInterval: 2 bins: [0.0, 0.2450395, 0.490079]
# Performing attribute: Att42814
# nInterval: 2 bins: [0.0, 0.062873, 0.125746]
# Performing attribute: Att42823
# nInterval: 2 bins: [0.0, 0.082484, 0.164968]
# Performing attribute: Att42837
# nInterval: 2 bins: [0.0, 0.1087335, 0.365654]
# Performing attribute: Att42866
# bins: [0.0, 0.705412]
# Performing attribute: Att42952
# bins: [0.0, 0.305476]
# Performing attribute: Att42973
# bins: [0.0, 0.346493]
# Performing attribute: Att42980
# bins: [0.0, 0.170266]
# Performing attribute: Att43049
# nInterval: 2 bins: [0.0, 0.096391, 0.339449]
# Performing attribute: Att43090
# nInterval: 2 bins: [0.0, 0.057277, 0.33464]
# Performing attribute: Att43118
# nInterval: 2 bins: [0.0, 0.108769, 0.399687]
# Performing attribute: Att43135
# nInterval: 2 bins: [0.0, 0.29623299999999997, 0.5924659999999999]
# Performing attribute: Att43227
# bins: [0.0, 0.155007]
# Performing attribute: Att43238
# bins: [0.0, 0.172528]
# Performing attribute: Att43246
# nInterval: 2 bins: [0.0, 0.1248625, 0.29957]
# Performing attribute: Att43264
# bins: [0.0, 0.31034]
# Performing attribute: Att43265
# nInterval: 2 bins: [0.0, 0.0679415, 0.223208]
# Performing attribute: Att43350
# bins: [0.0, 0.182986]
# Performing attribute: Att43372
# nInterval: 2 bins: [0.0, 0.086401, 0.172802]
# Performing attribute: Att43373
# bins: [0.0, 0.11291]
# Performing attribute: Att43497
# nInterval: 2 bins: [0.0, 0.01898, 0.52789]
# Performing attribute: Att43512
# nInterval: 2 bins: [0.0, 0.168633, 0.352643]
# Performing attribute: Att43514
# nInterval: 2 bins: [0.0, 0.129693, 0.26868200000000003]
# Performing attribute: Att43548
# nInterval: 2 bins: [0.0, 0.128686, 0.318316]
# Performing attribute: Att43571
# bins: [0.0, 0.174335]
# Performing attribute: Att43586
# bins: [0.0, 0.243329]
# Performing attribute: Att43625
# nInterval: 2 bins: [0.0, 0.0191865, 0.257123]
# Performing attribute: Att43633
# nInterval: 2 bins: [0.0, 0.157461, 0.452316]
# Performing attribute: Att43635
# bins: [0.0, 0.51342]
# Performing attribute: Att43656
# nInterval: 2 bins: [0.0, 0.088398, 0.176796]
# Performing attribute: Att43679
# bins: [0.0, 0.144607]
# Performing attribute: Att43688
# bins: [0.0, 0.178449]
# Performing attribute: Att43692
# nInterval: 2 bins: [0.0, 0.2200335, 0.440067]
# Performing attribute: Att43789
# bins: [0.0, 0.140903]
# Performing attribute: Att43880
# nInterval: 2 bins: [0.0, 0.0567525, 0.142242]
# Performing attribute: Att43884
# nInterval: 2 bins: [0.0, 0.1004915, 0.200983]
# Performing attribute: Att43885
# nInterval: 2 bins: [0.0, 0.0655635, 0.184915]
# Performing attribute: Att43901
# bins: [0.0, 0.7093149999999999]
# Performing attribute: Att43910
# nInterval: 2 bins: [0.0, 0.0556255, 0.229429]
# Performing attribute: Att43947
# nInterval: 2 bins: [0.0, 0.075946, 0.320387]
# Performing attribute: Att44023
# nInterval: 2 bins: [0.0, 0.0889045, 0.177809]
# Performing attribute: Att44032
# nInterval: 2 bins: [0.0, 0.062778, 0.423109]
# Performing attribute: Att44087
# nInterval: 2 bins: [0.0, 0.143458, 0.289239]
# Performing attribute: Att44139
# bins: [0.0, 0.605132]
# Performing attribute: Att44141
# nInterval: 2 bins: [0.0, 0.0566985, 0.378528]
# Performing attribute: Att44182
# nInterval: 2 bins: [0.0, 0.046978, 0.11948]
# Performing attribute: Att44184
# bins: [0.0, 0.187963]
# Performing attribute: Att44262
# bins: [0.0, 0.136542]
# Performing attribute: Att44271
# nInterval: 2 bins: [0.0, 0.127618, 0.255236]
# Performing attribute: Att44299
# nInterval: 2 bins: [0.0, 0.06447649999999999, 0.26300300000000004]
# Performing attribute: Att44325
# bins: [0.0, 0.192722]
# Performing attribute: Att44365
# nInterval: 2 bins: [0.0, 0.0476375, 0.259336]
# Performing attribute: Att44395
# nInterval: 2 bins: [0.0, 0.2043075, 0.408615]
# Performing attribute: Att44516
# nInterval: 2 bins: [0.0, 0.1490415, 0.50983]
# Performing attribute: Att44571
# nInterval: 2 bins: [0.0, 0.070484, 0.15566]
# Performing attribute: Att44683
# nInterval: 2 bins: [0.0, 0.0557325, 0.233513]
# Performing attribute: Att44697
# bins: [0.0, 0.155974]
# Performing attribute: Att44707
# bins: [0.0, 0.269233]
# Performing attribute: Att44711
# bins: [0.0, 0.382417]
# Performing attribute: Att44730
# bins: [0.0, 0.153288]
# Performing attribute: Att44758
# nInterval: 2 bins: [0.0, 0.076521, 0.153042]
# Performing attribute: Att44842
# bins: [0.0, 0.221264]
# Performing attribute: Att44919
# nInterval: 2 bins: [0.0, 0.1043185, 0.332772]
# Performing attribute: Att44933
# nInterval: 2 bins: [0.0, 0.131249, 0.303856]
# Performing attribute: Att44976
# bins: [0.0, 0.379488]
# Performing attribute: Att44992
# nInterval: 2 bins: [0.0, 0.0223255, 0.223013]
# Performing attribute: Att45040
# bins: [0.0, 0.490283]
# Performing attribute: Att45048
# bins: [0.0, 0.138897]
# Performing attribute: Att45058
# bins: [0.0, 0.328043]
# Performing attribute: Att45162
# nInterval: 2 bins: [0.0, 0.148029, 0.296058]
# Performing attribute: Att45166
# nInterval: 2 bins: [0.0, 0.049289, 0.390236]
# Performing attribute: Att45179
# nInterval: 2 bins: [0.0, 0.030327, 0.273136]
# Performing attribute: Att45196
# bins: [0.0, 0.086001]
# Performing attribute: Att45199
# nInterval: 2 bins: [0.0, 0.0731135, 0.541792]
# Performing attribute: Att45256
# nInterval: 2 bins: [0.0, 0.0500775, 0.24187600000000006]
# Performing attribute: Att45260
# nInterval: 2 bins: [0.0, 0.054604, 0.33926300000000004]
# Performing attribute: Att45327
# nInterval: 2 bins: [0.0, 0.05441, 0.266903]
# Performing attribute: Att45328
# nInterval: 2 bins: [0.0, 0.0681745, 0.246056]
# Performing attribute: Att45335
# nInterval: 2 bins: [0.0, 0.038850499999999996, 0.185889]
# Performing attribute: Att45339
# nInterval: 2 bins: [0.0, 0.1465685, 0.293137]
# Performing attribute: Att45470
# nInterval: 2 bins: [0.0, 0.046068, 0.4813520000000001]
# Performing attribute: Att45474
# nInterval: 2 bins: [0.0, 0.033607, 0.25558600000000004]
# Performing attribute: Att45479
# nInterval: 2 bins: [0.0, 0.049397, 0.41779]
# Performing attribute: Att45481
# bins: [0.0, 0.17694300000000002]
# Performing attribute: Att45486
# nInterval: 2 bins: [0.0, 0.0364175, 0.284465]
# Performing attribute: Att45556
# nInterval: 2 bins: [0.0, 0.0477915, 0.40772]
# Performing attribute: Att45628
# bins: [0.0, 0.392352]
# Performing attribute: Att45680
# bins: [0.0, 0.116668]
# Performing attribute: Att45691
# nInterval: 2 bins: [0.0, 0.0306495, 0.380618]
# Performing attribute: Att45719
# bins: [0.0, 0.342558]
# Performing attribute: Att45766
# nInterval: 2 bins: [0.0, 0.0693735, 0.385062]
# Performing attribute: Att45806
# nInterval: 2 bins: [0.0, 0.07370650000000001, 0.222876]
# Performing attribute: Att45860
# nInterval: 2 bins: [0.0, 0.0986955, 0.197391]
# Performing attribute: Att45886
# nInterval: 2 bins: [0.0, 0.13241050000000001, 0.26482100000000003]
# Performing attribute: Att45894
# nInterval: 2 bins: [0.0, 0.090785, 0.18157]
# Performing attribute: Att45915
# nInterval: 2 bins: [0.0, 0.054853, 0.35538400000000003]
# Performing attribute: Att45988
# bins: [0.0, 0.220668]
# Performing attribute: Att46040
# bins: [0.0, 0.402749]
# Performing attribute: Att46048
# bins: [0.0, 0.303563]
# Performing attribute: Att46074
# bins: [0.0, 0.404939]
# Performing attribute: Att46098
# bins: [0.0, 0.121096]
# Performing attribute: Att46103
# bins: [0.0, 0.12543900000000002]
# Performing attribute: Att46179
# bins: [0.0, 0.132722]
# Performing attribute: Att46191
# nInterval: 2 bins: [0.0, 0.0655325, 0.618123]
# Performing attribute: Att46207
# nInterval: 2 bins: [0.0, 0.0341515, 0.283822]
# Performing attribute: Att46213
# bins: [0.0, 0.422048]
# Performing attribute: Att46228
# nInterval: 2 bins: [0.0, 0.0680055, 0.154522]
# Performing attribute: Att46263
# nInterval: 2 bins: [0.0, 0.195471, 0.500276]
# Performing attribute: Att46277
# nInterval: 2 bins: [0.0, 0.051406500000000015, 0.337498]
# Performing attribute: Att46312
# bins: [0.0, 0.144817]
# Performing attribute: Att46448
# nInterval: 2 bins: [0.0, 0.083125, 0.6284569999999999]
# Performing attribute: Att46473
# bins: [0.0, 0.351934]
# Performing attribute: Att46490
# nInterval: 2 bins: [0.0, 0.221785, 0.528814]
# Performing attribute: Att46515
# bins: [0.0, 0.17971199999999998]
# Performing attribute: Att46571
# nInterval: 2 bins: [0.0, 0.07783150000000001, 0.5353060000000001]
# Performing attribute: Att46614
# nInterval: 2 bins: [0.0, 0.0837065, 0.29640500000000003]
# Performing attribute: Att46637
# nInterval: 2 bins: [0.0, 0.0367995, 0.174932]
# Performing attribute: Att46649
# bins: [0.0, 0.132157]
# Performing attribute: Att46664
# bins: [0.0, 0.153288]
# Performing attribute: Att46678
# nInterval: 2 bins: [0.0, 0.09146, 0.189415]
# Performing attribute: Att46686
# bins: [0.0, 0.127995]
# Performing attribute: Att46698
# bins: [0.0, 0.267848]
# Performing attribute: Att46733
# nInterval: 2 bins: [0.0, 0.1493285, 0.498253]
# Performing attribute: Att46753
# nInterval: 2 bins: [0.0, 0.180834, 0.425993]
# Performing attribute: Att46816
# nInterval: 2 bins: [0.0, 0.0803415, 0.160683]
# Performing attribute: Att46849
# bins: [0.0, 0.442896]
# Performing attribute: Att46894
# nInterval: 2 bins: [0.0, 0.0803415, 0.160683]
# Performing attribute: Att46929
# nInterval: 2 bins: [0.0, 0.045523, 0.237045]
# Performing attribute: Att46956
# nInterval: 2 bins: [0.0, 0.0723035, 0.144607]
# Performing attribute: Att46973
# nInterval: 2 bins: [0.0, 0.090796, 0.520472]
# Performing attribute: Att46978
# nInterval: 2 bins: [0.0, 0.204197, 0.408394]
# Performing attribute: Att46992
# bins: [0.0, 0.183213]
# Performing attribute: Att47037
# nInterval: 2 bins: [0.0, 0.070591, 0.290551]
# Performing attribute: Att47088
# nInterval: 2 bins: [0.0, 0.2110035, 0.422007]
# Performing attribute: Att47199
# bins: [0.0, 0.28675900000000004]
# Performing attribute: Att47223
# bins: [0.0, 0.212768]
# Performing attribute: Att47225
# nInterval: 2 bins: [0.0, 0.5, 1.0]
# Performing attribute: Att47226
# bins: [0.0, 1.0]
# Performing attribute: Att47227
# nInterval: 2 bins: [0.0, 0.5, 1.0]
# Performing attribute: Att47228
# bins: [0.0, 1.0]
# Performing attribute: Att47229
# nInterval: 2 bins: [0.0, 0.5, 1.0]
# Performing attribute: Att47230
# nInterval: 2 bins: [0.0, 0.5, 1.0]
# Performing attribute: Att47231
# nInterval: 2 bins: [0.0, 0.5, 1.0]
# Performing attribute: Att47232
# nInterval: 2 bins: [0.0, 0.5, 1.0]
# Performing attribute: Att47233
# bins: [0.0, 1.0]
# Performing attribute: Att47234
# nInterval: 2 bins: [0.0, 0.5, 1.0]
# Performing attribute: Att47235
# nInterval: 2 bins: [0.0, 0.5, 1.0]

# %%
def perform_LAIM(data, label):
    
    data_dis = pd.DataFrame()
    for i in range(data.shape[1]):
        index = random.sample(range(data.shape[0]), 2000)
        attr_long = data.iloc[:,i]
        attr = data.iloc[index,i].reset_index(drop=True)
        # step 1: intialization
        #attr = data.iloc[:,i]
        print("Performing attribute:",attr.name)
        max_value = attr.max()
        min_value = attr.min()
        sort_attr = attr.sort_values(ascending=True)
        
        # form B, the set of candidate interval boundaries, 
        # with min, max and 
        # all the mid points of all the adjacent pairs
        B = set()
        for i in range(len(sort_attr)):
            if i == 0:
                B.add(sort_attr[i])
                B.add((sort_attr[i] + sort_attr[i+1])/2)
            elif i == len(sort_attr)-1:
                B.add(sort_attr[i])
                break
            else:
                B.add((sort_attr[i] + sort_attr[i+1])/2) 
        len_b = len(B)
        
        D_i = [min_value, max_value] # initial interval
        globalLAIM = 0
        
        if len(B) == 2:
            feature_data = pd.cut(list(attr_long), bins = [min_value, max_value/2,max_value], include_lowest=True).codes
            data_dis = pd.concat([data_dis, pd.Series(feature_data)],axis=1)
        
        else:
            # step 2: Discretization
            nIntervals = 1
            while True:
                midpoint_LAIM = []
                for b_j in B:

                    D = list(D_i)
                    # Add a midpoint, b_j, into C which is not still in D_i
                    if b_j not in D:
                        D.append(b_j)
                        D.sort()
                        # calculate LAIM value
                        LAIM = calculate_LAIM(D, attr, label)
                        midpoint_LAIM.append((b_j, LAIM))       
                # Accept the midpoint, bj, with highest value of LAIM
                midpoint_max = max(midpoint_LAIM, key=lambda x: x[1])

                if midpoint_max[1] > globalLAIM:
                    D_i.append(midpoint_max[0])
                    D_i.sort()
                    B.remove(midpoint_max[0])
                    globalLAIM = midpoint_max[1]

                else:
                    feature_data = pd.cut(list(attr_long), bins = D_i, include_lowest=True).codes
                    data_dis = pd.concat([data_dis, pd.Series(feature_data)],axis=1)
                    print("nInterval:",nIntervals)
                    break

                nIntervals += 1
                if len(D_i) == len_b:
                    feature_data = pd.cut(list(attr_long), bins = D_i, include_lowest=True).codes
                    data_dis = pd.concat([data_dis, pd.Series(feature_data)],axis=1)
                    print("nInterval:",nIntervals)
                    break
    
    
    data_dis.columns = data.columns
    
    return data_dis

def read_data(dataPath):
    # input: '/Volumes/Samsung_T5/research/data/ABC_news_data/obesity/'
    # read data
    data = pd.read_csv(os.path.join(dataPath,'X.csv'))
    label = pd.read_csv(os.path.join(dataPath,'y.csv'))
    return data,label

filePath = '/Volumes/Samsung_T5/research/data/large_datasets/'
for dataset in ["mediamill"]:
    print(filePath+dataset)
    X, y = read_data(filePath+dataset)
    X_dis = perform_LAIM(X, y)
    # y.to_csv(os.path.join(filePath,dataset,'y.csv'), index=False)
    X_dis.to_csv(os.path.join(filePath,dataset,'X_dis_1500.csv'), index=False)
# Out:
# /Volumes/Samsung_T5/research/data/large_datasets/mediamill
# Performing attribute: Att1
# nInterval: 2
# Performing attribute: Att2
# nInterval: 2
# Performing attribute: Att3
# nInterval: 2
# Performing attribute: Att4
# nInterval: 2
# Performing attribute: Att5
# nInterval: 2
# Performing attribute: Att6
# nInterval: 2
# Performing attribute: Att7
# nInterval: 2
# Performing attribute: Att8
# nInterval: 2
# Performing attribute: Att9
# nInterval: 2
# Performing attribute: Att10
# nInterval: 2
# Performing attribute: Att11
# nInterval: 2
# Performing attribute: Att12
# nInterval: 2
# Performing attribute: Att13
# nInterval: 2
# Performing attribute: Att14
# nInterval: 2
# Performing attribute: Att15
# nInterval: 2
# Performing attribute: Att16
# nInterval: 2
# Performing attribute: Att17
# nInterval: 2
# Performing attribute: Att18
# nInterval: 2
# Performing attribute: Att19
# nInterval: 2
# Performing attribute: Att20
# nInterval: 2
# Performing attribute: Att21
# nInterval: 2
# Performing attribute: Att22
# nInterval: 2
# Performing attribute: Att23
# nInterval: 2
# Performing attribute: Att24
# nInterval: 2
# Performing attribute: Att25
# nInterval: 2
# Performing attribute: Att26
# nInterval: 2
# Performing attribute: Att27
# nInterval: 2
# Performing attribute: Att28
# nInterval: 2
# Performing attribute: Att29
# nInterval: 2
# Performing attribute: Att30
# nInterval: 2
# Performing attribute: Att31
# nInterval: 2
# Performing attribute: Att32
# nInterval: 2
# Performing attribute: Att33
# nInterval: 2
# Performing attribute: Att34
# nInterval: 2
# Performing attribute: Att35
# nInterval: 2
# Performing attribute: Att36
# nInterval: 2
# Performing attribute: Att37
# nInterval: 2
# Performing attribute: Att38
# nInterval: 2
# Performing attribute: Att39
# nInterval: 2
# Performing attribute: Att40
# nInterval: 2
# Performing attribute: Att41
# nInterval: 2
# Performing attribute: Att42
# nInterval: 2
# Performing attribute: Att43
# nInterval: 2
# Performing attribute: Att44
# nInterval: 2
# Performing attribute: Att45
# nInterval: 2
# Performing attribute: Att46
# nInterval: 2
# Performing attribute: Att47
# nInterval: 2
# Performing attribute: Att48
# nInterval: 2
# Performing attribute: Att49
# nInterval: 2
# Performing attribute: Att50
# nInterval: 2
# Performing attribute: Att51
# nInterval: 2
# Performing attribute: Att52
# nInterval: 2
# Performing attribute: Att53
# nInterval: 2
# Performing attribute: Att54
# nInterval: 2
# Performing attribute: Att55
# nInterval: 2
# Performing attribute: Att56
# nInterval: 2
# Performing attribute: Att57
# nInterval: 2
# Performing attribute: Att58
# nInterval: 2
# Performing attribute: Att59
# nInterval: 2
# Performing attribute: Att60
# nInterval: 2
# Performing attribute: Att61
# nInterval: 2
# Performing attribute: Att62
# nInterval: 2
# Performing attribute: Att63
# nInterval: 2
# Performing attribute: Att64
# nInterval: 2
# Performing attribute: Att65
# nInterval: 2
# Performing attribute: Att66
# nInterval: 2
# Performing attribute: Att67
# nInterval: 2
# Performing attribute: Att68
# nInterval: 2
# Performing attribute: Att69
# nInterval: 2
# Performing attribute: Att70
# nInterval: 2
# Performing attribute: Att71
# nInterval: 2
# Performing attribute: Att72
# nInterval: 2
# Performing attribute: Att73
# nInterval: 2
# Performing attribute: Att74
# nInterval: 2
# Performing attribute: Att75
# nInterval: 2
# Performing attribute: Att76
# nInterval: 2
# Performing attribute: Att77
# nInterval: 2
# Performing attribute: Att78
# nInterval: 2
# Performing attribute: Att79
# nInterval: 2
# Performing attribute: Att80
# nInterval: 2
# Performing attribute: Att81
# nInterval: 2
# Performing attribute: Att82
# nInterval: 2
# Performing attribute: Att83
# nInterval: 2
# Performing attribute: Att84
# nInterval: 2
# Performing attribute: Att85
# nInterval: 2
# Performing attribute: Att86
# nInterval: 2
# Performing attribute: Att87
# nInterval: 2
# Performing attribute: Att88
# nInterval: 2
# Performing attribute: Att89
# nInterval: 2
# Performing attribute: Att90
# nInterval: 2
# Performing attribute: Att91
# nInterval: 2
# Performing attribute: Att92
# nInterval: 2
# Performing attribute: Att93
# nInterval: 2
# Performing attribute: Att94
# nInterval: 2
# Performing attribute: Att95
# nInterval: 2
# Performing attribute: Att96
# nInterval: 2
# Performing attribute: Att97
# nInterval: 2
# Performing attribute: Att98
# nInterval: 2
# Performing attribute: Att99
# nInterval: 2
# Performing attribute: Att100
# nInterval: 2
# Performing attribute: Att101
# nInterval: 2
# Performing attribute: Att102
# nInterval: 2
# Performing attribute: Att103
# nInterval: 2
# Performing attribute: Att104
# nInterval: 2
# Performing attribute: Att105
# nInterval: 2
# Performing attribute: Att106
# nInterval: 2
# Performing attribute: Att107
# nInterval: 2
# Performing attribute: Att108
# nInterval: 2
# Performing attribute: Att109
# nInterval: 2
# Performing attribute: Att110
# nInterval: 2
# Performing attribute: Att111
# nInterval: 2
# Performing attribute: Att112
# nInterval: 2
# Performing attribute: Att113
# nInterval: 2
# Performing attribute: Att114
# nInterval: 2
# Performing attribute: Att115
# nInterval: 2
# Performing attribute: Att116
# nInterval: 2
# Performing attribute: Att117
# nInterval: 2
# Performing attribute: Att118
# nInterval: 2
# Performing attribute: Att119
# nInterval: 2
# Performing attribute: Att120
# nInterval: 2

# %%
X_dis.describe().loc["min",:].min()
# Out:
# 0.0
